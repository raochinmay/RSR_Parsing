# %%
import os
import codecs
from docx import *
import docx2txt
from PIL import Image
from wand.image import Image as IMG
import pytesseract
import textract

def get_string(name):
    img=Image.open(name)
    utf8_text = pytesseract.image_to_string(img)
    utf8_text = str(utf8_text.encode('ascii', 'ignore'))
    return utf8_text

data_dir = os.path.join('Resumes')
resume_count = 0
resume_text = "all_text1.txt"
if 1==0:
    with codecs.open(resume_text,'w',encoding='utf_8') as resume_txt:
        for filename in os.listdir(data_dir):
            print(filename)

            s = ""
            if filename.endswith(".docx"):
                location = str(os.path.join(data_dir,filename))
                #document = Document(location)
                #for paragraph in document.paragraphs:
                #    s += str(paragraph.text.encode(errors='ignore'))
                s = docx2txt.process(location)
                resume_txt.write(s+'\\n'+'\n')
                resume_count += 1


            elif filename.endswith(".pdf"):
                utf8_text = ""

                temp_doc = textract.process(os.path.join(data_dir,filename))
                if len(temp_doc) < 50:
                    img=IMG(filename=os.path.join(data_dir,filename),resolution=200)

                    img.save(filename=os.path.join(data_dir,'temp','temp.jpg'))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        utf8_text += get_string(os.path.join(data_dir,'temp',files))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        os.remove(os.path.join(data_dir,'temp',files))
                    temp_doc = utf8_text

                if type(temp_doc)==str:
                    resume_txt.write(temp_doc+'\\n'+'\n')    
                else:
                    resume_txt.write(temp_doc.decode("utf-8")+'\\n'+'\n')    
                resume_count +=1
                
print(resume_count)
# Out:
# 0

# %%
import spacy
import pandas as pd
import itertools as it

nlp = spacy.load('en')

# %%
with codecs.open(resume_text,encoding="utf_8") as f:
    sample_res = list(it.islice(f,8,9))[0]
    sample_res = sample_res.replace('\\n','\n')
print(sample_res)
# Out:
# • B.S. Physiology and Neurobiology

# %%
parsed_res_sample = nlp(sample_res)
print(parsed_res_sample)
# Out:
# • B.S. Physiology and Neurobiology

# %%
for num,entity in enumerate(parsed_res_sample):
    print("Entity",entity, '-',entity.ent_type_)
# Out:
# Entity • -
# Entity B.S. - PERSON
# Entity Physiology - PERSON
# Entity and -
# Entity Neurobiology -
# Entity
#  -

# %%
token_text = [token.orth_ for token in parsed_res_sample]
token_lemma = [token.lemma_ for token in parsed_res_sample]
token_shape = [token.shape_ for token in parsed_res_sample]
d = list(zip(token_text,token_lemma,token_shape))
pd.DataFrame(data =d,\
            columns=['token_text','token_lemma','token_shape'])
# Out:
#      token_text   token_lemma token_shape
# 0             •             •           •
# 1          B.S.          b.s.        X.X.
# 2    Physiology    physiology       Xxxxx
# 3           and           and         xxx
# 4  Neurobiology  neurobiology       Xxxxx
# 5            \n            \n          \n

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'

# %%
with codecs.open(unigram_filepath,'w',encoding='utf_8') as f:
    for sent in lemmatized_sentence_corpus(resume_text):
        f.write(sent+'\n')

# %%
normal_res = LineSentence(unigram_filepath)
bigram_sentence = ''
normal_res2 = Phrases(normal_res)
with codecs.open('bigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in normal_res:        
        bigram_sentence =  ' '.join(normal_res2[unigram_sentence])
        f.write(bigram_sentence+'\n')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
bigram_sentences = LineSentence('bigram.txt')

trigram_model = Phrases(bigram_sentences)
with codecs.open('trigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in bigram_sentences:        
        trigram_sentence =  ' '.join(trigram_model[unigram_sentence])
        f.write(trigram_sentence+'\n')
        
normal_res1 = LineSentence('trigram.txt')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"

# %%
if 1==0:
    res2vec = Word2Vec(normal_res,size=300,window=10,sg=1,workers=4,min_count=5)
    res2vec.save(word2vec_file)

    for i in range(1,15):
        res2vec.train(normal_res,total_examples=res2vec.corpus_count, epochs=res2vec.iter)
        res2vec.save(word2vec_file)
    
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                  0         1         2         3         4         5    \
# bfs         0.199705  0.236040  0.087032 -0.120283 -0.202355  0.077573
# sergeant   -0.376579  0.046125  0.120472 -0.016471 -0.233181  0.468469
# andrew      0.136811 -0.410337  0.099616  0.362227  0.078763 -0.555602
# incom      -0.138928 -0.810906 -0.165721  0.100483 -0.546616 -0.776490
# richardson  0.522056 -0.347972  0.197279  0.328059 -0.007861 -0.374945
#
#                  6         7         8         9      ...          290  \
# bfs        -0.458942  0.398559 -0.349454  0.339126    ...     0.015466
# sergeant   -0.048060  0.297085  0.419722 -0.351362    ...    -0.079581
# andrew      0.248132  0.515120  0.017973  0.393843    ...     0.346942
# incom       0.264013  0.165032 -0.101544 -0.382344    ...    -0.367798
# richardson  0.111577  0.196579  0.210712  0.096179    ...     0.154020
#
#                  291       292       293       294       295       296  \
# bfs        -0.229241 -0.126183  0.116820 -0.415612  0.033632 -0.282790
# sergeant    0.249527  0.095804  0.446600  0.123818  0.188248  0.018465
# andrew     -0.034701  0.304935  0.038600 -0.241795  0.201187  0.471659
# incom       0.369771  0.220006 -0.306855 -0.227855  0.155067 -0.301282
# richardson -0.041055  0.758517 -0.114372 -0.026017  0.250099  0.314334
#
#                  297       298       299
# bfs        -0.537478 -0.035635 -0.386489
# sergeant   -0.238874 -0.299504 -0.097548
# andrew      0.037708  0.251568  0.097207
# incom       0.100396  0.400063 -0.183878
# richardson -0.281763  0.039054  0.492292
#
# [5 rows x 300 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.27344552834871527

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# 3-sectored : 0.429
# verilog : 0.423
# bash : 0.402
# perl : 0.394
# html5 : 0.374
# palisade : 0.373
# ocaml : 0.373
# precisiontree : 0.368
# wlst : 0.365
# languag : 0.365

# %%
get_related_terms('java')
# Out:
# j2me : 0.514
# j2se : 0.437
# jsp : 0.43
# j2ee : 0.427
# swings : 0.425
# taglibs : 0.425
# applets : 0.423
# rmi : 0.415
# 1.4 : 0.412
# mdb : 0.404

# %%
from sklearn.manifold import TSNE
import _pickle as pickle

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                  0         1         2         3         4         5    \
# bfs         0.199705  0.236040  0.087032 -0.120283 -0.202355  0.077573
# sergeant   -0.376579  0.046125  0.120472 -0.016471 -0.233181  0.468469
# andrew      0.136811 -0.410337  0.099616  0.362227  0.078763 -0.555602
# incom      -0.138928 -0.810906 -0.165721  0.100483 -0.546616 -0.776490
# richardson  0.522056 -0.347972  0.197279  0.328059 -0.007861 -0.374945
#
#                  6         7         8         9      ...          290  \
# bfs        -0.458942  0.398559 -0.349454  0.339126    ...     0.015466
# sergeant   -0.048060  0.297085  0.419722 -0.351362    ...    -0.079581
# andrew      0.248132  0.515120  0.017973  0.393843    ...     0.346942
# incom       0.264013  0.165032 -0.101544 -0.382344    ...    -0.367798
# richardson  0.111577  0.196579  0.210712  0.096179    ...     0.154020
#
#                  291       292       293       294       295       296  \
# bfs        -0.229241 -0.126183  0.116820 -0.415612  0.033632 -0.282790
# sergeant    0.249527  0.095804  0.446600  0.123818  0.188248  0.018465
# andrew     -0.034701  0.304935  0.038600 -0.241795  0.201187  0.471659
# incom       0.369771  0.220006 -0.306855 -0.227855  0.155067 -0.301282
# richardson -0.041055  0.758517 -0.114372 -0.026017  0.250099  0.314334
#
#                  297       298       299
# bfs        -0.537478 -0.035635 -0.386489
# sergeant   -0.238874 -0.299504 -0.097548
# andrew      0.037708  0.251568  0.097207
# incom       0.100396  0.400063 -0.183878
# richardson -0.281763  0.039054  0.492292
#
# [5 rows x 300 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'

# %%
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])

# %%
tnse_vectors['word'] = tnse_vectors.index
print(tnse_vectors.head())
print(tnse_vectors[tnse_vectors['word']=='python'])
# Out:
#                    x          y        word
# bfs         9.670788   4.680027         bfs
# sergeant    9.083476  -6.809185    sergeant
# andrew      3.388728 -15.946638      andrew
# incom       3.156824 -15.541657       incom
# richardson  7.832393  -1.435206  richardson
#                x          y    word
# python  5.232392 -13.643827  python

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5505eb8a-51d8-4c5d-a920-67dc7c36638c">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(tnse_vectors)
# create the plot and configure the
# title, dimensions, and tools
tsne_plot = figure(title=u't-SNE Word Embeddings',
                   plot_width = 800,
                   plot_height = 800,
                   tools= (u'pan, wheel_zoom, box_zoom,'
                           u'box_select, resize, reset'),
                   active_scroll=u'wheel_zoom')

# add a hover tool to display words on roll-over
tsne_plot.add_tools( HoverTool(tooltips = u'@word') )

# draw the words as circles on the plot
tsne_plot.circle(u'x', u'y', source=plot_data,
                 color=u'blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color=u'black')

# configure visual elements of the plot
tsne_plot.title.text_font_size = value(u'16pt')
tsne_plot.xaxis.visible = True
tsne_plot.yaxis.visible = True
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None

# engage!
show(tsne_plot);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="20bc8788-014a-4a58-ac36-18b14d94419c"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("20bc8788-014a-4a58-ac36-18b14d94419c");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("20bc8788-014a-4a58-ac36-18b14d94419c");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '20bc8788-014a-4a58-ac36-18b14d94419c' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"da8b982b-5c13-4b5b-ba84-40d87a35fd0d":{"roots":{"references":[{"attributes":{"callback":null},"id":"9bc6f68a-62d8-48f6-afff-378acd539a4f","type":"DataRange1d"},{"attributes":{"formatter":{"id":"0817bb22-018c-434f-9cc8-5746d09eec96","type":"BasicTickFormatter"},"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"},"ticker":{"id":"d609e6c8-f460-4666-8d98-3998de4f45e6","type":"BasicTicker"}},"id":"81dfbcac-d119-4dd9-9724-c765c1011a6e","type":"LinearAxis"},{"attributes":{"fill_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"21973f79-9cb7-440e-aaf1-ea76e37b5cd1","type":"Circle"},{"attributes":{"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"}},"id":"10dab781-4b3f-4011-b6ae-e2300aebaaec","type":"WheelZoomTool"},{"attributes":{},"id":"fe5cf378-8275-4c70-a37e-89d631261206","type":"LinearScale"},{"attributes":{"below":[{"id":"482f641d-7f8d-4617-97e8-a300c0e303ca","type":"LinearAxis"}],"left":[{"id":"81dfbcac-d119-4dd9-9724-c765c1011a6e","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":800,"plot_width":800,"renderers":[{"id":"482f641d-7f8d-4617-97e8-a300c0e303ca","type":"LinearAxis"},{"id":"1913e7c7-3892-4ef1-8693-412e3195f1be","type":"Grid"},{"id":"81dfbcac-d119-4dd9-9724-c765c1011a6e","type":"LinearAxis"},{"id":"058c9f10-49e0-461a-9875-e700492e58f0","type":"Grid"},{"id":"6dd77279-5998-4d7f-8b64-8737e4847879","type":"BoxAnnotation"},{"id":"ed624af0-6e15-46ef-90f8-5904fdbaa842","type":"BoxAnnotation"},{"id":"8fb21289-c78e-4ab7-8f5f-ccafa15bea1d","type":"GlyphRenderer"}],"title":{"id":"46681ed7-1827-4ef5-a308-a6ea4450536e","type":"Title"},"tool_events":{"id":"760546ec-01a0-436b-9069-739c6e9691cf","type":"ToolEvents"},"toolbar":{"id":"33576eae-cdb2-4cf9-8c65-388c2c9fca93","type":"Toolbar"},"x_range":{"id":"8df81545-cb82-4034-a332-7f791c6aa5f9","type":"DataRange1d"},"x_scale":{"id":"fe5cf378-8275-4c70-a37e-89d631261206","type":"LinearScale"},"y_range":{"id":"9bc6f68a-62d8-48f6-afff-378acd539a4f","type":"DataRange1d"},"y_scale":{"id":"f0e0342c-4b4f-4f30-a361-1d6faed6e366","type":"LinearScale"}},"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"}},"id":"769586c6-91ac-4e5d-9d71-fe7c4d617558","type":"ResizeTool"},{"attributes":{"callback":null,"overlay":{"id":"ed624af0-6e15-46ef-90f8-5904fdbaa842","type":"BoxAnnotation"},"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"},"renderers":[{"id":"8fb21289-c78e-4ab7-8f5f-ccafa15bea1d","type":"GlyphRenderer"}]},"id":"11c0a574-ae39-4349-9402-8cb0bfe82ca3","type":"BoxSelectTool"},{"attributes":{},"id":"760546ec-01a0-436b-9069-739c6e9691cf","type":"ToolEvents"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"},"ticker":{"id":"d609e6c8-f460-4666-8d98-3998de4f45e6","type":"BasicTicker"}},"id":"058c9f10-49e0-461a-9875-e700492e58f0","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"ed624af0-6e15-46ef-90f8-5904fdbaa842","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"blue"},"line_alpha":{"value":0.2},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"f6b50303-d44d-417d-87f6-886b8f3b5ee8","type":"Circle"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"fbad2807-7a20-482d-a26c-fb7105815b24","subtype":"Figure","type":"Plot"},"ticker":{"id":"84c052c0-c074-487a-ab42-efe665943683","type" ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

l=linkage(res2vec.wv.syn0[0:50],method='complete',metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
l,leaf_rotation=0,leaf_font_size=16,orientation='left',leaf_label_func=lambda v:str(res2vec.wv.index2word[v]))
plt.show()

# %%
from sklearn.cluster import KMeans


word_vector = res2vec.wv.syn0
print(int(word_vector.shape[0]/50))
num_clusters = int(word_vector.shape[0]/50)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vector )
# Out:
# 111

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['wireless']
#
# Cluster: 1
# ['vlsi', 'drupal', 'zero', 'reliability', 'gps', 'pcb', 'classmate', 'techniques', 'filter', 'density', '95%', 'attack', 'continuously', 'navigation', 'detection', 'toolbox', 'autonomous', 'parametric', 'iot', 'image', 'circuit', 'structures', 'keil', 'based', 'hovercraft', 'programmed', 'color', 'microcontroller', 'detect', 'traffic', 'mount', 'stitching', 'translation', 'scientist', 'kalman', 'filtering', 'packet', 'thing', 'intrusion', 'bitbyte', 'sensor', 'temperature', 'mechanism', 'smart', 'proteus', 'compensate', 'pulse', 'algorithms', 'ride', 'familiar', 'static', 'ids', 'urban']
#
# Cluster: 2
# ['\uf09f', 'linkedin', 'rockville', 'college-', 'tulane', '224', 'baltimore', 'aflac', '410', 'hyattsville', 'ellicott', '240', 'tel', '=', '550', 'terrace', '318', '301', 'potomac', 'road', 'md', '1276', 'apt', 'island', '1', '|', 'jane', 'arundel', '■', '305', '4324', '48th', '825', '9530', '201', 'silver', '8125', '443', 'paradyme', '21', '360', '640', 'street', '20740', '101', '520', 'rd', '9111', 'bethesda', '20770', '\x97\uf097', '202', '20783', 'paul', 'knox', 'greenbelt', 'rowalt', 'ave', '♦', 'anne', 'park', '►', '3412', 'rhode', 'edmonston', 'avenue', '638']
#
# Cluster: 3
# ['surround', 'arm', 'propagation', 'antenna', 'poseidon', 'bsc', 'door', 'cdma', 'ofdm', 'wheel', 'suburb', 'shadow', 'kernel', '∙', 'pts', '5.7', 'behavior', 'preliminary', 'wimax', 'era', 'umts', 'downlink', 'processor', 'cellular', 'mentum', 'mock', 'wave', 'django', 'observation', 'gsm', 'nearby', 'signal', 'metro', 'coverage', 'pcs', 'detector', 'reuse', 'tilt', 'strength', 'channel', 'station', 'interference', 'stations', 'circuits', 'microwave', 'bluetooth', 'nara', 'ericsson', 'simulator', 'alarm', 'admission', 'path', 'sms', 'scheme', 'planet', '8051', 'lte', 'low', 'drop', '3-sectored', 'simulink', 'issn', 'fade', 'depict', 'simulate', 'd.c', 'arduino', 'simulation', 'rf', '\xad', 'wcdma', 'analog', 'partial', 'radio']
#
# Cluster: 4
# ['flavor', 'configuring', 'setting', 'plugins', 'distributed', 'topics', 'connection', 'integrations', 'configured', 'installation', 'manger', 'sources', 'shooting', 'console', 'appliance', 'cert', 'sp', 'generic', 'administration', 'installing', 'queues', 'server', 'agent', 'instances', 'synchronization', 'roles', 'url', 'weblogic', 'tar', 'environments', 'pools/', 'reverse', 'clusters', 'shared', 'dr', 'wls', 'configure', 'asm', 'jar', 'virtual', 'ear', 'connections', 'cluster', 'runtime', 'vertical', 'alone', 'repository', 'servers', 'command', 'unlock', 'tuxedo', 'clustering', 'aem', 'host', 'alias', 'guard', '10.3.5', 'depend', 'prod', 'managing', 'plug', 'sizing', 'managed', 'secured', 'domain', 'workload', 'integrating', '9.2/10', 'recycle', 'silent', 'dip', 'war', 'failover', 'rac', 'mode', 'stand', 'sign', 'proxy', 'shoot', 'wizard', 'cramer', 'admin', 'vob', 'mqserie', 'intel', 'wldf', 'clustered', 'installed', 'atom', 'startup', 'availability', 'deploy', 'setup', 'configuration', 'authenticator', 'foreign', 'vault', 'graphtalk', 'diagnostic', 'argument', 'deployed', 'apps', 'fault', 'permission', 'threads', 'instance', 'administered', 'assertion', 'ewm', 'monitoring', 'datapower', 'amdocs', 'instal', 'heterogeneous', 'exadata', 'throughput', 'eis', 'queue', 'destination', 'troubleshooting', 'oem', 'dev', 'realm', 'balanced', 'balancing', 'provision', 'varied', 'latency', 'nodes', 'enrol', 'catalog', 'cache', 'node', 'shutdown', 'xa', 'concurrent', 'components', 'factories', 'cryptography', 'administer', 'deploying', 'grid', 'horizontal', 'bridges', 'privilege', 'standalone', 'gate', 'datacenter', 'renewal', 'adaptors', 'single', 'pools', 'rpd', 'hosting', 'certificate', 'container', 'debugging', 'port', 'trouble', 'modules']
#
# Cluster: 5
# ['possess', 'interpersonal']
#
# Cluster: 6
# ['ufms', 'cfo', 'auditor', 'hhs', 'audit', 'unified']
#
# Cluster: 7
# ['2016-present']
#
# Cluster: 8
# ['workspace', 'saas', 'cloud', 'ec2', 'elastic', 's3', 'formation', 'rds', 'iam', 'vpc', 'watch', 'aws', 'sqs', 'ebs', 'scaling', 'route', '53', 'amazon', 'dynamodb']
#
# Cluster: 9
# ['richardson', 'bss', 'az', '09/2013', 'associates', 'verizon', 'oxford', 'mo', 'spectrum', 'siemens', 'mexico', 'wells', 'principal', 'hi', 'warner', 'fl', 'pacific', 'chennai', '08', 'western', 'co.', 'ca', 'chase', 'lockheed', 'boeing', 'designation', 'saba', 'impetus', 'hcl', 'now', 'ma', 'corp.', 'hewlett', '10/2013', 'hotels', 'csc', 'saudi', 'northrop', 'pa', 'alabama', '1988', 'va', 'philadelphia', 'fujitsu', 'teksystems', '05/2015', 'reuters', 'formerly', 'los', 'packard', 'america', 'taiwan', 'bradley', 'bowes', 'headquarter', 'noida', 'gallagher', 'ltd.', 'mclean', 'taipei', 'richmond', 'infosys', 'abb', 'sacramento', 'kansas', 'jpmorgan', '4th', '04/2015', 'clara', 'diego', 'florida', 'arc', '04/2005', 'hartford', 'holdings', '11/13', '05', 'miami', 'acs', 'lucent', 'alexandria', '\u200b', 'perot', '’12', 'hsbc', 'madison', 'at&t', 'alexander', 'consultants', '10/2014', '10/16', 'grumman', 'cox', 'sra', 'thomas', 'fitch', 'nextel', 'pittsburgh', 'portnov', 'mutual', 'west', 'corporation', 'austin', 'electric', 'wisconsin', '1c', 'stamford', 'bay', 'odessa', 'uk', 'bayer', 'allen', '08/2015', 'bharat', 'investments', '1998', 'llc', 'technologies', 'analyst-', 'san', 'beijing', 'huntsville', 'tester', 'wipro', 'emerson', 'q', 'orlando', 'bell', 'motors', 'il', 'inc.', 'tx', 'nokia', 'phoenix', 'contractor-', 'hill', 'gurgaon', 'laboratories', 'valley', 'arlington', '1994', 'venture', 'houston', 'silicon', 'addison', 'us', 'eagle', 'falls', '1999', 'angeles', 'york', 'thomson', 'oil', 'zurich', 'greenville', 'springfield', 'hanoi', 'beach', 'mary', 'irving', '10/2007', 'nc', 'texas', 'sunnyvale', 'atlanta', 'mcgraw', 'mountain', 'missouri', 'vp', 'bangalore', 'companies', '’13', 'unisys', '1996', 'tampa', 'herndon', 'industries', 'pitney', 'hamilton', 'labs', 'connecture', 'martin', 'birlasoft', 'satyam', 'boston', 'ltd', 'booz', 'milwaukee', 'ups', 'canvasser', 'virginia', 'jose', 'pvt', 'solutions', 'wm', 'plc', 'comcast', 'england', 'ohio', 'dac', 'denmark', '1986', 'green', 'plano', '03/2012', 'dallas', 'newport', 'mahindra', 'trainee', 'ny', 'santa', '03', 'francisco', 'premium', 'columbus', 'marathon', 'century', 'abercrombie', 'kelly', 'irvine', 'wi', 'jr', 'reston', 'corp', 'hills', 'abbott', '1997', 'oh', 'brown', 'hewitt', 'disney', '1993', 'fargo', 'ct', 'programmer', 'automotive', 'altos', 'creek', 'nj', 'ia', 'chantilly', 'johnson', 'massachusetts', 'india', 'chicago']
#
# Cluster: 10
# ['potential', 'investigate', 'mitigate', 'eliminate', 'finding', 'identify', 'root', 'bottleneck', 'cause']
#
# Cluster: 11
# ['introscope', 'sitescope', 'wily']
#
# Cluster: 12
# ['art', 'rome', 'rotary', 'arcelormittal', 'represent', 'phi', 'sponsorship', 'ambassador', 'fest', 'inter', 'trip', 'founding', 'institute', 'factgem', 'prize', '99', 'vesit', '34', 'students', 'council', 'gold', 'win', 'rodrigues', 'won', 'cricket', 'competition', 'chairman', 'bombay', '09/2014', 'league', 'pi', 'comprising', 'csi', 'men', 'president', 'fall', '2nd', 'sigma', 'events', 'tournament', 'memorial', 'intramural', 'committee', 'praxis', 'peace', 'tsan', 'deans', 'head', 'collegiate', 'mumbai', 'indian', 'admissions', 'college', 'nu', 'debate', 'kjsce', 'delta', 'technology-', 'honor', 'finalist', 'year-', 'iete', 'alpha', 'semester', 'soccer', 'festival', 'primannum', 'medal', 'club', 'naamba', 'ascend', 'basketball', 'cultural', 'sports', 'omega', 'founder', 'smsa', 'treasurer', 'society', 'workshop', 'sustainability', 'surat', 'scout', 'kappa', 'tennis', 'varsity', 'umd', 'hall', 'association', 'james', 'scholarship', 'father', 'music', 'ieee', 'alumni', 'maharashtra', 'undergraduate', 'homecoming', 'manipal', 'secretary', 'sorority', 'fraternity', 'fr', 'women', 'scholars', '2013-present', 'cummins', 'football', 'vice', 'chapter']
#
# Cluster: 13
# ['bloomberg']
#
# Cluster: 14
# ['odbc', 'javabeans', 'spr', 'rest', 'hibernate', 'jta', 'gemfire', 'stub', 'tiles', 'persistence', 'uddi', 'se', 'jstl', 'jms', 'j2se', 'libraries', 'jdbc', 'applets', 'javascript', 'validator', 'xi', 'jsps', 'mdb', 'xsd', 'xsl', 'ui', 'dom', '1.3', 'wsdl', 'quartz', 'jaxb', '8i', 'html5', 'faces', 'boingo', 'awt', 'singleton', 'asynchronous', 'velocity', 'ws', 'swings', 'bcbs', 'js', 'ee', 'dojo', 'di', 'frameworks', 'jmock', 'year(s', 'ext', 'jaas', 'multithreading', 'ejbs', 'ajax', '2.0', 'asp', 'struts', 'webservices', '2000/', 'servlet', 'mongo', 'jaxp', 'html', '1.1', 'restful', 'jee', 'binding', '3.2', 'plane', 'messaging', 'json', 'framework', 'embedded', 'jquery', 'gwt', 'extjs', 'css', 'portlets', 'jndi', 'spring', 'sax', 'junit', 'jasper', 'incidence', 'jersey', 'jsf', 'angular', 'ejb', 'java', 'orm', 'j2ee', 'api', 'cascading', 'markup', '3.0', 'jpa', 'jbuilder', '1.4', 'dhtml', 'mvc', 'xml', 'wcf', 'swing', 'mule', 'j', 'bound', 'aop', 'consume', '1.5', 'xquery', 'flex', 'wsad', 'bean', 'cxf', 'wireframe', 'icefaces', 'jdk1.6', 'axis', 'activemq', 'reusable', 'ioc', 'rmi', 'embed', 'groovy', 'webservice', 'dao', 'patterns', 'jax', '3.1', 'jsp', 'rs', 'angularjs', 'message', 'xhtml', 'annotation', 'soap', '1.6', 'beans', 'j2me', 'drools', 'jakarta', 'refactor', 'xslt', '5.0', 'jmx', 'strut', 'servlets', 'ilog', '2.5', 'css3', 'taglibs', 'cgi', 'tag', '1.2', 'ibatis']
#
# Cluster: 15
# ['pressure', 'recreational', 'exercise', 'kid', 'enjoy', 'keen']
#
# Cluster: 16
# ['pool', 'ph', 'treat', 'customers’', 'chemical', 'algae', 'suggest', 'diagnose', 'advised', 'water']
#
# Cluster: 17
# ['curtail', '700', 'bounce', 'revamp', 'intervention', '75%', 'reduce', 'improved', 'thus', '80%', '12%', '15%', 'reduced', 'delay', 'redundancy', 'unnecessary', '40%', '25%', 'stability', 'thereby', '60%', 'downtime', 'improve', 'loyalty', 'efficiency', 'productivity', 'initiation', 'avoid', '20%', 'spending', '30%', 'decrease', '50%', 'restructure', '10%', 'streamline', 'minimize', 'save', 'increase', 'tactic', 'rate', 'cut', 'percent', 'reduction']
#
# Cluster: 18
# ['ita']
#
# Cluster: 19
# ['ordering', 'gift', 'pos', 'chip', 'cards', 'merchandise', 'stripe', 'split', 'bed', 'receipt', 'shopping', 'damage', 'scanner', 'either', 'signature', 'mainly', 'card', 'do', 'correctly', 'emv', 'credit', 'checkout', 'reward', 'reader', 'compatible', 'register', 'jp', 'must', 'verifone', 'magnetic', 'weight', 'fee', 'transaction', 'wallet', 'me', 'kind', 'meter', 'wms', 'clearing', 'floor', 'ecs', 'controller', 'walmart', 'consider', 'amount', 'bulk', 'encore', 'injection', 'seller', 'insert', 'controllers', 'equipment', 'here', 'motor', 'voltage', 'refund', 'bag', 'purchase', 'handheld', 'cat', 'ingenico', 'flag', 'machines', 'activation', 'due', 'visa', 'tea', 'less', 'limit', 'difference', 'drm', 'debit', 'item', 'ncr', 'payment', 'dealer', 'touch']
#
# Cluster: 20
# ['fannie', 'mae', '1983', 'today', '8,000', 'downtown', 'say', '22', 'hour', 'trp']
#
# Cluster: 21
# ['audience', 'tone', 'nature', 'sentiment', 'appropriate', 'style', 'grade']
#
# Cluster: 22
# ['gsa', 'korea', 'overseas', 'd.c.', 'wellness', 'secondary', 'solar', 'st.', 'army', 'health', 'normal', 'american', 'carolina', 'medicaid', 'nasa', 'fairfax', 'brevard', 'academy', 'economy', 'navy', 'washington', 'nations', 'hong', 'walter', 'cnsi', '513', 'utah', 'cincinnati', 'interior', '11/2013', 'jumpstart', 'wa', '1990', 'researcher', 'agriculture', 'u.s', 'citizenship', 'cristiano', 'airlines', 'stanley', 'aviation', 'patrick', 'ridge', 'orleans', 'kong', 'isa', 'cerner', 'union', 'public', '2014-present', 'military', 'delaware', 'parking', 'l.', 'u.s.', 'georgia', 'john', 'maxim', 'lake', 'citizen', 'orange', 'organizations', 'devry', 'southern', 'winston', 'county', 'meadows', 'las', 'california', 'raleigh', 'worth', 'courts', 'nec', 'joseph', 'usa', 'pediatric', 'hospitals', 'asian', 'doe', 'ks', 'occupational', 'montgomery', 'medicare', 'north', 'sites', 'conway', 'seattle', 'eds', 'naval', 'embassy', 'federal', 'chamber', 'baylor', 'nv', 'commander', 'singh', 'district', 'morgan', 'environmental', 'barney', 'william', 'force', 'prasad', 'representatives', 'usda', 'residency', 'bothell', 'east', 'm.d.', 'children', 'fort', 'dow', 'johns', '09/2012', 'harvard', 'dept', 'dc', 'safety', 'south', 'recreation', 'bloomington', 'ex', 'international', 'city', 'newspaper', 'vegas', 'france', 'veteran', 'vsp', 'mexican', 'hopkins', 'la', 'nursing', 'h', 'court', 'clark', 'manhattan', 'air', 'george', 'police', 'de', 'universal', 'kumar', 'dr.', '2020', 'beta', 'kaiser', 'petition', 'affairs', 'kohl', 'clinic', 'headquarters', 'columbia', 'hospital', 'hanover', 'population', 'prince', 'state', 'annapolis']
#
# Cluster: 23
# ['recovery', 'exp', 'standby', 'rman', 'o', 'crp', 'space', 'awr', 'fine', 'opatch', 'frequently', 'addm', 'disaster', 'cloning', 'partition', 'compression', 'reorganization', 'restore', 'tuning', 'index', 'binary', 'clone', 'automatic', 'disk', 'backup', 'pump', 'spread', 'patching', 'sga', 'cold', 'snapshot', 'omni', 'hot']
#
# Cluster: 24
# ['sergeant', 'freshman', 'charity', 'awarded', 'affiliation', 'painting', 'restaurant', 'corps', 'entrepreneur', 'resident', 'hiring', 'book', 'e.', 'assistant', 'distance', 'body', 'ngo', 'tutorial', 'organize', 'orientation', 'marine', 'professor', 'empower', 'tutoring', 'editor', 'mentored', 'official', '2014-december', 'stationery', 'blackboard', 'outreach', 'athletic', 'people', 'camper', 'placement', 'personally', 'speaking', 'fire', 'internship', 'awareness', 'local', 'gym', 'teacher', 'supervisor', 'animal', 'outcome', 'vietnam', 'meal', 'ernst', 'teaching', 'rehabilitation', 'concert', 'instructional', 'fellow', 'teach', 'forum', 'leaders', 'event', 'prospective', 'social', 'church', 'education', 'amongst', 'academic', 'pursue', 'diversity', 'supervise', 'student', 'achievement', 'money', 'winter', 'coach', 'philanthropy', 'cater', 'cooperate', 'rural', 'capstone', 'campaign', 'leader', 'resume', 'hire', 'brazil', 'fair', '19', 'leadership', 'visitor', 'mentor', 'counseling', 'multimedia', 'extracurricular', 'african', 'volunteering', 'recruit', 'discuss', 'arrange', 'emerging', 'worker', 'olympics', 'stamp', 'stay', 'raise', 'tutor', 'rare', 'delegate', '650', 'please', 'charge', 'educate', 'supervised', 'eight', 'begin', 'career', 'housing', '30', 'especially', 'speech', 'seminar', 'familiarize', 'underprivileged', 'village', 'mark', 'examination', 'activities', 'abroad', 'welfare', 'officer', 'mental', '⃰', 'community', 'receptionist', 'paulo', 'blog', 'sport', 'appointment', 'arrangement', 'coaching', 'thirty', 'encourage', 'goldman', '1200', 'enter', 'participant', 'summer', 'clerical', 'previously', 'youth', 'sharing', 'contest', 'coworker', 'young', 'volunteer', 'letter', 'alumnus', 'organizer', 'greet', 'peer', 'lesson', 'specialty', 'chair', 'girl', 'member', 'join', 'fundraising', 'staff', '90', 'guest', 'parent', 'classroom', 'fill', 'reception', 'camp', 'swimming', 'artillery', 'duty', 'lunch', 'quiz', 'photography', 'elementary', 'counselor', 'served', 'crew', 'lecture', 'preside', 'rotaract', 'honduras', 'participation', 'elevator', 'são', 'weekend', 'homeless', 'calendar', 'child', 'travel', 'gsg', 'woman', 'fundraiser', 'invite', 'students’', 'facilitation', 'recruitment', 'performing', 'golf', 'foster', 'counsel', 'mathematic', 'shift', 'game', 'doctor']
#
# Cluster: 25
# ['cap', 'instruct', 'dozen', 'years’', 'professional', 'accenture', '1000', 'writing', 'planned', 'sba', 'course', 'duke', '16', 'appreciation', 'cashier', 'tech', 'award', 'bp', 'limited', 'publications', 'experiment', 'middle', 'fitness', 'attendee', 'promotional', 'year', 'ordinate', 'csr', 'fundamental', 'recognition', 'name', 'generalist', 'overview', '12', 'professionals', 'qualified', 'since', 'deloitte', '400', 'outstanding', 'organic', '200', 'uperform', 'boss', 'du', '17', 'auxiliary', 'co', 'interactive', 'ace', 'significant', 'devise', '5', '350', 'excellence', 'coordinated', 'membership', 'miller', 'curriculum', 'intern', 'spot', 'specialize', 'nationwide', 'shanghai', '25', 'zachary', 'haining', 'present', 'isd', 'larsen', 'merit', 'awards', 'champion', 'nine', 'bakery', '14', 'discovery', 'forklift', 'top', 'memberships', 'grouping', 'star', 'representative', 'intensive', 'cigna', 'tata', 'coe', 'consultancy', 'interests', '▪', 'recipient', 'demo', 'consult', 'junior', 'directors', 'scratch', 'consulting', '13', 'charter', 'background', 'rise', '50', 'received', 'entertainment', 'shore', 'associate', 'contribution', 'independent', '18', 'medium', 'section', 'dream', '8', 'mentoring', '20', 'former', 'l&t', '45', '15', 'brain', 'energy', 'douala', 'seed', 'exit', 'electricity', '4', 'attain', 'race', 'private', 'cms', 'preparer', 'trainer', '500', 'rio', 'rock', 'promotion', 'nearly', 'williams', 'qualifications', '100', 'cameroon', 'instructor', 'upk', 'infotech', '600', 'colleague', 'score', 'responsibilities', 'incentive', 'fortune', 'advisor', '+', 'achieved', 'strengthen', 'industrial', 'prep', '150', 'mid', '23', 'howard']
#
# Cluster: 26
# ['8.x', 'jdk', 'atg', 'skin', '12.1.3', 'oss', 'upgradation', 'apply', 'applied', '9', 'bit', 'pack', 'version', 'upgrades', '10.0', '8.1', 'upgraded', 'mix', '10.3', 'was', 'upgrading', 'sp3', 'rel', 'opm', '9.3', '11gr1', '7.5', '12c', '9.2mp2', 'sum', '10.2', '9.x', 'r12', 'upgrade', 'gradation', '9.14', 'endeca', '10.x', 'patch', 'migrate', '10.1', 'ebusiness', 'updates', '8.1/9.2', '10.3.6', 'packs', '11i', '8.0', '9.2', 'refresh', '8.2']
#
# Cluster: 27
# ['sim', 'rib', 'resa', 'allocation', 'rpm', 'retail', 'orpos', 'rms']
#
# Cluster: 28
# ['communications']
#
# Cluster: 29
# ['common']
#
# Cluster: 30
# ['venue', 'manufacturing', 'supplier', 'near', 'million', 'mobility', 'five', 'week', 'relocate', 'canada', '5%', 'than', 'large', 'twenty', '500,000', 'second', 'month', 'found', 'accomplishment', 'sale', 'location', 'donation', 'fifth', 'fund', 'saving', 'presence', 'usd', 'fiscal', 'almost', 'intra', 'company', 'reservation', 'four', 'nestlé', 'asia', 'premier', 'op', 'designate', 'more', 'locate', 'annual', 'waste', 'least', 'approximately', 'wind', 'billion', 'edwards', 'three', 'wall', 'offsite', 'pitch', 'wachovia', 'consumption', 'latin', 'working', 'mart', 'cooperative', 'replacement', 'facility', 'bentonville', 'volume', 'roll', '40', 'similar', 'tenure', '100,000', 'affiliate', 'coffee', 'yearly', 'lending', 'attract', 'controls', 'gas', 'grant', 'london', 'compete', 'rating', 'turn', 'quarter', 'wafer', 'portion', 'airline', 'footprint', 'launch', 'world', '10,000', 'fte', 'vehicle', 'hotel', 'jump', '18f', '3rd', 'bear', 'winner', 'gerber', 'fellowship', 'additional', 'survey', 'finally', 'become', 'relocation', 'mianyang', '35', 'dw', 'cci', 'obstacle', '75', 'around', 'retailer', 'small', 'worldwide', '$', 'ball', 'outsourced', 'blood', 'singapore', 'ubs', 'twice', 'trailer', '4,000', 'construction', 'accommodate', 'period', 'europe', 'estate', 'expansion', 'trial', 'advertisement', '228', '450', 'schneider', 'soldier', 'aggregate', 'span', '65', 'buyer', 'power', 'earn', 'subcontract', 'comprise', '5000', 'car', 'synchronize', 'lose', 'last', 'own', 'subgroup', 'country', 'civilian', 'iteration', 'dispatch', 'commercial', 'crime', 'activate', 'ge', 'monetary', '>', 'below', 'overhaul', 'square', 'ireland', 'sell', 'lot', 'total', 'employ', 'excess', 'rank', 'automobile', 'irs', 'institution', 'firm', 'bio', 'sears', 'thousand', 'branch', 'domestic', 'region', 'dollar', 'congress', 'patent', 'instrumental', 'globe', 'manufacture', 'household', 'treatment', 'ten', 'little', 'seat', 'aim', 'fuel', 'deal', 'japan', 'beverage', 'nutrition', 'manufacturer', 'australia', 'ever', 'polymer', 'bank', '300,000', 'pae', 'first', 'roughly', 'array', 'booking', '250', '20,000', '70', 'conclude', 'ehr', 'merger', 'airport', 'usaid', 'caci', 'primavera', '80', 'seven', 'm', 'hundred', 'poc', 'nuclear', 'scale', 'functioning', 'plant', 'spearhead', 'rebuild', 'ultimately', 'contract', 'consumer', 'two', 'hunter', 'pharmaceutical', 'lighting', 'subsidiary', 'oversaw', 'finish', 'dedicated', 'acquisition', 'family', 'half', 'fleet', 'nation', 'property', 'revenue']
#
# Cluster: 31
# ['enrollment', 'certain', 'programs', 'earning', 'trc', 'leave', 'pay', 'workgroups', 'holiday', 'codes', 'salary', 'deduction']
#
# Cluster: 32
# ['hindi', 'proficiency', 'engl', 'native', 'korean', 'ocaml', 'fluent', 'german', 'literature', 'conversational', 'english', 'chinese', 'speak', 'brazilian', 'ukrainian', 'russian', 'cmsc', 'beginner', 'sheets', '0.00', 'reading', 'character', 'languages', 'assembly', 'languag', 'spanish', 'hobby', 'mandarin', 'french', 'portuguese', 'language', 'basic', '\uf0a8', 'math', '\u200b-', 'calculus', 'proficient', 'intermediate', 'swim']
#
# Cluster: 33
# ['subcontractor', 'msde', 'procurement', 'specialist', 'avis', 'engineers', 'cto', 'clerk', 'ndms', 'disa', 'govt', 'e2e', 'wramc', 'tb', 'administrative', 'semiconductor', 'rfp', 'associated', 'supported', 'hyperion', 'assigned', 'workshops', 'isso', 'facilities', 'senior', 'agency', 'operations', 'coordinator', 'logistics', 'liaison', 'sponsor', 'contributed', 'consultant', 'broadcom', 'ea', 'principles', 'dpscs', 'mlds', 'act', 'xerox', 'department', 'openlink', 'engineer', 'dla', 'globally', 'ii', 'homeland', 'strategist', 'nhs', 'developers', 'doc', 'dhhs', 'geospatial', 'manager/', 'manpower', 'redstone', 'prism', 'dashboards', 'ordination', 'tsa', 'handled', 'managers', 'customers', 'fdic', 'chief', 'interpreter', 'incorporated', 'cfs', 'fabrication', 'abbvie', 'it', 'registry', 'noc', 'nsips', 'idiq', 'departmental', 'dot', 'sme', 'grc', 'centre', 'administrator', '3pl', 'fab', 'ccb', 'ccr', 'iii', 'cognizant', 'dcs', 'ba', 'w', 'plm', 'modernization', 'contractor', 'innovation', 'dhs', 'joint', 'ops', 'coordination', 'amsd', 'directly', 'vendor', 'division', 'pm', 'epic', 'reserve', 'prime', 'u.', 'fame', 'transportation', 'laboratory', 'augmentation', 'central', 'dod', 'professionalism', 'liaise', 'personnel', 'ice', 'ciso', 'broadband', 'pmo', 'cas', 'analyst', 'trusted', 'rttt', '11.5.10', 'customs', 'sr', 'cbs', 'defense', 'endur', 'uspto', 'users']
#
# Cluster: 34
# ['mi', 'gm', 'detroit']
#
# Cluster: 35
# ['planning', 'capacity', 'budgeting', 'sprint', 'benchmark']
#
# Cluster: 36
# ['law', 'enforcement']
#
# Cluster: 37
# ['andrew', '703', '1660', 'lane', 'd', '75094', 'phone', 'subramanian', 'p', 'ss', 'christopher', '||', 'si', '330', '412', 'cell', '368', '469', '720', 'ist', 'u', 'zgoldman@terpmail.umd.edu', '3102920250@pm.sprint.com', '7843', 'f', 'murphy', 'david', '310', 'ray', 'bheema', 'rajan', 'jared', '323', '3345', 'c', '626', 'rajvkk@yahoo.com', '919', '401', 'al', 'reiz', '262', '571', 'kranthi', 'galaxy', 'l', '864', '702', 'ic', '422', 'shah', 'st', 'circle', 'i', 'n', 't', 'tanvi', 'http://daveray.net', 'ross', '0250', '860', 's', 'io', 'comm', 'y', 'harris', 'daniel', 'quail', 'en', 'txt', '292']
#
# Cluster: 38
# ['habit', 'lifestyle', 'eat']
#
# Cluster: 39
# ['references', 'challenging', 'skill', 'exceptional', 'individually', 'attitude', 'innovative', 'succeed', 'creativity', 'adaptable', 'round', 'commitment', 'positive', 'respect', 'solve', 'productive', 'influence', 'competent', 'verbal', 'capable', 'posses', 'creative', 'hardwork', 'grasp', 'collaborative', 'thinking', 'ethic', '32', 'problem', 'prove', 'acuman', 'motivate', 'conflict', 'strong', 'proven', 'independently', 'motivated', 'player', 'orient', 'teamwork', 'effective', 'success', 'fast', 'supervision', 'able', 'highly', 'effectively', 'adaptability', 'discipline', 'great', 'self', 'simultaneously', 'demonstrate', 'excellent', 'attention', 'accomplish', 'managerial', 'choi', 'practical', 'learner', 'technically', 'commit', 'savvy', 'aptitude', 'oral', 'supervisory', 'starter', 'rapidly', 'motivation', 'pace', 'dedicate', 'ability', 'analytical']
#
# Cluster: 40
# ['pp', 'sd', 'fi', 'mm']
#
# Cluster: 41
# ['practices', 'term', 'industry', 'valid', 'donco', 'interest', 'rule', 'insurance', 'feasible', 'onboarding', 'crosswalk', 'healthcare', 'clinical', 'regulation', 'africa', 'eligibility', 'id', 'entitlement', 'icd', 'determined', '140', 'compliant', 'un', 'guideline', 'evaluation', 'theory', 'alza', 'hipaa', 'range', 'disability', 'records', 'lookup', '270/271', 'long', 'therapy', 'compliance', 'focu', 'hrci', 'portability', 'cybersecurity', 'employer', 'leading', 'threshold', 'vital', 'directive', 'tpocs', 'x12', 'dental', 'authorize', 'legal', 'conditional', 'aware', 'hippa', '276/277', 'reimbursement', 'truck', 'sound', 'minimum', 'assess', 'trs', 'provider', 'transmission', '834', 'employment', 'ferpa', 'pharmacy', 'disclosure', 'ansi', 'payer', 'confirm', 'selection', 'obtain', 'care', 'progressive', '837', 'hl7', 'fraud', 'regulatory', 'fsa', '835', 'novel', 'osha', 'observe', 'abac', 'auditing', 'accord', 'mandate', '90%', 'permanent', 'insure', 'gap', 'carrier', 'partnership', 'identification', '300', 'acquire', 'relevant', 'government', '4010', 'prevention', 'flight', 'formulation', 'govern', 'retention', 'telecom', 'policy', 'contracting', 'eu', 'liability', 'edi', 'candidate', 'pci', 'standardize', '5010', 'affect', 'far', 'debt', 'sox']
#
# Cluster: 42
# ['vb.net', 'measurement', 'c#.net', 'asp.net']
#
# Cluster: 43
# ['incom', 'frequent', 'renew', 'populate', 'extinguisher', 'few', 'move', 'patron', 'once', 'allocate', 'error', 'date', 'proactive', 'troubleshoot', '24', 'incident', 'before', 'above', 'delete', 'number', 'verification', 'daily', 'provided', 'basis', 'check', 'adhoc', 'vacation', 'lease', 'free', 'tight', 'auto', 'determination', 'occur', 'routine', 'status', 'get', 'run', 'correct', 'sure', 'no', 'manner', 'late', 'question', 'post', 'contact', 'outside', 'inquiry', 'schedule', 'beacon', 'biweekly', '24x7', 'agreements', 'collect', 'tickets', 'drink', 'off', 'pick', 'send', 'important', 'kept', 'restart', 'complaint', 'desk', 'arise', 'regularly', 'repair', 'emergency', 'handover', 'scheduling', 'encounter', 'escalate', 'agreement', 'workaround', 'address', 'repetitive', 'remove', 'fly', 'ready', 'job', 'take', 'notification', 'rotation', 'back', 'add', 'go', 'swap', 'inform', 'belzberg', 'not', 'cc', 'pssm', 'log', 'necessary', 'bookkeeping', 'pull', 'ring', 'ongoing', 'any', 'telephone', 'enforce', 'required', 'resolution', 'upon', 'room', 'come', 'staging', 'dap', 'authenticate', 'baseline', 'alamo.com', 'mass', 'another', 'resolve', 'exception', 'prevent', 'crisis', 'classified', 'issue', 'rca', 'caller', 'handling', 'after', 'narrow', 'chat', 'routinely', 'sat', 'concern', 'and/or', 'production', 'shipping', 'ems', 'old', 'oms', 'warranty', 'automatically', 'temporary', 'forth', 'find', 'alert', 'fail', 'prompt', 'assign', 'email', 'smooth', 'deletion', 'rent', 'push', 'readability', 'compilation', 'live', 'created', 'if', 'purge', 'coordinating', 'outage', 'executed', 'respond', 'timely', 'request', 'assistance', 'appropriately', 'regular', 'whenever', 'incoming', 'comet', 'weekly', 'failure', 'when', 'via', 'without', 'sync', 'nightly', 'ownership', 'escalation', 'uat', 'fix', 'simultaneous', 'light', 'update', 'uptime', 'recur', 'nationalcar.com', '24/7', 'monitor', 'attribute', 'respective', 'license', 'remotely', 'missing', 'disposal', 'smoothly', 'cq', 'everyday', 'look', 'checklist', 'teller', 'side', 'login', 'optimum', 'dependent', 'row', 'properly', 'feedback', 'notify', 'arrive', 'recover', 'answer', 'call', 'day', 'receive', 'malformed', 'logs', '100%', 'proactively', 'every', 'naming', 'proper', 'crontab']
# Cluster: 44
# ['4.00', 'b', '3.00', 'ctec', '12.000', 'discrete', '6.000', '9.000', 'intro', 'comp']
#
# Cluster: 45
# ['trade', 'invoicing', 'monthly', 'title', 'nyse', 'conform', 'financing', 'r/3', 'fidessa', 'dealing', 'discount', 'm&a', 'fico', 'agencies', 'equity', 'balance', 'bnym', 'markets', 'nasdaq', 'investor', 'jd', 'capital', 'treasury', 'expense', 'trading', 'edward', 'inventory', 'bond', 'account', 'po', 'loan', 'cantor', 'banking', 'commodity', 'diligence', 'supply', 'settlement', 'derivative', 'broad', 'contracts', 'chain', 'financial', 'finance', 'fulfillment', 'sales', 'swift', 'portfolio', 'income', 'commission', 'faa', 'bpc', 'trader', 'cash', 'finra', 'sector', 'deposit', 'ledger', 'asset', 'quote', 'equities', 'invoice', 'order', 'oats', 'hospitality', 'brokerage', 'stock', 'accountant', 'valuation', 'ap', 'currency', 'trail', 'tax', 'otc', 'fixed', 'ar', 'adjustment', 'extension', 'institutional', 'securities', 'purchasing', 'accounting', 'reconcile', 'investment', 'billing', 'eac', 'figure', 'general', 'metal', 'ecc', 'funds', 'petty', 'gl', 'orders', 'reconciliation', 'aggregation', 'wealth']
#
# Cluster: 46
# ['matching', 'variety', 'extra', 'pair', 'persuasive', 'easy', 'replace', 'ecommerce', 'stable', 'talent', 'understand', 'often', 'brand', 'accept', 'easily', 'rich', 'fashion', 'describe', 'opportunity', 'flexibility', 'very', 'quickly', 'pathway', 'super', 'already', 'honda', 'parse', 'symbol', 'grow', 'executable', 'would', 'synthesize', 'continued', 'together', 'tower', 'azure', 'see', 'bring', 'display', 'talk', 'simplify', 'then', 'article', 'craft', 'safe', 'whether', 'clarify', 'shelf', 'healthy', 'clinician', 'newsletter', 'poll', 'again', 'virtually', 'man', 'story', 'biomedical', 'contribute', 'could', 'prospect', 'concept', 'tackle', 'minimal', 'select', 'info', 'listen', 'personal', 'imagery', 'gain', 'same', 'friendly', 'how', 'possible', 'among', 'webnas', 'intuitive', 'stabilize', 'constituent', 'person', 'foundation', 'way', 'centralize', 'passion', 'refine', 'highlight', 'illustrate', 'recordkeeping', 'proof', 'navigate', 'redesign', 'most', 'complicated', 'prototype', 'valuable', 'spoe', 'adoption', 'can', 'unique', 'match', 'feel', 'emerge', 'advance', 'mind', 'elicit', 'divide', 'credential', 'should', 'efficiently', 'systematic', 'completely', 'will', 'allow', 'particular', 'where', 'suggestion', 'flexible', 'inside', 'correction', 'main', 'break', 'description', 'reach', 'viability', 'corresponding', 'continue', 'read', 'want', 'kyc', 'surplus', 'offer', 'only', 'willing', 'what', 'element', 'translate', 'simple', 'forward', 'introduction', 'complexity', 'articulate', 'learn', 'yet', 'seek', 'luther', 'desire', 'hope', 'know', 'those', 'seamless', 'about', 'discover', 'accessibility', 'integral', 'promote', 'responsive', 'recognize', 'adapt', 'apus', 'have', 'subscriber', 'meaningful', 'fully', 'next', 'construct', 'towards', 'disparate', 'combine', 'refer', 'compiler', 'abstract', 'but', 'concise', 'instrumentation', 'celerkost™', 'position', 'difficult', 'incorporate', 'downstream', 'picture', 'gmsec', 'right', 'step', 'face', 'think', 'intend', 'so', 'vary', 'challenge', 'give', 'advancement', 'overlap', 'servicing', 'scalable', 'extend', 'put', 'modular', 'further', 'inner', 'disseminate', 'transmit', 'ease', 'expose', 'mistake', 'unstructured', 'who', 'convey', 'poi', 'realistic', 'expand', 'ne', 'screen', 'idea', 'freddie', 'communicator', 'just', 'segregate', 'speed', 'diverse', 'rewrite', 'tenant', 'replicate', 'mirror', 'still', 'onboard', 'idms', 'always', 'there', 'advocate']
#
# Cluster: 47
# ['snmp', 'ospf', 'dhcp', 'igrp', 'dns', 'ipv6', 'eigrp', 'l2/l3', 'ipsec', 'dmz', 'pop', 'ip', 'tcp', 'ipv4', 't3', 'arp', 'relay', 'rip', 'sftp', 'atm', 'osi', 'stp', 'smtp', 'protocol', 'rsa', 'nat', 'acl', 'http', 'wins', 'switching', 'ethernet', 'https', 'bgp', 'ftp', 'routers', 'protocols', 'routing', 'vlan', 'ssh', 'nfs', 'vpn', 'telnet', 'rout']
#
# Cluster: 48
# ['sessions', 'sdlc', 'verse', 'hybrid', 'architectural', 'prototyping', 'scrum', 'diagram', 'exposure', 'methodology', 'client-', 'jad', 'iterative', 'waterfall', 'phase', 'queuing', 'life', 'facet', 'oo', 'full', 'pioneer', 'cmm', 'rad', 'uml', 'extreme', 'stage', 'judicial', 'lifecycle', 'followed', 'traditional', 'cycle', 'driven', 'ood', 'understanding', 'diagrams', 'inception', 'heavy', 'thorough', 'solid', 'stlc', '3d', 'cmmi', 'designing', 'methodologies', 'oriented', 'whole', 'conceptual', 'oop', 'ooad', 'ooa', 'agile', 'gathering', 'rup', 'adaptive']
#
# Cluster: 49
# ['4.0/4.0', 'andhra', 'school', 'adele', 'ugrd', 'b.', 'minor', 'mathematical', 'delhi', 'sanghvi', 'mechanical', 'citation', 'concentration', 'colorado', 'courses', 'moscow', 'principle', 'coursework', 'georgetown', 'electronics', 'bs', 'telecommunications', 'bachelor', 'gmat', 'psychology', 'pune', 'polytechnic', 'newark', 'behavioral', 'h.', '16.00', 'keller', 'economics', 'jaypee', '3.4', 'relations', 'msis', 'distinction', 'endowed', 'cumulative', 'master', 'vellore', 'berkeley', 'aerospace', 'cgpa', '2018', 'b.tech', 'expect', 'graduated', 'mathematics', 'm.s.', 'somaiya', 'sociology', 'dwarkadas', 'karnataka', 'artificial', 'totals', 'engineering', '3.7', 'michigan', 'is', 'maryland', 'modern', 'hunan', 'technology‐bs', 'biology', 'dean', 'pennsylvania', 'shonk', '3.8', 'systems', '12.00', 'mason', 'philosophy', 'natural', 'electrical', 'a.', 'science', 'arts', '3.5', 'b.s.', 'honors', 'graduation', 'blacksburg', 'gre', 'sciences', 'informatics', 'wayne', 'bowie', 'telecommunication', 'b.e.', 'jntu', 'macroeconomics', 'technological', 'specialization', 'northern', '3.3', 'diploma', 'university', 'ann', 'masters', 'summa', 'b.e', 'k.j.', 'entrepreneurship', 'computer', 'cum', 'studies', 'physics', 'russia', 'political', 'b.s', '2019', 'indianapolis', 'scholar', 'chemistry', 'robert', 'syracuse', '1991', 'methods', 'smith', 'sagar', 'cs', 'b.a.', 'civil', 'fellows', 'mba', 'double', 'ukraine', '3.6', '3.6/4', 'statistics', '1992', 'gpa', 'iowa', 'umbc', 'degree', '3.9', 'r.h.', 'standing', 'aas', 'iit', 'illinois', 'cohort', 'indiana', 'graduate', 'laude', 'nagpur']
#
# Cluster: 50
# ['expectation', 'profitability', 'situation', 'context', 'consistent', 'conducted', 'risk', 'align', 'breakdown', 'organizational', 'culture', 'tactical', 'advise', 'negotiation', 'upper', 'profit', 'infertility', 'constant', 'augment', 'deliverable', 'remain', 'competitor', 'optimal', 'maximize', 'briefing', 'exceed', 'competency', 'retrospective', 'assure', 'revise', 'estimation', 'meet', 'market', 'engagement', 'governance', 'clients’', 'alignment', 'improvement', 'strategic', 'prioritize', 'dso', 'standards', 'pain', 'emphasize', 'timeline', 'doj', 'recommend', 'deadline', 'oversight', 'goal', 'sla', 'strategies', 'proposition', 'americas', 'accountable', 'backlog', 'moderate', 'shape', 'share', 'upcoming', 'six', 'satisfaction', 'kpi', 'mwh', 'executive', 'consensus', 'visibility', 'milestone', 'alternative', 'roi', 'competitive', 'negotiate', 'sustainable', 'invest', 'approach', 'dual', 'stakeholder', 'wbs', 'suitable', 'convention', 'evaluate', 'met', 'underlie', 'prioritization', 'specified', 'achieve', 'workplace', 'short', 'direction', 'threat', 'offering', 'streamlined', 'maximum', 'option', 'agree', 'growth', 'cio', 'early', 'maturity', 'objective', 'cost', 'propose', 'proposal', 'demand', 'coo', 'sized', 'segment', 'boost', 'mission', 'strategy', 'clarification', 'recommendation', 'rollout', 'evolve', 'marketplace', 'overall', 'scalability', 'value', 'organization', 'entrepreneurial', 'knowledgeable', 'buy', 'expedite', 'consultation', 'groom', 'effect', 'lean', 'budget', 'cncs', 'staffing', 'demos', 'advantage', 'ceo', 'implication', 'limitation', 'ideal', 'accountability', 'roadmap', 'involvement', 'better', 'practice', 'consistently', 'adherence', 'price', 'future', 'ahead', 'feasibility', 'initiative', 'obligation', 'pricing', 'msrb', 'actionable', 'sourcing', 'strict', 'toward']
#
# Cluster: 51
# ['topic']
#
# Cluster: 52
# ['correlation', 'parameter', 'vuser', 'loadrunner', 'checkpoint', 'monitored', 'correspond', 'down', 'expenditure', 'runner', 'condition', 'vugen', 'click', 'running', 'generator']
#
# Cluster: 53
# ['claim']
#
# Cluster: 54
# ['payable', 'receivable', 'accounts']
#
# Cluster: 55
# ['hang', 'fixing', 'cpu', 'dump', 'sizes', 'memory', 'thread', 'size', 'garbage', 'idle', 'jprobe', 'tune', 'samurai', 'deadlock', 'dumps', 'gc', 'isolate', 'analyzer', 'leak', 'leaks', 'trace', 'crash', 'adjust', 'heap', 'jvm']
#
# Cluster: 56
# ['random', 'l’oreal', 'mean', 'explore', 'analytic', 'acknowledge', 'modelling', 'cdc', 'ยง', 'maker', 'hypothesis', 'explain', 'dive', 'structural', 'knn', 'decision', 'choice', 'contain', 'transformational', 'descriptive', 'big', 'election', 'defined', 'predictive', 'philips', 'movie', 'classify', 'pattern', 'column', 'popular', 'popularity', '3000', 'demographic', 'text', 'logistic', 'visualization', 'er', 'linear', 'classification', 'dbms', 'sensitivity', 'stores', 'vote', 'variable', 'death', 'harness', 'nn', '30,000', 'cart', 'churn', 'bar', 'conceptualized', 'profiling', 'restatement', 'normalization', 'deep', 'generalized', 'cleansing', 'diamond', 'semi', 'persistent', 'formulate', 'age', 'prediction', 'hughes', 'coursera', 'spark', 'cleaning', 'neural', 'concepts', 'predict', 'promise', 'ranking', 'fit', 'glm', 'useful', 'circumstance', 'disease', 'conjoint', 'models', 'mixture', 'mine', 'intelligent', 'anova', 'motion', 'hbase', 'huge', 'seasonal', 'interesting', 'rental', 'algorithm', 'confidence', 'repeat', 'presidential', 'statistical', 'comparison', 'forest', 'decisions', 'birth', 'count', 'forecasting', 'technique', 'choose', 'dataset', 'heat', 'bike', 'tree', 'naïve', 'vector', 'optimization', 'cuisine', 'trees', 'making', 'mining', 'model', 'preference', 'modeling', 'reviewer', 'geographic', 'twitter', 'regression', '1900', 'ingredient', 'factor', 'bayes', 'basket', 'maps', 'category', 'interval']
#
# Cluster: 57
# ['funding', 'track', 'keep', 'miss', 'progress', 'movement', 'progression', 'radar']
#
# Cluster: 58
# ['start', 'stop', 'partner', 'campus', 'clothing', 'donate', 'matter', 'medical', 'educational', 'food', 'drill', 'shelter', 'organized', 'dining', 'msc', 'adopt', 'faculty', 'employed', 'clean', 'loading', 'drug', 'insight', 'subject', 'extraction']
#
# Cluster: 59
# ['bfs', 'relational', 'ssas', 'designer', 'spy', 'object', 'converted', 'sybase', 'tsql', 'cleanse', 'autonomy', 'backend', 'warehouse', 'table', 'dfc', 'rapid', 'graphical', 'ssrs', 'store', 'notes', 'pds', 'ase', 'pro*c', 'mssql', 'bi', 'exam', 'flat', 'transactional', 'gis', 'crm', 'mulesoft', 'cube', 'documentum', 'oas', 'iq', 'utilities', 'cobol', 'netezza', 'towson', 'futures', 'pl', '12.5', 'mover', 'siebel', 'pentaho', 'queries', 'stored', 'query', 'extensively', 'rdbms', 'ddl', 'pages', 'expression', 'udb', 'schema', 'odi', 'menu', 'tm1', 'classic', 'informatica', 'aqua', 'frontend', 'mainframe', 'erp', 'reside', '9i/10g/11', 'cubes', 'coded', 'package', 'nfp', 'leveraged', 'combination', 'loader', 'powermart', 'reports', 'loaded', 'separate', 'extremely', 'databases', 'trigger', 'dimensional', '8i/9i/10', '9.2.2', 'transformation', 'ods', 'extract', 'views', 'telerik', 'mapping', 'dcl', 'resonate', '2.6', 'olap', 'manipulation', 'warehousing', 'suit', 'conversion', 'dimension', 'forms', 'app', 'broker', 'debugger', 'spool', '7.3', 'brio', 'procedures', 'advertising', 'feed', 'netweaver', 'scheduler', 'ota', 'golden', 'cots', 'engine', 'embarcadero', 'logical', 'dts', 'stag', 'erwin', 'modify', 'source', 'c#.', 'hana', 'dms', 'universe', 'goldengate', 'crystal', 'microstrategy', 'used', 'anywhere', 'jobs', 'cfr', 'retrieval', 'mongodb', 'view', 'datastage', 'coldfusion', 'shop', 'lotus', 'toad', 'triggers', 'vbscript', 'oltp', 'parts', 'packages', 'convert', 'express', 'hud', 'customized', 'bo', 'toolkit', 'plus', 'apex', 'transform', 'export', 'front', 'onto', 'claims', 'erd', 'clarity', 'interfaces', 'powerbuilder', 'logic', 'publishing', 'unload', 's/4', 'structured', 'fetch', 'hec', 'sql', 'hdfs', 'dynamically', 'metadata', 'teradata', 'esri', 'composer', 'import', 'jcl', 'db', 'powerexchange', 'integrator', 'db2', 'fms', 'mf', 'caching', 'ver', 'plsql', 'net', 'postgresql', 'files', 'bw', 'dml', 'workflows', 'manipulate', 'ssis', 'wiki', 'etl', 'objects', 'nosql', 'bobi', 'slt', 'ultra', 'mdm', 'conjunction', 'discoverer', 'cognos', 'oracle', 'edw', 'dynamics', 'aginity', '97', 'navigator', 'schemas', 'amp', 'cdm', 'powerful', 'thru', 'mvs', '9i/10', '8.4', 'connect', 'powercenter']
#
# Cluster: 60
# ['lan', 'wan']
#
# Cluster: 61
# ['demonstration']
#
# Cluster: 62
# ['adapter', 'webcenter', '10gas', 'mds', 'fmw', 'jdeveloper', 'mediator', '11', 'b2b', 'adapters', 'ucm', 'bpa', 'vordel', 'osb', 'aq', 'esb', 'bpel', 'fusion', 'owsm', '11.1.1.5', 'rcu', 'soa11', 'alsb', 'coherence', 'g', 'bpm', 'r3', 'timesten', 'soa', 'bus', 'adf', '11g/', 'aqualogic', 'bam', '10g/11', 'stack', 'middleware', 'composite', 'rules']
#
# Cluster: 63
# ['k']
#
# Cluster: 64
# ['quant', 'vanilla', 'options', 'fx']
#
# Cluster: 65
# ['switch', 'dell', 'modem', 'tablet', 'networking', 'vsphere', 'emc', 'media', 'icloud', 'peripheral', 'satellite', 'video', 'com', 'linksys', 'blade', 'install', 'juniper', 'intranet', 'firewall', 'hw', 'virtualization', 'pacs', 'voice', 'password', 'pc', 'des', 'frame', 'premise', 'storage', 'pspice', 'anti', 'pki', 'soft', 'gear', 'novell', 'camera', 'vmware', 'unity', 'hub', 'cisco', 'blackberry', 'avaya', 'imaging', 'citrix', 'reset', 'mail', 'digital', 'surveillance', 'voip', 'hardware', 'troubleshot', 'sw', 'network', 'spam', 'laptop', 'dsl', 'projector', 'cable', 'smartphone', 'connectivity', 'cli', 'netware', 'inventori', 'audio', 'wire', 'vm', 'photo', 'remote', 'desktop', 'router', 'machine', '2000/2003', 'disconnect', 'catalyst', 'antivirus', 'printer', 'nortel', 'hyper', 'banyan', 'terminal', 'cad', 'fiber', 'unclassified', 'sccm', '365', 'apple', 'token', 'os', 'devices', 'ghost']
#
# Cluster: 66
# ['parallel', 'press', 'm.', '1995', 'r.', 'scientific', 'computing', 'j.', 'atlas', 'f.', 'srikant', 'w.', '1989', 'simulations', '1st', 'p.', 'c.', 's.', 'k.', 'news', 'pooma']
#
# Cluster: 67
# ['sub']
#
# Cluster: 68
# ['china', 'administrate', 'tayohya', 'visit', 'questionnaire', 'effectiveness', '60', 'layout']
#
# Cluster: 69
# ['united', 'states']
#
# Cluster: 70
# ['review', 'reporter', 'return', '9001', 'necessity', 'results', 'updating', 'paper', 'supplementary', 'draft', 'dictionary', 'past', 'hard', 'redline', 'wrote', 'immediate', 'interpret', 'specification', 'notice', 'editorial', 'mrp', 'fda', 'decomposition', 'accordingly', 'graphic', 'written', 'qualification', 'response', 'updated', 'operator', 'revision', 'origin', 'statement', 'eco', 'submittal', 'walkthrough', 'preparation', 'macro', 'requirements', 'reviews', 'determine', 'discussion', 'download', 'input', 'optical', 'bill', 'form', 'boarding', 'owner', 'compile', 'advice', 'manual', 'guidance', 'publish', 'library', 'prepare', 'mockup', 'searching', 'requests', 'specify', 'comment', 'quarterly', 'registration', 'document', 'fulfil', 'attach', 'correctness', 'outgoing', 'spec', 'scanning', 'assignment', 'label', 'recording', 'documentation', 'guide', 'schematic', 'timeframe', 'upload', 'stake', 'drawing', 'inspector', 'bind', 'ecr', 'kit', 'archival', 'scr', 'comply', 'edms', 'closing', 'brochure', 'rfi', 'freight', 'sow', 'publication', 'flows', 'reflect', 'print', 'inconsistency', 'panel', 'loop', 'template', 'keeping', 'study', 'livelink', 'filing', 'readiness', 'inspection', 'board', 'retrieve', 'fax', 'indexing', 'detail', 'submit', 'attachment', 'selected', 'minute', 'bpp', 'indicate', 'original', 'binder', 'plans', 'history', 'periodic', 'accordance', 'validation', 'nugenesis', 'write', 'retro', 'scrub', 'srs', 'characteristic', 'invoices', 'produce', 'engineered', 'list', 'journal', 'raw', 'correspondence', '120', 'audited', 'sensitive', 'verify', 'completion', 'printing', 'upkeep', 'adhere', 'meeting', 'sheet', 'walk', 'approve', 'materials', 'assemble', 'gathered', 'approval', 'note', 'stearns', 'iso', 'submission', 'screening', 'prepared', 'mis', 'paperwork', 'rtm', 'file', 'attended', 'interview', 'brief', 'previous', 'instruction', 'assay', 'worksheet', 'pdf', 'gmp', 'sort', 'mailing', 'scenarios', 'sequence', 'validate', 'bom', 'evidence', 'laser', 'editing', 'dependency', 'matrix', 'finalize', 'artifact', 'record', 'transmittal', 'per', 'accurate', 'shipment', 'folder', 'designs', 'reference', 'material', 'outline', 'specifications', 'completeness', 'summary', 'entry', 'catalogue', 'sops', 'modified', 'author', 'pass', 'edit', 'format', 'reviewed', 'discrepancy', 'archive', 'brd', 'tie', 'fulfill', 'agenda', 'cover', 'elicitation', 'fact', 'prior', 'applicable', 'conformance', 'white', 'inclusion', 'permit', 'integrity', 'collected', 'criterion', 'standardized', 'procedure', 'sop', 'inspect', 'artist', 'accurately', 'holder', 'derive', 'categorize', 'aid', 'identifying', 'detailed', 'applicant', 'consolidated', 'sec', 'ship', 'copy', 'pertinent', 'traceability', 'electronic', 'final', 'rice', 'archiving', 'compose']
#
# Cluster: 71
# ['writer', 'networks', 'srm', 'christian', 'planner', 'tn', 'lab', 'segmentation', 'nike', 'brothers', 'memphis', 'collierville', '07', 'fedex']
#
# Cluster: 72
# ['portlet', 'selenium', 'templates', 'xpath', 'autosys', 'bootstrap', 'svn', 'parser', 'bourne', 'webdriver', 'clearcase', 'winscp', 'tdd', 'udeploy', 'powershell', 'cd', 'cucumber', 'mockito', 'joomla', 'docker', 'config', 'jaws', 'shell', 'theme', 'maven', 'invoke', 'jython', 'jconsole', 'tibco', 'sdkman', 'cygwin', 'sts', 'logo', 'cruise', 'rc', 'suites', 'putty', 'cassandra', 'solr', 'env', 'starteam', 'ruby', 'korn', 'intellij', 'bamboo', 'micro', 'boot', 'microservice', 'appway', 'mgmt', 'tortoise', 'artisan', 'soapui', 'orchestration', 'appium', 'confluence', 'xpress', 'hook', 'batch', 'puppet', 'netbeans', 'myeclipse', 'mask', 'vb', 'platforms', 'gradle', 'jenkins', 'ansible', 'yarn', 'devops', 'filezilla', 'em', 'sdk', 'ksh', 'chef', 'subversion', 'log4j', 'harvest', 'github', 'nexus', 'artifactory', 'liferay', 'ant', 'nant', 'perforce', 'tfs', 'galileo', 'scripting', 'jenkin', 'testng', 'xcode', 'scripts', 'cvs', 'builder', 'eclipse', 'rcp', 'bash', 'continuous', 'vss', 'prototyped', 'nodejs', 'git', 'ide', 'plugin', 'hudson', 'scala', 'wlst', 'node.js', 'perl', 'odm', 'firebug', 'adb', 'splunk', 'lambda', 'ci', 'iiq', 'webapps', 'cruisecontrol']
#
# Cluster: 73
# ['special']
#
# Cluster: 74
# ['economic']
#
# Cluster: 75
# ['ato', 'scan', 'protect', 'fisma', 'pta', 'nist', 'categorization', 'mitigation', 'nessus', 'audits', 'unauthorized', 'st&e', 'fips', 'action', 'remediate', 'ra', '199', 'authorization', 'milestones', 'hardening', 'ssp', 'c&a', '800', 'posture', 'a&a', 'assessment', 'sa', 'rar', 'poa&m', 'csam', 'virus', 'corrective', 'poa&ms', 'protection', 'remediation', '37', 'assessments', 'privacy', 'border', 'vulnerability', 'contingency', 'weakness', 'deficiency']
#
# Cluster: 76
# ['afghanistan', 'fluor', 'theater', 'epc', 'bagram', 'dubai', 'nyc', 'centers', 'projects']
#
# Cluster: 77
# ['block']
#
# Cluster: 78
# ['dreamweaver', 'photoshop', 'adobe']
#
# Cluster: 79
# ['sbg', '8.9', 'hcm', 'hris', 'recruiting', 'kronos', 'engines', '9.1', 'lms', 'om', 'benefits', 'na', 'employee', 'peoplecode', 'sandia', 'financials', 'payroll', '8.3', 'costing', 'tam', 'sqr', 'ess', 'par', 'clock', 'appraisal', 'compensation', 'istore', 'benefit', 'peopletools', 'erecruit', '8.8', '9.0', 'delegation', 'terminate', 'ps', 'blue', 'hr', 'mantech', 'maximo', 't&l', 'resources', 'timesheet', 'nbc', 'peoplesoft', 'pension', 'hrms', 'elements', 'labor', 'mss', 'accrual', 'ariba', 'fscm', 'baptist', 'adp', 'taleo', 'helpdesk', 'workday', 'elm', 'eperformance', 'workforce', 'darden', '8.51', 'lm', 'absence', 'ben', 'techno']
#
# Cluster: 80
# ['onshore', 'onsite', 'offshore']
#
# Cluster: 81
# ['7', 'portal', 'oc4j', '8.5', 'siteminder', 'p6', '2000/xp', 'cot', 'ga', 'websphere', 'ohs', 'oracle11', 'netscape', '7.0/8.0', 'glassfish', '6.x', 'edition', '5.x', 'mcafee', 'sunone', '98', '4.5', 'gateway', 'maestro', 'tc', '2003', '64', 'minder', '2.2', '6.2', 'viewer', 'wordpress', 'informix', '4.x', 'tomcat', 'apache', '6/7', '5.x/6.x', '1.0', 'alsr', 'portals', '8/10', '1.7', '2.x', '2000', '9.2/10.3', '6', 'diagnostics', 'symantec', 'z', '6.1/7.0', '10.3.x', 'series', '11.0', 'scom', 'couchbase', 'bea', '5.1', '5.1/6.0', 'iplanet', '10,shell', 'cics', '6.1', '4.0', 'nagios', 'veritas', 'v', 'balancer', 'ibm', 'sonic', 'window', 'aix', 'sphere', '6.5', 'windows', 'sqlserver', 'unix', 'nt', 'iis', 'dynatrace', 'alfresco', '9i', 'netegrity', '4.2', 'vms', 'mq', 'sever', 'plumtree', '7.1', 'webserver', '7.0', 'solaris10', 'oracle9i', 'solaris', 'vista', 'jboss', '8.5.5', 'oracle10', 'jrockit', 'spatial', '6.0', '2.1', '9/10', 'agents', '11g/12c', 'pega', 'tivoli', '7.x/8.x', 'eap', 'ware', 'r2', 'xp', 'el', '10.3/11', 'webmethods', 'f5', '7.x', '6.x/7.x', 'sun', '5.5', '9.2/10.0']
#
# Cluster: 82
# ['nov', 'aug', 'dec', 'sep', 'jun', 'oct', 'jul', 'feb', 'apr', 'jan']
#
# Cluster: 83
# ['pmi', 'a+', 'mcp', 'dos', 'itil', 'certify', 'mcse', 'certified', 'v3', 'comptia', '~', 'certification', 'iv', 'ccna', 'pmp', 'scrummaster', '95', 'cissp']
#
# Cluster: 84
# ['replication']
#
# Cluster: 85
# ['tsp', 'catch']
#
# Cluster: 86
# ['linux', 'rhel', 'centos', 'redhat', 'ux', 'ubuntu', 'red', 'hat', 'factory']
#
# Cluster: 87
# ['outbound', 'inbound']
#
# Cluster: 88
# ['ovd', 'oes', 'oaam', 'angular.js', 'odsee', 'odsm', 'idam', 'federated', 'identity', 'oig', 'provisioning', 'oid', 'sailpoint', 'idm', 'kerberos', 'sso', 'saml', 'accessgate', 'webgate', 'tfim', 'obiee', 'spml', 'ha', 'oim', 'ps3', 'kornshell', 'rbac', 'sandbox', 'directory', 'isam', 'oif', 'federation', 'publisher', 'oud', 'ps2', 'ad', 'connector', 'opensso', 'disable', '11gr2', 'ldap', 'products', 'oam', 'ofsll']
#
# Cluster: 89
# ['deputy']
#
# Cluster: 90
# ['hadoop', 'mobizen', 'pivot', 'acrobat', 'microsoft', 'd3.js', 'stata', 'tobii', 'neo4j', 'autocad', 'rstudio', 'cypher', 'powerpoint', 'solver', 'chart', 'arena', 'frontpage', 'precision', 'r', 'palisade', 'workbench', 'spreadsheet', '2005/2008', 'forensic', 'verilog', 'analytics', 'macintosh', 'macros', 'python', 'pig', 'lucidchart', 'vba', 'tools', 'charts', 'autodesk', 'tables', 'illustrator', 'word', 'docs', 'essential', 'infopath', 'minitab', 'mapreduce', 'visible', 'abode', 'bluemix', 'webex', 'modeler', 'creo', 'salesforce', '.net', 'arcgis', 'paradigm', 'ssi', 'salesforce.com', 'jaspersoft', 'lynda.com', 'google', 'virtualbox', 'macromedia', 'abap', 'inventor', 'captivate', '@risk', 'sql*plus', 'visio', 'sas', 'matlab', 'jigsaw', 'studios', 'draw', 'ms', 'jmp', 'stattools', 'glimmix', 'stat', 'intuit', 'spss', 'businessworks', 'graphics', 'studio', 'skills', 'sqoop', 'impala', 'flash', 'lucid', 'quickbooks', 'solvertable', 'prolog', 'precisiontree', 'excel', 'tracer', 'visual', 'advanced', 'wireshark', 'outlook', 'paint', 'axure', 'tableau', 'hive', 'c++', 'cloudera', 'miscellaneous', 'snagit', 'mysql', 'itsm', 'adwords', 'sharepoint', 'php']
#
# Cluster: 91
# ['vision']
#
# Cluster: 92
# ['pend']
#
# Cluster: 93
# ['versioning', 'logging', 'clear', 'sqa', 'bmc', 'patrol', 'repeatable', 'uploaded', 'retest', 'manually', 'tracking', 'mtm', 'uft', 'defect', 'works', 'atlassian', 'hp', 'thermo', 'installer', 'rtc', 'closure', '12.0', 'debugged', 'clearquest', 'case', '\uf020', 'jira', '11.5', 'bac', 'cron', 'serena', 'pvcs', 'debug', 'director', 'lock', 'bridge', 'robot', 'lb', 'spirent', 'bugzilla', 'jmeter', 'testrail', 'close', 'fiddler', 'qtp', '1500', 'charles', 'sbm', 'winrunner', 'center', 'duplicate', 'turnaround', 'opening', 'mantis', 'ab', 'alm', 'quest', 'triage', 'lims', 'until', 'analysed', 'vs', 'quick', 'satisfactory', 'tbs', 'qc', 'tracker', 'silk', 'servicenow', 'quality', 'hpalm', 'cases', 'ticketing', 'priority', 'mercury', 'severity', 'elementool', 'tasks', 'hpqc', 'caliber', 'performer', 'reproduce', 'rally', 'bug', 'ticket', 'rail', 'screenshot', 'openview']
#
# Cluster: 94
# ['louis', 'kpmg', '2014-may', 'suitland', '2002', 'llp', 'mn', 'ymca', '2015-', '2011-', 'system’', 'july', '2012', '2016-may', '2011', 'till', 'june', '2012-', 'sept', 'october', '2015', 'mar', 'september', 'nov.', 'hyderabad', '2005', 'november', '2011-may', '1987', 'jan.', 'apr.', '2008-', '01', 'chandigarh', 'aug.', 'february', 'oct.', '2014-august', '\uf0f2', '2015-dec', 'august', 'dossier', '2017-', '2017', 'project-', 'may', '04', '2009', 'freelance', '2007', 'jr.', '2015-august', '–may', '2001', 'march', '2016', '1985', 'duration', 'advisory', '2004', 'sept.', '06', '2013-may', '09', '2014', 'january', '2013-', 'jun.', 'chevy', '2013', 'partners', '2014-', 'minneapolis', '2006', '02', 'december', '2016-', 'april', 'inc', 'citigroup', 'mar.', 'dec.', '2008', '2010', '2015-present']
#
# Cluster: 95
# ['workstation']
#
# Cluster: 96
# ['requisite', 'pro', 'rational', 'rose']
#
# Cluster: 97
# ['farm']
#
# Cluster: 98
# ['3', 'work', 'execute', 'ensure', 'execution', 'workflow', 'multiple', 'emphasis', 'design', 'purpose', 'custom', 'legacy', '\uf06e', 'perspective', 'delivery', 'task', 'etc', 'ftd', 'developed', 'product', 'modification', 'train', 'of', 'integration', 'standard', 'site', 'existing', 'cod', 'analysis', 'internet', 'set', 'active', 'implementation', 'all', 'serve', 'test', 'optimize', 'activity', 'help', 'i.e.', 'office', 'process', 'as', 'automate', 'manage', 'end', 'intelligence', 'addie', 'provides', 'several', 'pwm', 'system', 'regard', 'formal', 'performance', 'module', 'software', 'utility', 'mortgage', 'physical', 'platform', 'involve', 'conduct', 'build', 'field', 'enterprise', 'collaboration', 'online', 'for', 'training', 'presentation', 'which', 'customize', 'project', 'sap', 'require', 'well', 'interface', 'make', 'centric', 'proprietary', 'apigee', 'qa', 'automation', 'function', 'tool', 'identified', 'closely', 'couple', 'michael', 'new', '3-tier', 'operate', 'areas', 'these', 'level', 'capture', 'conceptualize', 'utilize', 'each', 'along', 'interfac', 'through', 'centralized', 'consist', 'distribute', 'knowledge', '’s', 'enhanced', 'interim', 'distribution', 'developer', 'd.b.a.', 'primarily', 'available', '/contribution', 'gccp', 'control', 'operating', 'define', 'interact', 'management', 'gather', 'direct', 'within', 'testing', 'isr', '-PRON-', 'entity', 'time', 'efficient', 'participate', 'research', 'develop', 'support', 'functional', 'relation', 'processing', 'such', 'extensive', 'into', '●', 'access', 'team', 'page', 'scenario', 'pilot', 'reporting', 'dex', 're', 'specific', 'fpars', 'individual', 'at', 'focus', 'capability', 'technology', 'other', 'pfizer', 'jeppesen', 'infrastructure', 'pre', 'flow', 'deployment', 'packaging', 'create', 'geographically', 'entire', 'external', 'like', 'base', 'requirement', 'collaborate', '\uf0b7', 'geographical', 'map', 'crud', 'kranthikbheema@gmail.com', 'perform', 'standardization', 'collection', 'part', 'recent', 'respectively', '\uf0a7', 'delivered', 'numerous', 'web', 'solution', 'responsibility', 'e.g.', 'client', 'current', 'commerce', 'good', 'by', 'definition', 'many', 'ecybermission', 'facilitate', 'isrweb', 'complete', 'critical', '\ue00c', 'various', 'both', 'vast', 'oversee', 'exist', 'role', 'security', 'maintain', 'different', 'successfully', 'analyze', 'exchange', 'application', 'across', 'wise', 'report', 'website', 'engage', 'operational', 'manager', 'out', 'currently', 'with', 'processes', 'creation', 'introduce', 'wide', 'modernize', 'occasion', 'use', 'between', 'dynamic', 'link', 'tiered', 'database', 'be', 'initial', '○', 'marketing', 'this', 'configurable', 'assist', 'leverage', '10', 'teams', 'implement', 'integrate', 'building', 'enhancement', 'environment', 'subsystem', 'program', 'operation', 'ppm', 'technical', 'experienced', 'consolidation', 'in', 'cutover', 'scm', 'drive', 'cm', 'change', 'effort', 'include', 'some', 'open', 'stream', 'to', 'primary', 'content', 'during', 'addition', 'key', 'comprehensive', 'relationship', 'later', '2', 'suite', 'information', 'hands', 'also', 'third', 'plan', 'carry', 'specialized', 'up', 'r&d', 'real', 'consistency', 'data', 'specifically', 'code', 'major', 'migration', 'load', 'physician', 'optimized', 'business', 'e', 'expert', 'corporate', 'unit', 'assisted', 'enablement', "'s", 'customer', 'from', '’', 'party', 'responsible', 'line', 'undertaken', 'establish', 'mr.', 'actively', 'automated', 'integrated', 'an', 'high', 'newly', 'deliver', 'aspect', 'and', 'pipeline', 'led', 'learning', 'hand', 'target', 'driver', 'example', 'maintenance', 'structure', 'transition', 'feeder', 'customization', 'adept', 'communicate', 'successful', 'initiate', 'resource', 'coding', 'method', 'human', 'user', 'branding', 'skilled', 'class', 'depth', 'patient', 'follow', 'generation', 'consolidate', 'group', 'enable', 'profile', 'related', 'a', 'while', 'over', 'everything', 'that', 'programming', 'relate', 'script', 'enhan ...
#
# Cluster: 99
# ['technician']
#
# Cluster: 100
# ['examine', 'cr', 'cp', 'bid', 'constraint', 'swot', 'impact', 'standup', 'wine', 'scope', 'assumption']
#
# Cluster: 101
# ['roc', 'qualitative', 'compare', 'historical', 'indicator', 'loss', 'summarize', 'graphs', 'dashboard', 'utilization', 'measure', 'compute', 'quantity', 'projection', 'metrics', 'margin', 'trend', 'curve', 'eye', 'accuracy', 'forecast', 'variance', 'against', 'ir', 'usage', 'incur', 'calculation', 'anticipate', 'graph', 'accident', 'counter', 'probability', 'webpage', 'estimate', 'frequency', 'scorecard', 'visualize', 'average', 'cadence', 'quantitative', 'metric', 'calculate', 'p.l.a.n.', 'sample', 'mapbox', 'porter', 'actual', 'insertion', 'conclusion', 'statistic', 'plot', 'analyse', 'spend', 'formula', 'improvise', 'show', 'output', 'earned']
#
# Cluster: 102
# ['remedy']
#
# Cluster: 103
# ['bureau', 'census']
#
# Cluster: 104
# ['mozilla', 'sencha', 'opera', 'msie', 'compatibility', 'smoke', 'box', 'boundary', 'emulator', '508', 'ipad', 'iphone', 'gui', '∙test', 'ios', 'vr', 'device', 'ie', 'black', 'mobile', 'exploratory', 'interruption', 'sanity', 'facebook', 'explorer', 'stress', 'mac', 'samsung', 'firefox', 'edge', 'safari', 'android', '⦁', 'negative', 'acceptance', 'usability', 'hoc', 'ran', 'sit', 'localization', 'browser', 'periodically', 'x', 'chrome', 'ivr', '10/8/7']
#
# Cluster: 105
# ['nsa', 'immigration', 'attorney', 'magazine', 'contractual', 'ethical', 'authority', 'hacking', 'saic', 'breach', 'continuity', 'hold', 'clearance', 'investigation', 'attend', '6000', 'speaker', 'organizing', 'following', 'separation', 'european', 'alliance', 'trust', 'symposium', 'sandy', '1,000', 'proceeding', 'cyber', 'national', 'conference', 'transit', 'secret', 'summit', 'justice', 'criminal', 'compaq', 'fbi', 'sc', 'canadian', 'hurricane', 'regional']
#
# Cluster: 106
# ['instrument']
#
# Cluster: 107
# ['forwarding', 'secure', 'socket', 'layers', 'transfer', 'securely', 'timeout', 'layer', 'receiver', 'datagram', 'cryptographic', 'transmitter', 'reliable', 'pgp', 'encryption', 'rc4', 'certificates', 'authentication', 'ssl', 'retransmission', 'transport', 'udp', '\uf0d8', 'unreliable']
#
# Cluster: 108
# ['beyond']
#
# Cluster: 109
# ['home']
#
# Cluster: 110
# ['place']

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(list(word2vec.values())[0])

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

w2v = dict(zip(res2vec.wv.index2word, res2vec.wv.syn0))

etree_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("extra trees", ExtraTreesClassifier(n_estimators=200))])
svm_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("SVM", SVC())])

print(svm_w2v)
print(etree_w2v)
# Out:
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7fe21b1aef28>), ('SVM', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7fe21b1aed68>), ('extra trees', ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False))])

# %%
X=[['python','ocaml'],
  ['economics','sociology'],
  ['css','javascript']]
y=['scripting','majors','web']
etree_w2v.fit(X,y)
test_X=[['perl'],['psychology'],['asp.net']]
print(etree_w2v.predict(test_X))
# Out:
# ['scripting' 'majors' 'scripting']

# %%
df_skill = pd.read_excel('Skills.xlsx',columns='Skills')
print(df_skill.head(),'\n')
skill_series = df_skill.T.squeeze().str.lower()
print(skill_series)
# Out:
#                     Skills
# 0           iTunes Connect
# 1   Mobile Design Paradigm
# 2                     .NET
# 3         Abstract Factory
# 4        Accounting System
#
# 0                         itunes connect
# 1                 mobile design paradigm
# 2                                   .net
# 3                       abstract factory
# 4                      accounting system
# 5                 accuracy and precision
# 6                 acquisition management
# 7                           activerecord
# 8                               acunetix
# 9                acute coronary syndrome
# 10                 acute pain management
# 11                          ad campaigns
# 12                              adamsoft
# 13                          adaptability
# 14       adapting to changing priorities
# 15                                  adic
# 16      administration and configuration
# 17                       adobe fireworks
# 18                      adobe framemaker
# 19                        adobe freehand
# 20                     adobe illustrator
# 21                        adobe indesign
# 22                       adobe photoshop
# 23                     adolescent health
# 24        advanced features of carbonado
# 25                               adwords
# 26                                   aes
# 27                  aggressive marketing
# 28                                 agile
# 29                     agile development
#                       ...
# 1233                                wbts
# 1234                  web analytic tools
# 1235                       web analytics
# 1236                             web api
# 1237                    web applications
# 1238                       web marketing
# 1239                     web page design
# 1240                    web technologies
# 1241                          web trends
# 1242                            webdrive
# 1243                website optimization
# 1244                        websocket.js
# 1245                  what-if simulation
# 1246                           wikipedia
# 1247                             windows
# 1248                             windows
# 1249                          windows os
# 1250                              winscp
# 1251                           wireshark
# 1252                     word processing
# 1253                           wordpress
# 1254               working independently
# 1255                             writing
# 1256                 writing for the web
# 1257               written communication
# 1258                              xcode
# 1259                                 xen
# 1260                               xhtml
# 1261                                 xml
# 1262                             youtube
# Name: Skills, Length: 1263, dtype: object

# %%
d = {}
import operator
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    cluster_series = pd.Series(words)  
    temp = pd.Series(list(set(cluster_series)&(set(skill_series))))
    d[cluster] = len(temp.values)
sorted_d = list(reversed(sorted(d.items(),key=operator.itemgetter(1))))
print(sorted_d)
print(sorted_d[1])
top_ten_skills = []
for i in range(0,3):
    key,val = sorted_d[i]
    top_ten_skills.append(key)
top_ten_skills = pd.Series(top_ten_skills)    
print(top_ten_skills)
# Out:
# [(98, 26), (90, 26), (47, 14), (72, 13), (14, 9), (50, 7), (39, 7), (104, 6), (65, 6), (49, 6), (70, 5), (59, 5), (46, 5), (4, 5), (81, 4), (56, 4), (25, 4), (93, 3), (48, 3), (19, 3), (8, 3), (3, 3), (105, 2), (101, 2), (71, 2), (60, 2), (43, 2), (35, 2), (33, 2), (24, 2), (1, 2), (107, 1), (88, 1), (86, 1), (78, 1), (45, 1), (42, 1), (37, 1), (21, 1), (9, 1), (2, 1), (110, 0), (109, 0), (108, 0), (106, 0), (103, 0), (102, 0), (100, 0), (99, 0), (97, 0), (96, 0), (95, 0), (94, 0), (92, 0), (91, 0), (89, 0), (87, 0), (85, 0), (84, 0), (83, 0), (82, 0), (80, 0), (79, 0), (77, 0), (76, 0), (75, 0), (74, 0), (73, 0), (69, 0), (68, 0), (67, 0), (66, 0), (64, 0), (63, 0), (62, 0), (61, 0), (58, 0), (57, 0), (55, 0), (54, 0), (53, 0), (52, 0), (51, 0), (44, 0), (41, 0), (40, 0), (38, 0), (36, 0), (34, 0), (32, 0), (31, 0), (30, 0), (29, 0), (28, 0), (27, 0), (26, 0), (23, 0), (22, 0), (20, 0), (18, 0), (17, 0), (16, 0), (15, 0), (13, 0), (12, 0), (11, 0), (10, 0), (7, 0), (6, 0), (5, 0), (0, 0)]
# (90, 26)
# 0    98
# 1    90
# 2    47
# dtype: int64

# %%
skills = []
other = []
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    if top_ten_skills.isin([cluster]).any():
        for key,item in word_centroid_map.items():
            if(item == cluster):
                skills.append(key)
    else:
        for key,item in word_centroid_map.items():
            if(item == cluster):
                other.append(key)

# %%
len(skills)
# Out:
# 589

# %%
len(other)
# Out:
# 4984

# %%
X = [skills,other]
y=['skills','other']
etree_w2v.fit(X,y)
test_X = [['perl'],['ruby'],['university']]
print(etree_w2v.predict(test_X))
svm_w2v.fit(X,y)
print(svm_w2v.predict(test_X))
# Out:
# ['skills' 'skills' 'other']
# ['skills' 'other' 'other']

# %%
test_resume = """Jee Won Kang \n
3711 Campus Drive APT 139 College Park, MD \n
4439447487 | jwk1151@gmail.com \n

EDUCATION \n
University of Maryland College Park (Dual Degree) \n
Cumulative GPA: 3.7 \n
Anticipated Fall 2018 \n
• B.S. Physiology and Neurobiology \n
• B.S. in Computer Science \n
Relevant Courses: \n
• Object Oriented Programming I & II, Introduction to Computer Systems, Discrete Structures, \n
How Do Innovators Think? \n
\n
Languages and Technologies \n
§ Languages: Java, C \n
§ Programs: Eclipse, Android Studio, MATLAB, LaTeX, LabChart \n
\n
Projects \n
Projects can be found at my github: github.com/jeekang \n
Turnt Tower (2016): \n
• Independently developed an android app to augment the block tower game, Jenga. \n
• App features an attractive, user-friendly interface. \n
• Language: Java, Android \n
Java-Based DNA template strand Transcription/Translation (2016): \n
• Built a program using Java that takes an input nucleotide sequence and returns the \n
complementary strand, mRNA sequence, reading frame (if one exists) and amino acid sequence. \n
Independent Undergraduate Research Project (2016): \n
• Part of the Center for Bioinformatics and Computational Biology at the University of Maryland. \n
• Working with meta-genomic analysis algorithms and finding limitations of existing programs. \n
• Details to be determined, first meeting with team on September 21st \n
\n
Achievements \n
§\n
§\n
§\n
§\n
\n
Received Integrated Life Sciences Honors College Citation (2014) \n
Received Presidential Scholarship at the University of Maryland (Fall 2012 – Spring 2016) \n
Scored in the 94th percentile in the MCATs (Jan 2015) \n
6 semesters on the Dean’s List \n 
\n
Experience \n
Affective and Translational Neuroscience Laboratory \n
College Park, MD \n
Research Assistant \n
Fall 2013- Spring 2015 \n
• Brainstormed ideas for trial stages such as how to track social habits/movements of subjects. \n
• Front-end experience: briefed and debriefed study participants. \n
• Worked with the psychology clinic at University of Maryland using Titanium and Excel to manage \n
patient DSM-5 data. \n
• Assisted in running clinical trials involving the fMRI at Maryland Neuroimaging Center."""

# %%
test_resume = test_resume.replace('\n','').lower()
print(test_resume)
# Out:
# jee won kang 3711 campus drive apt 139 college park, md 4439447487 | jwk1151@gmail.com education university of maryland college park (dual degree) cumulative gpa: 3.7 anticipated fall 2018 • b.s. physiology and neurobiology • b.s. in computer science relevant courses: • object oriented programming i & ii, introduction to computer systems, discrete structures, how do innovators think? languages and technologies § languages: java, c § programs: eclipse, android studio, matlab, latex, labchart projects projects can be found at my github: github.com/jeekang turnt tower (2016): • independently developed an android app to augment the block tower game, jenga. • app features an attractive, user-friendly interface. • language: java, android java-based dna template strand transcription/translation (2016): • built a program using java that takes an input nucleotide sequence and returns the complementary strand, mrna sequence, reading frame (if one exists) and amino acid sequence. independent undergraduate research project (2016): • part of the center for bioinformatics and computational biology at the university of maryland. • working with meta-genomic analysis algorithms and finding limitations of existing programs. • details to be determined, first meeting with team on september 21st achievements §§§§received integrated life sciences honors college citation (2014) received presidential scholarship at the university of maryland (fall 2012 – spring 2016) scored in the 94th percentile in the mcats (jan 2015) 6 semesters on the dean’s list  experience affective and translational neuroscience laboratory college park, md research assistant fall 2013- spring 2015 • brainstormed ideas for trial stages such as how to track social habits/movements of subjects. • front-end experience: briefed and debriefed study participants. • worked with the psychology clinic at university of maryland using titanium and excel to manage patient dsm-5 data. • assisted in running clinical trials involving the fmri at maryland neuroimaging center.

# %%
test_res_arr = test_resume.split()
test_X = []
for word in test_res_arr:
    test_X.append([word])
test_X
# Out:
# [['jee'],
#  ['won'],
#  ['kang'],
#  ['3711'],
#  ['campus'],
#  ['drive'],
#  ['apt'],
#  ['139'],
#  ['college'],
#  ['park,'],
#  ['md'],
#  ['4439447487'],
#  ['|'],
#  ['jwk1151@gmail.com'],
#  ['education'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['college'],
#  ['park'],
#  ['(dual'],
#  ['degree)'],
#  ['cumulative'],
#  ['gpa:'],
#  ['3.7'],
#  ['anticipated'],
#  ['fall'],
#  ['2018'],
#  ['•'],
#  ['b.s.'],
#  ['physiology'],
#  ['and'],
#  ['neurobiology'],
#  ['•'],
#  ['b.s.'],
#  ['in'],
#  ['computer'],
#  ['science'],
#  ['relevant'],
#  ['courses:'],
#  ['•'],
#  ['object'],
#  ['oriented'],
#  ['programming'],
#  ['i'],
#  ['&'],
#  ['ii,'],
#  ['introduction'],
#  ['to'],
#  ['computer'],
#  ['systems,'],
#  ['discrete'],
#  ['structures,'],
#  ['how'],
#  ['do'],
#  ['innovators'],
#  ['think?'],
#  ['languages'],
#  ['and'],
#  ['technologies'],
#  ['§'],
#  ['languages:'],
#  ['java,'],
#  ['c'],
#  ['§'],
#  ['programs:'],
#  ['eclipse,'],
#  ['android'],
#  ['studio,'],
#  ['matlab,'],
#  ['latex,'],
#  ['labchart'],
#  ['projects'],
#  ['projects'],
#  ['can'],
#  ['be'],
#  ['found'],
#  ['at'],
#  ['my'],
#  ['github:'],
#  ['github.com/jeekang'],
#  ['turnt'],
#  ['tower'],
#  ['(2016):'],
#  ['•'],
#  ['independently'],
#  ['developed'],
#  ['an'],
#  ['android'],
#  ['app'],
#  ['to'],
#  ['augment'],
#  ['the'],
#  ['block'],
#  ['tower'],
#  ['game,'],
#  ['jenga.'],
#  ['•'],
#  ['app'],
#  ['features'],
#  ['an'],
#  ['attractive,'],
#  ['user-friendly'],
#  ['interface.'],
#  ['•'],
#  ['language:'],
#  ['java,'],
#  ['android'],
#  ['java-based'],
#  ['dna'],
#  ['template'],
#  ['strand'],
#  ['transcription/translation'],
#  ['(2016):'],
#  ['•'],
#  ['built'],
#  ['a'],
#  ['program'],
#  ['using'],
#  ['java'],
#  ['that'],
#  ['takes'],
#  ['an'],
#  ['input'],
#  ['nucleotide'],
#  ['sequence'],
#  ['and'],
#  ['returns'],
#  ['the'],
#  ['complementary'],
#  ['strand,'],
#  ['mrna'],
#  ['sequence,'],
#  ['reading'],
#  ['frame'],
#  ['(if'],
#  ['one'],
#  ['exists)'],
#  ['and'],
#  ['amino'],
#  ['acid'],
#  ['sequence.'],
#  ['independent'],
#  ['undergraduate'],
#  ['research'],
#  ['project'],
#  ['(2016):'],
#  ['•'],
#  ['part'],
#  ['of'],
#  ['the'],
#  ['center'],
#  ['for'],
#  ['bioinformatics'],
#  ['and'],
#  ['computational'],
#  ['biology'],
#  ['at'],
#  ['the'],
#  ['university'],
#  ['of'],
#  ['maryland.'],
#  ['•'],
#  ['working'],
#  ['with'],
#  ['meta-genomic'],
#  ['analysis'],
#  ['algorithms'],
#  ['and'],
#  ['finding'],
#  ['limitations'],
#  ['of'],
#  ['existing'],
#  ['programs.'],
#  ['•'],
#  ['details'],
#  ['to'],
#  ['be'],
#  ['determined,'],
#  ['first'],
#  ['meeting'],
#  ['with'],
#  ['team'],
#  ['on'],
#  ['september'],
#  ['21st'],
#  ['achievements'],
#  ['§§§§received'],
#  ['integrated'],
#  ['life'],
#  ['sciences'],
#  ['honors'],
#  ['college'],
#  ['citation'],
#  ['(2014)'],
#  ['received'],
#  ['presidential'],
#  ['scholarship'],
#  ['at'],
#  ['the'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['(fall'],
#  ['2012'],
#  ['–'],
#  ['spring'],
#  ['2016)'],
#  ['scored'],
#  ['in'],
#  ['the'],
#  ['94th'],
#  ['percentile'],
#  ['in'],
#  ['the'],
#  ['mcats'],
#  ['(jan'],
#  ['2015)'],
#  ['6'],
#  ['semesters'],
#  ['on'],
#  ['the'],
#  ['dean’s'],
#  ['list'],
#  ['experience'],
#  ['affective'],
#  ['and'],
#  ['translational'],
#  ['neuroscience'],
#  ['laboratory'],
#  ['college'],
#  ['park,'],
#  ['md'],
#  ['research'],
#  ['assistant'],
#  ['fall'],
#  ['2013-'],
#  ['spring'],
#  ['2015'],
#  ['•'],
#  ['brainstormed'],
#  ['ideas'],
#  ['for'],
#  ['trial'],
#  ['stages'],
#  ['such'],
#  ['as'],
#  ['how'],
#  ['to'],
#  ['track'],
#  ['social'],
#  ['habits/movements'],
#  ['of'],
#  ['subjects.'],
#  ['•'],
#  ['front-end'],
#  ['experience:'],
#  ['briefed'],
#  ['and'],
#  ['debriefed'],
#  ['study'],
#  ['participants.'],
#  ['•'],
#  ['worked'],
#  ['with'],
#  ['the'],
#  ['psychology'],
#  ['clinic'],
#  ['at'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['using'],
#  ['titanium'],
#  ['and'],
#  ['excel'],
#  ['to'],
#  ['manage'],
#  ['patient'],
#  ['dsm-5'],
#  ['data.'],
#  ['•'],
#  ['assisted'],
#  ['in'],
#  ['running'],
#  ['clinical'],
#  ['trials'],
#  ['involving'],
#  ['the'],
#  ['fmri'],
#  ['at'],
#  ['maryland'],
#  ['neuroimaging'],
#  ['center.']]

# %%
print(svm_w2v.p redict(test_X))
# Out:
# ['other' 'other' 'skills' 'skills' 'other' 'skills' 'other' 'skills'
#  'other' 'skills' 'other' 'skills' 'other' 'skills' 'other' 'other'
#  'skills' 'other' 'other' 'other' 'skills' 'skills' 'other' 'skills'
#  'other' 'skills' 'other' 'other' 'skills' 'other' 'skills' 'skills'
#  'skills' 'skills' 'other' 'skills' 'other' 'other' 'other' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'other' 'skills' 'skills' 'other'
#  'skills' 'other' 'skills' 'other' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'other' 'skills' 'other' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'other' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'other' 'skills' 'skills' 'other' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'other' 'skills' 'other' 'other' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'other' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'other' 'other'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'other' 'skills' 'skills' 'other'
#  'skills' 'skills' 'skills' 'other' 'skills' 'skills' 'skills' 'other'
#  'skills' 'other' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'other' 'other' 'skills' 'skills' 'skills'
#  'other' 'skills' 'skills' 'skills' 'skills' 'skills' 'other' 'other'
#  'other' 'other' 'skills' 'other' 'other' 'other' 'skills' 'skills' 'other'
#  'skills' 'other' 'skills' 'other' 'skills' 'other' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'other' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'other' 'other' 'skills' 'other'
#  'skills' 'other' 'other' 'other' 'other' 'other' 'skills' 'skills'
#  'skills' 'skills' 'other' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'other' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'other' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'other' 'other' 'skills' 'other' 'skills' 'other' 'skills'
#  'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'skills' 'other' 'other' 'skills' 'skills' 'skills'
#  'skills' 'skills' 'other' 'skills' 'skills']

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=2, algorithm='auto').fit(word_vector)
distances, indices = nbrs.kneighbors(word_vector)

# %%
res2vec.wv.doesnt_match('python java css html university'.split())
# Out:
# 'university'
