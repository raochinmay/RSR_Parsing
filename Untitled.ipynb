# %%
import os
import codecs
from docx import *
import docx2txt
from PIL import Image
from wand.image import Image as IMG
import pytesseract
import textract

def get_string(name):
    img=Image.open(name)
    utf8_text = pytesseract.image_to_string(img)
    utf8_text = str(utf8_text.encode('ascii', 'ignore'))
    return utf8_text

data_dir = os.path.join('Resumes')
resume_count = 0
resume_text = "all_text1.txt"
if 1==0:
    with codecs.open(resume_text,'w',encoding='utf_8') as resume_txt:
        for filename in os.listdir(data_dir):
            s = ""
            if filename.endswith(".docx"):
                location = str(os.path.join(data_dir,filename))
                #document = Document(location)
                #for paragraph in document.paragraphs:
                #    s += str(paragraph.text.encode(errors='ignore'))
                s = docx2txt.process(location)
                resume_txt.write(s+'\\n'+'\n')
                resume_count += 1


            elif filename.endswith(".pdf"):
                utf8_text = ""

                temp_doc = textract.process(os.path.join(data_dir,filename))
                if len(temp_doc) < 50:
                    img=IMG(filename=os.path.join(data_dir,filename),resolution=200)

                    img.save(filename=os.path.join(data_dir,'temp','temp.jpg'))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        utf8_text += get_string(os.path.join(data_dir,'temp',files))
                    for files in os.listdir(os.path.join(data_dir,'temp')):
                        os.remove(os.path.join(data_dir,'temp',files))
                    temp_doc = utf8_text

                if type(temp_doc)==str:
                    resume_txt.write(temp_doc+'\\n'+'\n')    
                else:
                    resume_txt.write(temp_doc.decode("utf-8")+'\\n'+'\n')    
                resume_count +=1
                
print(resume_count)
# Out:
# 0

# %%
import spacy
import pandas as pd
import itertools as it

nlp = spacy.load('en')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.21.1) or chardet (2.3.0) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
with codecs.open(resume_text,encoding="utf_8") as f:
    sample_res = list(it.islice(f,8,9))[0]
    sample_res = sample_res.replace('\\n','\n')
print(sample_res)
# Out:
# • B.S. Physiology and Neurobiology

# %%
parsed_res_sample = nlp(sample_res)
print(parsed_res_sample)
# Out:
# • B.S. Physiology and Neurobiology

# %%
for num,entity in enumerate(parsed_res_sample):
    print("Entity",entity, '-',entity.ent_type_)
# Out:
# Entity • -
# Entity B.S. - PERSON
# Entity Physiology - PERSON
# Entity and -
# Entity Neurobiology -
# Entity
#  -

# %%
token_text = [token.orth_ for token in parsed_res_sample]
token_lemma = [token.lemma_ for token in parsed_res_sample]
token_shape = [token.shape_ for token in parsed_res_sample]
d = list(zip(token_text,token_lemma,token_shape))
pd.DataFrame(data =d,\
            columns=['token_text','token_lemma','token_shape'])
# Out:
#      token_text   token_lemma token_shape
# 0             •             •           •
# 1          B.S.          b.s.        X.X.
# 2    Physiology    physiology       Xxxxx
# 3           and           and         xxx
# 4  Neurobiology  neurobiology       Xxxxx
# 5            \n            \n          \n

# %%
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'

# %%
with codecs.open(unigram_filepath,'w',encoding='utf_8') as f:
    for sent in lemmatized_sentence_corpus(resume_text):
        f.write(sent+'\n')

# %%
normal_res = LineSentence(unigram_filepath)
bigram_sentence = ''
normal_res2 = Phrases(normal_res)
with codecs.open('bigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in normal_res:        
        bigram_sentence =  ' '.join(normal_res2[unigram_sentence])
        f.write(bigram_sentence+'\n')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
bigram_sentences = LineSentence('bigram.txt')

trigram_model = Phrases(bigram_sentences)
with codecs.open('trigram.txt', 'w', encoding='utf_8') as f:
    for unigram_sentence in bigram_sentences:        
        trigram_sentence =  ' '.join(trigram_model[unigram_sentence])
        f.write(trigram_sentence+'\n')
        
normal_res1 = LineSentence('trigram.txt')
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"

# %%
if 1==0:
    res2vec = Word2Vec(normal_res,size=300,window=10,sg=1,workers=4,min_count=5)
    res2vec.save(word2vec_file)

    for i in range(1,15):
        res2vec.train(normal_res,total_examples=res2vec.corpus_count, epochs=res2vec.iter)
        res2vec.save(word2vec_file)
    
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                  0         1         2         3         4         5    \
# dashboard  -0.300756  0.275318  0.339677 -0.239608 -0.083503 -0.596592
# platform   -0.158272 -0.238026 -0.150511 -0.101551 -0.413765  0.135990
# streamline -0.418988  0.605714 -0.326817 -0.444864 -0.263341  0.359038
# trigger    -0.107115 -0.341545 -0.628969 -0.070311  0.497286 -0.664457
# channel    -0.204580  0.376000 -0.082298 -0.254202 -0.828475 -0.268459
#
#                  6         7         8         9      ...          290  \
# dashboard  -0.642870  0.212572 -0.230436 -0.204683    ...     0.130090
# platform    0.181226  0.245888 -0.115832  0.129854    ...     0.435242
# streamline -0.198208  0.098290 -0.812601 -0.258162    ...     0.146370
# trigger     0.350267  0.122755 -0.571587  0.347512    ...     0.036733
# channel    -0.459216  0.085882 -0.441563 -0.372363    ...    -0.566388
#
#                  291       292       293       294       295       296  \
# dashboard   0.294826 -0.092968 -0.311451 -0.213248  0.172714  0.845490
# platform    0.168878 -0.356876 -0.092540  0.047593 -0.042044 -0.106418
# streamline  0.459796 -0.163262 -0.593190  0.085365  0.322271 -0.774470
# trigger    -0.114541  0.111457 -0.314145 -0.556038 -0.464092  0.159681
# channel    -0.365129  0.407776 -0.040958 -0.085969 -0.349271 -1.384345
#
#                  297       298       299
# dashboard  -0.037145  0.168435  0.526344
# platform    0.156884  0.089472 -0.048911
# streamline  0.059170  0.196684  0.059107
# trigger    -0.433766 -0.138373 -0.376721
# channel     0.288894  0.282554  0.726955
#
# [5 rows x 300 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.27194211941165636

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# bash : 0.435
# 3-sectored : 0.428
# verilog : 0.416
# perl : 0.385
# impala : 0.381
# palisade : 0.38
# precisiontree : 0.372
# languag : 0.372
# kornshell : 0.367
# ocaml : 0.36

# %%
get_related_terms('java')
# Out:
# j2me : 0.479
# taglibs : 0.442
# j2se : 0.438
# jsp : 0.438
# swings : 0.436
# applets : 0.426
# j2ee : 0.418
# jdk1.6 : 0.41
# rmi : 0.405
# c++ : 0.403

# %%
from sklearn.manifold import TSNE
import _pickle as pickle

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                  0         1         2         3         4         5    \
# dashboard  -0.300756  0.275318  0.339677 -0.239608 -0.083503 -0.596592
# platform   -0.158272 -0.238026 -0.150511 -0.101551 -0.413765  0.135990
# streamline -0.418988  0.605714 -0.326817 -0.444864 -0.263341  0.359038
# trigger    -0.107115 -0.341545 -0.628969 -0.070311  0.497286 -0.664457
# channel    -0.204580  0.376000 -0.082298 -0.254202 -0.828475 -0.268459
#
#                  6         7         8         9      ...          290  \
# dashboard  -0.642870  0.212572 -0.230436 -0.204683    ...     0.130090
# platform    0.181226  0.245888 -0.115832  0.129854    ...     0.435242
# streamline -0.198208  0.098290 -0.812601 -0.258162    ...     0.146370
# trigger     0.350267  0.122755 -0.571587  0.347512    ...     0.036733
# channel    -0.459216  0.085882 -0.441563 -0.372363    ...    -0.566388
#
#                  291       292       293       294       295       296  \
# dashboard   0.294826 -0.092968 -0.311451 -0.213248  0.172714  0.845490
# platform    0.168878 -0.356876 -0.092540  0.047593 -0.042044 -0.106418
# streamline  0.459796 -0.163262 -0.593190  0.085365  0.322271 -0.774470
# trigger    -0.114541  0.111457 -0.314145 -0.556038 -0.464092  0.159681
# channel    -0.365129  0.407776 -0.040958 -0.085969 -0.349271 -1.384345
#
#                  297       298       299
# dashboard  -0.037145  0.168435  0.526344
# platform    0.156884  0.089472 -0.048911
# streamline  0.059170  0.196684  0.059107
# trigger    -0.433766 -0.138373 -0.376721
# channel     0.288894  0.282554  0.726955
#
# [5 rows x 300 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'

# %%
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])

# %%
tnse_vectors['word'] = tnse_vectors.index
print(tnse_vectors.head())
print(tnse_vectors[tnse_vectors['word']=='python'])
# Out:
#                    x          y        word
# dashboard   0.791130   7.310361   dashboard
# platform    0.883568   8.347024    platform
# streamline -0.005098   3.475843  streamline
# trigger     1.420774   8.383251     trigger
# channel     2.013096 -14.946893     channel
#                x        y    word
# python -1.674592 -8.16956  python

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e8c55666-847c-496f-839d-b8ab0c0b0f66">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(tnse_vectors)
# create the plot and configure the
# title, dimensions, and tools
tsne_plot = figure(title=u't-SNE Word Embeddings',
                   plot_width = 800,
                   plot_height = 800,
                   tools= (u'pan, wheel_zoom, box_zoom,'
                           u'box_select, resize, reset'),
                   active_scroll=u'wheel_zoom')

# add a hover tool to display words on roll-over
tsne_plot.add_tools( HoverTool(tooltips = u'@word') )

# draw the words as circles on the plot
tsne_plot.circle(u'x', u'y', source=plot_data,
                 color=u'blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color=u'black')

# configure visual elements of the plot
tsne_plot.title.text_font_size = value(u'16pt')
tsne_plot.xaxis.visible = True
tsne_plot.yaxis.visible = True
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None

# engage!
show(tsne_plot);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="18653b2d-a6e0-4a76-beba-6a75f5bc4a0e"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("18653b2d-a6e0-4a76-beba-6a75f5bc4a0e");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("18653b2d-a6e0-4a76-beba-6a75f5bc4a0e");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '18653b2d-a6e0-4a76-beba-6a75f5bc4a0e' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8852b670-925f-4909-9d88-5f0f4df8fb3f":{"roots":{"references":[{"attributes":{},"id":"05199911-560c-4964-aec5-ccd64f42d3a7","type":"LinearScale"},{"attributes":{},"id":"111e582c-18ea-4c69-adbc-db645e0d7a1e","type":"BasicTicker"},{"attributes":{"callback":null,"overlay":{"id":"035c8a9a-17b0-4a97-a586-22845b9d666b","type":"BoxAnnotation"},"plot":{"id":"abfe38af-8ef6-432e-8d71-f55e392cca89","subtype":"Figure","type":"Plot"},"renderers":[{"id":"67098ffb-9270-48a4-9a75-9e8e7757e3ed","type":"GlyphRenderer"}]},"id":"f8d4cdf8-c9a6-487a-b555-35600e54e486","type":"BoxSelectTool"},{"attributes":{"callback":null,"column_names":["y","index","word","x"],"data":{"index":["dashboard","platform","streamline","trigger","channel","b2b","25","earn","moderate","hana","technology-","juniper","rad","order","abac","europe","consultancy","net","netware","bash","scholar","eigrp","tdd","systems","cases","workshops","patterns","involve","aspect","instrumentation","kornshell","prod","assembly","platforms","v","oracle9i","smartphone","contracts","logic","visible","facet","debugged","determination","rich","facility","boeing","skilled","cryptography","stability","verifone","digital","9.2.2","mission","monitor","class","routine","forecast","banking","productive","mssql","monitored","bcbs","field","dimensional","ongoing","iiq","porter","movie","fellows","abbott","literature","macroeconomics","tables","leading","ready","engineers","devices","cost","mclean","pspice","r.h.","formula","stationery","shah","aggregation","linkedin","gsg","mcafee","combine","continued","factories","outcome","ultimately","prospect","phi","recruitment","freshman","60%","applied","diagrams","ha","receipt","tag","competent","reuters","pipeline","camera","regard","ivr","create","9530","formal","bethesda","vlan","craft","central","1999","uk","oim","compete","'s","undergraduate","shipment","apt","centralize","patching","mn","consistent","english","webgate","peripheral","ubuntu","mode","cluster","yarn","bed","clarification","associates","helpdesk","currency","sccm","jaas","tcp","lb","laptop","served","sandy","trade","difficult","customers\u2019","daniel","sop","operating","workforce","actionable","jobs","emc","harness","cad","style","sport","flexible","firefox","rally","statement","abbvie","iit","ssrs","transmittal","right","fest","1986","2009","date","myeclipse","internal","serve","pmi","tb","venue","factor","blackberry","intellij","credential","prototyped","scholars","ace","gemfire","press","ppm","mining","monitoring","unload","chinese","deposit","observation","deloitte","travel","constant","respectively","job","general","institutional","ex","invoke","end","later","2000","inbound","culture","series","scan","2.0","arrangement","winston","odessa","texas","statistic","com","5.7","invite","microservice","gre","receivable","10","6.000","a.","overhaul","leader","vendor","allocation","file","requirement","illustrator","heavy","theory","co","53","shooting","7.5","10g/11","grow","pentaho","converted","resolution","aix","scalability","attract","jd","public","d3.js","hill","ray","\u201913","infrastructure","administered","provide","leadership","tibco","coe","studio","du","r","state","consist","u","brokerage","national","\uf09f","bid","popularity","bulk","inter","employ","eliminate","oracle10","expose","msc","300","wiki","compose","autosys","structured","affect","immigration","invoice","annotation","3345","prediction","webdriver","functioning","amazon","s.","binder","p","abercrombie","prioritize","alignment","sagar","streamlined","coverage","administration","mixture","lighting","intra","transform","nc","solve","kranthi","performed","js","counselor","mechanical","3.6","specified","600","near","dynamodb","noc","7.3","siemens","elementool","load","abroad","jaspersoft","everyday","tight","joseph","6.5","encore","introduction","4.0/4.0","admission","obtain","markets","carrier","shopping","proceeding","ran","simplify","line","plan","fabrication","principal","profit","bureau","apu ...

# %%
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

l=linkage(res2vec.wv.syn0[0:50],method='complete',metric='seuclidean')

plt.figure(figsize=(25,10))
dendrogram(
l,leaf_rotation=0,leaf_font_size=16,orientation='left',leaf_label_func=lambda v:str(res2vec.wv.index2word[v]))
plt.show()

# %%
from sklearn.cluster import KMeans


word_vector = res2vec.wv.syn0
print(int(word_vector.shape[0]/50))
num_clusters = int(word_vector.shape[0]/50)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vector )
# Out:
# 111

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['diagrams', 'abstract', 'diagram', 'sequence', 'engineered', 'swim']
#
# Cluster: 1
# ['hill', 'mcgraw', 'gas', 'oil', 'companies']
#
# Cluster: 2
# ['chain', 'pgp', 'frontend', 'devry', 'keller', 'supply', 'interfaces', 'https']
#
# Cluster: 3
# ['systems', 'macroeconomics', 'alabama', 'mba', 'odessa', 'gre', 'mechanical', '3.6', '4.0/4.0', 'b.a.', 'sociology', '3.9', 'science', 'msis', 'philosophy', 'cs', 'natural', '2018', 'master', 'bloomington', 'mathematics', 'george', 'computer', 'studies', '1985', 'informatics', '16.00', 'ba', 'northern', 'dean', 'angeles', 'artificial', 'georgetown', 'andhra', 'ugrd', 'ohio', 'academy', 'robert', 'physics', 'statistics', 'university', 'distinction', 'chemistry', 'iowa', 'civil', 'engineering', 'b.s', 'gpa', 'cum', 'concentration', 'political', 'berkeley', 'degree', 'economics', 'russia', 'electrical', 'diploma', 'gmat', 'technological', 'communications', 'jntu', 'memphis', 'polytechnic', 'h.', '1995', 'b.s.', 'specialization', 'mason', 'b.e.', 'aas', 'expect', 'animal', '3.3', '12.00', '1991', '3.5', 'indiana', 'ann', 'tn', 'blacksburg', 'ukraine', 'dept', 'technology‐bs', 'm.s.', 'wayne', 'b.e', '2019', 'citation', 'b.', 'cgpa', 'bs', 'totals', 'minor', 'sciences', 'psychology', 'school', 'advancement', 'double', 'bachelor', 'jaypee', 'pennsylvania', 'telecommunication', 'courses', 'b.tech', '3.8', 'summa', 'honors', 'los', '3.4', '3.6/4', 'cumulative', '3.7', 'moscow', 'electronics', '1992', '1994', 'bowie', 'michigan', 'biology', 'graduated', 'arts', 'syracuse', '1993', 'masters', 'maryland', 'indianapolis', 'laude', 'environmental', 'illinois', 'aerospace', 'colorado', 'entrepreneurship', 'graduation']
#
# Cluster: 4
# ['scan', 'virus', 'nessus', 'deficiency', 'mitigation', 'corrective', 'remediation', 'mitigate', 'vulnerability', 'remediate', 'weakness']
#
# Cluster: 5
# ['runtime', 'transfer', 'transmission', 'encryption', 'transmitter', 'secure', 'timeout', '\uf0d8', 'securely', 'inner', 'authenticate', 'protocol', 'reliable', 'udp', 'socket', 'compensate', 'rc4', 'poll', 'layers', 'retransmission', 'authentication', 'decomposition', 'mean', 'datagram', 'unreliable', 'algorithm', 'receiver', 'cryptographic', 'layer']
#
# Cluster: 6
# ['gemfire', '2.0', 'microservice', 'js', 'di', 'esb', 'jersey', 'asynchronous', 'rs', 'xsd', 'soap', 'restful', 'jsps', 'json', 'webservices', 'hibernate', 'theme', 'ilog', 'ajax', 'rest', 'xquery', 'jaxp', 'ws', 'jax', 'jaxb', 'sax', '508', 'consume', 'xslt', 'jquery', 'activemq', 'xpath', 'dom', 'cascading', 'cxf', 'sheets', 'dhtml', 'uddi', 'angular.js', 'jstl', 'aop', 'jasper', 'xml', 'quartz', 'axis', 'webservice', 'wsdl', 'groovy', 'portlets', 'node.js', 'perl', 'binding', 'xsl', 'dojo', 'plsql', 'jpa', 'liferay', 'ext']
#
# Cluster: 7
# ['platform', 'server', 'prod', 'platforms', 'oracle9i', 'logic', '9.2.2', 'ubuntu', 'cluster', 'emc', 'prototyped', 'shooting', '10g/11', 'aix', 'install', 'applications', 'oracle10', 'jboss', '7.0/8.0', 'red', 'bea', 'wordpress', 'bus', 'edition', 'bit', 'hyper', '7.0', 'soa', '2000/2003', '9.2/10.3', 'sever', 'hat', 'coherence', 'sqlserver', 'databases', '11gr1', '8i', '8.1', '6.1', '6.5', 'rhel', 'hosting', '9.x', '5.1', 'virtualization', '11', '2.x', '10.3.x', '10.0', 'alsr', 'wls', '5.x/6.x', 'endeca', 'upgradation', 'deployed', 'blade', 'instal', 'pack', 'window', 'heterogeneous', '9.2mp2', 'redhat', '6.2', 'trouble', 'alfresco', '10', 'upgraded', 'r2', '8/10', 'silent', 'installed', 'administer', 'informix', 'deploying', 'sonic', 'flavor', '8.x', 'integrations', '10.3/11', 'websphere', '6/7', 'was', 'netegrity', 'vmware', 'webmethods', '7', '10.x', 'bpm', 'r3', 'sphere', 'rel', 'sunone', 'ux', 'iis', '10.3', 'linux', 'portal', 'soa11', '7.x/8.x', '11g/12c', 'h', '5.5', 'oc4j', 'tuxedo', '9/10', '5.1/6.0', 'solaris', 'gateway', 'standalone', 'version', '11g/', 'apache', 'pega', '64', 'beta', 'environment', '12.1.3', '6.0', '7.x', 'al', 'eap', 'fail', '8.5.5', '6.1/7.0', 'proxy', '5.x', 'graphtalk', 'suite', 'plumtree', '9i/10g/11', 'solaris10', 'shoot', 'admin', '10gas', 'reverse', '6.x/7.x', 'r12', 'oracle', 'aem', 'ibm', 'servers', 'jar', 'oas', 'gradation', 'troubleshoot', '11.1.1.5', 'clustered', 'clustering', 'centos', 'failover', 'webserver', 'instance', 'gate', '10.2', 'jdk', 'atg', 'glassfish', 'z', 'cot', 'dynatrace', 'war', 'virtual', 'installing', 'packs', '8i/9i/10', 'portals', 'workstation', '4.x', 'host', 'pfizer', 'plug', 'ebusiness', 'siteminder', 'balancing', '9i', 'rdbms', 'sp', '10.3.6', 'suit', '2.2', 'exadata', '9.2/10.0', 'g', '6.x', 'sp3', 'ear', 'instances', '8.1/9.2', 'aqualogic', 'nodes', 'alsb', 'unix', 'amdocs', 'shared', 'middleware', 'vordel', '9.3', 'fusion', 'tomcat', 'portlet', '10.3.5', 'weblogic', 'iplanet', 'upgrading', '24x7', 'os', '12c', 'spatial', '8.5', 'configure', 'clusters', 'configuring', 'fmw', 'windows', '24/7', 'ohs', 'agents', 'domain', 'sun', 'el']
#
# Cluster: 8
# ['dc', 'downtown', 'suburb', 'nearby', 'd.c', 'washington', 'd.c.']
#
# Cluster: 9
# ['3d', 'shadow', 'gear', 'wheel', 'circuit', 'gps', 'techniques', 'microcontroller', 'signal', 'analog', 'transport', 'sensor', 'density', 'traffic', 'rotation', 'alarm']
#
# Cluster: 10
# ['juniper', 'netware', 'eigrp', 'acl', 'telnet', 'tcp', 'ospf', 'catalyst', 'rip', 'intranet', 'switch', 'dell', 'l2/l3', 'cisco', 'rsa', 'firewall', 'ip', 'ipsec', 'nfs', 'rout', 'anti', 'ethernet', 'dns', 'router', 'spam', 'osi', 'routers', 'protocols', 'atm', 'dossier', 'voip', 'igrp', 'bgp', 'smtp', 'relay', 'dsl', 'dmz', 'linksys', 'ftp', 'ids', 'arp', 'vsphere', 'switching', 'http', 'wins', 'novell', 'pop', 'stp', 'vlan', 'cli', 'sftp', 'dhcp', 'forwarding', 'nat', 'vpn', 'routing', 'ssh', 't3']
#
# Cluster: 11
# ['abbott', 'abercrombie', 'lighting', 'holiday', 'mae', 'lake', 'nutrition', 'bagram', 'now', 'organizations', 'money', 'manufacture', 'worldwide', 'sears', 'hospitals', 'ct', 'north', 'denmark', 'carolina', 'world', 'commercial', 'nations', 'de', 'bank', 'baylor', 'mutual', 'western', 'disney', 'trailer', 'georgia', 'automobile', 'mexico', 'ge', 'jp', 'found', 'own', 'electric', 'miami', 'kohl', 'mexican', 'utah', 'american', 'wire', 'locate', 'fitch', 'automotive', 'ia', 'columbus', '4th', 'motor', 'emerson', 'mortgage', 'headquarter', 'japan', '412', 'property', '1983', 'retirement', 'korea', 'history', 'cashier', 'subgroup', 'jpmorgan', 'estate', 'home', 'sell', 'retailer', 'insurance', 'laboratories', '3rd', 'milwaukee', 'airlines', 'manhattan', 'calendar', 'nyc', 'location', 'fannie', 'richmond', 'array', 'ubs', 'hotels', 'bentonville', 'wachovia', 'são', 'australia', 'oh', 'brazil', 'worth', '513', 'nestlé', 'southern', 'bowes', 'family', 'bayer', 'vietnam', 'institution', 'vacation', 'nationwide', 'mwh', 'cincinnati', 'fifth', 'boston', 'cci', 'hsbc', 'philadelphia', 'shanghai', 'paulo', 'subsidiary', 'america', 'monetary', 'gerber', 'france', 'mianyang', 'south', 'fleet', 'pitney', 'china', 'large', 'latin', 'stamford']
#
# Cluster: 12
# ['slt', '7.3', 'fico', 's/4', 'mm', 'fi', 'hana', 'pi', 'bw', 'hec', 'otc', '1.0', '10.1', 'poc', '>', 'mdm', 'integrating', 'pm', 'bpc', 'ecc', 'pp', 'erp', 'sd', '||', 'bo', 'netweaver', 'r/3', 'bi', 'bobi', 'sap', 'scm', 'sum', 'mobility']
#
# Cluster: 13
# ['patching', 'disk', 'cloning', 'restore', 'exp', 'rman', 'snapshot', 'couchbase', 'clone', 'asm', 'triggers', 'routinely', 'cold', 'apex', 'express', 'reorganization', 'standby', 'space', 'guard', 'omni', 'dr', 'db', 'patch', 'opatch', 'disaster', 'index', 'rac', 'backup', 'replication', 'rcu', 'hot', 'pump', 'automatic', 'recovery', 'awr', 'addm', 'loader', 'grid', 'utilities', 'veritas']
#
# Cluster: 14
# ['stationery', 'child', 'underprivileged', 'ngo']
#
# Cluster: 15
# ['propagation']
#
# Cluster: 16
# ['rmi', 'beans', 'mdb', 'applets', 'frameworks', 'bean']
#
# Cluster: 17
# ['tibco', 'jaspersoft', 'businessworks', 'portfolio', 'objects', 'clarity']
#
# Cluster: 18
# ['delivered', 'law', 'modernize', 'enforcement']
#
# Cluster: 19
# ['morgan', 'stanley']
#
# Cluster: 20
# ['hardware']
#
# Cluster: 21
# ['626', 'mclean', 'shah', 'bethesda', 'sandy', '1986', 'winston', '’13', 'joseph', 'alexander', '401', 'rd', 'nj', 'bheema', 'irving', 'college-', 'thomas', '1276', 'chase', '20770', 'daniel', 'prince', 'subramanian', 'maxim', 'contractor-', 'tel', 'kelly', 'rajan', 'silver', 'doe', 'ks', 'kumar', '640', '2020', '09/2014', 'inc', 'va', 'hills', 'paul', '05/2015', 'lane', 'ymca', 'john', 'harris', 'fairfax', 'admissions', 'baltimore', 'kranthi', 'william', 'recreation', 'virginia', 'paradyme', 'orlando', 'pacific', '2014-present', 'ellicott', 'm.d.', 'johnson', 'omega', 'zachary', 'ridge', 'orange', 'parking', 'l.', '09/2013', 'east', 'greenbelt', 'church', 'jumpstart', 'county', 'umbc', 'jane', 'columbia', 'circle', 'delaware', 'cnsi', 'fl', 'andrew', 'ross', 'falls', 'tx', '09/2012', 'mary', '10/2014', '1996', '►', 'aflac', 'tanvi', 'brevard', 'christopher', 'rockville', '2013-present', 'las', 'dallas', 'arlington', 'vegas', 'addison', 'usa', 'meadows', 'newark', 'chevy', 'st.', '1987', 'oxford', 'alexandria', '9111', 'florida', 'prasad', 'singh', '919', '03/2012', 'inc.', 'bothell', 'howard', 'austin', '720', 'terrace', 'tampa', 'factgem', '1989', 'michael', 'chantilly', 'hi', 'montgomery', 'associates', 'seattle', 'llp', 'beach', 'city', 'jared', 'kaiser', 'annapolis', 'edmonston', 'jr.', 'hanoi', 'goldman', 'md']
#
# Cluster: 22
# ['lb', 'rally', 'resolution', 'progress', 'priority', 'outage', 'mantis', 'bug', 'identifying', 'repetitive', 'severity', 'progression', '9.14', 'detect', 'sbm', 'pssm', 'assign', 'triage', 'ticket', 'testrail', 'tracking', 'elementool', 'tickets', 'status', 'inform', 'atlassian', 'step', 'fix', 'logging', 'jira', 'duplicate', 'diagnose', 'ems', 'reproduce', 'tracker', 'mtm', 'screenshot', 'log', 'radar', 'track', 'uploaded', 'redline', 'closure', 'occur', 'rca', 'hpalm', 'until', 'description', 'bugzilla', 'evidence', 'dev', 'defect', 'satisfactory', 'o', 'retest', 'finding', 'viability', 'incident', 'failure', 'workaround']
#
# Cluster: 23
# ['factories', 'connections', 'port', 'adapters', 'threads', 'administered', 'connect', 'queues', 'apps', 'mule', 'wldf', 'bound', 'adaptors', 'generic', 'destination', 'jndi', 'foreign', 'modules', 'topics', 'distributed', 'mq', 'topic', 'mqserie', 'alias', 'configured', 'singleton', 'bridges', 'snmp', 'bridge', 'aq', 'queue', 'xa', 'sources', 'jdbc', 'adapter', 'enrol', 'connection', 'message', 'outbound', 'factory', 'mds', 'pool', 'pools', 'bam', 'stub', 'jms', 'pools/', 'partition', 'concepts', 'wizard', 'boingo', 'authenticator', 'eis', 'jta']
#
# Cluster: 24
# ['girl']
#
# Cluster: 25
# ['c&a', 'nist', '800', '37']
#
# Cluster: 26
# ['bureau', 'census']
#
# Cluster: 27
# ['p6', 'primavera', 'schedule', 'debug']
#
# Cluster: 28
# ['monitoring', 'wily', 'citrix', 'tivoli', 'sitescope', 'autosys', 'measurement', 'pulse', 'nagios', 'scom', 'splunk', 'monitored', 'viewer', 'em', 'analyzer', 'f5', 'managing', 'minder', 'jconsole', 'bac', 'jrockit', 'nortel', 'agent', 'jmeter', 'maestro', 'url', '10,shell', 'works', 'scripting', 'remedy', 'balancer', 'continuously', 'tbs', 'jprobe', 'bmc', 'diagnostics', 'oem', 'fiddler', 'servicenow', 'alert', 'tc', 'introscope', 'patrol', 'proactive', 'ticketing', 'openview', 'samurai']
#
# Cluster: 29
# ['276/277', '5010', 'd', 'icd', 'p', 'ansi', 'edi', 'hl7', '270/271', '837', 'hipaa', 'crosswalk', 'x12', '835', '4010', '834']
#
# Cluster: 30
# ['poa&ms', 'fips', 'pta', 'privacy', 'contingency', 'st&e', 'plans', 'ssp', 'cp', 'poa&m', 'rar', 'action', 'ra', '199', 'scenarios', 'milestones', 'milestone', 'assessment', 'hrci']
#
# Cluster: 31
# ['visit', 'deputy', 'ace', 'volunteer', 'mock', 'workshop', 'career', 'festival', 'organizer', 'msc', 'fair', 'elevator']
#
# Cluster: 32
# ['smoke']
#
# Cluster: 33
# ['scholar', 'technology-', 'fellows', 'literature', 'undergraduate', 'english', 'surat', 'iit', 'scholars', 'chinese', 'a.', 's.', 'deans', 'm.', 'debate', 'electricity', 'shonk', 'collegiate', 'secretary', 'sports', 'village', 'praxis', 'mumbai', 'photography', 'women', 'anne', 'reading', 'nagpur', 'varsity', 'california', 'hunan', 'ukrainian', 'r.', 'father', 'vesit', '2nd', 'french', 'csi', 'mandarin', 'tennis', 'c.', 'srikant', 'fall', 'soccer', 'welfare', 'fr', 'painting', 'swimming', 'sagar', 'society', 'bombay', 'rotary', 'clark', 'football', 'corps', 'pune', 'vellore', 'intramural', 'w.', 'honor', 'manipal', 'dwarkadas', '99', 'national', 'cummins', 'sanghvi', 'beijing', 'speaker', 'arundel', 'standing', 'college', 'interests', 'hobby', 'emerging', 'karnataka', 'maharashtra', 'art', 'council', 'kjsce', 'section', 'f.', 'k.', 'league', '\uf0a8', 'youth', '\u200b-', 'indian', 'pooma', 'portuguese', 'economy', 'hall', 'fluent', 'modern', 'basketball', 'hindi', 'ernst', 'christian', 'somaiya', 'institute', 'p.', 'conversational', 'russian', 'james', 'cricket', 'k.j.', 'rodrigues', 'sustainability', 'atlas', 'autonomous', 'spanish', 'memberships', 'rise', 'j.', 'endowed', 'qualifications', 'men', 'leaders']
#
# Cluster: 34
# ['streamline', 'determination', 'stability', 'cost', '60%', 'eliminate', 'everyday', 'simplify', 'percent', 'bounce', 'increase', '20%', '\uf020', 'loyalty', 'nationalcar.com', '10%', 'reduced', '80%', 'decrease', 'delay', 'save', 'error', 'rate', 'redundancy', 'thereby', 'ecommerce', 'improve', 'cut', '30%', 'unnecessary', 'onboard', 'turnaround', 'overall', 'honda', 'thus', 'reduce', 'turn', 'revamp', 'enhance', 'readability', '75%', 'speed', 'lose', '50%', '12%', 'curtail', 'recover', '15%', 'variance', '40%', 'boost', '25%', 'downtime', 'improved', 'efficiency', 'filtering', 'instrumental', 'half', 'click', 'initiation', 'saving', 'alamo.com', 'standardize', 'intervention', 'tactic']
#
# Cluster: 35
# ['trigger', 'dimensional', 'formula', 'front', 'central', 'mode', 'fms', 'statement', 'invoke', 'file', 'converted', 'expose', 'downstream', 'structured', 'transform', 'near', 'load', 'celerkost™', 'idms', 'relational', 'convert', 'stored', 'systematic', 'ddl', 'configurable', 'populate', 'standardization', 'esri', 'export', 'appraisal', 'hdfs', 'dimension', 'transformation', 'sync', 'gis', 'another', 'pathway', 'old', 'expression', 'beyond', 'bfs', 'constituent', 'mapping', 'screen', 'manipulation', 'setting', 'customized', 'queries', 'fpars', 'delete', 'cube', 'thru', 'used', 'join', 'complicated', 'ota', 'spoe', 'resa', 'mainframe', 'criterion', 'integral', 'batch', 'built', 'flat', 'query', 'pdf', 'dashboards', 'correspond', 'lims', 'reside', 'automatically', 'dcl', 'oltp', 't', 'mypi', 'pds', 'odm', 'data', 'ecybermission', 'reconciliation', 'split', 'fly', 'legacy', 'engine', 'parts', 'tsql', 'executed', 'mulesoft', 'dml', 'then', 'macro', 'into', 'azure', 'bulk', 'replicate', 'utility', 'easily', 'lookup', 'corresponding', 'cleanse', 'orchestration', 'import', 'cfr', 'ranking', 'centralized', 'gui', 'repository', 'publishing', 'dw', 'reporting', 'translation', 'refresh', 'nugenesis', 'label', 'olap', 'onto', 'sensitive', 'tax', '’', 'database', 'read', '2.6', 'vsp', 'tm1', 'mask', 'fetch', 'etl', 'hierarchy', 'validate', 'consolidated', 'dts', 'manually', 'datum', 'copy', 'fact', 'gmsec', 'map', 'calculation', 'amp', 'informatica', 'metadata', 'resonate', 'generator', 'towson', 'completely', 'coded', 'loaded', 'netezza', 'format', 'entity', 'interactive', 'logs', 'integrate', 'powerexchange', 'gccp', 'purge', 'robust', 'migrate', 'extraction', 'conditional', 'warehouse', 'aginity', 'package', 'pull', 'transactional', 'mockup', 'normalization', 'jeppesen', 'graphical', 'powercenter', 'brio', 'function', 'scrub', 'graph', 'caching', 'standardized', 'subscriber', 'powermart', 'crud', 'sybase', 'adhoc', 'reporter', 'balance', 'templates', 'modify', 'text', 'upload', 'insert', 'aggregate', 'thermo', 'character', 'powerful', 'clothing', 'main', 'nfp', 'connectivity', 'inside', 'dynamically', 'retrieval', 'mart', 'segregate', 'automated', 'archive', 'loading', 'backend', 'parser', 'broker', 'edw', 'access', 'table', 'fully', 'procedures', 'judicial', 'purpose', 'extract', 'extremely', 'source', 'contain', 'ods', 'required', 'normal', 'updating', 'combination', 'claims', 'goldengate', 'p.l.a.n.', 'folder', 'codes', 'views', 'compare', 'written', 'app', 'conversion', 'hud', 'adp', 'processing', 'circumstance', 'warehousing', 'disparate', 'extend', 'search', 'universe', 'cubes', 'retrieve', 'cdm', 'feed', 'store', 'extensively', 'schemas', 'real', 'view', 'target', 'teradata', 'separate', 'cas', 'hoc', 'back', 'comet', 'closing', 'schema', 'applicant']
#
# Cluster: 36
# ['abac', '53', 'dynamodb', 'hippa', 'conform', 'watch', 'formation', 'ebs', 'sqs', 'pci', 'elastic', 'cloud', 'ferpa', 'scaling', 'saas', 'aws', 'lambda', 'route', 'rds', 'ecs', 's3', 'sox', 'ec2', 'vpc', 'hybrid', 'iam', 'workspace']
#
# Cluster: 37
# ['patterns', 'rich', '1.2', 'tag', 'bcbs', 'jaas', 'd3.js', 'annotation', '2.1', '1.3', 'toolkit', 'spr', 'cgi', 'j2ee', 'angular', 'xi', 'jsp', 'refactor', 'api', 'mvc', 'html', 'j2se', 'se', 'taglibs', 'orm', '5.0', 'framework', 'servlets', '3.1', 'extjs', 'jdk1.6', 'jsf', 'mongo', 'intensive', 'reusable', 'wireframe', 'persistence', 'css', 'servlet', 'ui', 'javascript', 'faces', 'boot', 'j', 'libraries', 'oo', 'year(s', 'ejb', 'ibatis', 'abap', '1.5', 'icefaces', 'sencha', 'pages', 'awt', '1.7', '1.6', 'tiles', 'struts', 'java', 'boss', 'nodejs', 'bootstrap', 'html5', 'markup', 'css3', 'plugin', 'udb', 'queuing', 'j2me', '1.1', 'angularjs', 'arm', 'odbc', 'ee', 'messaging', 'velocity', 'swings', 'appway', 'responsive', 'swing', 'multithreading', 'spring', 'embedded', 'gwt', 'validator', 'strut', '3.0', 'flex', 'javabeans', 'dao', 'jakarta', '2.5', '1.4', 'ejbs', 'csr', 'xhtml', 'webapps', 'ioc', '2005/2008']
#
# Cluster: 38
# ['dashboard', 'coffee', 'aggregation', 'customers’', 'actionable', 'factor', 'observation', 'basket', 'vehicle', 'issn', 'manipulate', 'accident', 'tayohya', 'advertising', 'temperature', 'car', 'segmentation', 'spend', 'auxiliary', 'periodic', 'expenditure', 'accurate', 'sample', '228', 'brand', 'prevent', 'nation', 'dual', 'waste', 'collected', 'eye', 'news', 'indicator', 'maker', 'manufacturer', 'consolidate', 'age', 'vuser', 'survey', 'earned', 'seasonal', 'quant', 'effect', 'encounter', 'effectiveness', 'layout', 'ir', 'row', 'meaningful', 'category', 'medium', 'friendly', 'conclusion', 'questionnaire', 'filter', 'structural', '\uf0a7', 'compiler', 'door', 'quantity', '100,000', 'publish', 'valid', 'disease', 'characteristic', 'campaign', 'leveraged', 'incidence', 'criminal', 'brief', 'demographic', 'consumption', 'curve', 'output', 'summarize', 'quote', 'display', 'feasible', 'intelligent', 'loop', 'vote', 'r&d', 'nbc', 'trend', 'plot', 'pattern', 'funding', 'kernel', 'habit', 'marketing', 'household', 'forensic', 'l’oreal', 'input', 'explore', 'discount', 'cr', 'clean', 'sale', 'usage', 'scorecard', 'show', 'airport', 'scientist', 'panel', 'worksheet', 'prototype', 'urban', 'algae', 'experiment', 'mine', 'point', 'historical', 'treatment', 'webpage', 'measure', 'research', 'choice', 'graphs', 'polymer', 'promotion', 'bio', 'yearly', 'print', 'square', 'observe', 'biomedical', 'generation', 'bar', 'disposal', 'projection', 'scientific', 'determined', 'visualize', 'philips', 'eat', 'kalman', 'movement', 'consumer']
#
# Cluster: 39
# ['alone', 'stand']
#
# Cluster: 40
# ['gsg', 'r.h.', 'relations', 'ambassador', 'cohort', 'represent', 'african', 'admission', 'students', 'homecoming', 'chapter', 'isa', 'representative', 'affairs', 'alumni', 'body', 'primannum', 'organizing', 'tsan', 'events', 'smith', 'delta', 'is', 'club', 'association', 'chair', 'graduate', 'ascend', 'smsa', 'naamba', 'vice', 'nu', 'president', 'sorority', 'alumnus', 'telecommunications', 'umd']
#
# Cluster: 41
# ['third', 'party']
#
# Cluster: 42
# ['debugged', 'regard', 'deposit', 'specified', 'tight', '90%', 'arise', 'temporary', 'outside', 'concise', 'lease', 'missing', 'guest', 'receive', 'concern', 'discrepancy', '95%', 'activate', 'uptime', 'pay', 'any', 'manner', 'agreement', 'refund', 'notify', 'salary', 'clock', 'timely', '100%', 'appropriately', 'dap', 'far', 'personally', 'without', 'forth', 'question', 'prompt', 'complaint', 'free', 'correct', 'when', 'professionalism', 'arrive', 'remotely', 'volume', 'issue', 'proactively', 'insure', 'keep', 'scr', 'rent', 'tenant', '⃰', 'pertain', 'escalation', 'accurately', 'recur', 'fashion', 'sla', 'indicate', 'smooth', 'return', 'condition', 'satisfaction', 'accordance', 'properly', 'discover', 'necessity', 'adjustment', 'exceed', 'beverage', 'close', 'pick', 'cc', 'earning', 'suggestion', 'register', 'sure', 'requests', 'appointment', 'upper', 'inquiry', 'deduction', 'escalate', 'telephone', 'due', 'important', 'short', 'handover', 'outgoing', 'come', 'most', 'respective', 'respond', 'resolve', 'consistently', 'fee', 'expectation', 'acknowledge', 'if', 'coworker', 'score', 'investigate', 'confirm', 'teller', 'synchronize', 'possible', 'assure', 'kept', 'payment', 'above', 'footprint', 'timeframe', 'pend', 'met', 'opening', 'hurricane', 'desire', 'proper', 'submit', 'miss']
#
# Cluster: 43
# ['cryptography', 'digital', 'sccm', 'certificates', 'acs', 'federated', 'xerox', 'active', 'des', 'cerner', 'kerberos', 'certificate', 'password', 'reset', 'ssl', 'canadian', 'right', 'entitlement', 'trust', 'realm', 'token', 'cert', 'pacs', 'datapower', 'secured', 'renew', 'renewal', 'printing', 'pki', 'license', 'assertion']
#
# Cluster: 44
# ['earn', 'continued', 'outcome', 'ultimately', 'craft', 'compete', 'sport', 'press', 'leader', 'attract', 'du', 'intra', '4,000', 'dream', 'f', 'scout', 'magazine', 'paper', 'coursera', 'excellence', 'e.', 'winner', 'spot', 'accomplishment', 'book', 'hopkins', 'prize', 'rank', 'performer', 'extra', 'elementary', 'received', 'awarded', 'memorial', 'merit', 'tournament', 'performing', 'pitch', 'recognize', 'newspaper', 'race', 'booking', 'achieved', 'letter', 'caci', 'quiz', 'promotional', 'semester', 'young', 'outstanding', 'sergeant', 'participant', 'place', 'scholarship', 'significant', 'marathon', 'en', 'lifestyle', 'camp', 'star', 'contribution', 'academic', 'qualified', 'champion', 'woman', 'exit', 'advertisement', 'appreciation', 'achievement', 'especially', 'l&t', 'rotaract', 'rome', 'medal', '1st', 'brazilian', 'infotech', 'healthy', 'recipient', 'win', 'awards', 'simulations', 'gold', 'play', 'golf', 'white', 'scratch', 'fellowship', 'won', 'peace', 'wall', 'finalist', 'winter', 'award', 'contest', 'second', 'speech', 'twice', '5%', 'abroad', 'competition', 'recognition']
#
# Cluster: 45
# ['receipt', 'shipment', 'cad', 'transmittal', 'general', 'inbound', 'receivable', 'vendor', 'contracts', 'ledger', 'elements', 'fiber', 'eco', 'material', 'entry', 'agreements', 'livelink', 'optical', 'bill', 'shipping', 'completeness', 'bom', 'taleo', 'fulfillment', 'buyer', 'shop', 'expense', 'fedex', 'purchasing', 'invoicing', 'invoice', 'drm', 'journal', 'paperwork', 'edms', 'dealer', 'supplier', 'invoices', 'correctly', 'po', 'inventory', 'blue', 'archiving', 'billing', 'sheet', 'orders', 'approve', 'pertinent', '3pl', 'ecr', 'submittal', 'freight', 'inventori', 'item', 'sales', 'rfi', 'extension', 'procurement', 'keeping', 'permit', 'disconnect', 'binder', 'damage', 'schematic', 'ariba', 'kronos', 'correspondence', 'bpp', 'brochure', 'scanning', 'stock', 'purchase', 'filing', 'subcontract', 'reconcile', 'payable', 'notice', 'expedite', 'accounts', 'merchandise', 'reviewed', 'materials', 'catalog', 'indexing', 'drawing', 'tie', 'origin', 'fax', 'assemble', 'outline', 'storage', 'conformance', 'wms', 'bookkeeping', 'updated', 'ups']
#
# Cluster: 46
# ['combine', 'visualization', 'dataset', 'column', 'decision', 'unstructured', 'huge', 'parse', 'making', 'useful', 'original', 'intuitive', 'dive', 'big', 'deep', 'draw', 'valuable', 'insight', 'interesting']
#
# Cluster: 47
# ['forecast', 'prospect', 'opportunity', 'advise', 'bid', 'employ', 'alignment', 'profit', 'anticipate', 'remain', 'buy', 'augment', 'rental', 'sourcing', 'proposal', 'revenue', 'freddie', 'figure', 'segment', 'valuation', 'value', 'term', 'incorporated', 'tactical', 'consult', 'executable', 'merger', 'option', 'competitive', 'debt', 'corporate', 'direction', 'initiative', 'acquisition', 'align', 'alliance', 'entrepreneur', 'engagement', 'knowledgeable', 'competency', 'strategic', 'price', 'theater', 'implication', 'recommend', 'staffing', 'organization', 'company', 'industry', 'propose', 'pricing', 'quarterly', 'share', 'recommendation', 'strategy', 'usd', 'transformational', 'sized', 'appliance', 'market', 'expand', 'dso', 'sustainable', 'reimbursement', 'excess', 'm&a', 'presence', 'proposition', 'disclosure', 'roi', 'bike', 'contribute', 'roadmap', 'launch', 'suitable', 'spending', 'advised', 'promise', 'objective', 'agree', 'margin', 'fiscal', 'advantage', 'future', 'ea', 'toward', 'position', 'maximize', 'long', 'lean', 'operational', 'acquire', 'partnership', 'growth', 'offering', 'similar', 'demand', 'incur', 'threat', 'goal', 'infertility', 'quarter', 'ideal', 'competitor', 'profitability']
#
# Cluster: 48
# ['scalability', 'middle', 'mid', 'tier', 'architecture', 'fdic', 'link']
#
# Cluster: 49
# ['deadlock', 'gc', 'root', 'leak', 'isolate', 'exception', 'count', 'cause', 'idle', 'leaks', 'dump', 'fine', 'diagnostic', 'tuning', 'heap', 'thread', 'lock', 'collection', 'stack', 'frequently', 'jvm', 'fixing', 'cpu', 'size', 'crash', 'garbage', 'narrow', 'sga', 'trace', 'tune', 'dumps', 'memory', 'adjust', 'hang', 'bottleneck', 'malformed', 'sizes', 'find']
#
# Cluster: 50
# ['rad', 'tdd', 'mssql', 'myeclipse', 'intellij', 'series', 'wiki', 'jbuilder', 'mockito', '9i/10', 'wsad', 'xcode', 'jee', 'harvest', 'sit', 'uml', 'driven', 'cucumber', 'cygwin', '3.2', 'config', 'coldfusion', 'quest', 'testng', 'rcp', 'svn', 'db2', 'sdkman', 'putty', 'eclipse', 'hook', 'aqua', 'filezilla', '4.2', 'log4j', 'rose', 'artisan', 'perforce', 'confluence', 'subversion', 'charles', '2000/', 'jdeveloper', 'sdk', 'clear', 'hpqc', 'jaws', 'builder', 'winscp', '12.5', 'logo', 'ant', 'nexus', 'soapui', 'junit', 'cruise', 'starteam', 'jmock', 'adb', 'firebug', 'github', 'drools', 'sts', 'galileo', 'ide', 'maven', 'netbeans', 'cvs']
#
# Cluster: 51
# ['nine']
#
# Cluster: 52
# ['united', 'states']
#
# Cluster: 53
# ['ssrs', 'pentaho', 'answer', 'mongodb', 'ssis', 'postgresql', 'ssas']
#
# Cluster: 54
# ['smartphone', 'toolbox', 'camera', 'ivr', 'peripheral', 'bed', 'laptop', 'blackberry', 'com', 'rajvkk@yahoo.com', 'shopping', 'maximo', 'credit', 'gift', 'mobile', 'interruption', 'must', 'incom', 'cable', 'anywhere', 'unclassified', 'machine', '∙test', 'inspector', 'plane', 'ab', 'cat', 'ipad', '⦁', 'iot', 'fault', 'mainly', 'controller', 'match', 'me', 'ordering', 'processor', 'intend', 'note', 'iphone', 'activation', 'broadband', 'projector', 'aware', 'printer', 'debit', 'chat', 'epic', 'stations', 'circuits', 'desktop', 'mail', 'modem', 'ring', 'sms', 'video', 'either', 'surveillance', 'reader', 'ride', 'devices', 'ncr', 'magnetic', 'wireless', 'consider', 'injection', 'weight', 'emulator', 'walmart', 'attach', 'wallet', 'thousand', 'appium', 'samsung', 'swap', 'mount', 'chip', 'pos', 'machines', 'vr', 'verifone', 'scanner', 'terminal', 'handheld', 'skin', 'android', 'limit', 'dos', 'card', 'bind', 'meter', 'reward', 'troubleshot', 'device', 'ic', 'emv', 'pc', 'counter', 'operator', 'cards', 'ios', 'ingenico', 'x', 'controllers', 'phone', 'repair', 'accessibility', 'difference', 'touch', 'native', 'heat', 'signature', 'checkout', 'mathematical', 'voice', '8051', 'audio', 'equipment', 'motion', 'bluetooth', 'encore', 'bitbyte', 'id', 'kind', 'ghost', 'tablet', 'compatible', 'thing', 'apple', 'pwm', 'photo', 'banyan', 'adele', 'stripe', 'attachment']
#
# Cluster: 55
# ['monitor', 'with', 'class', 'routine', 'field', 'audited', 'create', 'operating', 'style', 'internal', 'respectively', 'job', 'end', 'allocation', 'provide', 'consist', 'affect', 'performed', 'ran', 'line', 'plan', 'occasion', 'nightly', 'appropriate', 'an', 'ensure', 'activity', 'underlie', 'depend', 'reference', 'created', 'operation', 'periodically', 'time', 'procedure', 'that', 'use', 'against', 'minimal', 'recent', 'testing', 'implemented', 'assignment', 'performance', 'follow', 'review', 'which', 'include', 'manual', 'checklist', 'a', 'listen', 'group', 'request', 'perform', 'setup', 'distribute', 'element', 'policy', 'exist', 'different', '3.50', 'establish', 'accordingly', 'execution', 'notification', 'while', 'the', 'check', 'easy', 'cod', 'client', 'developed', 'workgroups', 'release', 'timeline', 'area', 'internet', 'later', 'revision', 'vob', 'good', 'level', 'cq', 'handling', 'change', 'type', 'assist', 'session', 'product', 'program', 'profile', 'maintain', 'rule', 'edit', 'team', 'updates', 'common', 'tool', 'publication', 'permission', 'solution', 'by', 'application', 'responsible', 'capture', 'regular', 'validation', 'page', 'deploy', 'run', 'complete', 'detail', 're', 'open', 'interface', 'final', 'order', 'during', 'custom', 'one', 'standard', '\ue00c', 'prior', 'modification', 'each', 'unit', 'case', 'etc', 'automate', 'compilation', 'form', 'attribute', 'and/or', 'available', 'efficient', 'sort', 'retrofit', 'simultaneous', 'external', 'at', 'searching', 'inclusion', 'make', 'and', 'this', 'leverage', 'defined', 'generate', 'control', 'update', 'on', 'verify', 'throughout', 'meet', 'task', 'trc', 'multi', 'introduce', 'reflect', 'new', 'relate', 'component', 'workflow', 'artist', 'test', 'such', 'content', 'ownership', 'menu', 'accommodate', 'get', 'system', 'scalable', 'cover', 'disseminate', 'prepare', 'naming', 'supplementary', "'s", 'side', 'for', 'basis', 'drive', 'document', 'these', 'implement', 'late', 'complex', 'prepared', 'e.g.', 'feature', 'capability', 'interact', 'driver', 'email', 'enable', 'dependent', 'like', 'dynamic', 'post', 'guide', 'transaction', '●', 'example', 'of', 'interaction', 'upon', 'specify', 'internationalization', 'deliverable', 'physician', 'deletion', 'resource', 'necessary', 'between', 'account', 'as', 'i.e.', 'across', 'high', '∙', 'in', 'work', 'date', 'functionality', 'or', 'utilize', 'vital', 'multiple', 'add', 'compliant', 'non', 'flow', 'compile', 'code', 'inconsistency', 'service', 'set', 'every', 'binary', 'stream', 'login', '’s', 'template', 'within', 'build', 'baseline', 'threshold', 'address', 'customer', 'manager', 'library', 'newly', 'recordkeeping', 'cross', 'base', 'compliance', 'help', 'presentation', 'addition', 'design', 'consistency', 'both', 'wide', 'modified', 'successfully', 'web', 'execute', 'frequent', 'to', 'part', 'customize', 'handle', 'allocate', 'user', 'communicate', 'availability', 'develop', 'involve', 'report', 'apply', 'author', 'kranthikbheema@gmail.com', 'put', 'specific', 'send', 'various', 'approval', '\uf06e', 'process', 'enhancement', 'up', 'be', 'daily', 'allow', '-PRON-', 'critical', 'popular', 'need', '02/10/2012', 'all', 'accord', 'online', 'applicable', 'from', 'wrote', 'along', 'write', 'project', 'enforce', 'several', 'ahead', 'apigee', 'record', 'ease', 'through', 'per', 'many', 'module', 'site', 'monthly', 'require', 'rewrite', 'checkpoint', 'method', 'documentation', 'coordinate', 'whenever', 'well', 'response', 'some', 'deliver', 'manage', 'integrity', 'also', 'directly', 'other', 'way', 'via', 'evaluation', 'list']
#
# Cluster: 56
# ['planner']
#
# Cluster: 57
# ['porter', 'movie', 'random', 'harness', 'popularity', 'prediction', 'mixture', 'reliability', 'er', 'roc', 'formulation', 'models', 'conjoint', 'sentiment', 'predictive', 'bayes', 'verification', 'model', 'sensitivity', 'classification', 'stress', 'probability', 'choose', 'cuisine', 'linear', 'trees', 'cleansing', 'nature', 'nn', 'profiling', 'birth', 'negative', 'knn', 'anova', 'facebook', 'variable', 'ingredient', 'naïve', 'statistical', 'usability', 'election', 'dbms', 'tone', 'mining', 'cart', 'vector', 'neural', 'glm', 'generalized', 'decisions', 'predict', 'optimization', 'regression', '1900', 'logistic', 'confidence', 'localization', 'biweekly', 'hughes', 'churn', 'forecasting', 'interval', 'exploratory', 'classify', 'diamond', 'accuracy', 'presidential', 'boundary', 'static', 'stores', 'preference', 'wine', 'sanity', 'modelling', 'hypothesis', 'descriptive', 'forest']
#
# Cluster: 58
# ['webdriver', 'qtp', '12.0', 'uft', 'loadrunner', 'mercury', 'qc', 'hp', 'silk', 'runner', 'rail', 'automation', 'selenium', '11.5', '11.0', 'winrunner', 'vugen', 'rc', '8.2', 'alm']
#
# Cluster: 59
# ['2015', 'mar.', '1999', 'mn', '2009', 'september', 'jan', '2006', 'jul', '06', 'nov', 'august', '1997', '2004', 'ny', '1998', '2012', 'mo', '2015-present', 'system’', '2011-may', 'dec.', 'oct', 'suitland', '2008-', '07', '2011-', 'sep', 'apr', 'aug.', '2016', 'october', 'aug', '2013-may', '2014-', '04', '03', '2017-', 'oct.', 'minneapolis', 'july', '2016-', 'ma', '08', '2005', '2008', '2011', '–may', '09', 'april', 'york', '2001', 'louis', '\uf0f2', 'mar', '2013', '2016-present', 'sept', 'till', '2017', 'february', 'reston', '2015-', '~', 'may', '2007', '2015-august', '2002', 'january', 'project-', '2014-august', '2003', 'november', 'december', 'jan.', '2014', '2010', '2015-dec', '2012-', 'hyderabad', 'jun', 'june', '02', '2013-', '2016-may', '01', 'sept.', 'march', 'dec', '95', 'kansas', '2014-may', '’12', 'feb', 'jun.']
#
# Cluster: 60
# ['net', 'v', 'visible', 'powerpoint', 'tables', 'mcafee', 'jobs', '2000', 'illustrator', 'studio', 'light', 'xp', 'powershell', 'odi', 'plus', 'adaptive', 'quickbooks', 'designer', 'mobizen', 'adobe', '4.0', 'asp.net', 'flash', 'rup', 'vb', 'abode', 'pro', 'crystal', 'vba', 'suites', 'vb.net', 'wcf', 'nt', '97', 'c#.', 'visual', 'macintosh', 'asp', 'spy', 'cobol', 'word', '365', 'vss', 'clearquest', 'telerik', 'dfc', 'explorer', 'reports', 'ultra', 'ooad', 'cics', 'graphic', 'classic', 'vs', 'symantec', 'macromedia', 'forms', 'ware', 'captivate', 'rational', 'antivirus', 'vista', 'microstrategy', 'docs', 'sql', 'navigator', 'cots', 'paint', 'arcgis', 'composer', 'netscape', 'dynamics', 'intuit', 'powerbuilder', 'acrobat', 'sql*plus', 'files', 'oracle11', 'pl', 'avaya', 'tools', 'basic', 'jcl', 'visio', 'vms', 'photoshop', 'proficient', 'requisite', 'siebel', 'pro*c', 'microsoft', 'ssi', 'charts', 'infopath', 'mf', 'c#.net', 'sharepoint', 'axure', 'pvcs', 'erwin', 'mvs', 'studios', 'vbscript', '2000/xp', 'imaging', 'caliber', '.net', 'office', 'dreamweaver', 'frontpage', 'outlook', 'serena', 'documentum', 'ms', 'graphics', 'ver', 'toad', 'packages', 'snagit', '4.5']
#
# Cluster: 61
# ['6.000', 'introduction', 'comm', 'compression', 'i', 'networks', 'calculus', 'coursework', '3.00', 'math', '4.00', 'structures', '0.00', 'comp', 'cmsc', 'b', 'discrete', 'ctec', 'io', 'intro', 'algorithms', '9.000', '12.000', 'argument', 'theory', 'engl', 'ss']
#
# Cluster: 62
# ['iiq', 'ha', 'reuters', 'oim', 'webgate', 'oam', 'privilege', 'synchronization', 'discoverer', 'webcenter', 'oaam', 'opensso', 'ofsll', 'connector', 'idam', 'vm', 'odsm', 'console', 'xpress', 'sandbox', 'sso', 'rib', 'federation', 'accessgate', 'terminate', 'oif', 'products', 'owsm', 'odsee', 'cramer', 'sign', 'isam', 'provisioning', 'oes', 'obiee', 'rms', 'rpm', 'disable', 'publisher', 'roles', 'single', 'directory', '11gr2', 'ldap', 'unlock', 'saml', 'idm', 'provision', 'sim', 'ucm', 'oig', 'icloud', '7.1', 'plugins', 'rbac', 'sailpoint', 'adf', 'ps3', 'manger', 'identity', 'workflows', 'oud', 'tfim', 'spml', 'oid', 'ad', 'rpd', 'ps2', 'ovd']
#
# Cluster: 63
# ['facet', 'engineers', 'eligibility', 'tb', 'ex', 'overhaul', 'public', 'state', 'immigration', 'obligation', 'carrier', 'isr', 'division', 'department', 'medicaid', 'cms', 'authorize', 'airline', 'fsa', 'hhs', 'government', 'grant', 'wise', 'interpreter', 'portion', 'court', 'cncs', 'health', '21', 'compensation', 'medical', 'courts', 'interior', 'citizenship', 'sec', 'claim', 'nec', 'defense', 'air', 'epa', 'army', 'nara', 'medicare', 'primarily', 'provider', 'financial', 'faa', 'researcher', 'federal', 'u.s.', 'veteran', 'doc', 'govt', 'amsd', 'agencies', 'contractual', 'gsa', 'official', 'reserve', 'military', 'eac', 'manpower', 'webnas', 'doj', 'employer', 'contract', 'geospatial', 'un', 'cbs', 'feeder', 'osha', 'citizen', 'occupational', 'dental', 'representatives', 'modernization', 'attorney', 'blood', 'population', 'headquarters', 'clearing', 'accrual', 'barney', 'u.', 'dod', 'electronic', 'commerce', 'benefit', 'chamber', 'transportation', 'house', 'care', 'accountable', 'regulation', 'ndms', 'hospital', 'nasa', 'union', 'ehr', 'alza', 'european', 'servicing', 'aviation', 'asian', 'naval', 'ccr', 'force', 'comply', 'seat', 'laser', 'patient', 'legal', 'novel', 'us', 'tsp', 'portability', 'fraud', 'records', 'liability', 'branding', 'safety', 'usaid', 'irs', 'prime', 'enrollment', 'isrweb', 'agency', 'agriculture', 'flight', 'economic', 'loan', 'homeland', 'joint', 'tsa', 'accounting', 'justice', 'navy', 'idiq', 'usda', 'police', 'dot', 'therapy', 'u.s', 'civilian', 'housing', 'clinical', 'clinic', 'uspto', 'payer', 'mandate', 'healthcare', 'rfp', 'bnym', 'district', 'rehabilitation', 'principles', 'subsystem', 'centers', 'cfs', 'dex', 'disability', 'pension', 'focu', 'fda', 'tpocs']
#
# Cluster: 64
# ['reduction', 'mirror', 'partial', 'scheme', 'complexity', 'sponsor', 'iterative', 'stitching', 'embed', 'ofdm', 'extreme', 'pts', 'frame', 'ieee', 'transmit', 'minimize', 'image', 'pair', 'grouping']
#
# Cluster: 65
# ['adwords', 'google', 'analytics', 'maps']
#
# Cluster: 66
# ['simulation', 'productivity', 'based', 'upk', 'kit']
#
# Cluster: 67
# ['downlink', 'preliminary', 'gsm', 'lte', 'microwave', 'simulator', 'poseidon', 'interference', 'ericsson', '\xad', 'pcs', 'planet', 'cell', '3-sectored', 'station', 'simulate', 'mentum', '5.7', 'rf', 'cellular', 'wcdma', 'umts', 'cdma', 'wimax']
#
# Cluster: 68
# ['comparison']
#
# Cluster: 69
# ['emerge']
#
# Cluster: 70
# ['stearns', 'bear']
#
# Cluster: 71
# ['cache']
#
# Cluster: 72
# ['europe', 'banking', 'currency', 'trade', 'travel', 'institutional', 'firm', 'brokerage', 'markets', 'bloomberg', 'petty', 'generalist', 'cash', 'wealth', 'strategist', 'patent', 'asia', 'iq', 'hotel', 'investment', 'africa', 'raw', 'globe', 'diligence', 'trail', 'country', 'finra', 'marketplace', 'fx', 'hospitality', 'eu', 'equities', 'retail', 'fidessa', 'surplus', 'ase', 'americas', 'equity', 'dealing', 'nasdaq', 'income', 'sector', 'region', 'trading', 'trader', 'deal', 'fixed', 'instrument', 'floor', 'belzberg', 'satellite', 'funds', 'treasury', 'ita', 'cantor', 'futures', 'nyse', 'l', 'capital', 'securities', 'asset', 'interfac', 'financing', 'symposium', 'settlement', 'finish', 'oats', 'global', 'domestic', 'commodity', 'dedicated', 'international', 'manufacturing', 'globally', 'continuity', 'lending', 'swift', 'bond', 'oms', 'derivative', 'metal']
#
# Cluster: 73
# ['docker', 'container']
#
# Cluster: 74
# ['assembly', 'r', 'amazon', 'virtualbox', 'languages', 'hub', 'languag', 'itsm', 'client-', 'pspice', 'solvertable', 'embarcadero', 'twitter', 'cloudera', 'mapreduce', 'precisiontree', 'lucidchart', 'tableau', 'prolog', 'macros', 'modeler', 'lucid', 'arduino', 'proteus', 'c++', 'autodesk', 'solver', 'tree', 'stattools', 'php', 'drupal', 'programmed', 'lynda.com', 'pivot', 'mysql', 'tracer', 'programming', 'palisade', 'stata', 'packet', 'minitab', 'c', 'verilog', 'neo4j', 'wireshark', 'hbase', 'sas', 'language', 'creo', 'salesforce', 'paradigm', 'workbench', 'advanced', 'computing', 'familiar', 'spark', 'keil', 'matlab', 'jmp', 'jigsaw', 'inventor', 'robot', 'beginner', 'hadoop', 'impala', 'pcb', 'stat', 'django', 'python', 'proficiency', 'nosql', 'ocaml', 'sqoop', 'precision', 'rstudio', 'vlsi', 'ruby', 'glimmix', '@risk', 'methods', 'media', 'tobii', 'salesforce.com', 'cypher', 'pig', 'spss', 'simulink', 'hive', 'arena', 'skills', 'excel', 'bluemix', 'autocad', 'miscellaneous', 'parametric']
#
# Cluster: 75
# ['invite', 'chicago', 'il', 'arcelormittal']
#
# Cluster: 76
# ['ready', 'will', 'less', 'grow', 'apus', 'volunteering', 'smoothly', 'symbol', 'children', 'imagery', 'ever', 'those', 'who', 'treat', 'previous', 'boarding', 'hunter', 'premier', 'pediatric', 'couple', 'depict', 'download', 'almost', 'illustrate', 'donate', 'already', 'ne', 'continue', 'conway', 'catch', 'mark', 'early', 'move', 'employment', 'visa', 'whether', 'no', 'fill', 'beacon', 'y', 'begin', 'want', 'tenure', 'pass', 'title', 'still', 'dr.', 'finally', 'extinguisher', 'certain', 'look', 'patrick', 'feel', 'voltage', 'but', 'same', 'amount', 'would', 'go', 'soldier', 'select', 'willing', 'last', 'permanent', 'once', 'info', 'where', 'period', 'trp', 'divide', 'since', 'today', 'harvard', 'replace', 'first', 'before', 'know', 'seller', 'previously', 'dla', 'navigate', 'relocate', 'replacement', 'just', 'out', 'mix', 'accept', 'currently', 'kyc', 'could', 'man', 'bag', 'baptist', 'again', 'interest', 'there', 'hour', 'farm', 'hope', 'doctor', 'next', 'korean', 'immediate', 'residency', 'mantech', 'poi', 'leave', 'do', 'not', 'least', 'always', 'become', 'onboarding', 'should', 'tea', 'outsourced', 'so', 'how', 'only', 'what', 'take', 'timesheet', '24', 'here', 'hanover', 'after', 'lot', 'blog', 'commander', 'have', 'say', 'jump', 'congress', 'can', 'correction', 'please', 'forward']
#
# Cluster: 77
# ['horizontal', 'vertical']
#
# Cluster: 78
# ['death', 'cdc']
#
# Cluster: 79
# ['channel', 'statistic', 'coverage', 'call', 'frequency', 'surround', 'detector', 'metro', 'fulfill', 'drop', 'power', 'parameter', 'strength', 'off', 'path', 'shelf', 'loss', 'antenna', 'calculate', 'bsc', 'avoid', 'compute', 'handled', 'block', 'tilt', 'amongst', 'optimum', 'down', 'fade', 'number', 'reuse', 'insertion']
#
# Cluster: 80
# ['25', 'arrangement', '300', '600', '40', 'collect', 'donation', 'm', '$', 'wafer', 'bpa', 'ball', 'thirty', 'hundred', '200', 'years’', '2', '70', 'total', '140', 'million', '1,000', 'attendee', '1200', 'more', '250', '4', 'catalogue', '60', '100', 'ten', 'roughly', 'span', '1500', '300,000', 'minimum', 'seven', '350', 'iteration', '9', '13', 'k', 'day', 'crime', 'conclude', '15', '5000', 'average', 'affiliate', 'approximately', '34', '12', 'around', 'year', '10,000', 'five', '6000', 'nearly', '20,000', '45', 'seamless', 'two', '23', '500,000', 'twenty', 'olympics', '550', 'spearhead', '8,000', '1000', '1', 'below', 'demonstration', 'inspect', 'dozen', 'dollar', '▪', '30', '90', 'month', 'raise', 'name', 'fortune', '3', '6', '+', 'comprising', 'seed', '30,000', '5', 'three', '150', 'embassy', '18f', 'over', 'six', 'comprise', '50', '400', '80', 'than', 'matching', 'billion', '35', '75', '700', 'comment', '450', 'gym', '65', 'running', '20', '120', '500']
#
# Cluster: 81
# ['break']
#
# Cluster: 82
# ['phi', 'fraternity', 'kappa', 'alpha', 'sigma']
#
# Cluster: 83
# ['spreadsheet']
#
# Cluster: 84
# ['co', 'noc', 'ordinate', 'week', '32', 'charity', '16', 'founder', 'few', 'scrum', 'organic', 'unity', '8', 'under', 'fitness', '14', 'geographically', 'concert', 'op', 'colleague', 'wellness', 'fund', 'cox', 'warner', 'founding', 'ordination', 'safe', 'foster', 'comcast', 'cto', 'camper', 'promote', 'closely', '98']
#
# Cluster: 85
# ['b2b', 'bpel', 'composite', 'osb', 'mediator', 'rules']
#
# Cluster: 86
# ['gm', 'detroit', 'mi', 'eds', 'warranty']
#
# Cluster: 87
# ['black', 'box']
#
# Cluster: 88
# ['cases', 'aspect', 'ongoing', 'applied', 'workshops', 'consistent', 'sop', 'credential', 'heavy', 'infrastructure', 'coe', 'administration', 'rapid', 'integration', 'conjunction', 'followed', 'roll', 'requirements', 'discovery', 'initial', 'production', 'dba', 'developer', '○', 'coordination', 'mlds', 'understanding', 'msde', 'consolidation', 'uat', 'auditing', 'managerial', 'role', 'parallel', 'sayyad', 'pilot', 'datacenter', 'ftd', 'prototyping', 'development', 'upgrade', 'mgmt', 'emphasis', 'director', 'stag', 'onshore', 'inception', 'core', 'd.b.a.', 'teams', 'architectural', 'collaboration', 'oversee', 'live', 'cbt', 'negotiation', 'carry', 'customers', 'spirent', 'center', 'relation', 'cognos', 'environments', 'debugging', 'troubleshooting', 'intelligence', 'vast', 'management', 'crp', 'repeatable', 'enhanced', 'comprehensive', 'ood', 'technology', 'premise', 'identification', 'facilitate', 'super', 'responsibilities', 'undertaken', 'gathering', 'reviews', 'implementation', 'methodologies', 'mrp', 'rttt', 'modular', 'wave', 'concept', 'definition', 'processes', 'maintenance', 'hand', 'phase', 'endur', 'supported', 'software', 'designing', 'stlc', 'sow', 'expert', 'existing', 'lab', 'methodology', 'proof', 'projects', 'quality', 'agile', 'incorporate', 'cutover', 'installation', 'plm', 'migration', 'experienced', 'practice', 'entire', 'staging', 'vault', 'coding', 'tiered', 'ppm', 'hw', 'dpscs', 'whole', 'qa', 'involved', 'focus', 'related', 'full', 'verse', 'lead', 'traditional', 'unified', 'involvement', 'tasks', 'integrator', 'varied', 'stage', 'specifications', 'rollout', 'balanced', 'extensive', 'upgrades', 'major', 'e', 'capacity', 'areas', 'scale', 'sw', 'prioritization', 'adoption', 'sizing', 'workload', 'support', 'packaging', 'architected', 'object', 'pioneer', 'developers', 'enterprise', 'sdlc', 'centric', 'governance', 'selection', 'writing', 'demos', 'e2e', 'sub', 'rice', 'creation', 'mr.', '/contribution', 'lifecycle', 'clients’', 'hands', 'sqa', 'effort', 'sites', '3-tier', 'relocation', 'offshore', 'workday', 'technical', 'entrepreneurial', 'orpos', 'uperform', 'transition', 'repeat', 'proprietary', 'openlink', 'waterfall', 'intel', 'specialize', 'demo', 'knowledge', 'delivery', 'business', 'conceptual', 'encompass', 'life', 'integrated', 'oriented', 'users', 'managed', 'pre', 'customization', 'working', 'enablement', 'cycle', 'ewm', 'sme', 'readiness', 'concurrent', 'prism', 'experience', 'oop', 'numerous', 'configuration', 'strategies', 'wramc', 'specifically', 'modeling', 'redesign', 'planning', 'preparation', 'training', 'tackle', 'accountability', 'expertise', 'ooa', 'tar', 'mechanic', 'formal', 'deployment', 'led']
#
# Cluster: 89
# ['innovation']
#
# Cluster: 90
# ['ipv6', 'ipv4']
#
# Cluster: 91
# ['skilled', 'mission', 'competent', 'difficult', 'flexible', 'orient', 'solve', 'creativity', 'learner', 'posses', 'excellent', 'challenge', 'supervisory', 'discipline', 'interpersonal', 'individually', 'educate', 'thinking', 'flexibility', 'effective', 'collaborative', 'variety', 'adaptable', 'quick', 'towards', 'enjoy', 'bring', 'further', 'communication', 'sound', 'round', 'yet', 'see', 'savvy', 'motivated', 'skill', 'technically', 'solid', 'succeed', 'possess', 'progressive', 'hard', 'productive', 'learn', 'gain', 'passion', 'positive', 'rapidly', 'quickly', 'exceptional', 'challenging', 'hardwork', 'simultaneously', 'respect', 'influence', 'ability', 'starter', 'keen', 'capable', 'seek', 'consensus', 'prove', 'stable', 'ethic', 'often', 'pace', 'diverse', 'communicator', 'motivation', 'effectively', 'problem', 'obstacle', 'commitment', 'proven', 'dedicate', 'independently', 'acuman', 'very', 'creative', 'aptitude', 'persuasive', 'highly', 'grasp', 'hovercraft', 'commit', 'strong', 'deadline', 'innovative', 'kid', 'idea', 'motivate', 'attitude', 'fast', 'verbal', 'accomplish', 'attention', 'conflict', 'strict', 'simple', 'efficiently', 'oral', 'teamwork', 'player', 'success', 'self', 'pressure', 'broad', 'practical', 'great', 'luther', 'offer', 'demonstrate', 'choi', 'references', 'articulate', 'adapt', 'think', 'analytical', 'adaptability', 'able']
#
# Cluster: 92
# ['diego', 'san', 'francisco']
#
# Cluster: 93
# ['bash', 'kornshell', 'unload', 'timesten', 'architect', 'latency', 'oss', 'low', 'bss', 'throughput', 'interim', 'erd', 'physical', 'logical', 'datastage', 'yarn', 'solr', 'spool', 'wm', 'scala', 'cassandra']
#
# Cluster: 94
# ['lan', 'wan']
#
# Cluster: 95
# ['linkedin', '9530', 'ray', 'u', '\uf09f', '3345', 'reiz', '20740', '7843', 'knox', 'ph', '368', '860', '8125', '=', 'park', 'zgoldman@terpmail.umd.edu', '443', '48th', '571', 'street', '318', '201', '825', '292', '■', '240', 'apt', '310', '224', '3412', 'rowalt', 'mailing', '|', '520', '3102920250@pm.sprint.com', '301', 'potomac', '0250', '♦', 'txt', 'hyattsville', 'st', 'tulane', 'quail', 'road', 'http://daveray.net', 'david', '101', 'rhode', '360', '410', '638', 'ave', '330', '202', 'murphy', 'n', '469', '703', '262', '1660', 'island', '305', '323', '864', '4324', '422', '75094', '\x97\uf097', '20783', '702', 'avenue']
#
# Cluster: 96
# ['cultural']
#
# Cluster: 97
# ['accenture']
#
# Cluster: 98
# ['clarification', 'requirement', 'give', 'picture', 'prioritize', 'refer', 'overlap', 'contributed', 'aim', 'refine', 'cio', 'improvise', 'adept', 'approach', 'brd', 'context', 'analyse', 'conduct', 'current', 'conducted', 'qualitative', 'scenario', 'wbs', 'culture', 'relationship', 'backlog', 'evolve', 'ยง', 'identified', 'estimation', 'construct', 'perspective', 'detailed', 'owner', 'mapbox', 'impact', 'shape', 'invest', 'situation', 'analyze', 'formulate', 'visibility', 'rating', 'quantitative', 'describe', 'classmate', 'engage', 'behavior', 'sat', 'dependency', 'technique', 'suggest', 'scope', 'examine', 'results', 'guidance', 'explain', 'utilization', 'jad', 'particular', 'elicit', 'feedback', 'geographical', 'unique', 'zero', 'audience', 'story', 'convey', 'gather', 'exposure', 'pain', 'correctness', 'alternative', 'reviewer', 'specification', 'standup', 'past', 'brain', 'spec', 'groom', 'partner', 'evaluate', 'translate', 'understand', 'article', 'kpi', 'determine', 'donco', 'moderate', 'sessions', 'msrb', 'derive', 'analytic', 'matter', 'srs', 'cadence', 'organizational', 'conceptualize', 'traceability', '3000', 'membership', 'water', 'advocate', 'result', 'conceptualized', 'metric', 'matrix', 'chart', 'estimate', 'improvement', 'identify', 'feasibility', 'optimal', 'collaborate', 'tower', 'summary', '\uf0b7', 'vision', 'realistic', 'analysis', 'elicitation', 'color', 'risk', 'dictionary', 'mistake', 'mind', 'breakdown', 'finalize', 'devise', 'swot', 'study', 'talk', 'adopt', 'geographic', 'fit', 'achieve', 'actual', 'ist', 'clarify', 'limitation', 'optimize', 'metrics', 'categorize', 'designs', 'revise', 'benchmark', 'optimized', 'depth', 'flows', 'constraint', 'functional', 'interpret', 'stakeholder', 'restructure', 'interview', 'gap', 'structure', 'remove', 'addie', 'analysed', 'key', 'consultation', 'restatement', 'emphasize', 'together', 'convention', 'potential', 'joomla', 'acceptance', 'correlation', 'rtm', 'upcoming', 'better', 'define', 'assess', 'synthesize', 'actively', 'produce', 'gathered', 'vary', 'assumption', 'clinician', 'networking']
#
# Cluster: 99
# ['uk', 'instrumentation', 'texas', 'nc', 'houston', 'contractor', 'edwards', 'pharmaceutical', 'la', 'madison', 'chemical', 'fluor', '10/2013', 'raleigh', 'industries', 'afghanistan', 'brothers', 'hong', 'green', 'mountain', 'canada', 'plano', 'orleans', '04/2015', 'sc', 'specialist', 'nv', 'construction', 'ga', 'bradley', 'commission', 'truck', 'london', 'corp', 'dcs', 'fabrication', 'rebuild', 'dubai', 'epc', 'england', 'nuclear', 'eagle', 'distribution', 'wi', 'wind', 'controls', 'kong', 'dow', 'subcontractor', 'atlanta', 'solar', 'bay', 'clerk', 'expansion', 'summer', 'scheduler', 'jd', 'universal', 'fort', 'allen', 'ireland', 'dispatch', 'greenville', 'assigned', 'nov.', 'plc', 'wisconsin', 'facilities', 'apr.', 'plant', '1990']
#
# Cluster: 100
# ['abbvie', 'pmi', 'streamlined', 'obtain', 'proceeding', 'exchange', 'comptia', 'regulatory', 'maturity', 'nsa', 'grc', 'act', 'scrummaster', 'isso', 'cyber', 'manager/', 'registration', 'network', 'professional', 'cmm', 'iso', 'top', 'ice', 'attack', 'protection', 'hacking', 'si', 'ato', 'cmmi', 'operate', 'sops', 'foundation', 'directive', 'certified', 'submission', 'advisory', 'security', 'advisor', 'following', 'auditor', 'practices', 'centre', 'iv', 'relevant', 'posture', 'course', 'itil', 'govern', 'pmp', 'chief', 'breach', 'ops', 'specialized', 'intrusion', 'sa', 'certification', 'audits', 'a&a', 'adhere', 'artifact', 'advance', 'adherence', 'customs', 'dhs', 'redstone', 'best', 'hyperion', 'saic', 'classified', 'protect', 'pmo', 'professionals', 'era', 'edward', 'departmental', 'w', 'essential', 'mechanism', 'authorization', 'secret', 'ufms', 'mcse', 'associate', 'guideline', 'mcp', 'categorization', 'hold', 'logistics', 'maximum', 'v3', 'cybersecurity', 'overview', 'ethical', 'fundamental', 'ii', 'ccna', 'iii', 'archival', 'exam', 'clearance', 'audit', 'ciso', 'cissp', 'qualification', 'separation', 'fame', 'ccb', 'fisma', 'border', 's', 'desk', 'information', 'associated', 'principle', 'investigation', 'assessments', 'recording', 'authority', 'unauthorized', 'augmentation', 'sr', 'csam', 'provides', 'detection', 'administrator', 'trusted', 'hardening', 'a+', 'fbi', '9001', 'standards', 'regional', '17', 'assurance', 'gmp', 'transit', 'assay', 'laboratory', 'trs', 'registry', 'it', 'prevention', 'disa']
#
# Cluster: 101
# ['served', 'venue', 'inter', 'compose', 'functioning', 'reception', 'iete', 'event', 'meal', 'outreach', 'sponsorship', 'conference', 'fte', 'stay', 'fest', 'semi', 'preside', 'treasurer', 'meeting', 'organized', 'annual', 'forklift', 'directors', 'committee', 'editor', 'upkeep', 'offsite', '19', 'minute', 'managers', 'initiate', 'fundraiser', 'coo', 'mentored', 'budgeting', 'liaise', 'editorial', 'philanthropy', 'coordinated', 'retro', 'cfo', 'walkthrough', 'homeless', 'organize', 'weekly', 'trial', 'negotiate', 'onsite', 'present', 'participate', 'cooperate', 'lunch', 'webex', 'holder', 'reach', 'discuss', 'shift', 'inspection', 'briefing', 'planned', 'avis', 'arrange', 'mis', 'mass', 'head', 'agenda', 'retrospective', 'forum', 'executive', 'board', 'cooperative', 'weekend', 'trip', 'draft', 'chairman', 'shelter', 'cater', 'stake', 'attend', 'budget', '650', 'oversaw', 'year-', 'fundraising', '22', 'attended', 'sprint', 'charter', 'newsletter', '18', 'spread', 'member', 'music', 'coordinator', 'participation', 'ceo', 'walk', 'delegate', 'fuel', 'discussion']
#
# Cluster: 102
# ['hrms', '7.5', 'techno', 'debugger', '8.51', 'labor', '11.5.10', 'vanilla', 'opm', '8.4', 'payroll', 'mss', 'tam', 'sandia', '8.3', '8.9', 'eperformance', 'fscm', '9.0', 'benefits', 'ar', 'peopletools', 'peoplesoft', 'na', 'costing', 'mover', 'hcm', '9.1', 'dms', 'financials', 'ben', 'istore', 'om', '11i', '8.0', 'peoplecode', 'darden', 'engines', 'ap', 'ess', 'erecruit', 'hr', '9.2', 'ps', 'elm', 'gl', 'crm', 'par', 'lm', '8.8', 't&l', 'sqr']
#
# Cluster: 103
# ['components', 'restart', 'dip', 'stop', '9.2/10', 'shutdown', 'auto', 'cron', 'start', 'crontab', 'startup', 'node', 'script', 'bourne', 'shell', 'recycle', 'jython', 'jmx', 'ksh', 'wlst', 'scripts', 'korn']
#
# Cluster: 104
# ['smart']
#
# Cluster: 105
# ['radio']
#
# Cluster: 106
# ['facility', 'leading', 'recruitment', 'freshman', 'helpdesk', 'workforce', 'serve', 'constant', 'assistance', 'recruit', 'leadership', 'counselor', 'delegation', 'remote', 'familiarize', 'blackboard', 'learning', 'mental', 'command', 'sharing', 'professor', 'dining', 'food', 'train', 'direct', 'capstone', 'virtually', 'soft', 'officer', 'teacher', 'screening', 'student', 'education', 'educational', 'instructional', 'speaking', 'highlight', 'assistant', 'cameroon', 'cristiano', 'patron', 'completion', 'supervisor', 'selected', 'strengthen', 'publications', 'affiliation', 'programs', 'incentive', 'crew', 'receptionist', 'sba', 'extracurricular', 'talent', 'operations', 'reservation', 'cleaning', 'subject', 'marine', 'supervise', 'coaching', 'tutoring', 'encourage', 'workplace', 'distance', 'overseas', 'small', 'recruiting', 'absence', 'caller', 'contracting', 'lesson', 'designate', 'centralize', 'social', 'junior', 'regularly', 'honduras', 'personal', 'community', 'nhs', 'supervised', 'aid', 'individual', '2014-december', 'activities', 'attain', 'editing', 'local', 'hiring', 'background', 'employee', 'parent', 'isd', 'coordinating', 'internship', 'additional', 'classroom', 'staff', 'assisted', 'navigation', 'ship', 'facilitation', 'special', 'counseling', 'drug', 'drill', 'awareness', 'candidate', 'liaison', 'fulfil', 'face', 'building', 'teaching', 'petition', 'recreational', 'hire', 'douala', 'mentoring', 'instruction', 'eight', 'successful', 'behavioral', 'flag', 'prospective', 'sbg', 'about', 'coach', 'visitor', 'human', 'responsibility', 'instructor', 'primary', 'fire', 'finance', 'trainer', 'incoming', 'teach', 'specialty', 'technician', 'greet', 'tutor', 'artillery', 'intermediate', 'resident', 'pharmacy', 'exercise', 'retention', 'athletic', 'placement', 'duty', 'lms', 'nsips', 'supervision', 'mentor', 'contact', 'scheduling', 'among', 'clerical', 'advice', 'charge', 'german', 'rural', 'game', 'secondary', 'grade', 'website', 'pursue', 'thorough', 'faculty', 'people', 'rare', 'students’', 'tutorial', 'restaurant', 'crisis', 'diversity', 'enter', 'speak', 'instruct', 'emergency', 'person', 'oversight', 'four', 'campus', 'stabilize', 'little', 'orientation', 'resume', 'worker', 'counsel', 'curriculum', 'drink', 'room', 'provided', 'examination', 'empower', 'multimedia', 'administrative', 'fellow', 'stamp', 'webinar', 'range', 'lecture', 'seminar', 'nursing', 'personnel', 'peer', 'resources', 'mathematic']
#
# Cluster: 107
# ['boeing', 'deloitte', '11/2013', 'siemens', 'engineer', 'principal', 'taiwan', 'corp.', 'at&t', 'services', 'birlasoft', 'wells', 'packard', 'cognizant', 'telecom', 'delhi', 'dhhs', 'pvt', 'vp', 'hewlett', 'verizon', 'lucent', 'bangalore', 'saudi', 'jose', 'brown', 'accountant', 'singapore', 'kpmg', 'solutions', 'hewitt', 'pa', 'bharat', 'analyst-', 'fab', 'saba', 'phoenix', 'motors', 'mahindra', 'csc', 'investor', 'larsen', 'gurgaon', 'limited', 'jr', 'nextel', 'options', 'semiconductor', 'sunnyvale', 'persistent', 'tester', 'clara', 'senior', 'freelance', 'bell', 'preparer', '11/13', 'venture', 'martin', 'consultancy', 'industrial', 'haining', 'india', 'johns', 'certify', 'northrop', 'fargo', 'cap', 'bp', 'richardson', 'llc', 'employed', 'wipro', '05', '08/2015', 'programmer', 'consultant', 'duration', 'altos', 'fujitsu', 'technologies', 'infosys', 'writer', 'corporation', 'chennai', 'holdings', '1c', 'az', 'golden', 'partners', 'broadcom', 'rio', 'portnov', 'huntsville', 'nokia', 'bakery', 'chandigarh', 'gallagher', 'spectrum', 'zurich', '04/2005', '10/16', 'investments', 'springfield', '10/2007', 'century', 'dac', 'massachusetts', 'designation', 'summit', 'perot', 'pae', 'prep', 'silicon', 'abb', 'newport', 'ltd.', 'schneider', 'collierville', 'premium', 'independent', 'ca', 'galaxy', 'missouri', 'compaq', 'wa', 'santa', 'srm', 'west', 'trainee', 'thomson', 'williams', 'sacramento', 'consultants', 'tata', 'cigna', 'arc', 'connecture', 'labs', 'entertainment', 'nike', 'taipei', 'citigroup', '\u200b', 'herndon', 'q', 'former', 'noida', 'energy', 'impetus', 'analyst', 'hris', 'grumman', 'walter', '1988', 'satyam', 'consulting', 'intern', 'valley', 'pittsburgh', 'canvasser', 'formerly', 'irvine', 'lockheed', 'shore', 'rock', 'booz', 'hartford', 'private', 'sra', 'hamilton', 'creek', 'unisys', 'miller', 'ltd', 'teksystems', 'duke', 'tech', 'hcl', 'co.']
#
# Cluster: 108
# ['pipeline', 'cruisecontrol', 'everything', 'udeploy', 'administrate', 'branch', 'hudson', 'env', 'autonomy', 'tfs', 'versioning', 'gradle', 'tortoise', 'micro', 'atom', 'jenkins', 'continuous', 'bamboo', 'ansible', 'nant', 'clearcase', 'push', 'cd', 'artifactory', 'puppet', 'ci', 'git', 'devops', 'chef', 'cm', 'installer', 'rtc', 'merge', 'jenkin']
#
# Cluster: 109
# ['lotus', 'notes']
#
# Cluster: 110
# ['firefox', 'mozilla', 'msie', 'browser', 'opera', 'chrome', 'mac', 'edge', 'safari', 'compatibility', 'ie', '10/8/7']

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(list(word2vec.values())[0])

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

w2v = dict(zip(res2vec.wv.index2word, res2vec.wv.syn0))

etree_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("extra trees", ExtraTreesClassifier(n_estimators=200))])
svm_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("SVM", SVC())])

print(svm_w2v)
print(etree_w2v)
# Out:
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7fa40e18efd0>), ('SVM', SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])
# Pipeline(steps=[('word2vec vectorizer', <__main__.MeanEmbeddingVectorizer object at 0x7fa40e18e9e8>), ('extra trees', ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_split=1e-07, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#            verbose=0, warm_start=False))])

# %%
X=[['python','ocaml'],
  ['economics','sociology'],
  ['css','javascript']]
y=['scripting','majors','web']
etree_w2v.fit(X,y)
test_X=[['perl'],['psychology'],['asp.net']]
print(etree_w2v.predict(test_X))
# Out:
# ['web' 'majors' 'scripting']

# %%
df_skill = pd.read_excel('Skills.xlsx',columns='Skills')
print(df_skill.head(),'\n')
skill_series = df_skill.T.squeeze().str.lower()
print(skill_series)
# Out:
#   Skill Names
# 0        .Net
# 1   · iKeyman
# 2       @Risk
# 3        ABAP
# 4         ACL
#
# 0                               .net
# 1                          · ikeyman
# 2                              @risk
# 3                               abap
# 4                                acl
# 5                            acrobat
# 6                       active batch
# 7                   active directory
# 8                              adapt
# 9                          adaptable
# 10                 adobe acrobat pro
# 11                       adobe flash
# 12                 adobe illustrator
# 13                   adobe photoshop
# 14                    advanced excel
# 15                               aes
# 16                             agile
# 17               agile methodologies
# 18                 agile methodology
# 19                               aix
# 20                              ajax
# 21             alm hp quality center
# 22                           altiris
# 23               amazon web services
# 24                            amdocs
# 25        analytical/detail oriented
# 26         analyzing proper metadata
# 27            analyzing requirements
# 28                           android
# 29               android development
#                     ...
# 1933                   windows phone
# 1934                  windows server
# 1935                          winscp
# 1936                 wireless 802.11
# 1937                       wireshark
# 1938                            wlst
# 1939                    wlst scripts
# 1940                            word
# 1941                 word processing
# 1942                       wordpress
# 1943      work load management (wlm)
# 1944                         workday
# 1945                       workflows
# 1946        workforce administration
# 1947           working independently
# 1948             writing for the web
# 1949           written communication
# 1950                           xcode
# 1951                    xcode tcp/ip
# 1952                             xen
# 1953                           xhtml
# 1954                         xilinix
# 1955                             xml
# 1956    xml (utilization & analysis)
# 1957                           xpath
# 1958                         xpather
# 1959                           xymon
# 1960                        youtrack
# 1961                           yslow
# 1962                            zuul
# Name: Skill Names, Length: 1963, dtype: object

# %%
d = {}
import operator
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    cluster_series = pd.Series(words)  
    temp = pd.Series(list(set(cluster_series)&(set(skill_series))))
    d[cluster] = len(temp.values)
sorted_d = list(reversed(sorted(d.items(),key=operator.itemgetter(1))))
print(sorted_d)
print(sorted_d[1])
top_ten_skills = []
for i in range(0,3):
    key,val = sorted_d[i]
    top_ten_skills.append(key)
top_ten_skills = pd.Series(top_ten_skills)    
print(top_ten_skills)
# Out:
# [(74, 50), (60, 37), (7, 30), (10, 27), (50, 24), (37, 22), (88, 21), (28, 13), (102, 12), (35, 12), (6, 12), (108, 11), (54, 11), (91, 10), (55, 9), (98, 7), (67, 7), (47, 7), (106, 5), (100, 5), (62, 5), (58, 5), (22, 5), (3, 5), (76, 4), (63, 4), (57, 4), (43, 4), (72, 3), (53, 3), (45, 3), (36, 3), (23, 3), (103, 2), (101, 2), (99, 2), (94, 2), (90, 2), (85, 2), (38, 2), (110, 1), (107, 1), (95, 1), (93, 1), (84, 1), (83, 1), (73, 1), (65, 1), (64, 1), (61, 1), (44, 1), (42, 1), (29, 1), (20, 1), (16, 1), (13, 1), (12, 1), (5, 1), (109, 0), (105, 0), (104, 0), (97, 0), (96, 0), (92, 0), (89, 0), (87, 0), (86, 0), (82, 0), (81, 0), (80, 0), (79, 0), (78, 0), (77, 0), (75, 0), (71, 0), (70, 0), (69, 0), (68, 0), (66, 0), (59, 0), (56, 0), (52, 0), (51, 0), (49, 0), (48, 0), (46, 0), (41, 0), (40, 0), (39, 0), (34, 0), (33, 0), (32, 0), (31, 0), (30, 0), (27, 0), (26, 0), (25, 0), (24, 0), (21, 0), (19, 0), (18, 0), (17, 0), (15, 0), (14, 0), (11, 0), (9, 0), (8, 0), (4, 0), (2, 0), (1, 0), (0, 0)]
# (60, 37)
# 0    74
# 1    60
# 2     7
# dtype: int64

# %%
skills = []
other = []
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    #
    # Find all of the words for that cluster number, and print them out
    if top_ten_skills.isin([cluster]).any():
        for key,item in word_centroid_map.items():
            if(item == cluster):
                skills.append(key)
    else:
        for key,item in word_centroid_map.items():
            if(item == cluster):
                other.append(key)

# %%
len(skills)
# Out:
# 435

# %%
len(other)
# Out:
# 5138

# %%
X = [skills,other]
y=['skills','other']
etree_w2v.fit(X,y)
test_X = [['perl'],['ruby'],['university']]
print(etree_w2v.predict(test_X))
svm_w2v.fit(X,y)
print(svm_w2v.predict(test_X))
# Out:
# ['skills' 'skills' 'other']
# ['skills' 'skills' 'other']

# %%
test_resume = """Jee Won Kang \n
3711 Campus Drive APT 139 College Park, MD \n
4439447487 | jwk1151@gmail.com \n

EDUCATION \n
University of Maryland College Park (Dual Degree) \n
Cumulative GPA: 3.7 \n
Anticipated Fall 2018 \n
• B.S. Physiology and Neurobiology \n
• B.S. in Computer Science \n
Relevant Courses: \n
• Object Oriented Programming I & II, Introduction to Computer Systems, Discrete Structures, \n
How Do Innovators Think? \n
\n
Languages and Technologies \n
§ Languages: Java, C \n
§ Programs: Eclipse, Android Studio, MATLAB, LaTeX, LabChart \n
\n
Projects \n
Projects can be found at my github: github.com/jeekang \n
Turnt Tower (2016): \n
• Independently developed an android app to augment the block tower game, Jenga. \n
• App features an attractive, user-friendly interface. \n
• Language: Java, Android \n
Java-Based DNA template strand Transcription/Translation (2016): \n
• Built a program using Java that takes an input nucleotide sequence and returns the \n
complementary strand, mRNA sequence, reading frame (if one exists) and amino acid sequence. \n
Independent Undergraduate Research Project (2016): \n
• Part of the Center for Bioinformatics and Computational Biology at the University of Maryland. \n
• Working with meta-genomic analysis algorithms and finding limitations of existing programs. \n
• Details to be determined, first meeting with team on September 21st \n
\n
Achievements \n
§\n
§\n
§\n
§\n
\n
Received Integrated Life Sciences Honors College Citation (2014) \n
Received Presidential Scholarship at the University of Maryland (Fall 2012 – Spring 2016) \n
Scored in the 94th percentile in the MCATs (Jan 2015) \n
6 semesters on the Dean’s List \n 
\n
Experience \n
Affective and Translational Neuroscience Laboratory \n
College Park, MD \n
Research Assistant \n
Fall 2013- Spring 2015 \n
• Brainstormed ideas for trial stages such as how to track social habits/movements of subjects. \n
• Front-end experience: briefed and debriefed study participants. \n
• Worked with the psychology clinic at University of Maryland using Titanium and Excel to manage \n
patient DSM-5 data. \n
• Assisted in running clinical trials involving the fMRI at Maryland Neuroimaging Center."""

# %%
test_resume = test_resume.replace('\n','').lower()
print(test_resume)
# Out:
# jee won kang 3711 campus drive apt 139 college park, md 4439447487 | jwk1151@gmail.com education university of maryland college park (dual degree) cumulative gpa: 3.7 anticipated fall 2018 • b.s. physiology and neurobiology • b.s. in computer science relevant courses: • object oriented programming i & ii, introduction to computer systems, discrete structures, how do innovators think? languages and technologies § languages: java, c § programs: eclipse, android studio, matlab, latex, labchart projects projects can be found at my github: github.com/jeekang turnt tower (2016): • independently developed an android app to augment the block tower game, jenga. • app features an attractive, user-friendly interface. • language: java, android java-based dna template strand transcription/translation (2016): • built a program using java that takes an input nucleotide sequence and returns the complementary strand, mrna sequence, reading frame (if one exists) and amino acid sequence. independent undergraduate research project (2016): • part of the center for bioinformatics and computational biology at the university of maryland. • working with meta-genomic analysis algorithms and finding limitations of existing programs. • details to be determined, first meeting with team on september 21st achievements §§§§received integrated life sciences honors college citation (2014) received presidential scholarship at the university of maryland (fall 2012 – spring 2016) scored in the 94th percentile in the mcats (jan 2015) 6 semesters on the dean’s list  experience affective and translational neuroscience laboratory college park, md research assistant fall 2013- spring 2015 • brainstormed ideas for trial stages such as how to track social habits/movements of subjects. • front-end experience: briefed and debriefed study participants. • worked with the psychology clinic at university of maryland using titanium and excel to manage patient dsm-5 data. • assisted in running clinical trials involving the fmri at maryland neuroimaging center.

# %%
test_res_arr = test_resume.split()
test_X = []
for word in test_res_arr:
    test_X.append([word])
test_X
# Out:
# [['jee'],
#  ['won'],
#  ['kang'],
#  ['3711'],
#  ['campus'],
#  ['drive'],
#  ['apt'],
#  ['139'],
#  ['college'],
#  ['park,'],
#  ['md'],
#  ['4439447487'],
#  ['|'],
#  ['jwk1151@gmail.com'],
#  ['education'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['college'],
#  ['park'],
#  ['(dual'],
#  ['degree)'],
#  ['cumulative'],
#  ['gpa:'],
#  ['3.7'],
#  ['anticipated'],
#  ['fall'],
#  ['2018'],
#  ['•'],
#  ['b.s.'],
#  ['physiology'],
#  ['and'],
#  ['neurobiology'],
#  ['•'],
#  ['b.s.'],
#  ['in'],
#  ['computer'],
#  ['science'],
#  ['relevant'],
#  ['courses:'],
#  ['•'],
#  ['object'],
#  ['oriented'],
#  ['programming'],
#  ['i'],
#  ['&'],
#  ['ii,'],
#  ['introduction'],
#  ['to'],
#  ['computer'],
#  ['systems,'],
#  ['discrete'],
#  ['structures,'],
#  ['how'],
#  ['do'],
#  ['innovators'],
#  ['think?'],
#  ['languages'],
#  ['and'],
#  ['technologies'],
#  ['§'],
#  ['languages:'],
#  ['java,'],
#  ['c'],
#  ['§'],
#  ['programs:'],
#  ['eclipse,'],
#  ['android'],
#  ['studio,'],
#  ['matlab,'],
#  ['latex,'],
#  ['labchart'],
#  ['projects'],
#  ['projects'],
#  ['can'],
#  ['be'],
#  ['found'],
#  ['at'],
#  ['my'],
#  ['github:'],
#  ['github.com/jeekang'],
#  ['turnt'],
#  ['tower'],
#  ['(2016):'],
#  ['•'],
#  ['independently'],
#  ['developed'],
#  ['an'],
#  ['android'],
#  ['app'],
#  ['to'],
#  ['augment'],
#  ['the'],
#  ['block'],
#  ['tower'],
#  ['game,'],
#  ['jenga.'],
#  ['•'],
#  ['app'],
#  ['features'],
#  ['an'],
#  ['attractive,'],
#  ['user-friendly'],
#  ['interface.'],
#  ['•'],
#  ['language:'],
#  ['java,'],
#  ['android'],
#  ['java-based'],
#  ['dna'],
#  ['template'],
#  ['strand'],
#  ['transcription/translation'],
#  ['(2016):'],
#  ['•'],
#  ['built'],
#  ['a'],
#  ['program'],
#  ['using'],
#  ['java'],
#  ['that'],
#  ['takes'],
#  ['an'],
#  ['input'],
#  ['nucleotide'],
#  ['sequence'],
#  ['and'],
#  ['returns'],
#  ['the'],
#  ['complementary'],
#  ['strand,'],
#  ['mrna'],
#  ['sequence,'],
#  ['reading'],
#  ['frame'],
#  ['(if'],
#  ['one'],
#  ['exists)'],
#  ['and'],
#  ['amino'],
#  ['acid'],
#  ['sequence.'],
#  ['independent'],
#  ['undergraduate'],
#  ['research'],
#  ['project'],
#  ['(2016):'],
#  ['•'],
#  ['part'],
#  ['of'],
#  ['the'],
#  ['center'],
#  ['for'],
#  ['bioinformatics'],
#  ['and'],
#  ['computational'],
#  ['biology'],
#  ['at'],
#  ['the'],
#  ['university'],
#  ['of'],
#  ['maryland.'],
#  ['•'],
#  ['working'],
#  ['with'],
#  ['meta-genomic'],
#  ['analysis'],
#  ['algorithms'],
#  ['and'],
#  ['finding'],
#  ['limitations'],
#  ['of'],
#  ['existing'],
#  ['programs.'],
#  ['•'],
#  ['details'],
#  ['to'],
#  ['be'],
#  ['determined,'],
#  ['first'],
#  ['meeting'],
#  ['with'],
#  ['team'],
#  ['on'],
#  ['september'],
#  ['21st'],
#  ['achievements'],
#  ['§§§§received'],
#  ['integrated'],
#  ['life'],
#  ['sciences'],
#  ['honors'],
#  ['college'],
#  ['citation'],
#  ['(2014)'],
#  ['received'],
#  ['presidential'],
#  ['scholarship'],
#  ['at'],
#  ['the'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['(fall'],
#  ['2012'],
#  ['–'],
#  ['spring'],
#  ['2016)'],
#  ['scored'],
#  ['in'],
#  ['the'],
#  ['94th'],
#  ['percentile'],
#  ['in'],
#  ['the'],
#  ['mcats'],
#  ['(jan'],
#  ['2015)'],
#  ['6'],
#  ['semesters'],
#  ['on'],
#  ['the'],
#  ['dean’s'],
#  ['list'],
#  ['experience'],
#  ['affective'],
#  ['and'],
#  ['translational'],
#  ['neuroscience'],
#  ['laboratory'],
#  ['college'],
#  ['park,'],
#  ['md'],
#  ['research'],
#  ['assistant'],
#  ['fall'],
#  ['2013-'],
#  ['spring'],
#  ['2015'],
#  ['•'],
#  ['brainstormed'],
#  ['ideas'],
#  ['for'],
#  ['trial'],
#  ['stages'],
#  ['such'],
#  ['as'],
#  ['how'],
#  ['to'],
#  ['track'],
#  ['social'],
#  ['habits/movements'],
#  ['of'],
#  ['subjects.'],
#  ['•'],
#  ['front-end'],
#  ['experience:'],
#  ['briefed'],
#  ['and'],
#  ['debriefed'],
#  ['study'],
#  ['participants.'],
#  ['•'],
#  ['worked'],
#  ['with'],
#  ['the'],
#  ['psychology'],
#  ['clinic'],
#  ['at'],
#  ['university'],
#  ['of'],
#  ['maryland'],
#  ['using'],
#  ['titanium'],
#  ['and'],
#  ['excel'],
#  ['to'],
#  ['manage'],
#  ['patient'],
#  ['dsm-5'],
#  ['data.'],
#  ['•'],
#  ['assisted'],
#  ['in'],
#  ['running'],
#  ['clinical'],
#  ['trials'],
#  ['involving'],
#  ['the'],
#  ['fmri'],
#  ['at'],
#  ['maryland'],
#  ['neuroimaging'],
#  ['center.']]

# %%
predict = svm_w2v.predict(test_X)
for i in range(0,len(predict)):
    print(test_X[i],predict[i])
# Out:
# ['jee'] skills
# ['won'] other
# ['kang'] other
# ['3711'] other
# ['campus'] other
# ['drive'] other
# ['apt'] other
# ['139'] other
# ['college'] other
# ['park,'] other
# ['md'] other
# ['4439447487'] other
# ['|'] other
# ['jwk1151@gmail.com'] other
# ['education'] other
# ['university'] other
# ['of'] other
# ['maryland'] other
# ['college'] other
# ['park'] other
# ['(dual'] other
# ['degree)'] other
# ['cumulative'] other
# ['gpa:'] other
# ['3.7'] skills
# ['anticipated'] other
# ['fall'] other
# ['2018'] other
# ['•'] other
# ['b.s.'] other
# ['physiology'] other
# ['and'] other
# ['neurobiology'] other
# ['•'] other
# ['b.s.'] other
# ['in'] other
# ['computer'] other
# ['science'] other
# ['relevant'] other
# ['courses:'] other
# ['•'] other
# ['object'] skills
# ['oriented'] skills
# ['programming'] skills
# ['i'] other
# ['&'] other
# ['ii,'] other
# ['introduction'] other
# ['to'] other
# ['computer'] other
# ['systems,'] other
# ['discrete'] other
# ['structures,'] other
# ['how'] other
# ['do'] other
# ['innovators'] other
# ['think?'] other
# ['languages'] skills
# ['and'] other
# ['technologies'] skills
# ['§'] other
# ['languages:'] other
# ['java,'] other
# ['c'] skills
# ['§'] other
# ['programs:'] other
# ['eclipse,'] other
# ['android'] other
# ['studio,'] other
# ['matlab,'] other
# ['latex,'] other
# ['labchart'] other
# ['projects'] other
# ['projects'] other
# ['can'] other
# ['be'] other
# ['found'] other
# ['at'] other
# ['my'] other
# ['github:'] other
# ['github.com/jeekang'] other
# ['turnt'] other
# ['tower'] other
# ['(2016):'] other
# ['•'] other
# ['independently'] other
# ['developed'] other
# ['an'] other
# ['android'] other
# ['app'] other
# ['to'] other
# ['augment'] other
# ['the'] other
# ['block'] other
# ['tower'] other
# ['game,'] other
# ['jenga.'] other
# ['•'] other
# ['app'] other
# ['features'] other
# ['an'] other
# ['attractive,'] other
# ['user-friendly'] other
# ['interface.'] other
# ['•'] other
# ['language:'] other
# ['java,'] other
# ['android'] other
# ['java-based'] other
# ['dna'] other
# ['template'] other
# ['strand'] other
# ['transcription/translation'] other
# ['(2016):'] other
# ['•'] other
# ['built'] other
# ['a'] other
# ['program'] other
# ['using'] other
# ['java'] skills
# ['that'] other
# ['takes'] other
# ['an'] other
# ['input'] other
# ['nucleotide'] other
# ['sequence'] other
# ['and'] other
# ['returns'] other
# ['the'] other
# ['complementary'] other
# ['strand,'] other
# ['mrna'] other
# ['sequence,'] other
# ['reading'] other
# ['frame'] other
# ['(if'] other
# ['one'] other
# ['exists)'] other
# ['and'] other
# ['amino'] other
# ['acid'] other
# ['sequence.'] other
# ['independent'] other
# ['undergraduate'] other
# ['research'] other
# ['project'] other
# ['(2016):'] other
# ['•'] other
# ['part'] other
# ['of'] other
# ['the'] other
# ['center'] other
# ['for'] other
# ['bioinformatics'] other
# ['and'] other
# ['computational'] other
# ['biology'] other
# ['at'] other
# ['the'] other
# ['university'] other
# ['of'] other
# ['maryland.'] other
# ['•'] other
# ['working'] other
# ['with'] other
# ['meta-genomic'] other
# ['analysis'] other
# ['algorithms'] other
# ['and'] other
# ['finding'] other
# ['limitations'] other
# ['of'] other
# ['existing'] other
# ['programs.'] other
# ['•'] other
# ['details'] other
# ['to'] other
# ['be'] other
# ['determined,'] other
# ['first'] other
# ['meeting'] other
# ['with'] other
# ['team'] other
# ['on'] other
# ['september'] other
# ['21st'] other
# ['achievements'] other
# ['§§§§received'] other
# ['integrated'] other
# ['life'] other
# ['sciences'] other
# ['honors'] other
# ['college'] other
# ['citation'] other
# ['(2014)'] other
# ['received'] other
# ['presidential'] other
# ['scholarship'] other
# ['at'] other
# ['the'] other
# ['university'] other
# ['of'] other
# ['maryland'] other
# ['(fall'] other
# ['2012'] other
# ['–'] other
# ['spring'] other
# ['2016)'] other
# ['scored'] other
# ['in'] other
# ['the'] other
# ['94th'] other
# ['percentile'] other
# ['in'] other
# ['the'] other
# ['mcats'] other
# ['(jan'] other
# ['2015)'] other
# ['6'] skills
# ['semesters'] other
# ['on'] other
# ['the'] other
# ['dean’s'] other
# ['list'] other
# ['experience'] other
# ['affective'] other
# ['and'] other
# ['translational'] other
# ['neuroscience'] other
# ['laboratory'] other
# ['college'] other
# ['park,'] other
# ['md'] other
# ['research'] other
# ['assistant'] other
# ['fall'] other
# ['2013-'] other
# ['spring'] other
# ['2015'] other
# ['•'] other
# ['brainstormed'] other
# ['ideas'] other
# ['for'] other
# ['trial'] other
# ['stages'] other
# ['such'] other
# ['as'] other
# ['how'] other
# ['to'] other
# ['track'] other
# ['social'] other
# ['habits/movements'] other
# ['of'] other
# ['subjects.'] other
# ['•'] other
# ['front-end'] other
# ['experience:'] other
# ['briefed'] other
# ['and'] other
# ['debriefed'] other
# ['study'] other
# ['participants.'] other
# ['•'] other
# ['worked'] other
# ['with'] other
# ['the'] other
# ['psychology'] other
# ['clinic'] other
# ['at'] other
# ['university'] other
# ['of'] other
# ['maryland'] other
# ['using'] other
# ['titanium'] other
# ['and'] other
# ['excel'] skills
# ['to'] other
# ['manage'] other
# ['patient'] other
# ['dsm-5'] other
# ['data.'] other
# ['•'] other
# ['assisted'] other
# ['in'] other
# ['running'] other
# ['clinical'] other
# ['trials'] other
# ['involving'] other
# ['the'] other
# ['fmri'] other
# ['at'] other
# ['maryland'] other
# ['neuroimaging'] other
# ['center.'] other

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neighbors import NearestNeighbors

nbrs = NearestNeighbors(n_neighbors=2, algorithm='auto').fit(word_vector)
distances, indices = nbrs.kneighbors(word_vector)

# %%
res2vec.wv.doesnt_match('python java css html university'.split())
# Out:
# 'university'

# %%
stri = ''
with codecs.open(resume_text,encoding="utf_8") as f:
    for line in f:
        stri = stri+line
        
resumes = stri.split('\\n')
resumes[100]
# Out:
# '\nPRASAD KAVERI\n3412 University Boulevard East, Hyattsville, MD 20783\nContact No.: 301-273-4187 || Email ID: prasadkaveri9@gmail.com || https://www.linkedin.com/in/prasadkaveri\nEDUCATION\nUniversity of Maryland, College Park\nDec 17\nMaster of Science, Telecommunications Engineering\nGPA: 4.0/4.0\nTechnical Coursework: Network Programming, Network and Protocols, Cyber Security, Cellular Communication Networks\nManagement Coursework: Economics of telecommunications, Strategic Management in Telecommunications\nUniversity of Mumbai, India\nJune 15\nBachelor of Engineering, Electronics and Telecommunications Engineering\nRelated Coursework: Computer Communication Networks, Data Compression & Encryption, Java, C, Mobile Comm., Wireless\nNetworks, Digital Communication\nTECHNICAL SKILLS\nTools & Software: Drupal CMS, Quality Center, Jira, Eclipse, Visual Studio, MATLAB, WinAVR, Eagle software\nProgramming & Computer Skills: Python, Java, C, HTML, Microsoft office Suite, Assembly Language Programming\nPROFESSIONAL EXPERIENCE\nJohnson & Johnson, Ethicon Division, India\nJune 16\nMarketing & Business Development Intern\n• Documented the various treatments on Infertility segment and estimated the Indian infertility market size to be worth approximately\nUSD 11.2 billion\n• Developed an engagement module on infertility and designed procedure focused kits for J&J’s obstetrics/gynecology clients to\nimprove market share in the suture segment by at least USD 34 million\nTech Mahindra, India\nAug 15\nAssociate Software Engineer\n• Learned different technologies by pairing with experienced engineers\n• Involved in documenting QA procedures using the MS Office suite\n• Used Quality Center and JIRA for bug tracking and for the management of test documentation\nACADEMIC PROJECTS\nUniversity of Maryland, College Park\nSimulation of a 3-Sectored Base Station using Python\nMay 16\n• Implemented a Python application which simulated the downlink behavior of a 3-sectored base station along a road\n• Calculated metrics such as Propagation Loss, Shadowing, Fading and EIRP off Boresight to determine which sector offered the\nstrongest Received Signal Level\n• Computed statistics such as number of users serviced, completed calls, calls dropped and calls handed-off in each sector\nV.E.S.I.T, University of Mumbai\nFour Way Density Based Traffic Control System with Advanced Monitoring Techniques\nDec 14\n• Estimated a reduction potential for real-time traffic duration by 33.33%\n• Published a research paper in the International Journal of Application or Innovation in Engineering & Management, an International\nopen access journal. (Link: http://www.ijaiem.org/Volume4Issue3/IJAIEM-2015-03-31-94.pdf )\nArduino Based Shadow Alarm with GSM\nMarch 14\n• Designed a shadow alarm using Arduino which shoots an alert SMS using GSM 300 module\n• Published a paper in the ‘Journal of Emerging Technologies and Innovative Research’, an International open access journal. (Link:\nhttp://www.jetir.org/papers/JETIR1508004.pdf )\nVOLUNTEERING & EXTRACURRICLARS\n• Volunteered for ‘Chant4Change’ at Lincoln Memorial, a philanthropic event which was attended by over 1000 people and aimed at\nspreading peace, unity and harmony\n• Active volunteer at an animal NGO named: In Defense of Animals (IDA-INDIA)\nUniversity of Maryland\nJan 16-present\n• Telecommunications Students Alumni Network (TSAN) – Student Member\n• Graduate Student Government (GSG) - Telecommunications department representative\n• Active member at Bhakti Vedanta Club for Culture & Education at UMD– Organizing workshops on lifestyle management\nIndian Society for Technical Education, Student Chapter, India\n2012-15\n• B.E. Core Committee, senior year- Organized industrial trips, sponsorship and managed finances\n• Student Coordinator, sophomore year- Organized and managed events for 650 students\nPraxis, V.E.S Institute of Technology, Mumbai\n2012-14\n• Core committee member, senior year- Organized the inter-colle ...

# %%
from nltk.corpus import stopwords
from gensim.models.doc2vec import LabeledSentence

resumes_normal = []

special_characters = ['!','#', '$', '%','&','*','-', '/', '=','?',
                      '^','.','_','`', '{', '|', '}','~', "'", ',', '@', '(',')', ':', '•', '§','','\x0c','\t','',
                     '♦']

for res in resumes:
    res_norm = res.lower()
    for spec in special_characters:
        res_norm=res_norm.replace(spec,'')
    res_norm = res_norm.replace('\n',' ')
    res_arr = res_norm.split(' ')
    res_arr = list(filter(lambda x : x != '', res_arr))
    resumes_normal.append(LabeledSentence(words=res_arr,tags=[res_norm[0:15]]))
    print(res_norm[0:15])
print(len(resumes_normal))
#for i in range(0,15):
    #print(resumes_normal[i])
    #print('\n\n\n')
# Out:
# jee won kang 37
#  yaw owusu appi
#  dimitri  richa
#  3412 tulane dr
#  kane baccigalu
#  nirali deliwal
#  muhammad afola
#  terence mcpart
#  joseph man
#  tejal rikame
#  aakash desai 8
#  debi luff  682
#  prasad kaveri
#  lakhan abichan
#  vanya dasari
#  naveen gupta
#  bobbie bass  c
#  ‍‍julianah ale
#    merinajoy 50
#  rajan subraman
#  justin omps  1
#  tywan j mcdani
#  tammi kyle
#  jaspreet singh
#  diane thomas
#  volodymyr mayb
#  kyle martin  8
#  joseph cristia
#  ishmeet singh
#  samyak shah 34
#  arpit kapoor 8
#  binod kumar si
#  keerthi gadira
#  jared smith di
#  mary curto man
#  pallavi kambir
#  ethan r ace  7
#  navdeep singh
#  jeekang contac
#  john park 1452
#  kranthi bheema
#  nigel wheeler
#  yeshwanth sing
#  kingue menvout
#  gaurav hegde 4
#  091115     kev
#  842016unoffici
#  kaushalchandra
#  kanti bhojani
#  sandesh shanta
#  samantha leap
#  liudmila bolat
#  muhammad afola
#  raymond e geor
#  abdur rehman b
#  kulvinder b ka
#  an integration
#  anshita jain 6
#  tewodros e men
#  310passaicave
#  linda larsen
#  igor spektor m
#  manmohan uttar
#  zachary goldma
#  anagha diwanji
#  faith kim 2063
#  jeffry l barte
#  amit kumar  mo
#  namratha jagad
#  prasad kaveri
#  sumeet jeswani
#  anthony hoffma
#  christopher ro
#  deepika shastr
#  joel galvagni
#  joseph cardare
#  alvah walter m
#  min choi    ex
#  vivek shadrak
#  brendina barre
#  4318 101 rowal
#  stanley alexan
#  abebaw ayele
#  sangam karki
#  mikel bremer
#  tewodros e men
#  narjit singh
#  rajkumar vukka
#  rodrigo escami
#  reniece a fouc
#  titus andrade
#  sudipto saha
#  timothy baker
#  sarah lass sla
#  bharat pappu
#  prakhar singh
#  nadia okhara
#  deepthi viswan
#  paul curtis  m
#  michael antony
#  prasad kaveri
#  prakhar singh
#  anish patel  7
#  kevin maurice
#  sumeet jeswani
#  maria a davila
#  apurva sukthan
#  khadija sarhro
#  key person  lu
#  xinhui du 9530
#  roger vaede
#  henry hung dao
#  william furlow
#  julie robinson
#  bruce andrew r
#  srinivas ankam
#  grace kim  514
#  zachary goldma
#  ishmeet singh
#  zachary bruce
#  bliana fahie
#
# 6210 belcrest r
# hyattsville md
# tel 340 6429749
#
# viraj gandhi
#
# chief executive
# paradyme manage
#
# 9111 edmonston
# greenbelt md 20
#
# april 8 2015
#
# dear viraj
#
# i am sending th
# analyst at para
# my time at para
#
# earned my caree
# will help to ac
#
# my last day of
# advanced notice
#
# i plan to put f
# paradyme manage
# needed if you h
# me please feel
#
# i wish paradyme
#
# thank you for y
#
# y rs sincereml
#
# lana f ahie
#  aanchal kanodi
#  byonggen andre
#
# senior java dev
# 9720 eldwick wa
# mobile 24020522
#
# summary of qual
#
# highlyskilled a
# experiences in
# application str
# integration too
# problems and pe
# methodology and
# for whole softw
#
# certifications
#
# expertise years
# expertise
#
# languagesprogra
# java technologi
# java web jsp se
# web technologie
# javascript angu
# databases oracl
# app servers web
# design methodol
# patterns
# 05 linux unix s
# idecase tools e
# application fra
# hibernate
# configuration m
# build tool ant
# web services so
# testing junit m
# others 550 usin
#
# gm find21 eds d
#
# using jsp html
#  maintained cog
#  provided warra
#
#
#
#
#
# gm prts+ eds de
# project type jz
# role j2ee devel
#
#
#
# responsibilitie
#
#  developed java
# application
#
#  developed orac
# business model
#
#  developed fron
# using jsp html
#
#  developed user
# and xml
#
#  developed fron
# using jsp html
#
#  analyzed and r
#  provided warra
#
#
#
#
#
#
#
#
#
#
#
# education and t
#
#  master of scie
# detroit michiga
#  agile boot cam
#
# references avai
#
# relevant projec
#
# onstar gaa 4x 5
#
# 0908 to present
#
# project type
#
# mi
# java call cente
#
#
#
# role
#
# senior develope
#
#
#
# responsibilitie
#
# onstar opc
# refinement
#
# project type
#
#  lead a group d
# releases for sh
#
#  provided produ
# troubleshooting
# leak issues
#
#  supported perf
# tuning for java
#
# 0 experienced f
# design developm
#
#  experienced ag
# programming and
# hp detroit mi 0
#
# jzee applicatio
#
#
#
# role
#
# developer
#
#
#
# responsibilitie
#
#  prepared techn
#  developed juin
#  developed tnes
#
#  built and depl
# weblogic sever
#
#
#
# gm find21
# project type
#
# eds detroit mi
# j2ee web applic
#
# 0507 to 0308
#
#
#
# role
#
# jzee developer
#
#
#
# responsibilitie
#
#
#
#
#
#  prepared techn
#  developed batc
#
# i developed ora
# business model
#
#  built and depl
# weblogic sever
#
#  developed user
# and xml
#
#  developed fron
#  manasa gunda 4
#  an abbreviated
#  amandeep saini
#  muhammad kamra
#  kester enahoro
#  saleem khan
#  yiyangeric zho
#  eduard oganesy
#  liudmila bolat
#  ashley p cheng
#  rodrigopimenta
#  prasanjit chau
#  paul r chase
#  kalyan kuthadi
#  lizset chavez
#  vitalii marius
#  deepika shastr
#  arwa hatim gin
#  yeon choi 100
#  chakradhara ko
#  mihir     moha
#  christopher j
#  antionette chi
#  khushboo nigam
#  ethan r ace  7
#  dillon vural
#  suevgiri kkmsu
#  anthony hoffma
#  namesindhur mu
#  wilma dsouza 3
#  3012570493  ma
#  sergiilogvynet
#  bryan eric nor
#  usha prajapati
#  daniel h pyon
#  eiad z sayyad
#  varsha purswan
#  khalid shaik
#  david j harris
#  colin john cam
#  navdeep singh
#  anshita jain 6
#  nirupama menon
#  m srikant  dir
#  mandar h salun
#  jeffrey r adam
#  shreya shetty
#  christopher bl
#  ishan goradia
#  amanda yu
#  miguel lorenzo
#  zachary goldma
#  saada s redi 5
#  abbas roshan 8
#  zachary goldma
#  charles k owus
#  lucy murray  8
#  nicholas erbe
#  al dhanani   4
#  payal dalal  8
#  t ianqi t ina
#  pamela marie j
#  shashidhar kar
#  dear hiring ma
#  steven j ahlst
#  derhaw wang ja
#  saumitra dabra
#  john   pugh
#  shirin bhambha
#  khushboo nigam
#  yiyangeric zho
#  paris allen 61
#  rabia ahmed ǀ
#  tushar bhardwa
#  khushal navani
#  ann chamberlin
#  didem uzuncaov
#  maxim shapiro
#  michael p walk
#  william h hods
#  thangam kanimo
#  cynthia k bera
#  omkar h salunk
#  key person  sa
#  asim a malik
#  mahjaveen hass
#  tania m dasilv
#  henry hung dao
#  namratha jagad
#  ethan r ace  7
#  bio  patrick c
#  technical skil
#  zijing judy zh
#  maksym mykhail
#  daniel andrew
#  tanvi shah
#  richard charle
#  sushmitha s
#  yikai xu 11338
#  john   pugh
#  birinder chaha
#  mahesh t  webl
#  gaurav hegde 4
#  jessica a rose
#  vasutholetigma
#  shravan kumar
#  resume    hari
#  yilin wang  95
#  nahed kadih
#  vikram mattepa
#  chinmay raote
#  kiran kumar  w
#  kanishka ramam
#  hagos mebratu
#  avinash mishra
#  navdeep singh
#  naren nallapar
#  david shen  em
#  mykola yaroshe
#  4318 101 rowal
#  yiding xiong
#  ashish aggarwa
#  rubens massayu
#  ravi kumar tan
#  julia zschiesc
#  arpit kapoor 8
#  azsaneé truss
#  sukanti sahu
#  david ray reiz
#  regina ann lap
#  anagha diwanji
#  mariem yaha
#  tamela miller
#  mohana bansal
#  raheed khan  6
#  shilpa mandala
#  irina skarbovs
#  brittani thoma
#  jennifer doan
#  yiding xiong
#  shilpa venepal
#  daniel moscati
#  karen capek  8
#  tanvi shah
#  santosh chinta
#  michael antony
#  vincenzo dirie
#  abhinav jain 2
#  navdeep singh
#  rodrigopimenta
#  michael freema
#  kip cordero wo
#  aniket  tambay
#  alexander berg
#  howard israel
#  yang yang 9530
#  rujun dai 3300
#  william scott
#  atharva deshpa
#  kevin gough  7
#  mariem yaha 37
#  wenqi yang 912
#  sreedhar vasom
#  annette willia
#  john park 1452
#  ishan goradia
#  enidhat  chett
#  ely marrero  l
#  sonal sonawane
#  calvin chao  3
#  daniel p palme
#  joann ambrosin
#  nupur sidhaye
#  deanna l pare
#  seenithai kart
#  benjamin mitra
#  karthikesan ra
#  ankita kakalas
#  william j case
#  tanvi shah col
#  samyak shah 34
#  weblogic admin
#  douglas mason
#  howard bloombe
#  tori vienneau
#  brandon thomas
#  atharva deshpa
#  atharva deshpa
#  sebrina c malo
#  aakanksha jain
#  mike chung  32
#  nisha khanal
#  eric cottrell
#  kay adeyosoye
#  william joseph
#  pratik sawant
#  laveena b dula
#  robert joseph
#  zachary goldma
#  klarence simps
#  ramon silva 51
#  wayne sheu  em
#  jay sheth an o
#  kanishka mache
#  2  experience
#  ameya r chavan
#  jared j ross
#  zijing judy zh
#  roma kaul  las
#  rujun dai 3300
#  ksenia vanatsk
#  manu prabhakar
#  mariamawit zel
#  hitesh kumar
#  diane zaghal
#  bryan na    ex
#  ravindhar b  s
#  alexander kras
#  joy muehlenbei
#  alanna covingt
#  tanvi shah
#  martin yau
#  debra graham
#  karan kashyap
#  felecia washin
#  pratiksha sath
#  jeremy joyce
#  cynthia m sanc
#  bakhtier azizb
#  katherine forn
#  sandesh shanta
#  birinder chaha
#  abhishek  daml
#  md alam saikh
#  yeri zinn  21
#  atharva deshpa
#  sagar maniar h
#  konstantin bur
#  peter gathua
#  b152017 my acc
#
# my account
#
# unv099  interns
#
# work term
# spring 2017
#
# student informa
#
# university id
# 1 14280145
#
# studenl name
# kanishka ramamo
#
# preferred email
#
# kanishkaumdgmai
#
# phone number
#
# 2405501235
#
# currem mailing
#
# 3413 tulane dri
# apt no31 hyatts
#
# gender
#
# female
#
# citizenship sta
#
# other
#
# if other please
#
# united states
#
# httpslumdcsmsym
#
# my account  car
#
# wagessalary
#
# 14
#
# did you receive
# no
#
# learning contra
#
# total 4f weeks
# 1500
#
# hours per week
# 1 5
#
# total hours at
#
# 000
#
# list your speci
#
# a actively part
#
# b construct sol
# development hel
# management and
# knowledge base
#
# c demonstrate p
#
# d develop a rap
#
# e devise and de
#
# f practice publ
#
# 9 engage in lea
#
# what do you exp
#
# i believe that
# problem solving
# promote revenue
# problems at the
# analytical skil
#
# how does this a
#
# iwish to pursue
# analytics consu
# apart from the
# to use to this
# my professional
#
# httpsumdcsmsymp
#
# sludem learning
# kanishka ramamo
#
# nacezlink nacel
#
# arler slrvilli
# privacy policy
#
# hp53lumdcsmsymp
#
# class standing
# graduate studen
#
# major
# information stu
#
# internship info
#
# employer
# paradyme manage
#
# new employer
#
# select internsh
# corporate techn
#
# if you found yo
#
# internship site
# 9111 edmonston
#
# supervisor name
# noah parker wv
# supervisor titl
#
# training and de
#
# supervisor emai
#
# nparkergaradyme
#
# supervnsors pho
#
# 3012201345
#
# start date
# february 6 2017
#
# end date
# may 19 2017
#
# compensation ty
#
# paid
#
# http51lumdcsmsy
#  ida hampton  e
#  david tarcza
#  cameron somers
#  joseph l march
#  martin m mille
#  charles crook
#  nalaka deegala
#  ryan holder  1
#  leah alice zen
#  ravi  34798926
#  veena nath rev
#  bryan hampton
#  saikat kundu
#  education
#  kalkidan ashen
#  ishan goradia
#  sohni nagpal 8
#  saumitra dabra
#  fred t tucker
#  matthew bukows
#  professional s
#  tanvisharma 20
#  subash thapa
#  reshma haveli
#  jody w benson
#  wwwlinkedincom
#  robert l taylo
#  ritesh vijay s
#  viktoriia kote
#  finus a rascoe
#  paul johnson
#  t ianqi t ina
#  utkarsha devka
#  ethan r ace  7
#  thames s hillm
#  jared j ross 9
#  sunil kumar va
#  skill summary
#  parag salgaonk
#  maithreyi chan
#  matthew marchi
#  ozoda usman wa
#  surabhistambe
#  cameron somers
#  alecia randall
#  harshit ketan
#  bruce andrew r
#  i r y n a
#  jyothi rayavar
#  5133569626  ji
#
# 802

# %%
from gensim.models import Doc2Vec

if 1==1:
    model = Doc2Vec(min_count=1, window=10, size=200, sample=1e-4, negative=5, workers=8)
    model.build_vocab(resumes_normal)
    for epoch in range(10):
        model.train(resumes_normal,total_examples=model.corpus_count, epochs=model.iter)
        model.alpha -= 0.002  # decrease the learning rate
        model.min_alpha = model.alpha  # fix the learning rate, no decay
    model.save('doc2vec_model.doc2vec')

# %%
model_loaded = Doc2Vec.load('doc2vec_model.doc2vec')
model_loaded

# %%
def get_related_documents(token,topn=10):
    "get the top n most similar terms"
    for word,similar in model_loaded.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
model_loaded.docvecs.most_similar(' jared j ross  ')
# Out:
# [(' jared j ross 9', 0.7689490914344788),
#  (' john\xa0\xa0\xa0pugh\xa0 \xa0', 0.7572202682495117),
#  ('spring 2017', 0.7307022213935852),
#  (' payal dalal  8', 0.7160718441009521),
#  (' tanvisharma 20', 0.7130640745162964),
#  ('kanishka ramamo', 0.7091871500015259),
#  (' abhishek\xa0 daml', 0.708122730255127),
#  ('a actively part', 0.7048613429069519),
#  ('nparkergaradyme', 0.6974267959594727),
#  ('gender', 0.6972523331642151)]

# %%
ordered = [(term,voc.index,voc.count)for term, voc in model_loaded.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(model_loaded.wv.syn0[term_indices,:],index=ordered_terms)
word_vectors.head()
# Out:
#                        0         1         2         3         4         5    \
# postassessments   0.037150 -0.082187  0.048669  0.065059 -0.078366 -0.098949
# adminarbitration  0.213373 -0.104930 -0.207942 -0.233435 -0.316911 -0.048200
# 2016]             0.351596 -0.001532 -0.563803  0.041309 -0.389211  0.181078
# routes            0.621421  0.133769 -0.056632 -0.603150 -0.560396  0.141139
# streamline        0.299349  0.538936  0.078938 -0.471580 -0.338421 -0.609982
#
#                        6         7         8         9      ...          190  \
# postassessments   0.012352 -0.082823 -0.072572 -0.166408    ...    -0.039352
# adminarbitration  0.076871 -0.004604  0.030086 -0.117600    ...    -0.027280
# 2016]            -0.090426 -0.087457 -0.049234  0.087961    ...    -0.088680
# routes            0.594684 -0.209373  0.030612 -0.458048    ...    -0.141663
# streamline       -0.064122  0.180687 -0.089296  0.127238    ...    -0.148461
#
#                        191       192       193       194       195       196  \
# postassessments  -0.105143  0.046046 -0.125811  0.007335  0.052342  0.016539
# adminarbitration  0.224946 -0.006706 -0.071446 -0.038074  0.175219 -0.005885
# 2016]             0.253999  0.229883 -0.578320  0.019750  0.257581 -0.090008
# routes            0.178411 -0.007804 -0.349258  0.134721  0.435935 -0.144868
# streamline       -0.305221  0.438513 -0.576825  0.329393  0.466660  0.280228
#
#                        197       198       199
# postassessments   0.037385  0.086791  0.090420
# adminarbitration -0.140919  0.199965  0.036827
# 2016]            -0.846630  0.156342  0.060577
# routes           -0.131300  0.259899  0.470415
# streamline       -0.084301 -0.207648 -0.094162
#
# [5 rows x 200 columns]
