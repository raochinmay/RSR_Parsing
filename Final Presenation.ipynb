# %% [markdown]
# # Jared Ross

# %%
resume_text = "all_text1.txt"
from gensim.models import Phrases
from gensim.models.word2vec import LineSentence

def punct_space(token):
    "helper that elimates puncations and whitespace"
    return token.is_punct or token.is_space

def line_review(filename):
    "read reviews from the file and un-escapes orignal line break"
    with codecs.open(filename,encoding='utf_8') as f:
        for res in f:
            yield res.replace('\\n','\n')
 
def lemmatized_sentence_corpus(filename):
    "use spacy to parse, lemmatize and yield sentences"
    for parsed_res in nlp.pipe(line_review(filename),batch_size=10000,n_threads=3):
        for sent in parsed_res.sents:
            yield u' '.join([token.lemma_ for token in sent if not punct_space(token)])

# %%
unigram_filepath = 'unigram_sentences.txt'
normal_res = LineSentence(unigram_filepath)

# %%
from gensim.models import Word2Vec
word2vec_file = "vector_models"
res2vec = Word2Vec.load(word2vec_file)
res2vec.init_sims()

# %%
import pandas as pd

ordered = [(term,voc.index,voc.count)for term, voc in res2vec.wv.vocab.items()]
ordered_terms,term_indices,term_count = zip(*ordered)
word_vectors = pd.DataFrame(res2vec.wv.syn0[term_indices,:],index=ordered_terms)

word_vectors.head()
# Out:
#                   0         1         2         3         4         5    \
# stakeholder  0.030171 -0.578940 -0.140312 -0.431368  0.139060 -0.184949
# umd          0.636582  0.145355  0.028948 -0.685784  0.183876 -0.192557
# gm          -0.527539 -0.081446  0.112848 -0.786913  0.202775  0.063773
# distributed -0.159051  0.488896  0.247771 -0.085302 -0.310324  0.278545
# troubleshot  0.435049 -0.452891  0.243573 -0.324668  0.169153 -0.280413
#
#                   6         7         8         9      ...          290  \
# stakeholder  0.281638 -0.486964 -0.215997  0.317459    ...     0.216009
# umd         -0.116400 -0.037009  0.828778  0.784020    ...     0.847879
# gm           0.429179 -0.203711  0.415994  0.222439    ...    -0.277524
# distributed  0.522985  0.363179  0.358134  0.166417    ...     0.059012
# troubleshot  0.207720 -0.788195  0.035686 -0.061155    ...     0.072823
#
#                   291       292       293       294       295       296  \
# stakeholder -0.155120  0.385886 -0.430409 -0.447029  0.493696  0.024946
# umd          0.130493  0.739471  0.386520  0.630240 -0.047898  0.055178
# gm           0.281285  0.228909 -0.335671 -0.228273  0.157850  0.122891
# distributed  0.595668  0.023368 -0.717380 -0.033351  0.241998  0.066923
# troubleshot  0.457670  0.753623  0.076704  0.286444 -0.241608 -0.254652
#
#                   297       298       299
# stakeholder -0.057620  0.346376 -0.118032
# umd         -0.832729 -1.177598  0.128166
# gm          -0.223887 -0.111441  0.039465
# distributed  0.613473 -0.285315 -0.787055
# troubleshot  0.138938 -0.313926 -0.412263
#
# [5 rows x 300 columns]

# %%
res2vec.n_similarity(['python'],['java'])
# Out:
# 0.27475053289729667

# %%
def get_related_terms(token,topn=10):
    "get the top n most similar terms"
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        print(word,':',round(similar,3))

# %%
get_related_terms('python')
# Out:
# 3-sectored : 0.438
# verilog : 0.421
# bash : 0.402
# languag : 0.387
# ocaml : 0.374
# languages : 0.369
# html5 : 0.368
# palisade : 0.366
# stattools : 0.365
# precisiontree : 0.363

# %%
get_related_terms('java')
# Out:
# j2me : 0.5
# j2ee : 0.453
# jsp : 0.432
# j2se : 0.431
# swings : 0.426
# taglibs : 0.425
# applets : 0.41
# 1.4 : 0.408
# jdk1.6 : 0.395
# html : 0.394

# %%
from sklearn.manifold import TSNE
import _pickle as pickle
import spacy

tsne_input = word_vectors.drop(spacy.en.English.Defaults.stop_words,errors='ignore')
tsne_input.head()
# Out:
#                   0         1         2         3         4         5    \
# stakeholder  0.030171 -0.578940 -0.140312 -0.431368  0.139060 -0.184949
# umd          0.636582  0.145355  0.028948 -0.685784  0.183876 -0.192557
# gm          -0.527539 -0.081446  0.112848 -0.786913  0.202775  0.063773
# distributed -0.159051  0.488896  0.247771 -0.085302 -0.310324  0.278545
# troubleshot  0.435049 -0.452891  0.243573 -0.324668  0.169153 -0.280413
#
#                   6         7         8         9      ...          290  \
# stakeholder  0.281638 -0.486964 -0.215997  0.317459    ...     0.216009
# umd         -0.116400 -0.037009  0.828778  0.784020    ...     0.847879
# gm           0.429179 -0.203711  0.415994  0.222439    ...    -0.277524
# distributed  0.522985  0.363179  0.358134  0.166417    ...     0.059012
# troubleshot  0.207720 -0.788195  0.035686 -0.061155    ...     0.072823
#
#                   291       292       293       294       295       296  \
# stakeholder -0.155120  0.385886 -0.430409 -0.447029  0.493696  0.024946
# umd          0.130493  0.739471  0.386520  0.630240 -0.047898  0.055178
# gm           0.281285  0.228909 -0.335671 -0.228273  0.157850  0.122891
# distributed  0.595668  0.023368 -0.717380 -0.033351  0.241998  0.066923
# troubleshot  0.457670  0.753623  0.076704  0.286444 -0.241608 -0.254652
#
#                   297       298       299
# stakeholder -0.057620  0.346376 -0.118032
# umd         -0.832729 -1.177598  0.128166
# gm          -0.223887 -0.111441  0.039465
# distributed  0.613473 -0.285315 -0.787055
# troubleshot  0.138938 -0.313926 -0.412263
#
# [5 rows x 300 columns]

# %%
tsne_file = 'tsne_models'
tsne_vectors_file = 'tsne_vectors.npy'
tsne = TSNE()
tnse_vectors = tsne.fit_transform(tsne_input.values)
with open(tsne_file, 'wb') as f:
    pickle.dump(tsne,f)
    
pd.np.save(tsne_vectors_file,tnse_vectors)

with open(tsne_file,'rb') as f:
    tnse = pickle.load(f)
tnse_vectors = pd.np.load(tsne_vectors_file)

tnse_vectors = pd.DataFrame(tnse_vectors,index = pd.Index(tsne_input.index),columns=['x','y'])
tnse_vectors['word'] = tnse_vectors.index
print(tnse_vectors.head())
# Out:
#                      x         y         word
# stakeholder  11.757952  0.286746  stakeholder
# umd         -11.097395  4.400128          umd
# gm           -6.868803 -4.331574           gm
# distributed  -9.868099  0.031935  distributed
# troubleshot  10.516786  4.142271  troubleshot

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="77c64be7-ee60-45e4-b1d0-f98317f8b51a">Loading BokehJS ...</span>
#     </div>

# %%
plot_data = ColumnDataSource(tnse_vectors)
# create the plot and configure the
# title, dimensions, and tools
tsne_plot = figure(title=u't-SNE Word Embeddings',
                   plot_width = 800,
                   plot_height = 800,
                   tools= (u'pan, wheel_zoom, box_zoom,'
                           u'box_select, resize, reset'),
                   active_scroll=u'wheel_zoom')

# add a hover tool to display words on roll-over
tsne_plot.add_tools( HoverTool(tooltips = u'@word') )

# draw the words as circles on the plot
tsne_plot.circle(u'x', u'y', source=plot_data,
                 color=u'blue', line_alpha=0.2, fill_alpha=0.1,
                 size=10, hover_line_color=u'black')

# configure visual elements of the plot
tsne_plot.title.text_font_size = value(u'16pt')
tsne_plot.xaxis.visible = True
tsne_plot.yaxis.visible = True
tsne_plot.grid.grid_line_color = None
tsne_plot.outline_line_color = None

# engage!
show(tsne_plot);
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d7c1c8ad-e25a-49b4-8f90-71ac8e34b6a1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d7c1c8ad-e25a-49b4-8f90-71ac8e34b6a1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d7c1c8ad-e25a-49b4-8f90-71ac8e34b6a1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd7c1c8ad-e25a-49b4-8f90-71ac8e34b6a1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"acb18d4f-705b-4d7a-8ba1-51302b5e47e7":{"roots":{"references":[{"attributes":{"below":[{"id":"ee2594e2-bcba-4b73-8758-575c9fbda1bd","type":"LinearAxis"}],"left":[{"id":"847b27be-77fe-45fb-8ba3-952e210942b6","type":"LinearAxis"}],"outline_line_color":{"value":null},"plot_height":800,"plot_width":800,"renderers":[{"id":"ee2594e2-bcba-4b73-8758-575c9fbda1bd","type":"LinearAxis"},{"id":"97b792f9-57f3-4832-9ce7-36e8c94443df","type":"Grid"},{"id":"847b27be-77fe-45fb-8ba3-952e210942b6","type":"LinearAxis"},{"id":"c0e18607-31cc-4da9-b3ac-fa165514413e","type":"Grid"},{"id":"eb59dd38-17ce-4009-8652-0d4a75091beb","type":"BoxAnnotation"},{"id":"daf76d03-b6cf-46d9-ba65-320715a1d040","type":"BoxAnnotation"},{"id":"79dff01c-3675-420e-be31-734fb883f3df","type":"GlyphRenderer"}],"title":{"id":"a1a02ba9-9343-4ff4-896c-5cb4392d1d07","type":"Title"},"tool_events":{"id":"d239776e-7620-4246-8414-45d74809c00d","type":"ToolEvents"},"toolbar":{"id":"d8d26cc5-ea2f-4be8-9a3b-9cdd0182bbc2","type":"Toolbar"},"x_range":{"id":"515f4174-9805-443f-b620-28b40c701d91","type":"DataRange1d"},"x_scale":{"id":"c1a522a7-4225-4b7d-b056-3060b7767aa8","type":"LinearScale"},"y_range":{"id":"e440b642-a92c-440c-b4c6-b87ce1b43a4a","type":"DataRange1d"},"y_scale":{"id":"c5c11210-13de-45a6-9076-e5534ecffb34","type":"LinearScale"}},"id":"b32f1bf3-6628-484a-9592-5c9768f893cf","subtype":"Figure","type":"Plot"},{"attributes":{"formatter":{"id":"3e29c5af-f94f-4852-8743-627654bf68f8","type":"BasicTickFormatter"},"plot":{"id":"b32f1bf3-6628-484a-9592-5c9768f893cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b4442dc-c053-431b-8330-99ed6517b408","type":"BasicTicker"}},"id":"847b27be-77fe-45fb-8ba3-952e210942b6","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"eb59dd38-17ce-4009-8652-0d4a75091beb","type":"BoxAnnotation"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"1bdc50ec-ed32-47b4-be4e-570521af85ab","type":"Circle"},{"attributes":{"dimension":1,"grid_line_color":{"value":null},"plot":{"id":"b32f1bf3-6628-484a-9592-5c9768f893cf","subtype":"Figure","type":"Plot"},"ticker":{"id":"9b4442dc-c053-431b-8330-99ed6517b408","type":"BasicTicker"}},"id":"c0e18607-31cc-4da9-b3ac-fa165514413e","type":"Grid"},{"attributes":{"plot":null,"text":"t-SNE Word Embeddings","text_font_size":{"value":"16pt"}},"id":"a1a02ba9-9343-4ff4-896c-5cb4392d1d07","type":"Title"},{"attributes":{},"id":"d239776e-7620-4246-8414-45d74809c00d","type":"ToolEvents"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"daf76d03-b6cf-46d9-ba65-320715a1d040","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b32f1bf3-6628-484a-9592-5c9768f893cf","subtype":"Figure","type":"Plot"}},"id":"04c879bd-684d-4ec1-a90b-856aa241b7d0","type":"WheelZoomTool"},{"attributes":{"callback":null,"plot":{"id":"b32f1bf3-6628-484a-9592-5c9768f893cf","subtype":"Figure","type":"Plot"},"tooltips":"@word"},"id":"762116b2-acdb-4f05-966d-2c043f501036","type":"HoverTool"},{"attributes":{},"id":"bd46d88c-d7f6-463e-b203-085edbeca706","type":"BasicTickFormatter"},{"attributes":{},"id":"c5c11210-13de-45a6-9076-e5534ecffb34","type":"LinearScale"},{"attributes":{"callback":null},"id":"e440b642-a92c-440c-b4c6-b87ce1b43a4a","type":"DataRange1d"},{"attributes":{},"id":"6ea7c018-f241-4ff5-816b-b44d3454 ...

# %%
from sklearn.cluster import KMeans


word_vector = res2vec.wv.syn0
print(int(word_vector.shape[0]/50))
num_clusters = int(word_vector.shape[0]/50)

# Initalize a k-means object and use it to extract centroids
kmeans_clustering = KMeans( n_clusters = num_clusters )
idx = kmeans_clustering.fit_predict( word_vector )
# Out:
# 111

# %%
word_centroid_map = dict(zip( res2vec.wv.index2word, idx ))
for cluster in range(0,num_clusters):
    #
    # Print the cluster number  
    print ("\nCluster:",cluster)
    #
    # Find all of the words for that cluster number, and print them out
    words = []
    for key,item in word_centroid_map.items():
        if( item == cluster ):
            words.append(key)
    print(words)
# Out:
# Cluster: 0
# ['publishing']
#
# Cluster: 1
# ['convert', 'into', 'translate', 'break', 'understanding', 'transform', 'consistent']
#
# Cluster: 2
# ['spss', 'exam', 'score', 'dubai', 'professionals', '100%', 'above', 'methods', 'logistics', 'social']
#
# Cluster: 3
# ['creation']
#
# Cluster: 4
# ['creativity', 'leading', 'dedicated', 'succeed', 'very', 'contracting', 'term', 'leadership', 'mission', 'proposition', 'qualifications', 'valuable', 'spot', 'working', 'effectively', 'remain', 'craft', 'advance', 'commit', 'advised', 'dedicate', 'choi', 'initiative', 'involvement', 'verbal', 'gain', 'while', 'flexible', 'audience', 'rapidly', 'extra', 'practical', 'often', 'tackle', 'oversight', 'seek', 'passion', 'innovation', 'exceptional', 'competent', 'stable', 'cooperative', 'goal', 'bring', 'clinician', 'freddie', 'adoption', 'success', 'analytical', 'accomplish', 'continue', 'workplace', 'ceo', 'concept', 'acuman', 'way', 'fashion', 'influence', 'practice', 'entrepreneurial', 'face', 'individual', 'respect', 'advancement', 'mind', 'highly', 'healthy', 'teams', 'starter', 'commitment', 'empower', 'desire', 'partner', 'ethic', 'attitude', 'strategic', 'emphasis', 'inside', 'variety', 'adapt', 'complicated', 'advocate', 'keen', 'fact', 'independently', 'enjoy', 'hardwork', 'fully', 'meaningful', 'talent', 'posses', 'leverage', 'unstructured', 'towards', 'collaborative', 'consensus', 'executable', 'particular', 'evolve', 'ne', 'position', 'motivation', 'motivate', 'motivated', 'orient', 'engage', 'navigate', 'cio', 'consult', 'communicator', 'thinking', 'centralize', 'further', 'man', 'luther', 'oral', 'competency', 'emerge', 'prospect', 'savvy', 'outstanding', 'learner', 'employment', 'aptitude', 'hovercraft', 'augment', 'learn', 'minimal', 'discipline', 'early', 'idea', 'say', 'creative', 'describe', 'presentation', 'organizational', 'possess', 'managerial', 'toward', 'skill', 'interpersonal', 'significant', 'collaboration', 'flexibility', 'ability', 'technically', 'player', 'attention', 'hope', 'self', 'positive', 'supervisory', 'expand', 'communication', 'knowledgeable', 'successful', 'diverse', 'building', 'deep', 'difficult', 'key', 'strict', 'direction', 'incorporate', 'contribution', 'opportunity', 'intuitive', 'grow', 'recognize', 'synthesize', 'organization', 'advantage', 'play', 'challenging', 'grasp', 'round', 'align', 'small', 'manner', 'forward', 'among', 'solve', 'growth', 'appreciation', 'simple', 'promote', 'able', 'combine', 'think', 'friendly', 'references', 'articulate', 'challenge', 'leader', 'willing', 'standards', 'teamwork', 'strong', 'highlight', 'coaching', 'innovative', 'crisis', 'unique', 'negotiation', 'effective', 'onboard', 'can', 'offer', 'yet', 'most', 'prove', 'objective', 'still', 'adaptability', 'continued', 'conflict', 'vision', 'together', 'efficient', 'capable', 'surplus', 'counseling', 'great', 'deadline', 'electricity', 'relationship', 'insight', 'coo', 'competitive', 'persuasive', 'excellent', 'newsletter', 'ultimately', 'ideal', 'productive', 'adaptable', 'acquire', 'demonstrate', 'always', 'patrick', 'contribute', 'instrumentation', 'delivered', 'quickly', 'strengthen', 'proven', 'talk', 'already', 'cfo', 'pressure', 'where', 'situation']
#
# Cluster: 5
# ['normal', 'fulfil']
#
# Cluster: 6
# ['strut', 'messaging', 'dhtml', 'boss', 'jsf', 'appway', '1.6', 'swings', 'extjs', 'awt', 'hibernate', 'soap', 'json', 'servlet', 'cgi', 'embed', 'groovy', '1.5', 'annotation', 'entity', 'rest', 'jmx', 'mqserie', 'jersey', 'jmock', 'config', 'oriented', 'boot', 'uddi', 'aop', 'dom', 'axis', 'ext', 'j2me', 'ioc', 'micro', '1.2', 'jaas', 'reusable', 'embedded', 'year(s', 'expose', 'diagrams', 'driven', 'plane', '1.1', 'jquery', 'jasper', 'wsdl', 'esb', 'swing', 'restful', 'jee', 'jsp', 'angular.js', 'drools', 'tiles', 'patterns', 'microservice', 'api', 'jdk1.6', 'frameworks', 'controller', 'ejbs', 'rich', 'jstl', 'dao', 'orm', 'xhtml', 'jdbc', 'dojo', 'angularjs', 'applets', 'persistence', 'struts', 'kornshell', 'beans', 'd3.js', 'ui', 'portlets', 'velocity', 'ibatis', 'ejb', 'j2se', '2.0', 'xi', 'consume', 'frontend', 'refactor', '1.3', 'icefaces', 'bean', 'spring', 'jakarta', 'xsd', 'j2ee', '5.0', 'mongo', 'sax', '3.0', 'webservice', 'xml', 'liferay', 'taglibs', 'activemq', 'jaxb', 'quartz', 'mdb', 'asynchronous', 'xquery', 'rmi', 'dynamically', 'gwt', 'singleton', 'java', 'multithreading', 'gemfire', 'webservices', 'javabeans', 'jaxp', 'di', 'servlets', 'xslt', 'mvc', 'message', 'tag', 'xsl', 'toolkit', 'jpa', 'mule', 'sdkman', 'j', 'faces', 'wireframe', 'bound', 'ilog', 'plugin', 'framework', 'layer', 'ee', 'queuing', 'xpath', 'jsps', 'se', 'validator', 'odbc', 'libraries', 'binding', 'cxf', 'abstract', 'javascript', 'bcbs', 'ajax', 'boingo']
#
# Cluster: 7
# ['hud', 'register', 'correspondence', 'planner', 'procurement', 'enter', 'diligence', 'could', 'allow', 'ccr', 'important', 'valid', 'output', 'outside', 'hurricane', 'contract', 'petty', 'debt', 'materials', 'meter', 'repetitive', 'portfolio', 'medium', 'information', 'invoicing', 'material', 'kept', 'trail', 'reconcile', 'copy', 'rent', 'screening', 'subcontract', 'bloomberg', 'correctly', 'deal', 'auxiliary', 'title', 'correct', 'cash', 'universe', 'trial', 'account', 'distribution', 'permit', 'recognition', 'feed', 'deletion', 'settlement', 'nyse', 'interfac', 'shop', 'bag', 'facet', 'fill', 'disconnect', 'entry', 'ea', 'origin', 'activation', 'eac', 'conditional', 'party', 'info', 'obligation', 'opening', 'raw', 'imagery', 'price', 'binder', 'agreement', 'govt', 'biomedical', 'modernize', 'ems', 'cleaning', 'will', 'portion', 'engineered', 'contact', 'questionnaire', 'general', 'appointment', 'damage', 'matter', 'expenditure', 'ups', 'purge', 'deposit', 'tie', 'difference', 'worksheet', 'pertinent', 'ecr', 'shelf', 'main', 'canadian', 'kyc', 'retrieval', 'drill', 'receipt', 'central', 'proceeding', 'transmittal', 'pharmacy', 'quote', 'chain', 'aggregate', 'presence', 'parser', 'spoe', 'regulatory', 'calculation', 'novel', 'temporary', 'ehr', 'submission', 'oats', 'accept', 'thru', 'tsp', 'futures', 'book', 'assemble', 'cc', 'negotiate', 'filing', 'seller', 'refund', 'processing', 'trc', 'scrub', 'drm', 'supply', 'incorporated', 'receptionist', 'send', 'timely', 'brief', 'character', 'ordering', 'purchase', 'lease', 'optical', 'clearing', 'illustrate', 'ita', 'sub', 'agreements', 'orders', 'yearly', 'drink', 'handover', 'transmission', 'letter', 'expense', 'retrieve', 'livelink', 'stock', 'lookup', 'physician', 'edms', 'belzberg', 'cashier', 'wachovia', 'inquiry', 'recordkeeping', 'accurate', 'sensitive', 'populate', 'authorize', 'additional', 'locate', 'webnas', 'feel', 'outgoing', 'extension', 'oversee', 'patient', 'collected', 'fulfillment', 'charge', 'property', 'schematic', 'near', 'floor', 'parking', 'sheet', 'buyer', 'consolidated', 'bill', 'keeping', 'ship', 'prism', 'gmp', 'invoice', 'dealer', 'notice', 'ledger', 'thousand', 'statement', 'entitlement', 'drawing', 'loaded', 'adjustment', 'shipping', 'broker', 'checkout', 'third', 'registry', 'properly', 'due', 'servicing', 'upload', 'figure', 'activate', 'archiving', 'paperwork', 'insert', 'lot', 'barney', 'inspector', 'ownership', 'tax', 'pull', 'scheduling', 'inventory', 'audit', 'disposal', 'visa', 'merchandise', 'approve', 'liability', 'fixed', 'incom', 'dealing', 'brochure', 'must', 'applicant', 'electronic', 'comply', 'subcontractor', 'edit', 'pdf', 'loop', 'attachment', 'pend', 'trader', 'transaction', 'catch', 'delete', 'indexing', 'display', 'maximo', 'history', 'incoming', 'oms', 'payable', 'journal', 'submit', 'tracker', 'swap', 'only', 'receive', 'intend', 'again', 'receivable', 'overhaul', 'shipment', 'read', 'bear', 'answer', '3pl', 'folder', 'bpp', 'virtually', 'replace', 'clerical', 'contractual', 'duty', 'credit', 'should', 'vendor', 'here', 'invoices', 'bond', 'manufacturer', 'govern', 'accounting', 'forth', 'assay', 'reward', 'order', 'trade', 'editing', 'metal', 'return', 'onboarding', 'teller', 'incentive', 'stearns', 'balance', 'sale', 'date', 'easily', 'transmit', 'caller', 'finra', 'editorial', 'professionalism', 'retirement', 'notify', 'ran', 'bookkeeping', 'loan', 'id', 'payment', 'freight', 'instrument', 'appropriately', 'would', 'tea', 'regulation', 'fee', 'asset', 'record', 'manually', 'out', '⃰', 'billing', 'supplier', 'look', 'formula', 'keep', 'kind', 'missing', 'searching', 'extinguisher', 'tenant', 'reconciliation', 'fidessa', 'respond', 'edwards', 'claims', 'accounts']
#
# Cluster: 8
# ['ucm', 'discoverer', 'reuters', 'aqualogic', 'navigator', '8i/9i/10', '9i/10g/11', 'oracle', 'apex', 'deploying', 'composite', 'sqlserver', 'r3', 'gate', 'portals', 'portal', 'vordel', 'sandbox', '11', 'mediator', 'adapter', 'databases', 'installed', 'documentum', 'middleware', 'ofsll', 'metadata', '8i', 'oc4j', '11g/', 'coherence', '10g/11', 'hyperion', 'osb', 'owsm', 'pentaho', 'manger', 'sit', 'bpa', 'adaptive', 'rules', 'viewer', 'integrations', 'bpel', 'suit', 'bam', 'adf', '9i/10', '10', 'oas', 'grid', 'soa', 'cfr', 'b2b', 'fusion', 'ohs', '11.5.10', 'plsql', 'webcenter', 'r2', 'dr', 'jdeveloper', 'primavera', 'oracle11', 'db', 'scom', 'oem', 'publisher', 'products', 'guard', 'oracle10', 'stack', 'bpm', 'timesten', 'mds', 'spatial', 'suite', 'gateway', 'obiee', 'dashboards', 'p6', '10gas', 'label', 'rcu', 'soa11', 'gis', 'builder', 'utilities', 'apps', 'g', 'cot', 'em', 'forms', 'bus', 'fmw']
#
# Cluster: 9
# ['bottleneck', 'timeout', 'tuning', 'adjust', 'count', 'heap', 'memory', 'sizes', 'collection', 'hang', 'gc', 'garbage', 'dump', 'size', 'monitored', 'leak', 'sga', 'leaks', 'fixing', 'parameter', 'diagnostic', 'deadlock', 'cpu', 'dumps', 'analyzer', 'idle', 'thread', 'jvm', 'trace', 'crash', 'fine', 'lock', 'tune']
#
# Cluster: 10
# ['iiq', 'spml', 'saml', 'authentication', 'provisioning', 'kerberos', 'workflows', '7.1', 'xpress', 'idm', 'provision', 'sso', 'federated', 'roles', 'authenticate', 'directory', 'isam', 'sign', 'so', 'connector', 'terminate', 'ldap', 'tivoli', 'assertion', 'identity', 'tfim', 'synchronization', 'federation', 'opensso', 'disable', 'sailpoint']
#
# Cluster: 11
# ['before']
#
# Cluster: 12
# ['manufacture', 'fleet', 'baylor', 'semiconductor', 'thomas', 'devry', 'mexico', 'ga', 'johns', 'alza', 'vegas', 'cox', 'energy', 'canada', 'kong', 'canvasser', 'prasad', 'greenville', 'pharmaceutical', 'relocate', 'hill', 'mexican', 'us', '04/2015', 'delaware', 'trailer', 'denmark', 'sites', 'nyc', 'bentonville', 'seattle', 'utah', 'madison', 'beacon', '1989', '4th', 'north', 'boston', 'epc', 'motor', 'newport', 'paulo', 'western', 'bayer', 'brevard', 'carolina', 'headquarter', 'hanoi', 'las', 'commander', 'bothell', 'england', 'expansion', 'construction', 'assigned', 'tenure', 'contractor', 'taiwan', 'saudi', 'airport', 'wa', 'hospitals', 'vsp', 'usa', 'lake', 'cci', 'motors', 'nv', 'sc', 'warner', 'brazil', 'são', 'american', 'solar', 'hopkins', 'jd', 'vietnam', 'dla', 'residency', 'miami', 'oxford', 'orlando', 'ridge', '03/2012', 'christian', 'op', 'la', 'fl', 'cas', 'southern', '1983', 'irvine', 'bagram', '1990', 'georgia', 'rock', 'ny', 'ks', 'china', 'siemens', 'nations', 'jp', 'abbott', 'bay', 'de', 'hong', 'theater', 'lighting', 'controls', 'korea', 'birlasoft', 'york', 'zurich', 'fifth', 'mcgraw', 'stamford', 'japan', 'kohl', 'afghanistan', 'americas', '412', 'mountain', 'uk', 'facilities', 'truck', 'fabrication', 'gas', 'europe', 'industries', 'eu', 'latin', 'division', 'plant', 'wind', 'companies', 'gurgaon', 'philadelphia', 'atlanta', 'emerson', 'london', 'walmart', 'nokia', 'ireland', 'fort', 'subgroup', 'fluor', 'mianyang', 'relocation', 'laboratories', 'electric', 'milwaukee', 'galaxy', 'singapore', 'france', 'broadcom', 'hsbc', 'avis', 'hi', 'manhattan', 'disney', 'wire', 'bowes', 'jpmorgan', 'wisconsin', 'pitney', 'nuclear', '228', 'city', 'universal', 'beijing', 'church', 'kaiser', 'abercrombie', 'international', 'hotels', 'green', 'labs', 'dow', 'plc', 'ge', '401', 'australia', 'mwh', 'falls', 'fitch', 'compaq', 'at&t', 'arc', '513', 'orleans', 'wi', 'prep', '09/2012', 'harvard', 'taipei', 'abb', 'pacific', 'pediatric']
#
# Cluster: 13
# ['nosql', 'pig', 'hdfs', 'hive', 'hadoop', 'mapreduce', 'cloudera', 'impala', 'sqoop', 'cassandra', 'hbase', 'spark', 'yarn']
#
# Cluster: 14
# ['chemical', 'wine']
#
# Cluster: 15
# ['angular', 'js']
#
# Cluster: 16
# ['long']
#
# Cluster: 17
# ['alliance', 'm&a', 'marketing', 'securities', 'nestlé', 'subsidiary', 'found', 'perot', 'accountant', 'manufacturing', 'donco', 'infosys', 'sell', 'worldwide', 'financing', 'telecom', 'mutual', 'global', 'currency', 'partnership', 'commercial', 'america', 'country', 'south', 'airline', 'gerber', 'drug', 'hospitality', 'bnym', 'own', 'family', 'vacation', 'market', 'nutrition', 'laser', 'care', 'corporation', 'world', 'premium', 'scientific', 'large', 'verizon', 'range', 'aim', 'currently', 'banking', 'industry', 'payer', 'healthcare', 'cantor', 'functioning', 'marketplace', 'portability', 'consulting', 'venture', 'markets', 'tower', 'coffee', 'retailer', 'income', 'organizations', 'scale', 'footprint', 'hunter', 'economy', 'mae', 'trading', 'article', 'european', 'cigna', 'array', 'financial', 'offering', 'institution', 'brokerage', 'airlines', 'hotel', 'honda', 'insurance', 'rio', 'investor', 'globe', 'oil', 'square', 'retail', 'broad', 'asia', 'region', 'philips', 'estate', 'bank', 'equity', 'fortune', 'nationwide', 'sector', 'employ', 'become', 'monetary', 'ubs', 'nasdaq', 'gccp', 'principal', 'sized', 'ct', 'holdings', 'interest', 'lending', 'hanover', 'generalist', 'derivative', 'patent', 'wealth', 'consumer', 'calendar', 'private', 'location', 'africa', 'firm', 'adopt', 'company', 'investment', 'dream', 'funds', 'options', 'automotive', 'provider', 'sears', 'capital', 'fannie', 'travel', 'competitor', 'equities', 'automobile', 'farm', 'connecture', 'seed', 'exposure', 'entertainment']
#
# Cluster: 18
# ['summary']
#
# Cluster: 19
# ['eap', '6.x', '12.1.3', '2.5', 'tomcat', 'jboss', '10.x', '10.3.5', '8.x', '10.3.6', 'iplanet', 'jdk', '6.x/7.x', 'webserver', '11g/12c', 'bea', '2.x', 'al', '8.1/9.2', 'glassfish', '8.5.5', '6.1', '9.2/10.3', 'alsr', '5.1/6.0', 'was', '8.0', '9.2/10.0', '7.x/8.x', 'solr', '2.1', '10.3.x', 'sp3', '2.2', '8.5', 'websphere', '9.2mp2', '12c', 'installing', 'sonic', 'sunone', '6.1/7.0', '10.0', '8.1', '7.x', '9.x', 'agents', '9.2', '10.3', 'alsb', 'apache']
#
# Cluster: 20
# ['greet', 'rural', 'secondary', 'assistance', 'please', '2014-december', 'restaurant', 'cooperate', 'rare', 'fellow', 'received', 'constant', 'extracurricular', 'abroad', 'speaking', 'visit', 'swimming', 'organized', 'curriculum', 'internship', 'golf', 'delegate', 'activities', 'encourage', 'organizer', 'mathematic', 'awareness', 'transition', 'resident', 'apus', 'gym', 'emergency', 'career', 'community', 'kid', 'soldier', 'tayohya', 'village', 'professor', 'mentored', 'supervisor', 'newspaper', 'selected', 'nursing', 'special', 'counsel', 'listen', 'member', 'child', 'campus', 'interview', 'winter', 'tutor', 'girl', 'homeless', 'background', 'subject', 'outreach', 'educational', 'participation', '▪', 'mark', 'individually', 'quiz', 'shelter', 'haining', 'hire', 'welfare', 'complaint', 'game', 'lifestyle', 'math', '90', 'personally', 'personal', 'begin', 'food', 'capstone', 'stationery', 'tutoring', 'guest', '22', 'previously', 'want', 'woman', 'teaching', 'lecture', 'prospective', 'assistant', 'volunteer', 'meal', 'stamp', 'event', 'counselor', 'classroom', 'diversity', 'grade', 'about', 'arrange', 'hall', 'mentor', 'photography', 'donate', 'orientation', 'summer', 'placement', 'question', 'worker', 'board', 'seminar', 'supervision', 'examination', 'what', 'camp', 'organize', 'how', 'freshman', 'crew', 'eight', 'body', 'honduras', 'local', 'resume', 'staff', 'underprivileged', 'education', 'clarify', 'athletic', 'attended', 'children', 'treat', 'gsg', 'served', 'sergeant', 'who', 'especially', 'rotaract', 'budgeting', 'teacher', 'hiring', 'reception', 'dining', 'sustainability', 'olympics', 'preside', 'tutorial', 'parent', 'conway', 'promise', 'blackboard', 'patron', 'blog', 'behavioral', 'petition', 'ngo', 'students’', 'recruit', 'coach', 'dr.', 'e.', 'familiarize', 'peer', 'lunch', 'sport', 'shift', 'coordinator', 'volunteering', 'student', 'faculty', 'doctor', 'cater', 'boarding', 'educate', 'young', 'foster', 'pursue', 'coordinating', 'teach', 'recreational', 'artillery', 'academic', 'weekend', 'demonstration', 'elementary', 'technician', 'recruitment', 'colleague', 'fair', 'lesson', 'visitor', 'multimedia', 'entrepreneur', 'stabilize', 'mental']
#
# Cluster: 21
# ['notes', 'lotus']
#
# Cluster: 22
# ['tx', 'delta', 'dallas', 'stake', 'partners', 'holder', 'chicago', 'pi', 'irving']
#
# Cluster: 23
# ['predictive', 'mining']
#
# Cluster: 24
# ['controllers', 'scanner', 'card', 'magnetic', 'scan', 'ic', 'stripe', 'either', 'item', 'reader', 'shopping', 'chip', 'mainly', 'handheld', 'ncr', 'encore', 'verifone', 'machines', 'cat', 'cable', 'pos', 'debit', 'emv', 'gift', 'bed', 'ingenico']
#
# Cluster: 25
# ['select']
#
# Cluster: 26
# ['rate', 'simplify', 'half', '95%', 'retention', 'better', 'avoid', 'projection', 'propose', 'consumption', 'profitability', 'sourcing', '75%', 'departmental', 'margin', '50%', 'stay', '90%', 'limit', 'maximum', 'determined', 'down', 'suitable', 'upper', '20%', 'spend', 'threshold', 'value', 'delay', 'stability', 'option', 'operational', 'proactive', 'breach', 'determination', 'agree', 'save', '30%', 'gmsec', '60%', 'improvise', 'optimal', 'quant', 'commodity', 'far', 'recur', '80%', 'dso', 'unnecessary', 'efficiency', 'redundancy', 'eliminate', 'advertising', 'restructure', 'demand', 'productivity', '12%', 'enforce', 'observe', 'streamlined', 'bounce', 'improve', 'earned', 'kpi', 'manipulate', 'intervention', 'pulse', 'volume', 'venue', '\uf020', 'thereby', 'leveraged', 'complexity', 'potential', 'incur', 'improvement', 'sound', 'consistently', 'devise', 'lean', 'expedite', 'acquisition', 'overall', 'underlie', 'roi', 'close', 'prevent', 'reduction', 'disclosure', 'constraint', '10%', 'turn', 'loyalty', 'cost', 'accountable', 'customers’', 'tactic', '25%', 'curtail', 'measure', 'rental', 'exceed', 'increase', 'bid', 'reduce', 'sustainable', 'lose', 'promotion', 'funding', 'achieve', 'least', 'cut', 'adherence', 'tactical', 'improved', 'outline', 'breakdown', 'budget', 'buy', 'suggestion', '15%', 'thus', 'standardize', 'pts', 'streamline', 'decrease', 'staffing', 'downtime', '40%', 'pricing', 'suggest', 'revamp', 'implication', 'limitation', 'effectiveness', 'variance', 'sla', 'gmat', 'fx', 'saving', 'minimize', 'insertion', 'maximize', 'mistake', 'reduced', 'accomplishment', 'profit', 'percent', 'alignment', 'discount', 'dual', 'identified', 'time', 'spending', 'boost', 'optimize', 'turnaround']
#
# Cluster: 27
# ['santa', 'silicon', 'creek', 'jose', 'tester', 'altos', 'angeles', 'corp.', 'hills', '11/13', '10/16', 'los', 'clara', 'valley', 'courses', 'sacramento', 'ca', 'portnov']
#
# Cluster: 28
# ['instruction']
#
# Cluster: 29
# ['spr', 'nsips', 'scr']
#
# Cluster: 30
# ['statistic']
#
# Cluster: 31
# ['modeling', 'optimization', 'docs', 'dbms', 'glimmix', 'bluemix', 'decisions', 'minitab', 'businessworks', 'solver', 'arena', 'stata', 'mongodb', 'cypher', 'miscellaneous', 'er', 'draw', 'ssi', 'r', 'tree', 'salesforce', 'maps', 'pivot', 'palisade', 'making', 'clarity', 'lucid', 'precisiontree', 'visualization', 'statistical', 'analytics', 'decision', 'trees', 'tobii', 'rstudio', 'salesforce.com', 'excel', 'ms', 'precision', 'neo4j', 'simulink', 'modeler', 'solvertable', 'jmp', 'stattools', '@risk', 'big', 'tableau', 'charts', 'transformational', 'models', 'spreadsheet', 'lucidchart', 'macros', 'adwords', 'modelling', 'google', 'tables', 'stat', 'chart', 'cleansing', 'hypothesis', 'sas', 'skills']
#
# Cluster: 32
# ['trainer']
#
# Cluster: 33
# ['jan', 'nov', 'feb', 'jun', 'aug', 'jul', 'oct', 'mar', 'sep', 'apr', 'dec']
#
# Cluster: 34
# ['shadow', 'minimum', 'bsc', 'arduino', 'lte', 'metro', '1c', 'pcs', '∙', 'tilt', 'wave', 'gsm', 'radio', 'simulate', 'wcdma', 'channel', 'carrier', 'mock', 'umts', 'cellular', 'd.c.', 'drop', 'coverage', '\xad', 'antenna', 'surround', 'cdma', 'preliminary', 'suburb', 'downlink', 'stations', 'station', 'poseidon', 'alarm', 'ofdm', 'interference', 'microwave', 'cell', 'path', 'downtown', 'ericsson', 'simulation', 'wimax', '3-sectored', 'rf', 'block', 'd.c', 'nearby']
#
# Cluster: 35
# ['fast', 'pace']
#
# Cluster: 36
# ['format', 'edi', 'hl7', 'claim', 'dental', '835', 'mandate', 'x12', 'ansi', '270/271', 'institutional', 'crosswalk', 'p', 'reimbursement', '4010', 'icd', '834', '837', '276/277', 'hipaa', 'eligibility', 'translation', '5010']
#
# Cluster: 37
# ['cybersecurity', 'directive', 'trusted', 'fips', 'remediate', 'prevention', 'customs', 'authority', 'unauthorized', 'ciso', 'privacy', 'poa&m', 'isso', 'border', 'pta', 'nist', 'guideline', 'artifact', 'disa', 'following', 'poa&ms', 'st&e', 'ssp', 'ato', 'authorization', 'obtain', 'weakness', 'fisma', '199', 'sa', 'routinely', 'contingency', 'csam', 'mitigate', 'assessment', 'audits', 'ra', 'scanning', 'commission', 'nessus', 'a&a', 'posture', 'mitigation', 'c&a', 'rar', 'assessments', '37', 'protect', 'deficiency', '800', 'categorization', 'protection', 'corrective', 'realm', 'based', 'hrci', 'hardening', 'milestones', 'vulnerability', 'threat', 'cp', 'ice']
#
# Cluster: 38
# ['manipal', 'natural', 'ieee', '\u200b-', 's.', 'autonomous', 'karnataka', 'iit', 'jaypee', 'delhi', 'w.', 'contest', 'j.', 'rise', 'ltd.', 'mumbai', 'vellore', 'f.', 'm.', 'duration', 'sports', 'tata', 'srikant', 'sagar', 'bombay', 'noida', 'rank', 'chandigarh', 'head', 'praxis', 'wall', 'california', 'pooma', 'east', 'chennai', 'symposium', 'bharat', 'bakery', 'indian', 'k.j.', 'kjsce', 'computing', 'artificial', 'rodrigues', 'technology-', 'satyam', 'infotech', 'pune', 'somaiya', 'emerging', 'fr', 'institute', 'r.', 'cummins', 'impetus', 'mahindra', 'excellence', 'bangalore', 'hyderabad', 'k.', 'atlas', 'srm', 'maharashtra', '2nd', 'sanghvi', 'p.', 'dwarkadas', 'consultancy', 'berkeley', 'csi', 'surat', '1988', 'nagpur', 'west', 'c.', 'larsen', 'women', 'rotary', 'brown', 'rome', 'kpmg', 'india', 'leaders', 'merit', 'vesit', 'schneider']
#
# Cluster: 39
# ['agent', 'varied', 'jython', 'orchestration', 'logs', 'alamo.com', 'deployment', 'monitor', 'everyday', 'recycle', 'tuxedo', 'instance', 'balancing', 'alone', 'startup', 'clustered', 'crontab', 'rotation', 'components', 'monitoring', 'executed', 'node', 'proxy', 'admin', 'korn', 'adhoc', 'logging', 'packaging', 'auto', 'weblogic', 'space', 'jar', 'configure', 'binary', 'workload', 'endeca', 'graphtalk', 'env', 'webmethods', 'clustering', '24x7', 'cert', 'nodes', 'nationalcar.com', 'plugins', 'installer', 'wls', 'prototyped', 'configuring', 'fail', 'deploy', 'failover', 'mode', 'start', 'cron', 'wizard', 'scripts', 'cache', 'standalone', 'war', 'jenkin', 'clusters', 'administrate', 'shell', 'url', 'run', 'servers', 'wlst', 'cluster', 'shared', 'silent', 'console', 'shutdown', 'script', 'environments', 'debug', 'disk', 'dip', 'deployed', 'atg', 'restart', 'alert', 'plug', 'bamboo', 'concurrent', 'container', 'stop', 'runtime', 'virtualization', 'tc', 'availability', 'bash', 'ear', 'invoke', 'dynatrace', 'heterogeneous', 'malformed', 'portlet', 'docker', 'domain', 'aem', 'running', 'bourne', 'ksh', 'dev', 'atom', 'udeploy']
#
# Cluster: 40
# ['russia', 'moscow']
#
# Cluster: 41
# ['distributed', 'workshop', 'super', 'developers', 'thomson', 'trs', 'miller', 'zachary', 'analyst', 'primarily', 'bp', 'engineer', 'administrative', 'iii', 'emphasize', 'designation', 'cameroon', 'representative', 'liaise', 'workshops', 'users', 'roadmap', 'managers', 'senior', 'tech', 'boeing', 'technology', 'briefing', 'programmer', 'qualification', 'section', 'now', 'administrator', 'it', 'certification', 'centre', 'interests', 'manager/', 'supported', 'ufms', 'pmp', 'lynda.com', 'sw', 'engineers', 'course', 'cmm', 'assurance', 'advanced', 'ops', 'overview', '/contribution', 'facilitation', 'cmmi', 'relevant', 'devops', 'top', 'scrum', 'forklift', 'intelligence', 'foundation', 'jumpstart', 'du', 'auditor', 'instructor', 'jaspersoft', 'comptia', 'a+', 'openlink', 'professional', 'associate', 'helpdesk', 'act', 'itil', 'hacking', 'preparer', 'cap', 'noc', '17', 'globally', 'publications', 'continuity', 'deloitte', 'accenture', 'advisor', 'contributed', 'cd', 'certified', 'train', 'howard', 'limited', 'cms', 'pmo', '9001', 'mcp', 'hosting', 'executive', 'coe', 'fame', 'demos', 'v3', 'itsm', 'edward', 'instructional', 'fundamental', 'msrb', 'shore', 'mcse', 'attain', 'desk', 'systems', 'ethical', 'principles', 'exercise', 'cissp', 'iso', 'proprietary', 'former', 'arm', 'laboratory', 'brain', 'hands', 'junior', 'ba', 'iv', 'liaison', 'practices', 'ii', 'advise', 'douala', 'industrial', 'cyber', 'learning', 'managing', 'years’', 'training', 'enablement', 'intern', 'certify', 'pioneer', 'provides', 'consultant', 'hewitt', 'present', 'forum', 'sr', 'isd', 'principle', 'dba', 'associated', 'saba', 'mentoring', 'goldman', 'ccna', 'scrummaster', 'essential', 'cognizant', 'elevator', 'upk', 'endur', 'specialist', 'maturity', 'pmi']
#
# Cluster: 42
# ['law', 'enforcement']
#
# Cluster: 43
# ['detroit', 'gm', 'mi']
#
# Cluster: 44
# ['segment']
#
# Cluster: 45
# ['k']
#
# Cluster: 46
# ['sept']
#
# Cluster: 47
# ['ecs', 'putty', 'dynamodb', 'workspace', 'ebs', 'watch', 'hybrid', 'formation', 'saas', 'cloud', 'scaling', '53', 'sqs', 'az', 'route', 'vpc']
#
# Cluster: 48
# ['eye', 'curve', 'simulator', 'graph', 'accuracy', 'l’oreal', 'probability', 'roc', 'stress', 'predict', 'traffic', 'plot', 'compute', 'emulator']
#
# Cluster: 49
# ['conversational', 'german', 'russian', 'english', 'french', 'tone', 'literature', 'korean', 'mandarin', 'native', 'spanish', 'ukrainian', 'african', 'intermediate', 'fluent', 'reading', 'chinese', 'beginner', 'portuguese', 'speak', 'swim', 'hindi', 'hobby', 'language']
#
# Cluster: 50
# ['projects']
#
# Cluster: 51
# ['approach']
#
# Cluster: 52
# ['bi', 'po', 's/4', 'poc', 'sum', 'fico', 'bobi', 'ordination', 'ewm', 'ecc', 'bw', 'r/3', 'hana', 'bpc', 'customers', 'co', '10.1', 'otc', 'mobility', '>', 'integrating', 'fi', 'pilot', 'followed', 'pm', 'sales', 'mm', 'sd', 'costing', 'slt', 'hec', 'erp', 'plm', 'netweaver', 'wm', 'sap', 'scm', '||', '7.3', 'mdm', 'grc', 'pp']
#
# Cluster: 53
# ['advisory']
#
# Cluster: 54
# ['express']
#
# Cluster: 55
# ['powerpoint', 'acrobat', 'outlook', 'visio', 'word']
#
# Cluster: 56
# ['washington', 'dc']
#
# Cluster: 57
# ['setting', 'consolidation', 'but', 'activity', 'scalability', 'program', 'feature', 'mirror', 'modify', 'services', 'developed', 'appliance', 'conceptualize', 'base', 'wrote', 'required', '\uf0a7', 'software', 'clients’', 'relation', 'tracking', 'object', 'involve', 'customization', 'design', 'encompass', '’s', '○', 'work', 'customer', 'kit', 'cbs', 'architected', 'troubleshoot', 'end', 'reporting', 'delivery', 'regularly', 'respectively', 'scratch', 'extremely', 'include', 'job', 'support', 'via', 'few', 'routine', 'write', 'grouping', 'guide', 'formulation', 'strategy', 'functionality', 'full', 'create', 'effort', 'expertise', 'custom', 'provide', 'cover', 'other', 'credential', 'point', 'internationalization', 'this', 'specialized', 'migration', 'require', 'existing', 'flow', 'solid', 'office', 'house', 'administration', 'application', 'perspective', 'warranty', 'hierarchy', 'infrastructure', 'expert', 'add', 'legacy', 'capture', 'some', 'mainframe', 'hoc', '3.50', 'call', 'automated', 'handle', 'managed', 'same', 'white', 'that', 'retrofit', 'odm', '919', 'non', 'dcs', 'webinar', 'verse', 'rollout', 'establish', 'under', 'tier', 'r&d', 'maintain', 'ecybermission', 'have', 'fpars', 'update', 'responsibility', 'resource', 'form', 'certain', 'critical', 'michael', 'manual', 'kranthikbheema@gmail.com', 'execute', 'feeder', 'onshore', 'setup', 'datum', 'parallel', 'workflow', 'field', 'take', 'do', 'like', 'i.e.', 'file', 'implemented', 'integration', 'pfizer', 'naming', 'enhanced', 'client', 'maintenance', 'mis', 'caching', 'best', 'facilitate', 'responsible', 'cm', 'pre', 'across', 'common', 'system', 'implementation', '-PRON-', 'all', 'real', 'archive', 'available', 'troubleshooting', 'redesign', 'extensive', 'bfs', 'modular', 'cbt', 'code', 'relate', 'repository', 'specifically', 'distribute', 'auditing', 'optimized', 'procedure', 'link', 'subsystem', 'rewrite', 'designing', 'enrol', 'along', 'unified', 'batch', 'number', 'architecture', 'template', 'transfer', 'consistency', 'contain', 'high', 'library', 'team', 'within', 'centralized', 'utilize', 'occasion', 'entire', 'user', 'database', 'conversion', 'architect', 'assist', 'method', 'undertaken', 'pwm', 'type', 'logic', 'enterprise', 'e.g.', 'developer', 'navigation', 'apigee', 'part', 'good', 'uptime', 'rice', 'many', 'search', 'access', 'corporate', 'interaction', 'knowledge', 'couple', 'whole', 'level', 'these', 'automate', 'just', 'app', 'conduct', 'stlc', 'function', '’', 'domestic', 'subscriber', 'external', 'graphical', 'integrity', 'robust', 'platform', 'ongoing', 'performance', 'primary', 'core', 'physical', 'capability', 'author', 'complex', 'map', 'jump', 'consist', 'merge', 'discovery', 'middle', 'compliance', '\uf06e', 'internal', 'speed', 'geographical', 'enhancement', 'heavy', 'management', 'automation', 'scalable', "'s", 'between', 'disparate', 'module', 'broadband', 'screen', 'in', 'technical', 'business', 'led', 'planning', 'both', 'interface', 'cq', 'email', 'accommodate', 'on', 'scheme', 'wise', 'session', '11/2013', 'from', 'hand', 'generation', 'tool', 'not', 'proposal', 'product', 'built', 'enable', 'compilation', 'e', 'carry', 'cod', 'involved', 'example', '\ue00c', 'd.b.a.', 'data', 'wide', 'different', 'everything', 'service', 're', 'crud', 'report', 'addie', 'develop', 'related', 'rule', 'mechanism', 'used', 'governance', 'customize', 'build', 'capacity', '02/10/2012', 'role', 'specific', 'through', 'such', 'ease', 'complete', 'site', 'menu', 'profile', 'make', 'component', 'policy', 'launch', 'jeppesen', 'structure', 'publish', 'as', 'aspect', 'extend', 'several', 'completely', 'line', 'life', 'stream', 'group', 'unit', 'use', 'catalog', 'source', 'vital', 'solution', 'jcl', 'multi', 'replicate', 'enhance', 'downstream', 'ecommerce', 'online', 'independent', 'page', 'recent', 'project', 'handling', 'performed', 'security', 'collaborate', 'generate', 'driver', 'modification', 'standard', 'focus', 'vault', 'load', 'manager', 'addition', 'necess ...
#
# Cluster: 58
# ['street', 'quail', 'terrace', 'rhode', '626', '330', '410', '20783', 'ray', 'silver', '318', '292', 'apt', 'bethesda', '48th', '21', 'linkedin', '571', 'edmonston', 'christopher', '422', 'knox', 'ave', '9111', '20740', 'kranthi', 'rockville', 'baltimore', 'txt', 'st', 'bheema', '\uf09f', 'rowalt', '224', '3102920250@pm.sprint.com', '75094', '1660', '702', '720', '|', 'md', '310', '8125', '301', 'lane', 'island', '443', '7843', 'subramanian', '360', '=', '703', '♦', 'hyattsville', 'rd', 'aflac', 'andrew', '4324', 'reiz', '305', 'david', '550', '640', '►', '1276', 'college-', 'factgem', '202', '■', '864', 'zgoldman@terpmail.umd.edu', 'harris', '638', 'tulane', 'rajan', 'road', '323', '\x97\uf097', 'ellicott', '469', 'arundel', '3412', 'murphy', '368', 'circle', 'avenue', '240', 'tel', 'mailing', 'potomac', '9530', 'park', '262', '860', 'greenbelt', 'http://daveray.net', '20770', 'ph', 'anne', '0250', '201', '3345', '101', '825', '520']
#
# Cluster: 59
# ['jax', 'ws', 'rs']
#
# Cluster: 60
# ['employer']
#
# Cluster: 61
# ['factor', 'conjoint', 'stitching', 'swot', 'logistic', 'strength', 'issn', 'characteristic', 'usage', 'forecast', 'circumstance', 'outcome', 'technique', 'vote', 'construct', 'fraud', 'disease', 'quantitative', 'category', '100,000', 'density', 'death', 'acknowledge', 'iot', 'economic', 'linear', 'anova', 'harness', 'presidential', 'examine', 'porter', 'ingredient', 'frequently', 'effect', 'confidence', '8051', 'forest', 'restatement', 'ir', 'trend', 'cart', 'bayes', 'manipulation', 'birth', 'loss', 'ride', 'structural', 'column', 'experiment', 'amount', 'bar', 'fly', 'intrusion', 'programmed', 'study', 'thing', 'webpage', 'detector', 'hughes', 'news', 'kalman', 'intelligent', 'qualitative', 'observation', 'interesting', 'rating', 'persistent', 'popular', 'classify', 'techniques', 'bio', 'weight', 'polymer', 'aggregation', 'churn', 'measurement', 'eat', 'naïve', 'retransmission', 'motion', 'visualize', 'neural', 'symbol', 'analytic', 'conceptualized', 'kernel', 'maker', 'toolbox', 'age', 'gps', 'signal', 'model', 'geographic', 'handled', 'compiler', 'filtering', 'static', 'attack', 'movement', 'descriptive', 'mixture', 'pattern', 'knn', 'explore', 'compensate', 'analog', 'show', 'systematic', 'cadence', 'vuser', 'counter', 'cuisine', 'sensitivity', 'classification', 'compare', 'propagation', 'indicator', 'vector', 'feasible', '1900', 'incidence', 'transmitter', '3000', 'election', 'sample', '3d', 'mine', 'consider', 'correlation', 'wheel', 'scientist', 'reliability', 'algorithm', 'forecasting', 'sentiment', 'paper', 'microcontroller', 'mean', 'huge', 'seasonal', 'calculate', 'scorecard', 'prediction', 'quantity', 'panel', 'dataset', 'dependent', 'filter', 'clean', 'choice', 'door', 'nation', 'habit', 'popularity', 'condition', 'resonate', 'sensor', 'interval', 'frequency', 'utilization', 'parse', 'accident', 'nature', 'semi', 'diamond', 'demographic', 'text', 'depict', 'heat', 'temperature', 'mapbox', 'bluetooth', 'bitbyte', 'similar', 'water', 'comparison', 'waste', 'glm', 'mathematical', 'graphs', 'treatment', 'movie', 'generalized', 'choose', 'split', 'random', 'reviewer', 'detection', 'segmentation', 'algae', 'nn', 'classmate', 'fade', 'explain', 'zero', 'receiver', 'arrive', 'useful', 'normalization', 'basket', 'fit', 'continuously', 'inner', 'color', 'dive', 'stores']
#
# Cluster: 62
# ['qtp', 'elementool', 'director', 'works', 'alm', 'radar', 'lab', 'jira', 'rally', 'ppm', 'webdriver', 'sqa', 'vs', 'runner', 'loadrunner', 'quality', 'serena', 'winrunner', 'servicenow', 'vugen', 'sbm', 'generator', 'pro', 'rail', 'mtm', 'jaws', 'clear', 'caliber', 'qc', 'bugzilla', 'quest', '8.2', 'atlassian', 'uperform', 'center', 'hpalm', 'quick', 'remedy', 'mercury', 'hp', '12.0', 'selenium', 'hpqc', 'composer', 'robot', 'spirent', 'mantis', 'uft', 'silk', 'siebel', 'testrail', 'tbs', '11.5']
#
# Cluster: 63
# ['webgate', 'oud', 'oid', 'odsee', 'ovd', 'accessgate', 'oaam', 'oif', '11gr2', 'oig', 'ps3', 'ha', 'oim', 'odsm', 'idam', 'oam', 'oes', 'ps2']
#
# Cluster: 64
# ['preference', 'ranking', 'see', 'trp', 'p.l.a.n.', 'billion', 'mypi']
#
# Cluster: 65
# ['lockheed', 'martin', 'pae']
#
# Cluster: 66
# ['dns']
#
# Cluster: 67
# ['ltd', 'pvt']
#
# Cluster: 68
# ['schemas', 'odi', 'powerexchange', 'join', 'query', 'idms', 'cdm', 'queries', 'interactive', 'exp', 'ddl', 'edw', 'iq', 'schema', 'store', 'c#.net', 'package', 'stored', 'cognos', 'pump', 'ab', 'sql', 'star', 'ssrs', '2.6', 'dw', 'datastage', 'interim', 'templates', 'transformation', 'dictionary', 'target', 'extraction', 'dml', 'rdbms', 'bss', 'stag', 'mapping', 'mart', 'oltp', 'table', 'flat', 'warehousing', 'logical', 'fms', 'pro*c', 'classic', 'procedures', 'powerful', 'amp', 'fetch', 'microstrategy', 'netezza', 'cube', 'unload', 'trigger', 'addm', 'warehouse', 'cleanse', 'macro', 'aginity', 'view', 'power', 'powermart', 'mask', 'informatica', 'bo', 'structured', 'objects', 'sftp', 'mulesoft', 'tsql', 'spy', 'olap', 'triggers', 'packages', 'export', 'teradata', 'embarcadero', 'loading', 'udb', 'pl', 'tm1', 'ods', 'powercenter', 'omni', 'ase', 'nfp', 'db2', 'index', 'sybase', 'clothing', 'combination', 'loader', 'dimensional', 'golden', 'bulk', 'dts', 'postgresql', 'dcl', 'transactional', 'reside', 'erwin', 'separate', 'powerbuilder', 'extensively', 'brio', 'ssis', 'relational', 'ssas', 'erd', 'cubes', 'extract', 'pds', 'import', 'dimension', 'integrator', 'spool', 'etl', 'awr']
#
# Cluster: 69
# ['svn', 'chef', 'artisan', 'versioning', 'cots', 'mgmt', 'starteam', 'sql*plus', 'plus', 'ooad', 'maven', 'fiddler', '3.2', 'sdk', 'ant', 'coldfusion', 'hudson', 'harvest', 'debugging', 'perforce', 'junit', 'myeclipse', 'toad', 'tools', 'rup', '4.2', 'files', 'ansible', 'gradle', 'sdlc', 'autosys', 'mssql', 'nant', 'intellij', 'hook', 'safe', 'firebug', 'ssh', 'clearcase', 'cucumber', 'agile', 'logo', 'log4j', 'aqua', 'tdd', 'confluence', 'jbuilder', 'tibco', 'virtualbox', 'adb', 'vss', 'cruisecontrol', 'wiki', 'requisite', 'rapid', 'oop', 'git', 'eclipse', 'methodology', 'pvcs', 'rad', 'waterfall', 'subversion', 'clearquest', 'ooa', 'rtc', 'artifactory', '2000/', 'rational', 'ci', 'tortoise', 'familiar', 'nexus', 'pair', 'jenkins', 'winscp', 'xcode', 'wsad', 'rcp', 'paradigm', 'v', 'client-', 'continuous', 'puppet', 'ood', 'rc', 'uml', 'filezilla', 'cvs', 'methodologies', 'rose', 'jobs', 'sts', 'charles', 'galileo', 'autonomy', 'soapui', 'cruise', 'testng', 'tfs', 'theme', 'mockito', 'github', '12.5', 'cygwin', 'ide']
#
# Cluster: 70
# ['5.7', 'planet', 'mentum']
#
# Cluster: 71
# ['electronics']
#
# Cluster: 72
# ['variable']
#
# Cluster: 73
# ['wells', 'mortgage', 'fargo']
#
# Cluster: 74
# ['troubleshot', 'printing', 'internet', 'datapower', 'nortel', 'tablet', 'facebook', 'devices', 'securely', 'citrix', 'anti', 'pega', 'voltage', 'soft', 'hub', 'keil', 'virus', 'mail', 'csr', 'intranet', 'separation', 'photo', 'printer', 'host', 'catalyst', 'msc', 'connect', '1,000', 'accessibility', 'sccm', '∙test', 'permission', 'attach', 'peripheral', 'pacs', 'projector', 'pki', 'download', 'networking', 'ring', 'signature', 'vob', 'unclassified', 'cryptography', 'layout', 'renewal', 'voip', 'lims', 'renew', 'ipad', 'touch', 'encryption', 'com', 'des', 'anywhere', 'machine', 'sms', 'proteus', 'rajvkk@yahoo.com', 'remotely', 'cad', 'wireless', 'chat', 'blackberry', 'constituent', 'synchronize', 'unity', 'device', 'symantec', 'laptop', 'terminal', 'membership', 'unlock', 'antivirus', 'forwarding', 'right', 'classified', 'spam', 'abbvie', 'circuit', 'certificates', 'iphone', 'adele', 'xerox', 'remove', 'storage', 'active', 'certificate', 'ssl', 'hard', 'layers', 'registration', 'surveillance', 'smartphone', 'camera', 'equipment', 'pspice', 'secure', 'virtual', 'upkeep', 'network', 'hardware', 'fax', 'pc', 'install', 'workstation', 'cards', 'media', 'video', 'pgp', 'voice', 'instal', 'repair', 'audio', 'fiber', 'smart', 'ghost', 'dsl', 'poll', 'connectivity', 'remote', 'wms', 'secured', 'nfs', 'print', 'image', 'django', 'premise', 'fedex', 'room', 'avaya', 'ware', 'license', 'privilege', 'linksys', 'password', 'token', 'gear', 'intel', 'wallet', 'bind', 'frame', 'firewall', 'ids', 'login', 'desktop', 'apple', 'port', 'transport', 'telephone', 'modem', 'exchange', 'icloud', 'processor', 'reverse', 'cerner', '\uf0d8', 'hw', 'banyan', 'rsa', 'switch', 'provided', 'phone', 'circuits', 'reset', 'seamless', 'ticketing', 'router', 'simultaneous', 'satellite', 'inventori', 'mount', 'imaging', 'digital']
#
# Cluster: 75
# ['telecommunications', 'ann', 'robert', 'statistics', 'cum', 'gre', 'syracuse', 'aas', 'sociology', 'b.s', '3.6', 'totals', 'school', 'telecommunication', 'b.tech', 'candidate', 'science', 'summa', 'academy', '3.5', 'studies', 'communications', 'michigan', 'expect', 'laude', 'computer', 'masters', '4.0/4.0', 'arts', '3.9', 'informatics', 'philosophy', 'b.e.', 'h', '1991', 'indianapolis', 'modern', 'il', 'is', 'tn', 'maryland', 'physics', 'repeat', 'minor', 'mba', '2019', 'b.e', 'graduation', 'shanghai', 'civil', 'sciences', 'a.', 'cumulative', 'graduate', 'alabama', '16.00', 'ernst', 'bowie', '3.7', 'citation', 'aerospace', 'andhra', 'finance', 'shonk', 'electrical', 'cohort', 'b.s.', 'ugrd', 'r.h.', 'endowed', 'george', '12.00', 'iowa', 'deans', 'college', 'mary', 'specialization', 'mason', 'technological', '3.3', 'master', 'indiana', 'chemistry', 'gpa', '2018', 'economics', 'b.a.', 'biology', 'isa', 'illinois', 'mechanical', 'msis', 'double', 'university', 'macroeconomics', 'b.', 'ukraine', 'cs', 'hunan', 'relations', '1992', 'bachelor', 'georgetown', '1985', 'pennsylvania', 'political', 'clark', 'polytechnic', 'anticipate', 'coursera', 'smith', 'standing', 'distinction', '1995', 'psychology', 'diploma', 'james', 'umbc', '3.4', 'keller', '3.6/4', 'fellows', '3.8', 'jntu', 'northern', 'technology‐bs', 'degree', 'cgpa', 'h.', 'scholar', 'clerk', 'memphis', 'bloomington', 'bs', 'mathematics', 'entrepreneurship', 'colorado', 'graduated', 'm.s.', 'concentration', 'duke', 'wayne', 'engineering', 'animal']
#
# Cluster: 76
# ['amazon', 'ec2', 'aws']
#
# Cluster: 77
# ['census', 'bureau', 'amsd']
#
# Cluster: 78
# ['admission']
#
# Cluster: 79
# ['t', 'd', 'i', 'l', 'cmsc', 'comm', 'si', 'ctec', 'y', '0.00', 'introduction', '12.000', 'o', '\uf0a8', 'io', 's', 'networks', 'f', 'theory', 'intro', '3.00', 'structures', 'b', 'ist', 'permanent', 'oo', 'engl', 'argument', '4.00', 'discrete', 'en', 'ss', 'coursework', 'compression', 'comp', 'u', '6.000', '9.000', 'calculus', 'n', 'ex', 'algorithms']
#
# Cluster: 80
# ['wireshark']
#
# Cluster: 81
# ['openview', 'splunk', 'jprobe', 'minder', 'jconsole', 'wily', 'bmc', 'bac', 'maestro', 'nagios', 'diagnostics', 'jmeter', 'patrol', 'jrockit', 'samurai', 'sitescope', 'introscope']
#
# Cluster: 82
# ['stanley', 'morgan']
#
# Cluster: 83
# ['19', 'instruct', '15', 'valuation', '20', 'million', 'first', 'over', 'approximately', '24', '3', 'wafer', 'achieved', 'almost', 'organic', '13', 'fte', '65', '100', '35', 'ever', 'month', '80', 'below', 'coordinated', 'two', 'coworker', 'person', 'raise', 'supervised', '2', 'union', '34', '16', 'brand', '75', '12', 'integral', 'asian', 'partial', 'outsourced', '6', 'replacement', 'l&t', 'attract', '60', 'matching', 'advertisement', 'five', 'annual', 'onsite', '400', 'today', 'revenue', 'per', '$', 'nightly', 'spread', 'beverage', '1000', 'reach', 'hour', 'engagement', 'excess', 'm', 'affiliate', '600', '+', 'past', '32', '1500', '120', 'music', 'charity', '300', '500', 'second', 'nine', '150', 'week', 'little', 'premier', 'span', '23', 'camper', '300,000', 'three', 'crime', 'year', 'fest', '40', 'last', 'four', 'isrweb', '30', '5000', 'geographically', 'campaign', '5', 'recover', '500,000', 'booking', 'efficiently', '700', '4', 'planned', 'seat', 'total', 'concert', '14', 'nearly', 'peace', '25', 'reservation', '6000', '140', 'fund', 'thirty', 'every', 'day', 'usd', 'magazine', 'six', 'direct', 'twenty', 'branch', 'fiscal', 'holiday', 'quarter', '4,000', 'dollar', 'name', 'seven', 'ahead', 'more', 'money', 'fellowship', '45', '350', 'oversaw', 'survey', '50', 'donation', 'than', 'spearhead', '1', 'ten', 'home', 'attendee', 'catalogue', 'progressive', 'inspect', '30,000', 'average', 'vary', 'allocation', 'arrangement', 'ace', 'dozen', 'since', '20,000', 'roughly', 'less', 'around', 'hundred', 'sba', 'congress', '1200', 'pitch', 'comprising', '200', '70', 'household', '18', '250', '10,000', 'embassy', 'supervise', 'period', 'intensive', '5%', '450', 'earn', '8,000', 'offsite']
#
# Cluster: 84
# ['people', 'hr', 'scheduler', 'ota', 'adp', 'beyond', 'payroll', 'compensation', 'row', 'clock', 'sandia', '7.5', 'leave', 'vanilla', 'accrual', 'treasury', 'opm', 'fscm', 'salary', '8.3', 'elements', 'employee', 'codes', 'ariba', '9.0', 't&l', 'absence', '8.9', 'designer', 'poi', 'appraisal', 'responsibilities', 'recruiting', 'hcm', 'tam', 'par', 'interfaces', 'ps', 'hris', 'contracts', 'debugger', 'peoplecode', 'reports', 'dms', 'deduction', 'taleo', 'elm', 'enrollment', 'earning', 'workforce', 'benefits', 'mover', 'sqr', 'ap', 'purchasing', 'lm', 'sbg', 'blue', 'eperformance', 'engine', 'lms', '8.4', 'pay', 'erecruit', 'gl', 'financials', 'peoplesoft', 'mantech', 'istore', 'ar', 'timesheet', 'nbc', 'om', '9.1', 'peopletools', 'mss', 'resources', 'epa', 'baptist', 'crystal', '8.51', 'kronos', 'techno', 'darden', 'labor', 'ben', 'hrms', 'na', 'engines', 'benefit', 'ver', 'ess', 'delegation', '8.8', 'workday', 'views', 'crm']
#
# Cluster: 85
# ['ftd', '11.1.1.5', 'exit', 'goldengate', 'packs', 'upgrades', 'hot', 'csc', 'opatch', 'recovery', 'cloning', 'upgrading', 'upgrade', 'prod', 'apply', 'rms', 'mid', 'sim', 'staging', 'nextel', 'gradation', 'datacenter', 'sync', 'upgradation', 'resa', 'snapshot', 'applications', 'dispatch', 'standby', 'upgraded', '9.2.2', 'migrate', 'rebuild', '11i', '9.14', 'refresh', 'cramer', 'rpm', 'restore', 'rpd', 'rel', 'skin', 'updates', 'patching', 'disaster', 'patch', 'rman', 'pack', 'notification', 'oss', 'onto', 'rac', 'clone', 'asm', '10.2', 'orpos', 'automatic', 'exadata', '24/7', 'later', 'tar', 'r12', 'replication', 'epic', 'crp', 'version', 'reorganization', 'cold', '11gr1', 'rib', 'car', 'ebusiness', '9.3', 'amdocs', 'wramc', 'backup', 'applied', 'utility', 'instances', 'mechanic']
#
# Cluster: 86
# ['pension', 'court', 'montgomery', 'chief', 'operations', 'regional', 'dot', 'affairs', 'doe', 'ndms', 'records', 'public', 'rfp', 'medicare', 'tb', 'defense', 'sayyad', 'interpreter', 'trust', 'tsa', 'department', 'fdic', 'cto', 'focu', 'agencies', 'health', 'flight', 'environmental', 'u.s.', 'strategist', 'deputy', 'fsa', 'legal', 'cfs', 'doc', 'navy', 'criminal', 'u.s', 'gsa', 'faa', 'federal', 'therapy', 'cdc', 'serve', 'sharing', 'un', 'civilian', 'states', 'secret', 'facility', 'overseas', 'medicaid', 'dhs', 'commerce', 'reserve', 'urban', 'agriculture', 'police', 'agency', 'nasa', 'disability', 'occupational', 'citizen', 'prime', 'clearance', 'united', 'cncs', 'representatives', 'homeland', 'augmentation', 'marine', 'era', 'county', 'doj', 'nec', 'eds', 'joint', 'tpocs', 'corps', 'rehabilitation', 'command', 'population', 'dod', 'district', 'official', 'attorney', 'clinic', 'programs', 'centers', 'clinical', 'medical', 'modernization', 'safety', 'saic', 'army', 'air', 'idiq', 'researcher', 'investigation', 'justice', 'specialize', 'personnel', 'mr.', '18f', 'housing', 'hhs', 'specialty', 'walter', 'vehicle', 'isr', 'dex', 'officer', 'comprise', 'redstone', 'manpower', 'immigration', 'blood', 'sponsor', 'state', 'headquarters', 'national', 'nara', 'courts', 'government', 'citizenship', 'cristiano', 'irs', 'uspto', 'interior', 'osha', 'prince', 'nhs', 'grant', 'transportation', 'chamber', 'military', 'u.', 'naval', 'orange', 'nsa', 'sec', 'fire', 'veteran', 'hospital', 'aviation', 'usaid', 'force', 'usda', 'fbi']
#
# Cluster: 87
# ['1.0']
#
# Cluster: 88
# ['pipeline']
#
# Cluster: 89
# ['groom', 'story', 'backlog', 'standup', 'clarification', 'retro', 'retrospective', 'sprint']
#
# Cluster: 90
# ['studio', 'suites', 'html', 'infopath', 'parametric', 'macromedia', 'inventor', 'workbench', 'axure', 'frontpage', 'vb', 'c++', 'light', 'style', 'flash', '2005/2008', 'verilog', 'simulations', 'pcb', 'drupal', 'sharepoint', 'swift', 'creo', 'paint', 'programming', 'joomla', 'ruby', 'mobizen', 'languages', 'responsive', 'quickbooks', 'markup', '.net', 'dynamics', 'pages', 'net', 'branding', 'ocaml', 'html5', 'proficiency', 'asp', 'vba', 'vbscript', 'click', 'assembly', 'powershell', '97', 'visual', 'abap', 'languag', 'mysql', 'bootstrap', 'matlab', 'coded', 'webex', 'c#.', 'abode', 'autodesk', 'graphics', 'flex', 'asp.net', 'css', 'photoshop', 'php', 'autocad', 'adobe', 'twitter', 'basic', 'vlsi', 'arcgis', 'jigsaw', 'nodejs', 'proficient', 'css3', 'studios', 'parts', 'wcf', 'python', 'expression', 'telerik', 'prolog', 'geospatial', 'captivate', 'cascading', 'microsoft', 'c', 'dreamweaver', 'visible', 'sheets', 'intuit', 'netbeans', 'esri', 'vb.net', 'illustrator', 'graphic', 'dfc', 'editor', 'snagit']
#
# Cluster: 91
# ['throughput', 'latency', 'low']
#
# Cluster: 92
# ['vertical', 'horizontal']
#
# Cluster: 93
# ['vsphere', 'dmz', 'lan', 'tcp', 'vpn', 'rip', 'acl', 'protocols', 'isolate', 'ftp', 'stp', 'protocol', 'pop', 'juniper', 'dossier', 'datagram', 'arp', 'unreliable', 'ipv4', 'ipv6', 'cryptographic', 'telnet', 'cli', 'reliable', 'bgp', 'relay', 'wins', 'igrp', 'routers', 'netware', 'http', 'cisco', 'ethernet', 'osi', 'tracer', 'eigrp', 'atm', 'udp', 'vlan', 'rout', 'ipsec', 'distance', 'https', 'ip', 'ospf', 'dhcp', 'packet', 'wan', 't3', 'smtp', 'l2/l3', 'routing', 'socket', 'switching', 'rc4', 'nat']
#
# Cluster: 94
# ['iam', 'ferpa', 'hippa', 'rbac', 'sox', 'abac', 'pci']
#
# Cluster: 95
# ['historical']
#
# Cluster: 96
# ['mobile', 'chrome', 'cross', 'x', 'mozilla', 'browser', 'mac', 'explorer', 'samsung', 'smoke', 'appium', 'sencha', 'ie', 'usability', 'negative', 'safari', 'localization', 'firefox', 'android', '508', 'interruption', 'gui', 'black', 'injection', 'acceptance', 'edge', 'compatibility', 'vr', 'box', 'ios', 'exploratory', 'compatible', 'regression', 'opera', 'fault', 'ivr', 'boundary', 'msie', '10/8/7', 'sanity']
#
# Cluster: 97
# ['shoot', 'shooting', 'trouble', 'ticket']
#
# Cluster: 98
# ['outbound', 'inbound']
#
# Cluster: 99
# ['topics', 'factory', 'bridges', 'adaptors', 'connections', 'pool', 'aq', 'configured', 'wldf', 'generic', 'jndi', 'connection', 'threads', 'destination', 'authenticator', 'pools', 'topic', 'eis', 'bridge', 'jta', 'alias', 'factories', 'stub', 'administered', 'snmp', 'adapters', 'modules', 'queue', 'concepts', 'partition', 'sources', 'queues', 'jms', '9.2/10', 'foreign', 'pools/', 'xa']
#
# Cluster: 100
# ['lambda', 'scala', 's3', 'elastic', 'rds', 'node.js']
#
# Cluster: 101
# ['umd', 'honors', 'year-', 'sigma', 'inter', 'memberships', 'omega', 'sorority', 'fundraising', 'collegiate', 'fraternity', 'semester', 'philanthropy', 'chairman', 'league', 'sponsorship', 'tsan', '2013-present', 'smsa', 'organizing', '650', 'ambassador', 'scholars', 'alpha', 'conference', 'varsity', 'kappa', 'naamba', 'undergraduate', 'beta', '09/2014', 'fall', 'secretary', 'father', 'committee', 'awards', '99', 'treasurer', 'men', 'dean', 'speaker', 'students', 'nu', 'youth', 'cultural', 'scholarship', 'founding', 'festival', 'association', 'club', 'vice', 'wellness', 'performing', 'fundraiser', 'chair', 'events', 'primannum', 'fitness', 'football', 'ascend', 'admissions', 'flag', 'homecoming', 'cricket', 'intramural', 'soccer', 'phi', 'chapter', 'society', 'recreation', 'president', 'honor', 'affiliation', 'alumni', 'council', 'founder', 'alumnus', 'trip']
#
# Cluster: 102
# ['mlds', 'msde', 'dpscs', 'rttt']
#
# Cluster: 103
# ['diego', 'san', 'francisco']
#
# Cluster: 104
# ['stakeholder', 'profiling', 'schedule', 'consolidate', 'action', 'dependency', 'progression', 'weekly', 'accountability', 'wbs', 'sure', 'thorough', 'coordinate', 'ordinate', 'lifecycle', 'adhere', 'change', 'determine', 'resolution', 'no', 'whether', 'expectation', 'conceptual', 'monthly', 'understand', 'remediation', 'depend', 'scenario', 'assisted', 'diagnose', 'closure', 'correspond', 'coordination', 'lb', 'status', 'reflect', 'root', 'instrumental', 'need', 'processes', 'finally', 'derive', 'eco', 'w', 'inception', 'guidance', '⦁', 'pass', 'late', 'plan', 'strategies', 'refer', 'live', 'analysed', 'stage', 'advice', 'until', 'architectural', 'problem', 'gather', 'dap', 'draft', 'compliant', 'appropriate', 'merger', 'post', 'reviews', 'meet', 'satisfaction', 'free', 'checkpoint', 'owner', 'specifications', 'reviewed', 'sops', 'convention', 'screenshot', 'iterative', 'miss', 'viability', 'prepare', 'ยง', 'validation', 'divide', 'bom', 'outage', 'functional', 'concern', 'completion', 'formulate', 'criterion', 'future', 'written', 'rfi', 'correction', 'affect', 'fda', 'requests', 'basis', 'validate', 'preparation', 'depth', 'ensure', 'actively', 'once', 'estimate', 'sme', 'review', 'brd', 'result', 'sequence', 'selection', 'assumption', 'nugenesis', 'daily', 'elicitation', 'cycle', 'periodically', 'corresponding', 'discuss', 'follow', 'uat', 'specify', 'diagram', 'those', 'analyse', 'fix', 'scenarios', 'specification', 'archival', 'evaluation', 'interpret', 'skilled', 'find', 'picture', 'timeline', 'rca', 'collect', 'accord', 'estimation', 'when', 'qa', 'pssm', 'recording', 'triage', 'ccb', 'research', 'exception', 'finalize', 'failure', 'workaround', 'occur', 'documentation', 'original', 'resolve', 'definition', 'go', 'without', 'verification', 'case', 'recommend', 'sop', 'participate', 'pain', 'completeness', 'segregate', 'metrics', 'compose', 'iteration', 'flows', 'know', 'reuse', 'baseline', 'summarize', 'evaluate', 'any', 'give', 'requirement', 'roll', 'checklist', 'realistic', 'insure', 'easy', 'defined', 'jad', 'benchmark', 'thermo', 'publication', 'plans', 'submittal', 'optimum', 'biweekly', 'confirm', 'approval', 'assignment', 'inclusion', 'inconsistency', 'metric', 'prompt', 'discover', 'judicial', 'e2e', 'assess', 'against', 'then', 'match', 'risk', 'and/or', 'previous', 'phase', 'formal', 'uploaded', 'conformance', 'response', 'gathered', 'comprehensive', 'walk', 'each', 'periodic', 'comment', 'supplementary', 'audited', 'actionable', 'regard', 'discrepancy', 'accurately', 'quarterly', 'next', 'refine', 'recommendation', 'context', 'necessity', 'address', 'shape', 'assign', 'overlap', 'priority', 'arise', 'smoothly', 'offshore', 'conform', 'charter', 'amongst', 'meeting', 'inspection', 'indicate', 'push', 'if', 'tight', 'execution', 'identify', 'communicate', 'come', 'prior', 'requirements', 'repeatable', 'fulfill', 'cutover', 'cases', 'visibility', 'cause', 'cr', 'convey', 'upcoming', 'verify', 'sort', 'specified', 'feedback', 'possible', 'mockup', 'allocate', 'actual', 'designate', 'description', 'incident', 'updated', 'minute', 'categorize', 'during', 'interact', 'extreme', 'proactively', 'current', 'walkthrough', 'identifying', 'assure', 'met', 'put', 'inform', 'check', 'note', 'step', 'progress', 'off', 'evidence', 'aware', 'revise', 'reporter', 'ready', 'discussion', 'short', 'automatically', 'prepared', 'finding', 'release', 'pick', 'there', 'disseminate', 'designs', 'redline', 'fuel', 'revision', 'track', 'gap', 'finish', 'debugged', 'impact', 'encounter', 'compile', 'spec', 'reproduce', 'input', 'readiness', 'comet', 'initial', 'tickets', 'feasibility', 'request', 'immediate', 'invest', 'or', 'demo', 'identification', 'defect', 'initiation', 'prioritize', 'correctness', 'list', 'consultation', 'milestone', 'sat', 'applicable', 'closely', 'closing', 'agenda', 'bug', 'moderate', 'standardized', 'satisfactory', 'accordingly', 'timeframe', 'analyze', 'results', 'conducted', 'sow', 'regular', 'detect', 'smoot ...
#
# Cluster: 105
# ['7', 'mvs', 'aix', 'vmware', 'veritas', 'xp', 'cics', '11.0', 'platforms', '5.x', '3.1', 'window', 'hyper', 'cobol', 'ubuntu', '1.4', 'solaris10', '4.5', '64', '2000/2003', 'windows', '1.7', '9i', 'operating', '8/10', 'me', 'redhat', 'couchbase', '6.5', '6.2', 'unix', 'vms', 'informix', 'sun', '5.x/6.x', 'ultra', 'oracle9i', 'dos', 'mix', '2000', '5.1', 'series', 'nt', 'dell', '4.x', 'ibm', '7.0/8.0', 'vista', 'wordpress', 'blade', 'scripting', 'rhel', 'alfresco', 'sever', '95', 'vm', '8', 'mcafee', 'red', 'balancer', 'edition', 'novell', 'linux', '7.0', 'bit', '98', 'emc', '5.5', 'iis', 'mf', 'mq', '10.3/11', '2003', '9/10', 'netscape', 'siteminder', '10,shell', 'perl', 'plumtree', '4.0', 'solaris', 'flavor', 'ux', 'f5', 'el', '365', 'sphere', 'macintosh', 'z', 'centos', '6/7', 'webapps', 'os', 'netegrity', 'hat', '6.0', '9', '2000/xp']
#
# Cluster: 106
# ['award', 'competition', 'ball', 'hold', 'scout', 'twice', 'awarded', 'champion', 'winner', 'stand', 'iete', 'speech', '1st', 'painting', 'race', 'promotional', 'debate', 'medal', 'won', 'represent', 'invite', 'compete', 'achievement', 'obstacle', 'gold', '3rd', 'press', 'arcelormittal', 'qualified', 'worth', 'win', 'marathon', 'prize', 'participant', 'infertility', 'brazilian', 'intra', 'tournament', 'art', 'performer', 'place', 'bike', 'attend', 'finalist', 'memorial', 'recipient', 'tennis', 'basketball']
#
# Cluster: 107
# ['1987', 'eagle', '~', 'cincinnati', 'december', 'nj', 'spectrum', 'annapolis', '2009', 'june', '2016-', 'inc.', 'october', '2016', 'chantilly', 'hamilton', 'ohio', 'suitland', 'northrop', '2011-', 'hartford', 'florida', 'aug.', 'collierville', '1996', 'odessa', '02', 'phoenix', '2014', '2015-', 'chevy', 'wipro', 'sept.', '2007', 'paradyme', 'plano', 'summit', '2013-', 'nike', '10/2013', '05/2015', '1997', '10/2007', '2013-may', 'mar.', '08', 'q', 'project-', 'september', '’13', 'johnson', 'dac', 'nov.', '’12', 'system’', 'daniel', 'packard', 'citigroup', 'november', 'till', 'inc', 'herndon', 'sandy', 'february', '2005', 'ma', '\uf0f2', 'april', 'may', 'virginia', '2015-dec', 'beach', 'texas', 'va', '09/2013', 'hcl', 'august', 'teksystems', 'jun.', 'associates', 'hewlett', '–may', '2020', '2014-present', '08/2015', '04', 'richardson', 'sunnyvale', 'paul', 'blacksburg', 'dhhs', 'william', 'newark', 'missouri', 'raleigh', '2015-present', 'mn', 'allen', '03', '2004', 'analyst-', '2008-', 'freelance', 'grumman', 'columbus', 'st.', '1994', 'unisys', 'vp', 'tanvi', 'cnsi', '2001', '2008', 'joseph', '2012', 'formerly', 'brothers', '1998', '2014-august', '09', 'tampa', 'llc', 'm.d.', 'houston', 'gallagher', '04/2005', 'llp', '2016-may', 'mclean', 'acs', '10/2014', 'trainee', '2011', 'arlington', '2014-may', '2017-', '2010', 'oh', 'addison', 'nc', 'july', 'shah', 'jr.', '2016-present', 'march', 'ia', 'fujitsu', 'investments', 'columbia', 'dec.', 'lucent', '2006', 'oct.', 'writer', 'booz', 'minneapolis', 'richmond', 'chase', 'alexandria', '06', 'consultants', '2014-', 'austin', 'pittsburgh', 'january', 'mo', '2015', 'williams', 'solutions', '01', 'jr', '05', 'pa', 'century', 'dept', 'contractor-', 'singh', 'technologies', 'louis', 'ymca', 'sra', 'springfield', '\u200b', 'kumar', 'maxim', 'corp', 'l.', 'transit', 'jane', '2002', 'apr.', '2013', '07', 'bradley', '1986', 'reston', 'bell', '2011-may', 'winston', '1993', '2012-', 'huntsville', '2015-august', 'comcast', 'john', 'massachusetts', 'caci', 'kelly', '2017', 'fairfax', 'alexander', 'jan.', 'kansas', 'co.', '1999']
#
# Cluster: 108
# ['culture']
#
# Cluster: 109
# ['rtm', 'matrix', 'traceability']
#
# Cluster: 110
# ['behavior']

# %%
class MeanEmbeddingVectorizer(object):
    def __init__(self, word2vec):
        self.word2vec = word2vec
        # if a text is empty we should return a vector of zeros
        # with the same dimensionality as all the other vectors
        self.dim = len(list(word2vec.values())[0])

    def fit(self, X, y):
        return self

    def transform(self, X):
        return np.array([
            np.mean([self.word2vec[w] for w in words if w in self.word2vec]
                    or [np.zeros(self.dim)], axis=0)
            for words in X
        ])

# %%
from sklearn.svm import SVC
from sklearn.pipeline import Pipeline
from sklearn.ensemble import ExtraTreesClassifier
import numpy as np

w2v = dict(zip(res2vec.wv.index2word, res2vec.wv.syn0))

etree_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("extra trees", ExtraTreesClassifier(n_estimators=200))])
svm_w2v = Pipeline([
    ("word2vec vectorizer", MeanEmbeddingVectorizer(w2v)),
    ("SVM", SVC())])

# %%
X=[['python','ocaml'],
  ['economics','sociology'],
  ['css','javascript']]
y=['scripting','majors','web']
etree_w2v.fit(X,y)
test_X=[['perl'],['psychology'],['asp.net']]
print(etree_w2v.predict(test_X))
# Out:
# ['web' 'web' 'scripting']

# %% [markdown]
# # Eric Zhou

# %%
#all imports
import re
import pandas
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams
from fuzzywuzzy.process import dedupe
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os
from IPython.display import HTML
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/fuzzywuzzy/fuzz.py:35: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
#import path & variables


#import and tokenize resume
resume_path = r"Yiyang (Eric) Zhou Resume 2017 Fall.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Zeng_Leah_Resume.txt"
resume_file = open(resume_path).read()
resume_file2 = open(resume_path).read()
resume_file2 = resume_file2.lower()

#import a list of majors 
major_df = pandas.read_excel('majors.xlsx')
major_df.columns
major_file = major_df['Majors'].values
major_lower = [item.lower() for item in major_file]
tokenizer = RegexpTokenizer(r'\w+')
resume_token = tokenizer.tokenize(resume_file) 
resume_token2 = tokenizer.tokenize(resume_file2)
updated_majors1 = []
indexes_majors1 = []
updated_majors2 = []
indexes_majors2 = []
updated_majors3 = []
indexes_majors3 = []
updated_majors4 = []
indexes_majors4 = []
majors_minors_all = updated_majors1 + updated_majors2 + updated_majors3 + updated_majors4

#import a list of universities
university_df1 = pandas.read_excel('China_University.xlsx')
university_df2 = pandas.read_excel('India_University.xlsx')
university_df3 = pandas.read_excel('US_University.xlsx')
university_file1 = university_df1['Universities'].values
university_file2 = university_df2['Universities'].values
university_file3 = university_df3['Universities'].values
university_lower1 = [item.lower() for item in university_file1]
university_lower2 = [item.lower() for item in university_file2]
university_lower3 = [item.lower() for item in university_file3]
university_combined = university_lower1 + university_lower2 + university_lower3

# %%
#extract name 

def extract_first_name(resume):
    name = resume.split('\n', 1)[0]
    first_name = name.split(' ', 1)[0]
    return (first_name)
    print (first_name)
    
def extract_last_name(resume):
    name = resume.split('\n', 1)[0]
    last_name = name.split(' ', 1)[-1]
    return (last_name)
    print (last_name)
    
def extract_name(resume):
    name = extract_first_name(resume_file) + extract_last_name(resume_file)
    print (name)
    
extract_name(resume_file)
# Out:
# Yiyang(Eric)Zhou

# %%
#extract phone number

def check_phone_number1(resume):
    resume2 = "".join(c for c in resume if c not in ('!','.','-','(',')',' ','+',))
    result = re.findall(r"\d{10}", resume2)                   
    result = ''.join(result)
    return (result)

def check_phone_number2(resume):
    resume2 = "".join(c for c in resume if c not in ('!','.','-','(',')',' ','+',))
    result = re.findall(r"\d{11}", resume2)                   
    result = ''.join(result)
    result = result[1:11]
    return (result)

def extract_phone_number(resume):
    try:
        return check_phone_number1(resume) 
        print (check_phone_number1(resume))
    except:
        return check_phone_number2(resume)
        print (check_phone_number2(resume))

extract_phone_number(resume_file)
# Out:
# '6125162045'

# %%
#scraping tools

r = requests.get('http://www.4icu.org/us/')
soup = BeautifulSoup(r.content, "lxml")
letters = soup.find_all(class_="lead")

university = {}
for element in letters:
    university[element.get_text()] = {}
    
list_keys = [ k for k in university.keys() ]

us_university_list = pd.DataFrame(list_keys)
print (us_university_list.head())
# Out:
#                                      0
# 0               Hampden-Sydney College
# 1                   Crossroads College
# 2               Mount Mercy University
# 3  Kutztown University of Pennsylvania
# 4                      Spelman College

# %%
#Extract University

def get_bigrams(input):
    n = 2
    result = []
    bigrams = ngrams(input, n)
    for grams in bigrams:
        x = "%s %s" % grams
        result.append(x)
    return (result)    
    print (result)


test1 = get_bigrams(resume_token)
#print (test1)

def get_threegrams(input):
    n = 3
    result = []
    threegrams = ngrams(input, n)
    for grams in threegrams:
        x = "%s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test2 = get_threegrams(resume_token)
#print (test2)

def get_fourgrams(input):
    n = 4
    result = []
    fourgrams = ngrams(input, n)
    for grams in fourgrams:
        x = "%s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test3 = get_fourgrams(resume_token)
#print (test3)

def get_fivegrams(input):
    n = 5
    result = []
    fivegrams = ngrams(input, n)
    for grams in fivegrams:
        x = "%s %s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test4 = get_fivegrams(resume_token)
#print (test4)

def get_sixgrams(input):
    n = 6
    result = []
    sixgrams = ngrams(input, n)
    for grams in sixgrams:
        x = "%s %s %s %s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)


def get_university(a,b):
    resume_university=[]
    for x in a:
        if x in b:
            resume_university.append(x)
    return (resume_university)
    print (resume_university)

def extract_university(resume_token_lower,university_combined):
    unigram_university = get_university(resume_token_lower, university_combined)  
    bigram_university = get_university(get_bigrams(resume_token_lower), university_combined)
    threegram_university = get_university(get_threegrams(resume_token_lower), university_combined)
    fourgram_university = get_university(get_fourgrams(resume_token_lower), university_combined)
    fivegram_university = get_university(get_fivegrams(resume_token_lower), university_combined)
    sixgram_university = get_university(get_sixgrams(resume_token_lower), university_combined)
    combined_university_extraction = set(bigram_university + threegram_university + fourgram_university + fivegram_university + sixgram_university)
    return combined_university_extraction

combined_university_extraction = extract_university(resume_token2,university_combined)

combined_university_extraction
# Out:
# {'university of maryland', 'university of minnesota'}

# %%
#extract GPA:
def extract_GPA(resume):
    result = re.search(r'(GPA|gpa): ?\d.\d{1,}',resume)
    if result:
        result = result.group(0)
    return (result)
    print (result)

extract_GPA(resume_file)
# Out:
# 'gpa: 3.4'

# %%
#extract majors:

def extract_majors(a,b):
    majors=[]
    for x in a:
        if x in b:
            majors.append(x)
    return (majors)
    print (majors)
    
unigram_major = extract_majors(resume_token2, major_lower)  
bigram_major = extract_majors(get_bigrams(resume_token2), major_lower)
threegram_major = extract_majors(get_threegrams(resume_token2), major_lower)
combined_majors_list = unigram_major + bigram_major + threegram_major

major_distinct = []
for i in combined_majors_list:
    if i not in major_distinct:
        major_distinct.append(i)
        
#print (combined_majors_list)
print (major_distinct)
# Out:
# ['education', 'business', 'information', 'management', 'accounting', 'finance', 'insurance', 'web', 'development', 'home', 'specialist', 'history', 'analyst', 'marketing', 'english', 'information system', 'accounting and finance']

# %%
#get major indexes 
dict = {'Name': 5}
for i, element in enumerate(major_distinct):
   x = resume_file2.find(element)
   dict[element] = x
   

del dict['Name']
print(dict)
# Out:
# {'analyst': 2318, 'english': 3327, 'accounting and finance': 416, 'history': 1245, 'specialist': 1080, 'web': 800, 'development': 896, 'information': 220, 'finance': 431, 'accounting': 416, 'business': 144, 'insurance': 447, 'education': 108, 'information system': 220, 'home': 1051, 'marketing': 2799, 'management': 326}

# %%
#get indexes for specific terms

#bachelor
regular_expression = re.compile(r"/BA|BS|Bachelor of Science|Bachelor of Arts|BBA |B/A|Bachelor of Business Administration/", re.IGNORECASE)
bach_major_result = re.search(regular_expression, resume_file)
if bach_major_result:
   bach_major_result = bach_major_result.group()
print (bach_major_result)

if bach_major_result is not None:
    bach_major_index = resume_file.find(bach_major_result)
    print(bach_major_index)
    
#minor
regular_expression_two = re.compile(r"minor|Minor", re.IGNORECASE)
minor_result = re.search(regular_expression_two, resume_file)
if minor_result:
   minor_result = minor_result.group()
print (minor_result)

if minor_result is not None:
    minor_index = resume_file.find(minor_result)
    print(minor_index)

#master
regular_expression_three = re.compile(r"Master|master", re.IGNORECASE)
master_major_result = re.search(regular_expression_three, resume_file)
if master_major_result:
   master_major_result = master_major_result.group()
print (master_major_result)

if master_major_result is not None:
    master_major_index = resume_file.find(master_major_result)
    print(master_major_index)
    
#university
regular_expression_four = re.compile(r"university", re.IGNORECASE)
university_major_result = re.search(regular_expression_four, resume_file)
if university_major_result:
   university_major_result = university_major_result.group()
print (university_major_result)

if university_major_result is not None:
    university_major_index = resume_file.find(university_major_result)
    print(university_major_index)
# Out:
# bachelor of science
# 173
# minor
# 244
# master
# 267
# university
# 115

# %%
upper_bound1 = bach_major_index+100
for k, v in dict.items():
   if (bach_major_index < v < upper_bound1):
       updated_majors1.append(k)
       indexes_majors1.append(v)
print(updated_majors1)
print(indexes_majors1)

upper_bound2 = master_major_index+100
for k, v in dict.items():
   if (master_major_index < v < upper_bound2):
       updated_majors2.append(k)
       indexes_majors2.append(v)
print(updated_majors2)
print(indexes_majors2)

upper_bound3 = university_major_index+100
for k, v in dict.items():
   if (university_major_index < v < upper_bound3):
       updated_majors3.append(k)
       indexes_majors3.append(v)
print(updated_majors3)
print(indexes_majors3)

upper_bound4 = minor_index+100
for k, v in dict.items():
   if (minor_index < v < upper_bound4):
       updated_majors4.append(k)
       indexes_majors4.append(v)
print(updated_majors4)
print(indexes_majors4)
# Out:
# ['accounting and management', 'accounting', 'management', 'information', 'information system']
# [194, 194, 209, 220, 220]
# ['information', 'information systems', 'management']
# [308, 308, 326]
# ['accounting and management', 'accounting', 'management', 'business']
# [194, 194, 209, 144]
# ['communications', 'management']
# [251, 326]

# %%
majors_minors_all = updated_majors1 + updated_majors2 + updated_majors3 + updated_majors4
majors_minors_final_list = list(dedupe(majors_minors_all))
print (majors_minors_final_list)
# Out:
# ['information systems', 'accounting and management', 'communications', 'business']

# %% [markdown]
# # Rodrigo Pimenta

# %% [markdown]
# # Web Scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import os

r = requests.get('https://www.mymajors.com/college-majors/')

soup = BeautifulSoup(r.content, "lxml")

# %%
print (soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="MyMajors.com" name="author"/>
# <link href="../../../v6/css/?type=css&amp;files=bootstrap.min.css,style-edits.css,jquery.zflickrfeed.css,webfont/climacons-font.css,niceforms.css" media="all" rel="stylesheet" type="text/css"/>
# <link href="../../../v6/css/font-awesome.min.css" rel="stylesheet" type="text/css"/>
# <!-- HTML5 Shim and Respond.js IE8 support of HTML5 elements and media queries -->
# <!-- WARNING: Respond.js doesn't work if you view the page via file:// -->
# <!--[if lt IE 9]>
# <script src="https://oss.maxcdn.com/libs/html5shiv/3.7.0/html5shiv.js"></script>
# <script src="https://oss.maxcdn.com/libs/respond.js/1.4.2/respond.min.js"></script>
# <![endif]-->
# <style>.autocomplete-suggestions { border: 1px solid #999; background: #FFF; overflow: auto;}
# .autocomplete-suggestion { padding: 2px 5px; white-space: nowrap; overflow: hidden; }
# .autocomplete-selected { background: #efefef; }
# .autocomplete-suggestions strong { font-weight: normal; color: #00AEEF; }
# .autocomplete-group { margin-top:5px; padding: 2px 5px; }
# .autocomplete-group strong { display: block; border-bottom: 1px solid #000; font-weight:bolder;}</style>
# <script>
# var $buoop = {vs:{i:10,f:-4,o:-4,s:7,c:-4},api:4};
# function $buo_f(){
#  var e = document.createElement("script");
#  e.src = "//browser-update.org/update.min.js";
#  document.body.appendChild(e);
# };
# try {document.addEventListener("DOMContentLoaded", $buo_f,false)}
# catch(e){window.attachEvent("onload", $buo_f)}
# </script>
# <script type="text/javascript"> //<![CDATA[
# var tlJsHost = ((window.location.protocol == "https:") ? "https://secure.comodo.com/" : "http://www.trustlogo.com/");
# document.write(unescape("%3Cscript src='" + tlJsHost + "trustlogo/javascript/trustlogo.js' type='text/javascript'%3E%3C/script%3E"));
# //]]>
# </script>
# <script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <script>
#   (adsbygoogle = window.adsbygoogle || []).push({
#     google_ad_client: "ca-pub-9616498254024547",
#     enable_page_level_ads: true
#   });
# </script>
# <meta content="The Largest Listing on the Web. Over 1,600 College Major Descriptions" name="description"/>
# <title>List of College Majors</title>
# <link href="../v6/css/major-career-lists.css" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <nav class="navbar navbar-default navbar-static-top" role="navigation">
# <div class="container">
# <small style="color:#888;float:right;"><a href="#" onclick="$('html,body').animate({
#         scrollTop: $('.content').offset().top},
#         'slow');">skip to content</a></small><br/>
# <div class="navbar-header">
# <button aria-controls="navbar" aria-expanded="false" class="navbar-toggle collapsed" data-target="#navbar" data-toggle="collapse" type="button">
# <span class="sr-only">Toggle navigation</span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# <span class="icon-bar"></span>
# </button>
# <a class="navbar-brand" href="../"><img class="img-responsive nav-logo" src="../v6/images/mm-logo.jpg"/></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="navbar-collapse collapse" id="navbar">
# <ul class="nav navbar-nav navbar-right">
# <li><a href="../college-major-quiz/">Assessment</a></li>
# <li><a href="../college-majors/">Majors</a></li>
# <li><a href="../find-a-college/">Colleges</a></li>
# <li><a href="../career-list/">Careers</a></li>
# <li><a href="../blog/">Blog</a></li>
# <li>
# <form action="../search/" class="navbar-form navbar-left" role="search">
# <div class="form-group">
# <input class="form-control" id="autocomplete" name="q" placeholder="Search" type="text"/>
# </div>
# <button class="btn btn-default" type="submit"><span class="glyphicon glyphicon-search"></span></button>
# </form>
# </li>
# <li>
# <a href="../login" style="padding:0;"><button class="btn btn-default btn-sm navbar-btn" data-container="body" data-content="" data-placement="bottom" data-toggle="popover" type="button"><span class="glyphicon glyphicon-user"></span> Login</button></a>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <!-- /.container -->
# </nav>
# <!-- Begin Body -->
# <div class="container content">
# <div class="row">
# <div class="col-md-12">
# <div class="row" style="margin-bottom:20px;">
# <div class="col-md-8">
# <h1 class="school">List of College Majors</h1>
# <p class="lead">Below is a list of over 1,800 college majors profiled on MyMajors. Search for majors by selecting a category and refining your search or use search box below.</p>
# <p class="lead">Major Pages include Description, Courses, Careers, Salary, Related Majors and Colleges offering major.</p>
# </div>
# <div class="col-md-4">
# <a href="../college-major-quiz/"><img class="pull-right img-responsive" src="../images/ad.jpg"/></a>
# </div>
# </div>
# <div class="row" style="background:#efefef; padding:20px 0 20px 0;">
# <div class="col-md-6">
# <h3>Know what major you want? Type it here:</h3>
# <form action="../search/" class="" id="cse-search-box">
# <div class="input-group">
# <input class="form-control panel-primary" id="autocomplete2" name="q" size="30" type="text"/>
# <span class="input-group-btn">
# <button class="btn btn-primary" type="submit"><span class="glyphicon glyphicon-search"></span></button>
# </span>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <div class="row">
# <div class="col-md-12" id="majorTree" style="margin-top:20px;">
# <ul class="menu" id="columnlist">
# <li class="expanded top"><a><strong>Featured Majors</strong></a>
# <ul class="menu">
# <li><a href="aviation-flight-training">Aviation / Flight Training (UND Aerospace) </a></li>
# <li class="leaf"><a href="http://www.unity.edu/Academic/Majors/WildlifeCareAndEducation/WildlifeCareAndEducation.aspx" target="_blank">Captive Wildlife Care and Education( Unity College in Maine )</a> </li>
# <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=83732">Contemporary Christian Music ( Greenville College)</a></li>
# <li class="leaf"><a href="http://thunder1.cudenver.edu/clas/ISMmajor.html">Individually Structured Major  ( University of Colorado Denver)</a></li>
# <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=102695">Recording Industry ( Greenville College)</a></li>
# <li class="leaf"><a href="http://www.unity.edu/Academic/Majors/SustainableDesignAndTechnology.aspx" target="_blank">Sustainable Design and Technology ( Unity College in Maine )</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agriculture, Agriculture Operations, and Related Sciences</a>
# <ul class="menu">
# <li class="expanded top"><a>Agricultural and Domestic Animal Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Training">Animal Training</a></li>
# <li class="leaf"><a href="../college-majors/Dog-Pet-Animal-Grooming">Dog/Pet/Animal Grooming</a></li>
# <li class="leaf"><a href="../college-majors/Equestrian-Equine-Studies">Equestrian/Equine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Taxidermy-Taxidermist">Taxidermy/Taxidermist</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural and Food Products Processing</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Food-Products-Processing">Agricultural and Food Products Processing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Business and Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agribusiness-Agricultural-Business-Operations">Agribusiness/Agricultural Business Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-and-Management-General">Agricultural Business and Management</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-Technology">Agricultural Business Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Economics">Agricultural Economics</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Farm-Supplies-Retailing-and-Wholesaling">Agricultural/Farm Supplies Retailing and Wholesaling</a></li>
# <li class="leaf"><a href="../college-majors/Farm-Farm-and-Ranch-Management">Farm/Farm and Ranch Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Mechanization</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanics-and-Equipment-Machine-Technology">Agricultural Mechanics and Equipment/Machine Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanization-General">Agricultural Mechanization</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Power-Machinery-Operation">Agricultural Power Machinery Operation</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Production Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Production-Operations-General">Agricultural Production Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agroecology-and-Sustainable-Agriculture">Agroecology and Sustainable Agriculture</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Livestock-Husbandry-and-Production">Animal/Livestock Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Aquaculture">Aquaculture</a></li>
# <li class="leaf"><a href="../college-majors/Crop-Production">Crop Production</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Husbandry-and-Production">Dairy Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Horse-Husbandry-Equine-Science-and-Management">Horse Husbandry/Equine Science and Management</a></li>
# <li class="leaf"><a href="../college-majors/Viticulture-and-Enology">Viticulture and Enology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Public Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Extension-Education-Services">Agricultural and Extension Education Services</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Communication-Journalism">Agricultural Communication/Journalism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Animal Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Animal-Breeding">Agricultural Animal Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Health">Animal Health</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Nutrition">Animal Nutrition</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Sciences-General">Animal Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Science">Dairy Science</a></li>
# <li class="leaf"><a href="../college-majors/Livestock-Management">Livestock Management</a></li>
# <li class="leaf"><a href="../college-majors/Poultry-Science">Poultry Science</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Applied Horticulture and Horticultural Business Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Applied-Horticulture-Horticulture-Operations-General">Applied Horticulture/Horticulture Operations</a></li>
# <li class="leaf"><a href="../college-majors/Floriculture-Floristry-Operations-and-Management">Floriculture/Floristry Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Greenhouse-Operations-and-Management">Greenhouse Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Landscaping-and-Groundskeeping">Landscaping and Groundskeeping</a></li>
# <li class="leaf"><a href="../college-majors/Ornamental-Horticulture">Ornamental Horticulture</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Nursery-Operations-and-Management">Plant Nursery Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Turf-and-Turfgrass-Management">Turf and Turfgrass Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Food Science and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Food-Science">Food Science</a></li>
# <li class="leaf"><a href="../college-majors/Food-Technology-and-Processing">Food Technology and Processing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>International Agriculture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/International-Agriculture">International Agriculture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Plant Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Horticultural-Plant-Breeding">Agricultural and Horticultural Plant Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Agronomy-and-Crop-Science">Agronomy and Crop Science</a></li>
# <li class="leaf"><a href="../college-majors/Horticultural-Science">Horticultural Science</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Protection-and-Integrated-Pest-Management">Plant Protection and Integrated Pest Management</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Sciences-General">Plant Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Range-Science-and-Management">Range Science and Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Soil Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Soil-Chemistry-and-Physics">Soil Chemistry and Physics</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Microbiology">Soil Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Science-and-Agronomy-General">Soil Science and Agronomy</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Architecture and Related Services</a>
# <ul class="menu">
# <li class="expanded top"><a>Architectural History and Criticism</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-History-and-Criticism-General">Architectural History and Criticism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Architectural Sciences and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-and-Building-Sciences-Technology">Architectural and Building Sciences/Technology</a></li>
# <li class="leaf"><a href="../college-majors/Architectural-Technology-Technician">Architectural Technology/Technician</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architecture">Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>City/Urban, Community and Regional Planning</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/City-Urban-Community-and-Regional-Planning">City/Urban, Community and Regional Planning</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Environmental Design</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Design-Architecture">Environmental Design/Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Interior Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Interior-Architecture">Interior Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Landscape Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Landscape-Architecture">Landscape Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Real Estate Development</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Real-Estate-Development">Real Estate Development</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Area, Ethnic, Cultural, Gender, and Group Studies</a>
# <ul class="menu">
# <li class="expanded top"><a>Area Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-Studies">African Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-United-States-Studies-Civilization">American/United States Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Asian-Studies-Civilization">Asian Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Balkans-Studies">Balkans Studies</a></li>
# <li class="leaf"><a href="../college-majors/Baltic-Studies">Baltic Studies</a></li>
# <li class="leaf"><a href="../college-majors/Canadian-Studies">Canadian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Caribbean-Studies">Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Chinese-Studies">Chinese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Commonwealth-Studies">Commonwealth Studies</a></li>
# <li class="leaf"><a href="../college-majors/East-Asian-Studies">East Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/European-Studies-Civilization">European Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/French-Studies">French Studies</a></li>
# <li class="leaf"><a href="../college-majors/German-Studies">German Studies</a></li>
# <li class="leaf"><a href="../college-majors/Irish-Studies">Irish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Italian-Studies">Italian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Japanese-Studies">Japanese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Korean-Studies">Korean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-and-Caribbean-Studies">Latin American and Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-Studies">Latin American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Near-and-Middle-Eastern-Studies">Near and Middle Eastern Studies</a></li>
# <li class="leaf"><a href="../college-majors/Pacific-Area-Pacific-Rim-Studies">Pacific Area/Pacific Rim Studies</a></li>
# <li class="leaf"><a href="../college-majors/Polish-Studies">Polish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Regional-Studies-US-Canadian-Foreign">Regional Studies (US, Canadian, Foreign)</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Studies">Russian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Central-European-East-European-and-Eurasian-Studies">Russian, Central European, East European and Eurasian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Scandinavian-Studies">Scandinavian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Slavic-Studies">Slavic Studies</a></li>
# <li class="leaf"><a href="../college-majors/South-Asian-Studies">South Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Southeast-Asian-Studies">Southeast Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Spanish-and-Iberian-Studies">Spanish and Iberian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Tibetan-Studies">Tibetan Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ukraine-Studies">Ukraine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ural-Altaic-and-Central-Asian-Studies">Ural-Altaic and Central Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Western-European-Studies">Western European Studies</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Ethnic Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-American-Black-Studies">African-American/Black Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-Indian-Native-American-Studies">American Indian/Native American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Asian-American-Studies">Asian-American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Deaf-Studies">Deaf Studies</a></li>
# <li class="leaf"><a href="../college-majors/Disability-Studies">Disability Studies</a></li>
# <li class="leaf"><a href="../college-majors/Folklore-Studies">Folklore Studies</a></li>
# <li class="leaf"><a href="../college-majors/Gay-Lesbian-Studies">Gay/Lesbian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Hispanic-American-Puerto-Rican-and-Mexican-American-Chicano-Studies">Hispanic-American, Puerto Rican, and Mexican-American/Chicano Studies</a></li>
# <li class="leaf"><a href="../college-majors/Womens-Studies">Women's Studies</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Aviation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/aviation-flight-training">Aviation / Flight Training (UND Aerospace) </a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biological and Biomedical Sciences</a>
# <ul class="menu">
# <li class="expanded top"><a>Biochemistry, Biophysics and Molecular Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biochemistry">Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Biochemistry-and-Molecular-Biology">Biochemistry and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Biophysics">Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biochemistry">Molecular Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biology">Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biophysics">Molecular Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Photobiology">Photobiology</a></li>
# <li class="leaf"><a href="../college-majors/Radiation-Biology-Radiobiology">Radiation Biology/Radiobiology</a></li>
# <li class="leaf"><a href="../college-majors/Structural-Biology">Structural Biology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biology-Biological-Sciences-General">Biology/Biological Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Biomedical-Sciences-General">Biomedical Sciences</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biomathematics, Bioinformatics, and Computational Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Bioinformatics">Bioinformatics</a></li>
# <li class="leaf"><a href="../college-majors/Biometry-Biometrics">Biometry/Biometrics</a></li>
# <li class="leaf"><a href="../college-majors/Biostatistics">Biostatistics</a></li>
# <li class="leaf"><a href="../college-majors/Computational-Biology">Computational Biology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biotechnology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biotechnology">Biotechnology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Botany/Plant Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Botany-Plant-Biology">Botany/Plant Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Molecular-Biology">Plant Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Pathology-Phytopathology">Plant Pathology/Phytopathology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Physiology">Plant Physiology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Cell/Cellular Biology and Anatomical Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Anatomy">Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Biology-and-Anatomy">Cell Biology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-and-Molecular-Biology">Cell/Cellular and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-Biology-and-Histology">Cell/Cellular Biology and Histology</a></li>
# <li class="leaf"><a href="../college-majors/Developmental-Biology-and-Embryology">Developmental Biology and Embryology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Ecology, Evolution, Systematics, and Population Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aquatic-Biology-Limnology">Aquatic Biology/Limnology</a></li>
# <li class="leaf"><a href="../college-majors/Conservation-Biology">Conservation Biology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology">Ecology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology-and-Evolutionary-Biology">Ecology and Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Environmental-Biology">Environmental Biology</a></li>
# <li class="leaf"><a href="../college-majors/Epidemiology">Epidemiology</a></li>
# <li class="leaf"><a href="../college-majors/Evolutionary-Biology">Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Biology-and-Biological-Oceanography">Marine Biology and Biological Oceanography</a></li>
# <li class="leaf"><a href="../college-majors/Population-Biology">Population Biology</a></li>
# <li class="leaf"><a href="../college-majors/Systematic-Biology-Biological-Systematics">Systematic Biology/Biological Systematics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Genetics</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Genetics">Animal Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genetics-General">Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genome-Sciences-Genomics">Genome Sciences/Genomics</a></li>
# <li class="leaf"><a href="../college-majors/Human-Medical-Genetics">Human/Medical Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Microbial-and-Eukaryotic-Genetics">Microbial and Eukaryotic Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Genetics">Molecular Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Genetics">Plant Genetics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Microbiological Sciences and Immunology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Immunology">Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Medical-Microbiology-and-Bacteriology">Medical Microbiology and Bacteriology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-General">Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-and-Immunology">Microbiology and Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Mycology">Mycology</a></li>
# <li class="leaf"><a href="../college-majors/Parasitology">Parasitology</a></li>
# <li class="leaf"><a href="../college-majors/Virology">Virology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Molecular Medicine</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Molecular-Medicine">Molecular Medicine</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Neurobiology and Neurosciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Neuroanatomy">Neuroanatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Anatomy">Neurobiology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Behavior">Neurobiology and Behavior</a></li>
# <li class="leaf"><a href="../college-majors/Neuroscience">Neuroscience</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Pharmacology and Toxicology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Toxicology">Environmental Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Pharmacology">Molecular Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Toxicology">Molecular Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Neuropharmacology">Neuropharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology">Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology-and-Toxicology">Pharmacology and Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Toxicology">Toxicology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Physiology, Pathology and Related Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aerospace-Physiology-and-Medicine">Aerospace Physiology and Medicine</a></li>
# <li class="leaf"><a href="../college-majors/Cardiovascular-Science">Cardiovascular Science</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Physiology">Cell Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Endocrinology">Endocrinology</a></li>
# <li class="leaf"><a href="../college-majors/Exercise-Physiology">Exercise Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Physiology">Molecular Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Oncology-and-Cancer-Biology">Oncology and Cancer Biology</a></li>
# <li class="leaf"><a href="../college-majors/Pathology-Experimental-Pathology">Pathology/Experimental Pathology</a></li>
# <li class="leaf"><a href="../college-majors/Physiology-General">Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Reproductive-Biology">Reproductive Biology</a></li>
# <li class="leaf"><a href="../college-majors/Vision-Science-Physiological-Optics">Vision Science/Physiological Optics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Zoology/Animal Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Behavior-and-Ethology">Animal Behavior and Ethology</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Physiology">Animal Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Entomology">Entomology</a></li>
# <li class="leaf"><a href="../college-majors/Wildlife-Biology">Wildlife Biology</a></li>
# <li class="leaf"><a href="../college-majors/Zoology-Animal-Biology">Zoology/Animal Biology</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Business, Management, Marketing, and Related Support Services</a>
# <ul class="menu">
# <li class="expanded top"><a>Accounting and Related Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Accounting">Accounting</a></li>
# <li class="leaf"><a href="../college-majors/Accounting-and-Business-Management">Accounting and Business/Management</a></li>
# <li class="leaf"><a href="../college-majors/Accounting-and-Finance">Accounting and Finance</a></li>
# <li class="leaf"><a href="../college-majors/Accounting-Technology-Technician-and-Bookkeeping">Accounting Technology/Technician and Bookkeeping</a></li>
# <li class="leaf"><a href="../college-majors/Auditing">Auditing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Business Administration, Management and Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Business-Administration-and-Management-General">Business Administration and Management</a></li>
# <li class="leaf"><a href="../college-majors/Customer-Service-Management">Customer Service Management</a></li>
# <li class="leaf"><a href="../college-majors/E-Commerce-Electronic-Commerce">E-Commerce/Electronic Commerce</a></li>
# <li class="leaf"><a href="../college-majors/Logistics-Materials-and-Supply-Chain-Management">Logistics, Materials, and Supply Chain Management</a></li>
# <li class="leaf"><a href="../college-majors/Non-Profit-Public-Organizational-Management">Non-Profit/Public/Organizational Management</a></li>
# <li class="leaf"><a href="../college-majors/Office-Management-and-Supervision">Office Management and Supervision</a></li>
# <li class="leaf"><a href="../college-majors/Operations-Management-and-Supervision">Operations Management and Supervision</a></li>
# <li class="leaf"><a href="../college-majors/Organizational-Leadership">Organizational Leadership</a></li>
# <li class="leaf"><a href="../college-majors/Project-Management">Project Management</a></li>
# <li class="leaf"><a href="../college-majors/Purchasing-Procurement-Acquisitions-and-Contracts-Management">Purchasing, Procurement/Acquisitions and Contracts Management</a></li>
# <li class="leaf"><a href="../college-majors/Research-and-Development-Management">Research and Development Management</a></li>
# <li class="leaf"><a href="../college-majors/Retail-Management">Retail Management</a></li>
# <li class="leaf"><a href="../college-majors/Transportation-Mobility-Management">Transportation/Mobility Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Business Operations Support and Assistant Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Administrative-Assistant-and-Secretarial-Science-General">Administrative Assistant and Secretarial Science</a></li>
# <li class="leaf"><a href="../college-majors/Business-Office-Automation-Technology-Data-Entry">Business/Office Automation/Technology/Data Entry</a></li>
# <li class="leaf"><a href="../college-majors/Customer-Service-Support-Call-Center-Teleservice-Operation">Customer Service Support/Call Center/Teleservice Operation</a></li>
# <li class="leaf"><a href="../college-majors/Executive-Assistant-Executive-Secretary">Executive Assistant/Executive Secretary</a></li>
# <li class="leaf"><a href="../college-majors/General-Office-Occupations-and-Clerical-Services">General Office Occupations and Clerical Services</a></li>
# <li class="leaf"><a href="../college-majors/Parts-Warehousing-and-Inventory-Management-Operations">Parts, Warehousing, and Inventory Management Operations</a></li>
# <li class="leaf"><a href="../college-majors/Receptionist">Receptionist</a></li>
# <li class="leaf"><a href="../college-majors/Traffic-Customs-and-Transportation-Clerk-Technician">Traffic, Customs, and Transportation Clerk/Technician</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Business/Commerce</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Business-Commerce-General">Business/Commerce</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Business/Corporate Communications</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Business-Corporate-Communications">Business/Corporate Communications</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Business/Managerial Economics</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Business-Managerial-Economics">Business/Managerial Economics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Construction Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Construction-Management">Construction Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Entrepreneurial and Small Business Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Entrepreneurship-Entrepreneurial-Studies">Entrepreneurship/Entrepreneurial Studies</a></li>
# <li class="leaf"><a href="../college-majors/Franchising-and-Franchise-Operations">Franchising and Franchise Operations</a></li>
# <li class="leaf"><a href="../college-majors/Small-Business-Administration-Management">Small Business Administration/Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Finance and Financial Management Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Banking-and-Financial-Support-Services">Banking and Financial Support Services</a></li>
# <li class="leaf"><a href="../college-majors/Credit-Management">Credit Management</a></li>
# <li class="leaf"><a href="../college-majors/Finance-General">Finance</a></li>
# <li class="leaf"><a href="../college-majors/Financial-Planning-and-Services">Financial Planning and Services</a></li>
# <li class="leaf"><a href="../college-majors/International-Finance">International Finance</a></li>
# <li class="leaf"><a href="../college-majors/Investments-and-Securities">Investments and Securities</a></li>
# <li class="leaf"><a href="../college-majors/Public-Finance">Public Finance</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>General Sales, Merchandising and Related Marketing Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Merchandising-and-Buying-Operations">Merchandising and Buying Operations</a></li>
# <li class="leaf"><a href="../college-majors/Retailing-and-Retail-Operations">Retailing and Retail Operations</a></li>
# <li class="leaf"><a href="../college-majors/Sales-Distribution-and-Marketing-Operations-General">Sales, Distribution, and Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Selling-Skills-and-Sales-Operations">Selling Skills and Sales Operations</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Hospitality Administration/Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Casino-Management">Casino Management</a></li>
# <li class="leaf"><a href="../college-majors/Hospitality-Administration-Management-General">Hospitality Administration/Management</a></li>
# <li class="leaf"><a href="../college-majors/Hotel-Motel-and-Restaurant-Management">Hotel, Motel, and Restaurant Management</a></li>
# <li class="leaf"><a href="../college-majors/Hotel-Motel-Administration-Management">Hotel/Motel Administration/Management</a></li>
# <li class="leaf"><a href="../college-majors/Meeting-and-Event-Planning">Meeting and Event Planning</a></li>
# <li class="leaf"><a href="../college-majors/Resort-Management">Resort Management</a></li>
# <li class="leaf"><a href="../college-majors/Restaurant-Food-Services-Management">Restaurant/Food Services Management</a></li>
# <li class="leaf"><a href="../college-majors/Tourism-and-Travel-Services-Management">Tourism and Travel Services Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Human Resources Management and Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Human-Resources-Development">Human Resources Development</a></li>
# <li class="leaf"><a href="../college-majors/Human-Resources-Management-Personnel-Administration-General">Human Resources Management/Personnel Administration</a></li>
# <li class="leaf"><a href="../college-majors/Labor-and-Industrial-Relations">Labor and Industrial Relations</a></li>
# <li class="leaf"><a href="../college-majors/Labor-Studies">Labor Studies</a></li>
# <li class="leaf"><a href="../college-majors/Organizational-Behavior-Studies">Organizational Behavior Studies</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Insurance</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Insurance">Insurance</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>International Business</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/International-Business-Trade-Commerce">International Business/Trade/Commerce</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Management Information Systems and Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Information-Resources-Management">Information Resources Management</a></li>
# <li class="leaf"><a href="../college-majors/Knowledge-Management">Knowledge Management</a></li>
# <li class="leaf"><a href="../college-majors/Management-Information-Systems-General">Management Information Systems</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Management Sciences and Quantitative Methods</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Actuarial-Science">Actuarial Science</a></li>
# <li class="leaf"><a href="../college-majors/Business-Statistics">Business Statistics</a></li>
# <li class="leaf"><a href="../college-majors/Management-Science">Management Science</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Marketing</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/International-Marketing">International Marketing</a></li>
# <li class="leaf"><a href="../college-majors/Marketing-Research">Marketing Research</a></li>
# <li class="leaf"><a href="../college-majors/Marketing-Marketing-Management-General">Marketing/Marketing Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Real Estate</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Real-Estate">Real Estate</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Specialized Sales, Merchandising and  Marketing Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Apparel-and-Accessories-Marketing-Operations">Apparel and Accessories Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Auctioneering">Auctioneering</a></li>
# <li class="leaf"><a href="../college-majors/Business-and-Personal-Financial-Services-Marketing-Operations">Business and Personal/Financial Services Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Fashion-Merchandising">Fashion Merchandising</a></li>
# <li class="leaf"><a href="../college-majors/Fashion-Modeling">Fashion Modeling</a></li>
# <li class="leaf"><a href="../college-majors/Hospitality-and-Recreation-Marketing-Operations">Hospitality and Recreation Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Special-Products-Marketing-Operations">Special Products Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Tourism-and-Travel-Services-Marketing-Operations">Tourism and Travel Services Marketing Operations</a></li>
# <li class="leaf"><a href="../college-majors/Tourism-Promotion-Operations">Tourism Promotion Operations</a></li>
# <li class="leaf"><a href="../college-majors/Vehicle-and-Vehicle-Parts-and-Accessories-Marketing-Operations">Vehicle and Vehicle Parts and Accessories Marketing Operations</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Taxation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Taxation">Taxation</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Telecommunications Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Telecommunications-Management">Telecommunications Management</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Communication, Journalism, and Related Programs</a>
# <ul class="menu">
# <li class="expanded top"><a>Communication and Media Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Mass-Communication-Media-Studies">Mass Communication/Media Studies</a></li>
# <li class="leaf"><a href="../college-majors/Speech-Communication-and-Rhetoric">Speech Communication and Rhetoric</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Journalism</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Broadcast-Journalism">Broadcast Journalism</a></li>
# <li class="leaf"><a href="../college-majors/Journalism">Journalism</a></li>
# <li class="leaf"><a href="../college-majors/Photojournalism">Photojournalism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Public Relations, Advertising, and Applied Communication</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Advertising">Advertising</a></li>
# <li class="leaf"><a href="../college-majors/Health-Communication">Health Communication</a></li>
# <li class="leaf"><a href="../college-majors/International-and-Intercultural-Communication">International and Intercultural Communication</a></li>
# <li class="leaf"><a href="../college-majors/Organizational-Communication-General">Organizational Communication</a></li>
# <li class="leaf"><a href="../college-majors/Political-Communication">Political Communication</a></li>
# <li class="leaf"><a href="../college-majors/Public-Relations-Image-Management">Public Relations/Image Management</a></li>
# <li class="leaf"><a href="../college-majors/Sports-Communication">Sports Communication</a></li>
# <li class="leaf"><a href="../college-majors/Technical-and-Scientific-Communication">Technical and Scientific Communication</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Publishing</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Publishing">Publishing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Radio, Television, and Digital Communication</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Digital-Communication-and-Media-Multimedia">Digital Communication and Media/Multimedia</a></li>
# <li class="leaf"><a href="../college-majors/Radio-and-Television">Radio and Television</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Communications Technologies/technicians and Support Services</a>
# <ul class="menu">
# <li class="expanded top"><a>Audiovisual Communications Technologies/Technicians</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Photographic-and-Film-Video-Technology-Technician-and-Assistant">Photographic and Film/Video Technology/Technician and Assistant</a></li>
# <li class="leaf"><a href="../college-majors/Radio-and-Television-Broadcasting-Technology-Technician">Radio and Television Broadcasting Technology/Technician</a></li>
# <li class="leaf"><a href="../college-majors/Recording-Arts-Technology-Technician">Recording Arts Technology/Technician</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Communications Technology/Technician</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Communications-Technology-Technician">Communications Technology/Technician</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Graphic Communications</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animation-Interactive-Technology-Video-Graphics-and-Special-Effects">Animation, Interactive Technology, Video Graphics and Special Effects</a></li>
# <li class="leaf"><a href="../college-majors/Computer-Typography-and-Composition-Equipment-Operator">Computer Typography and Composition Equipment Operator</a></li>
# <li class="leaf"><a href="../college-majors/Graphic-and-Printing-Equipment-Operator-General-Production">Graphic and Printing Equipment Operator Production</a></li>
# <li class="leaf"><a href="../college-majors/Graphic-Communications-General">Graphic Communications</a></li>
# <li class="leaf"><a href="../college-majors/Platemaker-Imager">Platemaker/Imager</a></li>
# <li class="leaf"><a href="../college-majors/Prepress-Desktop-Publishing-and-Digital-Imaging-Design">Prepress/Desktop Publishing and Digital Imaging Design</a></li>
# <li class="leaf"><a href="../college-majors/Printing-Management">Printing Management</a></li>
# <li class="leaf"><a href="../college-majors/Printing-Press-Operator">Printing Press Operator</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer and Information Sciences and Support Services</a>
# <ul class="menu">
# <li class="expanded top"><a>Computer and Information Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Artificial-Intelligence">Artificial Intelligence</a></li>
# <li class="leaf"><a href="../college-majors/Computer-and-Information-Sciences-General">Computer and Information Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Informatics">Informatics</a></li>
# <li class="leaf"><a href="../college-majors/Information-Technology">Information Technology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer Programming</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Computer-Programming-Specific-Applications">Computer Programming, Specific Applications</a></li>
# <li class="leaf"><a href="../college-majors/Computer-Programming-Vendor-Product-Certification">Computer Programming, Vendor/Product Certification</a></li>
# <li class="leaf"><a href="../college-majors/Computer-Programming-Programmer-General">Computer Programming/Programmer</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer Science</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Computer-Science">Computer Science</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer Software and Media Applications</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Computer-Graphics">Computer Graphics</a></li>
# <li class="leaf"><a href="../college-majors/Data-Modeling-Warehousing-and-Database-Administration">Data Modeling/Warehousing and Database Administration</a></li>
# <li class="leaf"><a href="../college-majors/Modeling-Virtual-Environments-and-Simulation">Modeling, Virtual Environments and Simulation</a></li>
# <li class="leaf"><a href="../college-majors/Web-Page-Digital-Multimedia-and-Information-Resources-Design">Web Page, Digital/Multimedia and Information Resources Design</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer Systems Analysis</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Computer-Systems-Analysis-Analyst">Computer Systems Analysis/Analyst</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer Systems Networking and Telecommunications</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Computer-Systems-Networking-and-Telecommunications">Computer Systems Networking and Telecommunications</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Computer/Information Technology Administration and Management</a>
# <ul class="menu">
# ...
# <li class="leaf"><a href="../college-majors/Social-Sciences-General">Social Sciences</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Sociology and Anthropology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Sociology-and-Anthropology">Sociology and Anthropology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Sociology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Sociology">Sociology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Urban Studies/Affairs</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Urban-Studies-Affairs">Urban Studies/Affairs</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Theology and Religious Vocations</a>
# <ul class="menu">
# <li class="expanded top"><a>Bible/Biblical Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Bible-Biblical-Studies">Bible/Biblical Studies</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Missions/Missionary Studies and Missiology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Missions-Missionary-Studies-and-Missiology">Missions/Missionary Studies and Missiology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Pastoral Counseling and Specialized Ministries</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Lay-Ministry">Lay Ministry</a></li>
# <li class="leaf"><a href="../college-majors/Pastoral-Studies-Counseling">Pastoral Studies/Counseling</a></li>
# <li class="leaf"><a href="../college-majors/Urban-Ministry">Urban Ministry</a></li>
# <li class="leaf"><a href="../college-majors/Womens-Ministry">Women's Ministry</a></li>
# <li class="leaf"><a href="../college-majors/Youth-Ministry">Youth Ministry</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Religious Education</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Religious-Education">Religious Education</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Religious/Sacred Music</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Religious-Sacred-Music">Religious/Sacred Music</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Theological and Ministerial Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Divinity-Ministry">Divinity/Ministry</a></li>
# <li class="leaf"><a href="../college-majors/Pre-Theology-Pre-Ministerial-Studies">Pre-Theology/Pre-Ministerial Studies</a></li>
# <li class="leaf"><a href="../college-majors/Rabbinical-Studies">Rabbinical Studies</a></li>
# <li class="leaf"><a href="../college-majors/Talmudic-Studies">Talmudic Studies</a></li>
# <li class="leaf"><a href="../college-majors/Theology-Theological-Studies">Theology/Theological Studies</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Transportation and Materials Moving</a>
# <ul class="menu">
# <li class="expanded top"><a>Air Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aeronautics-Aviation-Aerospace-Science-and-Technology-General">Aeronautics/Aviation/Aerospace Science and Technology</a></li>
# <li class="leaf"><a href="../college-majors/Air-Traffic-Controller">Air Traffic Controller</a></li>
# <li class="leaf"><a href="../college-majors/Airline-Flight-Attendant">Airline Flight Attendant</a></li>
# <li class="leaf"><a href="../college-majors/Airline-Commercial-Professional-Pilot-and-Flight-Crew">Airline/Commercial/Professional Pilot and Flight Crew</a></li>
# <li class="leaf"><a href="../college-majors/Aviation-Airway-Management-and-Operations">Aviation/Airway Management and Operations</a></li>
# <li class="leaf"><a href="../college-majors/Flight-Instructor">Flight Instructor</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Ground Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Construction-Heavy-Equipment-Earthmoving-Equipment-Operation">Construction/Heavy Equipment/Earthmoving Equipment Operation</a></li>
# <li class="leaf"><a href="../college-majors/Flagging-and-Traffic-Control">Flagging and Traffic Control</a></li>
# <li class="leaf"><a href="../college-majors/Mobil-Crane-Operation-Operator">Mobil Crane Operation/Operator</a></li>
# <li class="leaf"><a href="../college-majors/Railroad-and-Railway-Transportation">Railroad and Railway Transportation</a></li>
# <li class="leaf"><a href="../college-majors/Truck-and-Bus-Driver-Commercial-Vehicle-Operator-and-Instructor">Truck and Bus Driver/Commercial Vehicle Operator and Instructor</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Marine Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-Fishing">Commercial Fishing</a></li>
# <li class="leaf"><a href="../college-majors/Diver-Professional-and-Instructor">Diver, Professional and Instructor</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Science-Merchant-Marine-Officer">Marine Science/Merchant Marine Officer</a></li>
# </ul>
# </li>
# </ul>
# </li>
# <li class="expanded top"><a>Visual and Performing Arts</a>
# <ul class="menu">
# <li class="expanded top"><a>Arts, Entertainment,and Media Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Arts-Entertainment-and-Media-Management-General">Arts, Entertainment,and Media Management</a></li>
# <li class="leaf"><a href="../college-majors/Fine-and-Studio-Arts-Management">Fine and Studio Arts Management</a></li>
# <li class="leaf"><a href="../college-majors/Music-Management">Music Management</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Theatre-Arts-Management">Theatre/Theatre Arts Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Crafts/Craft Design, Folk Art and Artisanry</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Crafts-Craft-Design-Folk-Art-and-Artisanry">Crafts/Craft Design, Folk Art and Artisanry</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Dance</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Ballet">Ballet</a></li>
# <li class="leaf"><a href="../college-majors/Dance-General">Dance</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Design and Applied Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-and-Advertising-Art">Commercial and Advertising Art</a></li>
# <li class="leaf"><a href="../college-majors/Commercial-Photography">Commercial Photography</a></li>
# <li class="leaf"><a href="../college-majors/Design-and-Visual-Communications-General">Design and Visual Communications</a></li>
# <li class="leaf"><a href="../college-majors/Fashion-Apparel-Design">Fashion/Apparel Design</a></li>
# <li class="leaf"><a href="../college-majors/Game-and-Interactive-Media-Design">Game and Interactive Media Design</a></li>
# <li class="leaf"><a href="../college-majors/Graphic-Design">Graphic Design</a></li>
# <li class="leaf"><a href="../college-majors/Illustration">Illustration</a></li>
# <li class="leaf"><a href="../college-majors/Industrial-and-Product-Design">Industrial and Product Design</a></li>
# <li class="leaf"><a href="../college-majors/Interior-Design">Interior Design</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Drama/Theatre Arts and Stagecraft</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Acting">Acting</a></li>
# <li class="leaf"><a href="../college-majors/Costume-Design">Costume Design</a></li>
# <li class="leaf"><a href="../college-majors/Directing-and-Theatrical-Production">Directing and Theatrical Production</a></li>
# <li class="leaf"><a href="../college-majors/Drama-and-Dramatics-Theatre-Arts-General">Drama and Dramatics/Theatre Arts</a></li>
# <li class="leaf"><a href="../college-majors/Musical-Theatre">Musical Theatre</a></li>
# <li class="leaf"><a href="../college-majors/Playwriting-and-Screenwriting">Playwriting and Screenwriting</a></li>
# <li class="leaf"><a href="../college-majors/Technical-Theatre-Theatre-Design-and-Technology">Technical Theatre/Theatre Design and Technology</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Literature-History-and-Criticism">Theatre Literature, History and Criticism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Film/Video and Photographic Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Cinematography-and-Film-Video-Production">Cinematography and Film/Video Production</a></li>
# <li class="leaf"><a href="../college-majors/Documentary-Production">Documentary Production</a></li>
# <li class="leaf"><a href="../college-majors/Film-Cinema-Video-Studies">Film/Cinema/Video Studies</a></li>
# <li class="leaf"><a href="../college-majors/Photography">Photography</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Fine and Studio Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Art-History-Criticism-and-Conservation">Art History, Criticism and Conservation</a></li>
# <li class="leaf"><a href="../college-majors/Art-Art-Studies-General">Art/Art Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ceramic-Arts-and-Ceramics">Ceramic Arts and Ceramics</a></li>
# <li class="leaf"><a href="../college-majors/Drawing">Drawing</a></li>
# <li class="leaf"><a href="../college-majors/Fiber-Textile-and-Weaving-Arts">Fiber, Textile and Weaving Arts</a></li>
# <li class="leaf"><a href="../college-majors/Fine-Studio-Arts-General">Fine/Studio Arts</a></li>
# <li class="leaf"><a href="../college-majors/Intermedia-Multimedia">Intermedia/Multimedia</a></li>
# <li class="leaf"><a href="../college-majors/Metal-and-Jewelry-Arts">Metal and Jewelry Arts</a></li>
# <li class="leaf"><a href="../college-majors/Painting">Painting</a></li>
# <li class="leaf"><a href="../college-majors/Printmaking">Printmaking</a></li>
# <li class="leaf"><a href="../college-majors/Sculpture">Sculpture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Music</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Brass-Instruments">Brass Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Conducting">Conducting</a></li>
# <li class="leaf"><a href="../college-majors/Jazz-Jazz-Studies">Jazz/Jazz Studies</a></li>
# <li class="leaf"><a href="../college-majors/Keyboard-Instruments">Keyboard Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Music-General">Music</a></li>
# <li class="leaf"><a href="../college-majors/Music-History-Literature-and-Theory">Music History, Literature, and Theory</a></li>
# <li class="leaf"><a href="../college-majors/Music-Pedagogy">Music Pedagogy</a></li>
# <li class="leaf"><a href="../college-majors/Music-Performance-General">Music Performance</a></li>
# <li class="leaf"><a href="../college-majors/Music-Technology">Music Technology</a></li>
# <li class="leaf"><a href="../college-majors/Music-Theory-and-Composition">Music Theory and Composition</a></li>
# <li class="leaf"><a href="../college-majors/Musicology-and-Ethnomusicology">Musicology and Ethnomusicology</a></li>
# <li class="leaf"><a href="../college-majors/Percussion-Instruments">Percussion Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Stringed-Instruments">Stringed Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Voice-and-Opera">Voice and Opera</a></li>
# <li class="leaf"><a href="../college-majors/Woodwind-Instruments">Woodwind Instruments</a> </li>
# </ul>
# </li>
# <li class="expanded top"><a>Visual and Performing Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Digital-Arts">Digital Arts</a></li>
# <li class="leaf"><a href="../college-majors/Visual-and-Performing-Arts-General">Visual and Performing Arts</a></li>
# </ul>
# </li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <p class="small"></p>
# </div>
# <footer id="footer">
# <div class="container">
# <div class="row">
# <div class="col-sm-4 text-left">
# <p class="text-left"><img alt="mymajors logo" class="text-left" src="../v6/images/mymajors-logo-sm.png" width="150px"/></p>
# <h4><a href="../college-majors/" style="color:#FFFFFF !important;"><span style="color:#fff;">Find a</span> Major</a></h4>
# <h4><a href="../find-a-college/" style="color:#FFFFFF !important;"><span style="color:#fff;">Find a</span> College</a></h4>
# <h4><a href="../career-list/" style="color:#FFFFFF !important;"><span style="color:#fff;">Find a</span> Career</a></h4>
# </div>
# <div class="col-sm-4" style="padding-top: 10px;">
# <h4><a href="../about/" style="color:#FFFFFF !important;">About</a></h4>
# <p class="small" style="color:#fff;"><a href="http://www.mymajors.com/about/" style="color:#FFFFFF !important;">What is MyMajors?</a><br/>
# <a href="../counselors/" style="color:#FFFFFF !important;">For Counselors</a><br/>
# <a href="http://www.mymajors.com/privatelabel" style="color:#FFFFFF !important;">For Colleges</a><br/>
# <a href="../blog/counselors/magazines/" style="color:#FFFFFF !important;">Magazines</a><br/>
# <a href="../blog/" style="color:#FFFFFF !important;">Blog</a></p>
# </div>
# <div class="col-sm-4" style="padding-top: 10px;">
# <h4 style="color:#fff;"><script type="text/javascript">var a = new Array('contact@my','majors.com');document.write("<a   style="color:#FFFFFF !important;" href='mailto:"+a[0]+a[1]+"'>");</script>Contact Us</h4>
# <h4> <a href="http://www.facebook.com/MyMajors"><span class="fa-stack"> <i class="fa fa-square fa-stack-2x"></i> <i class="fa fa-facebook fa-stack-1x fa-inverse"></i> </span></a> <a href="http://twitter.com/mymajors"><span class="fa-stack"> <i class="fa fa-square fa-stack-2x"></i> <i class="fa fa-twitter fa-stack-1x fa-inverse"></i> </span></a> <a href="http://plus.google.com/+Mymajors"><span class="fa-stack"> <i class="fa fa-square fa-stack-2x"></i> <i class="fa fa-google-plus fa-stack-1x fa-inverse"></i> </span></a> </h4>
# <p class="small" style="color:#fff;"><a href="../terms-and-conditions/" style="color:#FFFFFF !important;">Terms</a> | <a href="../privacy-policy/" style="color:#FFFFFF !important;">Privacy</a></p>
# <!-- AddThis Smart Layers BEGIN -->
# <!-- Go to http://www.addthis.com/get/smart-layers to customize -->
# <script src="//s7.addthis.com/js/300/addthis_widget.js#pubid=TCI1" type="text/javascript"></script>
# <script type="text/javascript">
#   addthis.layers({
#     'theme' : 'transparent',
#     'share' : {
#       'position' : 'right',
#       'numPreferredServices' : 6
#     }
#   });
# </script>
# <!-- AddThis Smart Layers END -->
# </div>
# </div>
# </div>
# </footer>
# <script charset="utf-8" src="https://code.jquery.com/jquery-1.8.2.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="../v6/js/jquery.columnview.min.js" type="text/javascript"></script>
# <script charset="utf-8" src="../v6/js/jquery.search.js" type="text/javascript"></script>
# <script>
# $("#columnlist").hide();
# </script>
# <script charset="utf-8" type="text/javascript">
#     $(document).ready(function(){
#       $("#columnlist").columnview();
# 	  $("#columnlist").show();
#     $('#autocomplete').autocomplete({
#     serviceUrl: '/autocomplete/',
#     groupBy: 'category',
#     maxHeight: 1500,
#     width: 350,
#     deferRequestBy: 50,
#     minChars: 2,
#     triggerSelectOnValidInput: false,
#     onSelect: function (suggestion) {
#         //alert('You selected: ' + suggestion.value + ', ' + suggestion.data.url);
#         window.location.href = "http://www.mymajors.com/"+suggestion.data.url;
#     }
# });
#     $('#autocomplete2').autocomplete({
#     serviceUrl: '/autocomplete/?t=1',
#     groupBy: 'category',
#     maxHeight: 1500,
#     width: 550,
#     deferRequestBy: 50,
#     minChars: 2,
#     triggerSelectOnValidInput: false,
#     onSelect: function (suggestion) {
#         //alert('You selected: ' + suggestion.value + ', ' + suggestion.data.url);
#         window.location.href = "http://www.mymajors.com/"+suggestion.data.url;
#     }
# });
#     });
#   </script>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-1477316-1', 'mymajors.com');
#   ga('require', 'linkid', 'linkid.js');
#   ga('send', 'pageview');
#
# </script>
# </body>
# </html>

# %%
from IPython.display import HTML
type (soup)

letters1 = soup.find_all(class_="leaf")
letters2 = soup.find_all(class_="expanded top")


print (letters1, letters2)
# Out:
# [<li class="leaf"><a href="http://www.unity.edu/Academic/Majors/WildlifeCareAndEducation/WildlifeCareAndEducation.aspx" target="_blank">Captive Wildlife Care and Education( Unity College in Maine )</a> </li>, <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=83732">Contemporary Christian Music ( Greenville College)</a></li>, <li class="leaf"><a href="http://thunder1.cudenver.edu/clas/ISMmajor.html">Individually Structured Major  ( University of Colorado Denver)</a></li>, <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=102695">Recording Industry ( Greenville College)</a></li>, <li class="leaf"><a href="http://www.unity.edu/Academic/Majors/SustainableDesignAndTechnology.aspx" target="_blank">Sustainable Design and Technology ( Unity College in Maine )</a></li>, <li class="leaf"><a href="../college-majors/Animal-Training">Animal Training</a></li>, <li class="leaf"><a href="../college-majors/Dog-Pet-Animal-Grooming">Dog/Pet/Animal Grooming</a></li>, <li class="leaf"><a href="../college-majors/Equestrian-Equine-Studies">Equestrian/Equine Studies</a></li>, <li class="leaf"><a href="../college-majors/Taxidermy-Taxidermist">Taxidermy/Taxidermist</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-and-Food-Products-Processing">Agricultural and Food Products Processing</a></li>, <li class="leaf"><a href="../college-majors/Agribusiness-Agricultural-Business-Operations">Agribusiness/Agricultural Business Operations</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Business-and-Management-General">Agricultural Business and Management</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Business-Technology">Agricultural Business Technology</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Economics">Agricultural Economics</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Farm-Supplies-Retailing-and-Wholesaling">Agricultural/Farm Supplies Retailing and Wholesaling</a></li>, <li class="leaf"><a href="../college-majors/Farm-Farm-and-Ranch-Management">Farm/Farm and Ranch Management</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Mechanics-and-Equipment-Machine-Technology">Agricultural Mechanics and Equipment/Machine Technology</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Mechanization-General">Agricultural Mechanization</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Power-Machinery-Operation">Agricultural Power Machinery Operation</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Production-Operations-General">Agricultural Production Operations</a></li>, <li class="leaf"><a href="../college-majors/Agroecology-and-Sustainable-Agriculture">Agroecology and Sustainable Agriculture</a></li>, <li class="leaf"><a href="../college-majors/Animal-Livestock-Husbandry-and-Production">Animal/Livestock Husbandry and Production</a></li>, <li class="leaf"><a href="../college-majors/Aquaculture">Aquaculture</a></li>, <li class="leaf"><a href="../college-majors/Crop-Production">Crop Production</a></li>, <li class="leaf"><a href="../college-majors/Dairy-Husbandry-and-Production">Dairy Husbandry and Production</a></li>, <li class="leaf"><a href="../college-majors/Horse-Husbandry-Equine-Science-and-Management">Horse Husbandry/Equine Science and Management</a></li>, <li class="leaf"><a href="../college-majors/Viticulture-and-Enology">Viticulture and Enology</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-and-Extension-Education-Services">Agricultural and Extension Education Services</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Communication-Journalism">Agricultural Communication/Journalism</a></li>, <li class="leaf"><a href="../college-majors/Agricultural-Animal-Breeding">Agricultural Animal Breeding</a></li>, <li class="leaf"><a href="../college-majors/Animal-Health"> ...
# [<li class="expanded top"><a><strong>Featured Majors</strong></a>
# <ul class="menu">
# <li><a href="aviation-flight-training">Aviation / Flight Training (UND Aerospace) </a></li>
# <li class="leaf"><a href="http://www.unity.edu/Academic/Majors/WildlifeCareAndEducation/WildlifeCareAndEducation.aspx" target="_blank">Captive Wildlife Care and Education( Unity College in Maine )</a> </li>
# <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=83732">Contemporary Christian Music ( Greenville College)</a></li>
# <li class="leaf"><a href="http://thunder1.cudenver.edu/clas/ISMmajor.html">Individually Structured Major  ( University of Colorado Denver)</a></li>
# <li class="leaf"><a href="http://www.greenville.edu/academics/majors_minors/major_minordetail.dot?id=102695">Recording Industry ( Greenville College)</a></li>
# <li class="leaf"><a href="http://www.unity.edu/Academic/Majors/SustainableDesignAndTechnology.aspx" target="_blank">Sustainable Design and Technology ( Unity College in Maine )</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agriculture, Agriculture Operations, and Related Sciences</a>
# <ul class="menu">
# <li class="expanded top"><a>Agricultural and Domestic Animal Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Training">Animal Training</a></li>
# <li class="leaf"><a href="../college-majors/Dog-Pet-Animal-Grooming">Dog/Pet/Animal Grooming</a></li>
# <li class="leaf"><a href="../college-majors/Equestrian-Equine-Studies">Equestrian/Equine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Taxidermy-Taxidermist">Taxidermy/Taxidermist</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural and Food Products Processing</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Food-Products-Processing">Agricultural and Food Products Processing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Business and Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agribusiness-Agricultural-Business-Operations">Agribusiness/Agricultural Business Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-and-Management-General">Agricultural Business and Management</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-Technology">Agricultural Business Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Economics">Agricultural Economics</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Farm-Supplies-Retailing-and-Wholesaling">Agricultural/Farm Supplies Retailing and Wholesaling</a></li>
# <li class="leaf"><a href="../college-majors/Farm-Farm-and-Ranch-Management">Farm/Farm and Ranch Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Mechanization</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanics-and-Equipment-Machine-Technology">Agricultural Mechanics and Equipment/Machine Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanization-General">Agricultural Mechanization</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Power-Machinery-Operation">Agricultural Power Machinery Operation</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Production Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Production-Operations-General">Agricultural Production Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agroecology-and-Sustainable-Agriculture">Agroecology and Sustainable Agriculture</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Livestock-Husbandry-and-Production">Animal/Livestock Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Aquaculture">Aquaculture</a></li>
# <li class="leaf"><a href="../college-majors/Crop-Production">Crop Production</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Husbandry-and-Production">Dairy Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Horse-Husbandry-Equine-Science-and-Management">Horse Husbandry/Equine Science and Management</a></li>
# <li class="leaf"><a href="../college-majors/Viticulture-and-Enology">Viticulture and Enology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Agricultural Public Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Extension-Education-Services">Agricultural and Extension Education Services</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Communication-Journalism">Agricultural Communication/Journalism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Animal Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Animal-Breeding">Agricultural Animal Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Health">Animal Health</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Nutrition">Animal Nutrition</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Sciences-General">Animal Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Science">Dairy Science</a></li>
# <li class="leaf"><a href="../college-majors/Livestock-Management">Livestock Management</a></li>
# <li class="leaf"><a href="../college-majors/Poultry-Science">Poultry Science</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Applied Horticulture and Horticultural Business Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Applied-Horticulture-Horticulture-Operations-General">Applied Horticulture/Horticulture Operations</a></li>
# <li class="leaf"><a href="../college-majors/Floriculture-Floristry-Operations-and-Management">Floriculture/Floristry Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Greenhouse-Operations-and-Management">Greenhouse Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Landscaping-and-Groundskeeping">Landscaping and Groundskeeping</a></li>
# <li class="leaf"><a href="../college-majors/Ornamental-Horticulture">Ornamental Horticulture</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Nursery-Operations-and-Management">Plant Nursery Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Turf-and-Turfgrass-Management">Turf and Turfgrass Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Food Science and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Food-Science">Food Science</a></li>
# <li class="leaf"><a href="../college-majors/Food-Technology-and-Processing">Food Technology and Processing</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>International Agriculture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/International-Agriculture">International Agriculture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Plant Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Horticultural-Plant-Breeding">Agricultural and Horticultural Plant Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Agronomy-and-Crop-Science">Agronomy and Crop Science</a></li>
# <li class="leaf"><a href="../college-majors/Horticultural-Science">Horticultural Science</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Protection-and-Integrated-Pest-Management">Plant Protection and Integrated Pest Management</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Sciences-General">Plant Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Range-Science-and-Management">Range Science and Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Soil Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Soil-Chemistry-and-Physics">Soil Chemistry and Physics</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Microbiology">Soil Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Science-and-Agronomy-General">Soil Science and Agronomy</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural and Domestic Animal Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Training">Animal Training</a></li>
# <li class="leaf"><a href="../college-majors/Dog-Pet-Animal-Grooming">Dog/Pet/Animal Grooming</a></li>
# <li class="leaf"><a href="../college-majors/Equestrian-Equine-Studies">Equestrian/Equine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Taxidermy-Taxidermist">Taxidermy/Taxidermist</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural and Food Products Processing</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Food-Products-Processing">Agricultural and Food Products Processing</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural Business and Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agribusiness-Agricultural-Business-Operations">Agribusiness/Agricultural Business Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-and-Management-General">Agricultural Business and Management</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Business-Technology">Agricultural Business Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Economics">Agricultural Economics</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Farm-Supplies-Retailing-and-Wholesaling">Agricultural/Farm Supplies Retailing and Wholesaling</a></li>
# <li class="leaf"><a href="../college-majors/Farm-Farm-and-Ranch-Management">Farm/Farm and Ranch Management</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural Mechanization</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanics-and-Equipment-Machine-Technology">Agricultural Mechanics and Equipment/Machine Technology</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Mechanization-General">Agricultural Mechanization</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Power-Machinery-Operation">Agricultural Power Machinery Operation</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural Production Operations</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Production-Operations-General">Agricultural Production Operations</a></li>
# <li class="leaf"><a href="../college-majors/Agroecology-and-Sustainable-Agriculture">Agroecology and Sustainable Agriculture</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Livestock-Husbandry-and-Production">Animal/Livestock Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Aquaculture">Aquaculture</a></li>
# <li class="leaf"><a href="../college-majors/Crop-Production">Crop Production</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Husbandry-and-Production">Dairy Husbandry and Production</a></li>
# <li class="leaf"><a href="../college-majors/Horse-Husbandry-Equine-Science-and-Management">Horse Husbandry/Equine Science and Management</a></li>
# <li class="leaf"><a href="../college-majors/Viticulture-and-Enology">Viticulture and Enology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Agricultural Public Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Extension-Education-Services">Agricultural and Extension Education Services</a></li>
# <li class="leaf"><a href="../college-majors/Agricultural-Communication-Journalism">Agricultural Communication/Journalism</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Animal Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-Animal-Breeding">Agricultural Animal Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Health">Animal Health</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Nutrition">Animal Nutrition</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Sciences-General">Animal Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Dairy-Science">Dairy Science</a></li>
# <li class="leaf"><a href="../college-majors/Livestock-Management">Livestock Management</a></li>
# <li class="leaf"><a href="../college-majors/Poultry-Science">Poultry Science</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Applied Horticulture and Horticultural Business Services</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Applied-Horticulture-Horticulture-Operations-General">Applied Horticulture/Horticulture Operations</a></li>
# <li class="leaf"><a href="../college-majors/Floriculture-Floristry-Operations-and-Management">Floriculture/Floristry Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Greenhouse-Operations-and-Management">Greenhouse Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Landscaping-and-Groundskeeping">Landscaping and Groundskeeping</a></li>
# <li class="leaf"><a href="../college-majors/Ornamental-Horticulture">Ornamental Horticulture</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Nursery-Operations-and-Management">Plant Nursery Operations and Management</a></li>
# <li class="leaf"><a href="../college-majors/Turf-and-Turfgrass-Management">Turf and Turfgrass Management</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Food Science and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Food-Science">Food Science</a></li>
# <li class="leaf"><a href="../college-majors/Food-Technology-and-Processing">Food Technology and Processing</a></li>
# </ul>
# </li>, <li class="expanded top"><a>International Agriculture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/International-Agriculture">International Agriculture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Plant Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Agricultural-and-Horticultural-Plant-Breeding">Agricultural and Horticultural Plant Breeding</a></li>
# <li class="leaf"><a href="../college-majors/Agronomy-and-Crop-Science">Agronomy and Crop Science</a></li>
# <li class="leaf"><a href="../college-majors/Horticultural-Science">Horticultural Science</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Protection-and-Integrated-Pest-Management">Plant Protection and Integrated Pest Management</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Sciences-General">Plant Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Range-Science-and-Management">Range Science and Management</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Soil Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Soil-Chemistry-and-Physics">Soil Chemistry and Physics</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Microbiology">Soil Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Soil-Science-and-Agronomy-General">Soil Science and Agronomy</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Architecture and Related Services</a>
# <ul class="menu">
# <li class="expanded top"><a>Architectural History and Criticism</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-History-and-Criticism-General">Architectural History and Criticism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Architectural Sciences and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-and-Building-Sciences-Technology">Architectural and Building Sciences/Technology</a></li>
# <li class="leaf"><a href="../college-majors/Architectural-Technology-Technician">Architectural Technology/Technician</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architecture">Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>City/Urban, Community and Regional Planning</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/City-Urban-Community-and-Regional-Planning">City/Urban, Community and Regional Planning</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Environmental Design</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Design-Architecture">Environmental Design/Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Interior Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Interior-Architecture">Interior Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Landscape Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Landscape-Architecture">Landscape Architecture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Real Estate Development</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Real-Estate-Development">Real Estate Development</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Architectural History and Criticism</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-History-and-Criticism-General">Architectural History and Criticism</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Architectural Sciences and Technology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architectural-and-Building-Sciences-Technology">Architectural and Building Sciences/Technology</a></li>
# <li class="leaf"><a href="../college-majors/Architectural-Technology-Technician">Architectural Technology/Technician</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Architecture">Architecture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>City/Urban, Community and Regional Planning</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/City-Urban-Community-and-Regional-Planning">City/Urban, Community and Regional Planning</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Environmental Design</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Design-Architecture">Environmental Design/Architecture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Interior Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Interior-Architecture">Interior Architecture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Landscape Architecture</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Landscape-Architecture">Landscape Architecture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Real Estate Development</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Real-Estate-Development">Real Estate Development</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Area, Ethnic, Cultural, Gender, and Group Studies</a>
# <ul class="menu">
# <li class="expanded top"><a>Area Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-Studies">African Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-United-States-Studies-Civilization">American/United States Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Asian-Studies-Civilization">Asian Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Balkans-Studies">Balkans Studies</a></li>
# <li class="leaf"><a href="../college-majors/Baltic-Studies">Baltic Studies</a></li>
# <li class="leaf"><a href="../college-majors/Canadian-Studies">Canadian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Caribbean-Studies">Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Chinese-Studies">Chinese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Commonwealth-Studies">Commonwealth Studies</a></li>
# <li class="leaf"><a href="../college-majors/East-Asian-Studies">East Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/European-Studies-Civilization">European Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/French-Studies">French Studies</a></li>
# <li class="leaf"><a href="../college-majors/German-Studies">German Studies</a></li>
# <li class="leaf"><a href="../college-majors/Irish-Studies">Irish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Italian-Studies">Italian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Japanese-Studies">Japanese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Korean-Studies">Korean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-and-Caribbean-Studies">Latin American and Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-Studies">Latin American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Near-and-Middle-Eastern-Studies">Near and Middle Eastern Studies</a></li>
# <li class="leaf"><a href="../college-majors/Pacific-Area-Pacific-Rim-Studies">Pacific Area/Pacific Rim Studies</a></li>
# <li class="leaf"><a href="../college-majors/Polish-Studies">Polish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Regional-Studies-US-Canadian-Foreign">Regional Studies (US, Canadian, Foreign)</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Studies">Russian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Central-European-East-European-and-Eurasian-Studies">Russian, Central European, East European and Eurasian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Scandinavian-Studies">Scandinavian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Slavic-Studies">Slavic Studies</a></li>
# <li class="leaf"><a href="../college-majors/South-Asian-Studies">South Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Southeast-Asian-Studies">Southeast Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Spanish-and-Iberian-Studies">Spanish and Iberian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Tibetan-Studies">Tibetan Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ukraine-Studies">Ukraine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ural-Altaic-and-Central-Asian-Studies">Ural-Altaic and Central Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Western-European-Studies">Western European Studies</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Ethnic Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-American-Black-Studies">African-American/Black Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-Indian-Native-American-Studies">American Indian/Native American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Asian-American-Studies">Asian-American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Deaf-Studies">Deaf Studies</a></li>
# <li class="leaf"><a href="../college-majors/Disability-Studies">Disability Studies</a></li>
# <li class="leaf"><a href="../college-majors/Folklore-Studies">Folklore Studies</a></li>
# <li class="leaf"><a href="../college-majors/Gay-Lesbian-Studies">Gay/Lesbian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Hispanic-American-Puerto-Rican-and-Mexican-American-Chicano-Studies">Hispanic-American, Puerto Rican, and Mexican-American/Chicano Studies</a></li>
# <li class="leaf"><a href="../college-majors/Womens-Studies">Women's Studies</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Area Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-Studies">African Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-United-States-Studies-Civilization">American/United States Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Asian-Studies-Civilization">Asian Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/Balkans-Studies">Balkans Studies</a></li>
# <li class="leaf"><a href="../college-majors/Baltic-Studies">Baltic Studies</a></li>
# <li class="leaf"><a href="../college-majors/Canadian-Studies">Canadian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Caribbean-Studies">Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Chinese-Studies">Chinese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Commonwealth-Studies">Commonwealth Studies</a></li>
# <li class="leaf"><a href="../college-majors/East-Asian-Studies">East Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/European-Studies-Civilization">European Studies/Civilization</a></li>
# <li class="leaf"><a href="../college-majors/French-Studies">French Studies</a></li>
# <li class="leaf"><a href="../college-majors/German-Studies">German Studies</a></li>
# <li class="leaf"><a href="../college-majors/Irish-Studies">Irish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Italian-Studies">Italian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Japanese-Studies">Japanese Studies</a></li>
# <li class="leaf"><a href="../college-majors/Korean-Studies">Korean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-and-Caribbean-Studies">Latin American and Caribbean Studies</a></li>
# <li class="leaf"><a href="../college-majors/Latin-American-Studies">Latin American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Near-and-Middle-Eastern-Studies">Near and Middle Eastern Studies</a></li>
# <li class="leaf"><a href="../college-majors/Pacific-Area-Pacific-Rim-Studies">Pacific Area/Pacific Rim Studies</a></li>
# <li class="leaf"><a href="../college-majors/Polish-Studies">Polish Studies</a></li>
# <li class="leaf"><a href="../college-majors/Regional-Studies-US-Canadian-Foreign">Regional Studies (US, Canadian, Foreign)</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Studies">Russian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Russian-Central-European-East-European-and-Eurasian-Studies">Russian, Central European, East European and Eurasian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Scandinavian-Studies">Scandinavian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Slavic-Studies">Slavic Studies</a></li>
# <li class="leaf"><a href="../college-majors/South-Asian-Studies">South Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Southeast-Asian-Studies">Southeast Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Spanish-and-Iberian-Studies">Spanish and Iberian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Tibetan-Studies">Tibetan Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ukraine-Studies">Ukraine Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ural-Altaic-and-Central-Asian-Studies">Ural-Altaic and Central Asian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Western-European-Studies">Western European Studies</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Ethnic Studies</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/African-American-Black-Studies">African-American/Black Studies</a></li>
# <li class="leaf"><a href="../college-majors/American-Indian-Native-American-Studies">American Indian/Native American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Asian-American-Studies">Asian-American Studies</a></li>
# <li class="leaf"><a href="../college-majors/Deaf-Studies">Deaf Studies</a></li>
# <li class="leaf"><a href="../college-majors/Disability-Studies">Disability Studies</a></li>
# <li class="leaf"><a href="../college-majors/Folklore-Studies">Folklore Studies</a></li>
# <li class="leaf"><a href="../college-majors/Gay-Lesbian-Studies">Gay/Lesbian Studies</a></li>
# <li class="leaf"><a href="../college-majors/Hispanic-American-Puerto-Rican-and-Mexican-American-Chicano-Studies">Hispanic-American, Puerto Rican, and Mexican-American/Chicano Studies</a></li>
# <li class="leaf"><a href="../college-majors/Womens-Studies">Women's Studies</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Aviation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/aviation-flight-training">Aviation / Flight Training (UND Aerospace) </a></li>
# </ul>
# </li>, <li class="expanded top"><a>Biological and Biomedical Sciences</a>
# <ul class="menu">
# <li class="expanded top"><a>Biochemistry, Biophysics and Molecular Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biochemistry">Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Biochemistry-and-Molecular-Biology">Biochemistry and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Biophysics">Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biochemistry">Molecular Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biology">Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biophysics">Molecular Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Photobiology">Photobiology</a></li>
# <li class="leaf"><a href="../college-majors/Radiation-Biology-Radiobiology">Radiation Biology/Radiobiology</a></li>
# <li class="leaf"><a href="../college-majors/Structural-Biology">Structural Biology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biology-Biological-Sciences-General">Biology/Biological Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Biomedical-Sciences-General">Biomedical Sciences</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biomathematics, Bioinformatics, and Computational Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Bioinformatics">Bioinformatics</a></li>
# <li class="leaf"><a href="../college-majors/Biometry-Biometrics">Biometry/Biometrics</a></li>
# <li class="leaf"><a href="../college-majors/Biostatistics">Biostatistics</a></li>
# <li class="leaf"><a href="../college-majors/Computational-Biology">Computational Biology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Biotechnology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biotechnology">Biotechnology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Botany/Plant Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Botany-Plant-Biology">Botany/Plant Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Molecular-Biology">Plant Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Pathology-Phytopathology">Plant Pathology/Phytopathology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Physiology">Plant Physiology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Cell/Cellular Biology and Anatomical Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Anatomy">Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Biology-and-Anatomy">Cell Biology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-and-Molecular-Biology">Cell/Cellular and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-Biology-and-Histology">Cell/Cellular Biology and Histology</a></li>
# <li class="leaf"><a href="../college-majors/Developmental-Biology-and-Embryology">Developmental Biology and Embryology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Ecology, Evolution, Systematics, and Population Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aquatic-Biology-Limnology">Aquatic Biology/Limnology</a></li>
# <li class="leaf"><a href="../college-majors/Conservation-Biology">Conservation Biology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology">Ecology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology-and-Evolutionary-Biology">Ecology and Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Environmental-Biology">Environmental Biology</a></li>
# <li class="leaf"><a href="../college-majors/Epidemiology">Epidemiology</a></li>
# <li class="leaf"><a href="../college-majors/Evolutionary-Biology">Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Biology-and-Biological-Oceanography">Marine Biology and Biological Oceanography</a></li>
# <li class="leaf"><a href="../college-majors/Population-Biology">Population Biology</a></li>
# <li class="leaf"><a href="../college-majors/Systematic-Biology-Biological-Systematics">Systematic Biology/Biological Systematics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Genetics</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Genetics">Animal Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genetics-General">Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genome-Sciences-Genomics">Genome Sciences/Genomics</a></li>
# <li class="leaf"><a href="../college-majors/Human-Medical-Genetics">Human/Medical Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Microbial-and-Eukaryotic-Genetics">Microbial and Eukaryotic Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Genetics">Molecular Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Genetics">Plant Genetics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Microbiological Sciences and Immunology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Immunology">Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Medical-Microbiology-and-Bacteriology">Medical Microbiology and Bacteriology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-General">Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-and-Immunology">Microbiology and Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Mycology">Mycology</a></li>
# <li class="leaf"><a href="../college-majors/Parasitology">Parasitology</a></li>
# <li class="leaf"><a href="../college-majors/Virology">Virology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Molecular Medicine</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Molecular-Medicine">Molecular Medicine</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Neurobiology and Neurosciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Neuroanatomy">Neuroanatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Anatomy">Neurobiology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Behavior">Neurobiology and Behavior</a></li>
# <li class="leaf"><a href="../college-majors/Neuroscience">Neuroscience</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Pharmacology and Toxicology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Toxicology">Environmental Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Pharmacology">Molecular Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Toxicology">Molecular Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Neuropharmacology">Neuropharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology">Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology-and-Toxicology">Pharmacology and Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Toxicology">Toxicology</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Physiology, Pathology and Related Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aerospace-Physiology-and-Medicine">Aerospace Physiology and Medicine</a></li>
# <li class="leaf"><a href="../college-majors/Cardiovascular-Science">Cardiovascular Science</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Physiology">Cell Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Endocrinology">Endocrinology</a></li>
# <li class="leaf"><a href="../college-majors/Exercise-Physiology">Exercise Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Physiology">Molecular Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Oncology-and-Cancer-Biology">Oncology and Cancer Biology</a></li>
# <li class="leaf"><a href="../college-majors/Pathology-Experimental-Pathology">Pathology/Experimental Pathology</a></li>
# <li class="leaf"><a href="../college-majors/Physiology-General">Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Reproductive-Biology">Reproductive Biology</a></li>
# <li class="leaf"><a href="../college-majors/Vision-Science-Physiological-Optics">Vision Science/Physiological Optics</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Zoology/Animal Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Behavior-and-Ethology">Animal Behavior and Ethology</a></li>
# <li class="leaf"><a href="../college-majors/Animal-Physiology">Animal Physiology</a></li>
# <li class="leaf"><a href="../college-majors/Entomology">Entomology</a></li>
# <li class="leaf"><a href="../college-majors/Wildlife-Biology">Wildlife Biology</a></li>
# <li class="leaf"><a href="../college-majors/Zoology-Animal-Biology">Zoology/Animal Biology</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Biochemistry, Biophysics and Molecular Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biochemistry">Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Biochemistry-and-Molecular-Biology">Biochemistry and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Biophysics">Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biochemistry">Molecular Biochemistry</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biology">Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Biophysics">Molecular Biophysics</a></li>
# <li class="leaf"><a href="../college-majors/Photobiology">Photobiology</a></li>
# <li class="leaf"><a href="../college-majors/Radiation-Biology-Radiobiology">Radiation Biology/Radiobiology</a></li>
# <li class="leaf"><a href="../college-majors/Structural-Biology">Structural Biology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biology-Biological-Sciences-General">Biology/Biological Sciences</a></li>
# <li class="leaf"><a href="../college-majors/Biomedical-Sciences-General">Biomedical Sciences</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Biomathematics, Bioinformatics, and Computational Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Bioinformatics">Bioinformatics</a></li>
# <li class="leaf"><a href="../college-majors/Biometry-Biometrics">Biometry/Biometrics</a></li>
# <li class="leaf"><a href="../college-majors/Biostatistics">Biostatistics</a></li>
# <li class="leaf"><a href="../college-majors/Computational-Biology">Computational Biology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Biotechnology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Biotechnology">Biotechnology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Botany/Plant Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Botany-Plant-Biology">Botany/Plant Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Molecular-Biology">Plant Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Pathology-Phytopathology">Plant Pathology/Phytopathology</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Physiology">Plant Physiology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Cell/Cellular Biology and Anatomical Sciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Anatomy">Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Biology-and-Anatomy">Cell Biology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-and-Molecular-Biology">Cell/Cellular and Molecular Biology</a></li>
# <li class="leaf"><a href="../college-majors/Cell-Cellular-Biology-and-Histology">Cell/Cellular Biology and Histology</a></li>
# <li class="leaf"><a href="../college-majors/Developmental-Biology-and-Embryology">Developmental Biology and Embryology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Ecology, Evolution, Systematics, and Population Biology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aquatic-Biology-Limnology">Aquatic Biology/Limnology</a></li>
# <li class="leaf"><a href="../college-majors/Conservation-Biology">Conservation Biology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology">Ecology</a></li>
# <li class="leaf"><a href="../college-majors/Ecology-and-Evolutionary-Biology">Ecology and Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Environmental-Biology">Environmental Biology</a></li>
# <li class="leaf"><a href="../college-majors/Epidemiology">Epidemiology</a></li>
# <li class="leaf"><a href="../college-majors/Evolutionary-Biology">Evolutionary Biology</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Biology-and-Biological-Oceanography">Marine Biology and Biological Oceanography</a></li>
# <li class="leaf"><a href="../college-majors/Population-Biology">Population Biology</a></li>
# <li class="leaf"><a href="../college-majors/Systematic-Biology-Biological-Systematics">Systematic Biology/Biological Systematics</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Genetics</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Animal-Genetics">Animal Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genetics-General">Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Genome-Sciences-Genomics">Genome Sciences/Genomics</a></li>
# <li class="leaf"><a href="../college-majors/Human-Medical-Genetics">Human/Medical Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Microbial-and-Eukaryotic-Genetics">Microbial and Eukaryotic Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Genetics">Molecular Genetics</a></li>
# <li class="leaf"><a href="../college-majors/Plant-Genetics">Plant Genetics</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Microbiological Sciences and Immunology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Immunology">Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Medical-Microbiology-and-Bacteriology">Medical Microbiology and Bacteriology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-General">Microbiology</a></li>
# <li class="leaf"><a href="../college-majors/Microbiology-and-Immunology">Microbiology and Immunology</a></li>
# <li class="leaf"><a href="../college-majors/Mycology">Mycology</a></li>
# <li class="leaf"><a href="../college-majors/Parasitology">Parasitology</a></li>
# <li class="leaf"><a href="../college-majors/Virology">Virology</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Molecular Medicine</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Molecular-Medicine">Molecular Medicine</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Neurobiology and Neurosciences</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Neuroanatomy">Neuroanatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Anatomy">Neurobiology and Anatomy</a></li>
# <li class="leaf"><a href="../college-majors/Neurobiology-and-Behavior">Neurobiology and Behavior</a></li>
# <li class="leaf"><a href="../college-majors/Neuroscience">Neuroscience</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Pharmacology and Toxicology</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Environmental-Toxicology">Environmental Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Pharmacology">Molecular Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Molecular-Toxicology">Molecular Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Neuropharmacology">Neuropharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology">Pharmacology</a></li>
# <li class="leaf"><a href="../college-majors/Pharmacology-and-Toxicology">Pharmacology and Toxicology</a></li>
# <li class="leaf"><a href="../college-majors/Toxicology">Toxicology</a></li>
# </ul>
# ...
# <li class="leaf"><a href="../college-majors/Mobil-Crane-Operation-Operator">Mobil Crane Operation/Operator</a></li>
# <li class="leaf"><a href="../college-majors/Railroad-and-Railway-Transportation">Railroad and Railway Transportation</a></li>
# <li class="leaf"><a href="../college-majors/Truck-and-Bus-Driver-Commercial-Vehicle-Operator-and-Instructor">Truck and Bus Driver/Commercial Vehicle Operator and Instructor</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Marine Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-Fishing">Commercial Fishing</a></li>
# <li class="leaf"><a href="../college-majors/Diver-Professional-and-Instructor">Diver, Professional and Instructor</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Science-Merchant-Marine-Officer">Marine Science/Merchant Marine Officer</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Air Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Aeronautics-Aviation-Aerospace-Science-and-Technology-General">Aeronautics/Aviation/Aerospace Science and Technology</a></li>
# <li class="leaf"><a href="../college-majors/Air-Traffic-Controller">Air Traffic Controller</a></li>
# <li class="leaf"><a href="../college-majors/Airline-Flight-Attendant">Airline Flight Attendant</a></li>
# <li class="leaf"><a href="../college-majors/Airline-Commercial-Professional-Pilot-and-Flight-Crew">Airline/Commercial/Professional Pilot and Flight Crew</a></li>
# <li class="leaf"><a href="../college-majors/Aviation-Airway-Management-and-Operations">Aviation/Airway Management and Operations</a></li>
# <li class="leaf"><a href="../college-majors/Flight-Instructor">Flight Instructor</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Ground Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Construction-Heavy-Equipment-Earthmoving-Equipment-Operation">Construction/Heavy Equipment/Earthmoving Equipment Operation</a></li>
# <li class="leaf"><a href="../college-majors/Flagging-and-Traffic-Control">Flagging and Traffic Control</a></li>
# <li class="leaf"><a href="../college-majors/Mobil-Crane-Operation-Operator">Mobil Crane Operation/Operator</a></li>
# <li class="leaf"><a href="../college-majors/Railroad-and-Railway-Transportation">Railroad and Railway Transportation</a></li>
# <li class="leaf"><a href="../college-majors/Truck-and-Bus-Driver-Commercial-Vehicle-Operator-and-Instructor">Truck and Bus Driver/Commercial Vehicle Operator and Instructor</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Marine Transportation</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-Fishing">Commercial Fishing</a></li>
# <li class="leaf"><a href="../college-majors/Diver-Professional-and-Instructor">Diver, Professional and Instructor</a></li>
# <li class="leaf"><a href="../college-majors/Marine-Science-Merchant-Marine-Officer">Marine Science/Merchant Marine Officer</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Visual and Performing Arts</a>
# <ul class="menu">
# <li class="expanded top"><a>Arts, Entertainment,and Media Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Arts-Entertainment-and-Media-Management-General">Arts, Entertainment,and Media Management</a></li>
# <li class="leaf"><a href="../college-majors/Fine-and-Studio-Arts-Management">Fine and Studio Arts Management</a></li>
# <li class="leaf"><a href="../college-majors/Music-Management">Music Management</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Theatre-Arts-Management">Theatre/Theatre Arts Management</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Crafts/Craft Design, Folk Art and Artisanry</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Crafts-Craft-Design-Folk-Art-and-Artisanry">Crafts/Craft Design, Folk Art and Artisanry</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Dance</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Ballet">Ballet</a></li>
# <li class="leaf"><a href="../college-majors/Dance-General">Dance</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Design and Applied Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-and-Advertising-Art">Commercial and Advertising Art</a></li>
# <li class="leaf"><a href="../college-majors/Commercial-Photography">Commercial Photography</a></li>
# <li class="leaf"><a href="../college-majors/Design-and-Visual-Communications-General">Design and Visual Communications</a></li>
# <li class="leaf"><a href="../college-majors/Fashion-Apparel-Design">Fashion/Apparel Design</a></li>
# <li class="leaf"><a href="../college-majors/Game-and-Interactive-Media-Design">Game and Interactive Media Design</a></li>
# <li class="leaf"><a href="../college-majors/Graphic-Design">Graphic Design</a></li>
# <li class="leaf"><a href="../college-majors/Illustration">Illustration</a></li>
# <li class="leaf"><a href="../college-majors/Industrial-and-Product-Design">Industrial and Product Design</a></li>
# <li class="leaf"><a href="../college-majors/Interior-Design">Interior Design</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Drama/Theatre Arts and Stagecraft</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Acting">Acting</a></li>
# <li class="leaf"><a href="../college-majors/Costume-Design">Costume Design</a></li>
# <li class="leaf"><a href="../college-majors/Directing-and-Theatrical-Production">Directing and Theatrical Production</a></li>
# <li class="leaf"><a href="../college-majors/Drama-and-Dramatics-Theatre-Arts-General">Drama and Dramatics/Theatre Arts</a></li>
# <li class="leaf"><a href="../college-majors/Musical-Theatre">Musical Theatre</a></li>
# <li class="leaf"><a href="../college-majors/Playwriting-and-Screenwriting">Playwriting and Screenwriting</a></li>
# <li class="leaf"><a href="../college-majors/Technical-Theatre-Theatre-Design-and-Technology">Technical Theatre/Theatre Design and Technology</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Literature-History-and-Criticism">Theatre Literature, History and Criticism</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Film/Video and Photographic Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Cinematography-and-Film-Video-Production">Cinematography and Film/Video Production</a></li>
# <li class="leaf"><a href="../college-majors/Documentary-Production">Documentary Production</a></li>
# <li class="leaf"><a href="../college-majors/Film-Cinema-Video-Studies">Film/Cinema/Video Studies</a></li>
# <li class="leaf"><a href="../college-majors/Photography">Photography</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Fine and Studio Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Art-History-Criticism-and-Conservation">Art History, Criticism and Conservation</a></li>
# <li class="leaf"><a href="../college-majors/Art-Art-Studies-General">Art/Art Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ceramic-Arts-and-Ceramics">Ceramic Arts and Ceramics</a></li>
# <li class="leaf"><a href="../college-majors/Drawing">Drawing</a></li>
# <li class="leaf"><a href="../college-majors/Fiber-Textile-and-Weaving-Arts">Fiber, Textile and Weaving Arts</a></li>
# <li class="leaf"><a href="../college-majors/Fine-Studio-Arts-General">Fine/Studio Arts</a></li>
# <li class="leaf"><a href="../college-majors/Intermedia-Multimedia">Intermedia/Multimedia</a></li>
# <li class="leaf"><a href="../college-majors/Metal-and-Jewelry-Arts">Metal and Jewelry Arts</a></li>
# <li class="leaf"><a href="../college-majors/Painting">Painting</a></li>
# <li class="leaf"><a href="../college-majors/Printmaking">Printmaking</a></li>
# <li class="leaf"><a href="../college-majors/Sculpture">Sculpture</a></li>
# </ul>
# </li>
# <li class="expanded top"><a>Music</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Brass-Instruments">Brass Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Conducting">Conducting</a></li>
# <li class="leaf"><a href="../college-majors/Jazz-Jazz-Studies">Jazz/Jazz Studies</a></li>
# <li class="leaf"><a href="../college-majors/Keyboard-Instruments">Keyboard Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Music-General">Music</a></li>
# <li class="leaf"><a href="../college-majors/Music-History-Literature-and-Theory">Music History, Literature, and Theory</a></li>
# <li class="leaf"><a href="../college-majors/Music-Pedagogy">Music Pedagogy</a></li>
# <li class="leaf"><a href="../college-majors/Music-Performance-General">Music Performance</a></li>
# <li class="leaf"><a href="../college-majors/Music-Technology">Music Technology</a></li>
# <li class="leaf"><a href="../college-majors/Music-Theory-and-Composition">Music Theory and Composition</a></li>
# <li class="leaf"><a href="../college-majors/Musicology-and-Ethnomusicology">Musicology and Ethnomusicology</a></li>
# <li class="leaf"><a href="../college-majors/Percussion-Instruments">Percussion Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Stringed-Instruments">Stringed Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Voice-and-Opera">Voice and Opera</a></li>
# <li class="leaf"><a href="../college-majors/Woodwind-Instruments">Woodwind Instruments</a> </li>
# </ul>
# </li>
# <li class="expanded top"><a>Visual and Performing Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Digital-Arts">Digital Arts</a></li>
# <li class="leaf"><a href="../college-majors/Visual-and-Performing-Arts-General">Visual and Performing Arts</a></li>
# </ul>
# </li>
# </ul>
# </li>, <li class="expanded top"><a>Arts, Entertainment,and Media Management</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Arts-Entertainment-and-Media-Management-General">Arts, Entertainment,and Media Management</a></li>
# <li class="leaf"><a href="../college-majors/Fine-and-Studio-Arts-Management">Fine and Studio Arts Management</a></li>
# <li class="leaf"><a href="../college-majors/Music-Management">Music Management</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Theatre-Arts-Management">Theatre/Theatre Arts Management</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Crafts/Craft Design, Folk Art and Artisanry</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Crafts-Craft-Design-Folk-Art-and-Artisanry">Crafts/Craft Design, Folk Art and Artisanry</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Dance</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Ballet">Ballet</a></li>
# <li class="leaf"><a href="../college-majors/Dance-General">Dance</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Design and Applied Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Commercial-and-Advertising-Art">Commercial and Advertising Art</a></li>
# <li class="leaf"><a href="../college-majors/Commercial-Photography">Commercial Photography</a></li>
# <li class="leaf"><a href="../college-majors/Design-and-Visual-Communications-General">Design and Visual Communications</a></li>
# <li class="leaf"><a href="../college-majors/Fashion-Apparel-Design">Fashion/Apparel Design</a></li>
# <li class="leaf"><a href="../college-majors/Game-and-Interactive-Media-Design">Game and Interactive Media Design</a></li>
# <li class="leaf"><a href="../college-majors/Graphic-Design">Graphic Design</a></li>
# <li class="leaf"><a href="../college-majors/Illustration">Illustration</a></li>
# <li class="leaf"><a href="../college-majors/Industrial-and-Product-Design">Industrial and Product Design</a></li>
# <li class="leaf"><a href="../college-majors/Interior-Design">Interior Design</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Drama/Theatre Arts and Stagecraft</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Acting">Acting</a></li>
# <li class="leaf"><a href="../college-majors/Costume-Design">Costume Design</a></li>
# <li class="leaf"><a href="../college-majors/Directing-and-Theatrical-Production">Directing and Theatrical Production</a></li>
# <li class="leaf"><a href="../college-majors/Drama-and-Dramatics-Theatre-Arts-General">Drama and Dramatics/Theatre Arts</a></li>
# <li class="leaf"><a href="../college-majors/Musical-Theatre">Musical Theatre</a></li>
# <li class="leaf"><a href="../college-majors/Playwriting-and-Screenwriting">Playwriting and Screenwriting</a></li>
# <li class="leaf"><a href="../college-majors/Technical-Theatre-Theatre-Design-and-Technology">Technical Theatre/Theatre Design and Technology</a></li>
# <li class="leaf"><a href="../college-majors/Theatre-Literature-History-and-Criticism">Theatre Literature, History and Criticism</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Film/Video and Photographic Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Cinematography-and-Film-Video-Production">Cinematography and Film/Video Production</a></li>
# <li class="leaf"><a href="../college-majors/Documentary-Production">Documentary Production</a></li>
# <li class="leaf"><a href="../college-majors/Film-Cinema-Video-Studies">Film/Cinema/Video Studies</a></li>
# <li class="leaf"><a href="../college-majors/Photography">Photography</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Fine and Studio Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Art-History-Criticism-and-Conservation">Art History, Criticism and Conservation</a></li>
# <li class="leaf"><a href="../college-majors/Art-Art-Studies-General">Art/Art Studies</a></li>
# <li class="leaf"><a href="../college-majors/Ceramic-Arts-and-Ceramics">Ceramic Arts and Ceramics</a></li>
# <li class="leaf"><a href="../college-majors/Drawing">Drawing</a></li>
# <li class="leaf"><a href="../college-majors/Fiber-Textile-and-Weaving-Arts">Fiber, Textile and Weaving Arts</a></li>
# <li class="leaf"><a href="../college-majors/Fine-Studio-Arts-General">Fine/Studio Arts</a></li>
# <li class="leaf"><a href="../college-majors/Intermedia-Multimedia">Intermedia/Multimedia</a></li>
# <li class="leaf"><a href="../college-majors/Metal-and-Jewelry-Arts">Metal and Jewelry Arts</a></li>
# <li class="leaf"><a href="../college-majors/Painting">Painting</a></li>
# <li class="leaf"><a href="../college-majors/Printmaking">Printmaking</a></li>
# <li class="leaf"><a href="../college-majors/Sculpture">Sculpture</a></li>
# </ul>
# </li>, <li class="expanded top"><a>Music</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Brass-Instruments">Brass Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Conducting">Conducting</a></li>
# <li class="leaf"><a href="../college-majors/Jazz-Jazz-Studies">Jazz/Jazz Studies</a></li>
# <li class="leaf"><a href="../college-majors/Keyboard-Instruments">Keyboard Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Music-General">Music</a></li>
# <li class="leaf"><a href="../college-majors/Music-History-Literature-and-Theory">Music History, Literature, and Theory</a></li>
# <li class="leaf"><a href="../college-majors/Music-Pedagogy">Music Pedagogy</a></li>
# <li class="leaf"><a href="../college-majors/Music-Performance-General">Music Performance</a></li>
# <li class="leaf"><a href="../college-majors/Music-Technology">Music Technology</a></li>
# <li class="leaf"><a href="../college-majors/Music-Theory-and-Composition">Music Theory and Composition</a></li>
# <li class="leaf"><a href="../college-majors/Musicology-and-Ethnomusicology">Musicology and Ethnomusicology</a></li>
# <li class="leaf"><a href="../college-majors/Percussion-Instruments">Percussion Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Stringed-Instruments">Stringed Instruments</a></li>
# <li class="leaf"><a href="../college-majors/Voice-and-Opera">Voice and Opera</a></li>
# <li class="leaf"><a href="../college-majors/Woodwind-Instruments">Woodwind Instruments</a> </li>
# </ul>
# </li>, <li class="expanded top"><a>Visual and Performing Arts</a>
# <ul class="menu">
# <li class="leaf"><a href="../college-majors/Digital-Arts">Digital Arts</a></li>
# <li class="leaf"><a href="../college-majors/Visual-and-Performing-Arts-General">Visual and Performing Arts</a></li>
# </ul>
# </li>]

# %%
major1 = {}
for element in letters1:
    major1[element.get_text()] = {}
    
major2 = {}
for element in letters2:
    major2[element.get_text()] = {}   
    
print (major1)
print (major2)
# Out:
# {'Clinical, Hospital, and Managed Care Pharmacy': {}, 'Financial Planning and Services': {}, 'Inorganic Chemistry': {}, 'Public Health': {}, 'Auctioneering': {}, 'Molecular Physiology': {}, 'Physics': {}, 'Fashion Merchandising': {}, 'Latin Teacher Education': {}, 'Metallurgical Technology/Technician': {}, 'Theology/Theological Studies': {}, 'Plant Molecular Biology': {}, 'Sustainable Design and Technology ( Unity College in Maine )': {}, 'Archives/Archival Administration': {}, 'Ayurvedic Medicine/Ayurveda': {}, 'Uralic Languages, Literatures, and Linguistics': {}, 'Structural Engineering': {}, 'Quality Control Technology/Technician': {}, 'Geography Teacher Education': {}, 'Conservation Biology': {}, 'Meeting and Event Planning': {}, 'Speech Teacher Education': {}, 'Somatic Bodywork': {}, 'Marketing Research': {}, 'Finance': {}, 'Radar Communications and Systems Technology': {}, 'Space Systems Operations': {}, 'Pathology/Experimental Pathology': {}, 'Marine Biology and Biological Oceanography': {}, 'General Studies': {}, 'Fire Science/Fire-fighting': {}, 'Youth Services/Administration': {}, 'Fiber, Textile and Weaving Arts': {}, 'Pipefitting/Pipefitter and Sprinkler Fitter': {}, 'Sustainability Studies': {}, 'Electrolysis/Electrology and Electrolysis Technician': {}, 'Mathematics Teacher Education': {}, 'Health Teacher Education': {}, 'Health Information/Medical Records Administration/Administrator': {}, 'Management Science': {}, 'Contemporary Christian Music ( Greenville College)': {}, 'Pathology/Pathologist Assistant': {}, 'Hospital and Health Care Facilities Administration/Management': {}, 'Mathematics': {}, 'International Economics': {}, 'Construction/Heavy Equipment/Earthmoving Equipment Operation': {}, 'Caribbean Studies': {}, 'Sheet Metal Technology/Sheetworking': {}, 'Food Technology and Processing': {}, 'American/United States Studies/Civilization': {}, 'Pre-Physical Therapy Studies': {}, 'Electrical and Power Transmission Installation/Installer': {}, 'Musical Theatre': {}, 'Spanish and Iberian Studies': {}, 'Tourism Promotion Operations': {}, 'Photobiology': {}, 'Environmental Design/Architecture': {}, 'Genetics': {}, 'Pre-Medicine/Pre-Medical Studies': {}, 'Metal Fabricator': {}, 'Sports Communication': {}, 'Civil Engineering Technology/Technician': {}, 'Religion/Religious Studies': {}, 'Religious/Sacred Music': {}, 'Applied Linguistics': {}, 'Medium/Heavy Vehicle and Truck Technology/Technician': {}, 'Ecology and Evolutionary Biology': {}, 'Gunsmithing/Gunsmith': {}, 'Molecular Genetics': {}, 'Korean Studies': {}, 'Canadian Law/Legal Studies/Jurisprudence': {}, 'Fire/Arson Investigation and Prevention': {}, 'Hospitality and Recreation Marketing Operations': {}, 'Juvenile Corrections': {}, 'Community Organization and Advocacy': {}, 'Mathematical Biology': {}, 'Woodworking': {}, 'Biomedical Sciences': {}, 'Ocean Engineering': {}, 'Computer Typography and Composition Equipment Operator': {}, 'Homeland Security': {}, 'Education': {}, 'Banking and Financial Support Services': {}, 'Game and Interactive Media Design': {}, 'Chiropractic': {}, 'Neurobiology and Behavior': {}, 'Fashion Modeling': {}, 'Arts, Entertainment,and Media Management': {}, 'Veterinary Physiology': {}, 'Nurse Anesthetist': {}, 'Watchmaking and Jewelrymaking': {}, 'Histologic Technology/Histotechnologist': {}, 'Carpentry/Carpenter': {}, 'Physical Fitness Technician': {}, 'International and Intercultural Communication': {}, 'East Asian Studies': {}, 'Zoology/Animal Biology': {}, 'Khmer/Cambodian Language and Literature': {}, 'Pharmacoeconomics/Pharmaceutical Economics': {}, 'Graphic Communications': {}, 'Mobil Crane Operation/Operator': {}, 'Telecommunications Technology/Technician': {}, 'Agricultural Mechanization': {}, 'Civil Engineering': {}, 'Renal/Dialysis Technologist/Technician': {}, 'Real Estate Development': {}, 'Veterinary Toxicology and Pharmacology': {}, 'Ceramic Arts and Ceramics': {}, 'Cultural/Archaelogical Resources Protection': {}, 'His ...
# {'Business Administration, Management and Operations\n\nBusiness Administration and Management\nCustomer Service Management\nE-Commerce/Electronic Commerce\nLogistics, Materials, and Supply Chain Management\nNon-Profit/Public/Organizational Management\nOffice Management and Supervision\nOperations Management and Supervision\nOrganizational Leadership\nProject Management\nPurchasing, Procurement/Acquisitions and Contracts Management\nResearch and Development Management\nRetail Management\nTransportation/Mobility Management\n\n': {}, 'Human Development, Family Studies, and Related Services\n\nAdult Development and Aging\nChild Care and Support Services Management\nChild Care Provider/Assistant\nChild Development\nDevelopmental Services Worker\nFamily and Community Services\nFamily Systems\nHuman Development and Family Studies\n\n': {}, 'Ground Transportation\n\nConstruction/Heavy Equipment/Earthmoving Equipment Operation\nFlagging and Traffic Control\nMobil Crane Operation/Operator\nRailroad and Railway Transportation\nTruck and Bus Driver/Commercial Vehicle Operator and Instructor\n\n': {}, 'Statistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n': {}, 'Intelligence, Command Control and Information Operations\n\nCommand & Control (C3, C4I) Systems and Operations\nCyber/Electronic Operations and Warfare\nInformation Operations/Joint Information Operations\nInformation/Psychological Warfare and Military Media Relations\nIntelligence\nSignal/Geospatial Intelligence\nStrategic Intelligence\n\n': {}, 'Urban Studies/Affairs\n\nUrban Studies/Affairs\n\n': {}, 'Alternative and Complementary Medicine and Medical Systems\n\nAcupuncture and Oriental Medicine\nAyurvedic Medicine/Ayurveda\nHolistic Health\nHomeopathic Medicine/Homeopathy\nNaturopathic Medicine/Naturopathy\nTraditional Chinese Medicine and Chinese Herbology\n\n': {}, 'Botany/Plant Biology\n\nBotany/Plant Biology\nPlant Molecular Biology\nPlant Pathology/Phytopathology\nPlant Physiology\n\n': {}, 'Drafting/Design Engineering Technologies/Technicians\n\nArchitectural Drafting and Architectural CAD/CADD\nCAD/CADD Drafting and/or Design Technology/Technician\nCivil Drafting and Civil Engineering CAD/CADD\nDrafting and Design Technology/Technician\nElectrical/Electronics Drafting and Electrical/Electronics CAD/CADD\nMechanical Drafting and Mechanical Drafting CAD/CADD\n\n': {}, 'Military Applied Sciences\n\nCombat Systems Engineering\nDirected Energy Systems\nEngineering Acoustics\nLow-Observables and Stealth Technology\nOperational Oceanography\nSpace Systems Operations\nUndersea Warfare\n\n': {}, 'Natural Resources Conservation and Research\n\nEnvironmental Science\nEnvironmental Studies\nNatural Resources/Conservation\n\n': {}, 'Ophthalmic and Optometric Support Services and Allied Professions\n\nOphthalmic Technician/Technologist\nOpticianry/Ophthalmic Dispensing Optician\nOptometric Technician/Assistant\nOrthoptics/Orthoptist\n\n': {}, 'Social and Philosophical Foundations of Education\n\nSocial and Philosophical Foundations of Education\n\n': {}, 'Visual and Performing Arts\n\nDigital Arts\nVisual and Performing Arts\n\n': {}, 'Law\n\nLaw\n\n': {}, 'Precision Metal Working\n\nComputer Numerically Controlled (CNC) Machinist Technology/CNC Machinist\nIronworking/Ironworker\nMachine Shop Technology/Assistant\nMachine Tool Technology/Machinist\nMetal Fabricator\nSheet Metal Technology/Sheetworking\nTool and Die Technology/Technician\nWelding Technology/Welder\n\n': {}, 'Mathematics and Statistics\n\nApplied Mathematics\n\nApplied Mathematics\nComputational and Applied Mathematics\nComputational Mathematics\nFinancial Mathematics\nMathematical Biology\n\n\nMathematics\n\nAlgebra and Number Theory\nAnalysis and Functional Analysis\nGeometry/Geometric Analysis\nMathematics\nTopology and Foundations\n\n\nStatistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n\n\n': {}, 'Rhetoric and Composition/Writ ...

# %%
type(major1)
type(major2)
# Out:
# dict

# %%
major1.keys()
major2.keys()
# Out:
# dict_keys(['Business Administration, Management and Operations\n\nBusiness Administration and Management\nCustomer Service Management\nE-Commerce/Electronic Commerce\nLogistics, Materials, and Supply Chain Management\nNon-Profit/Public/Organizational Management\nOffice Management and Supervision\nOperations Management and Supervision\nOrganizational Leadership\nProject Management\nPurchasing, Procurement/Acquisitions and Contracts Management\nResearch and Development Management\nRetail Management\nTransportation/Mobility Management\n\n', 'Human Development, Family Studies, and Related Services\n\nAdult Development and Aging\nChild Care and Support Services Management\nChild Care Provider/Assistant\nChild Development\nDevelopmental Services Worker\nFamily and Community Services\nFamily Systems\nHuman Development and Family Studies\n\n', 'Ground Transportation\n\nConstruction/Heavy Equipment/Earthmoving Equipment Operation\nFlagging and Traffic Control\nMobil Crane Operation/Operator\nRailroad and Railway Transportation\nTruck and Bus Driver/Commercial Vehicle Operator and Instructor\n\n', 'Statistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n', 'Intelligence, Command Control and Information Operations\n\nCommand & Control (C3, C4I) Systems and Operations\nCyber/Electronic Operations and Warfare\nInformation Operations/Joint Information Operations\nInformation/Psychological Warfare and Military Media Relations\nIntelligence\nSignal/Geospatial Intelligence\nStrategic Intelligence\n\n', 'Urban Studies/Affairs\n\nUrban Studies/Affairs\n\n', 'Alternative and Complementary Medicine and Medical Systems\n\nAcupuncture and Oriental Medicine\nAyurvedic Medicine/Ayurveda\nHolistic Health\nHomeopathic Medicine/Homeopathy\nNaturopathic Medicine/Naturopathy\nTraditional Chinese Medicine and Chinese Herbology\n\n', 'Botany/Plant Biology\n\nBotany/Plant Biology\nPlant Molecular Biology\nPlant Pathology/Phytopathology\nPlant Physiology\n\n', 'Drafting/Design Engineering Technologies/Technicians\n\nArchitectural Drafting and Architectural CAD/CADD\nCAD/CADD Drafting and/or Design Technology/Technician\nCivil Drafting and Civil Engineering CAD/CADD\nDrafting and Design Technology/Technician\nElectrical/Electronics Drafting and Electrical/Electronics CAD/CADD\nMechanical Drafting and Mechanical Drafting CAD/CADD\n\n', 'Military Applied Sciences\n\nCombat Systems Engineering\nDirected Energy Systems\nEngineering Acoustics\nLow-Observables and Stealth Technology\nOperational Oceanography\nSpace Systems Operations\nUndersea Warfare\n\n', 'Natural Resources Conservation and Research\n\nEnvironmental Science\nEnvironmental Studies\nNatural Resources/Conservation\n\n', 'Ophthalmic and Optometric Support Services and Allied Professions\n\nOphthalmic Technician/Technologist\nOpticianry/Ophthalmic Dispensing Optician\nOptometric Technician/Assistant\nOrthoptics/Orthoptist\n\n', 'Social and Philosophical Foundations of Education\n\nSocial and Philosophical Foundations of Education\n\n', 'Visual and Performing Arts\n\nDigital Arts\nVisual and Performing Arts\n\n', 'Law\n\nLaw\n\n', 'Precision Metal Working\n\nComputer Numerically Controlled (CNC) Machinist Technology/CNC Machinist\nIronworking/Ironworker\nMachine Shop Technology/Assistant\nMachine Tool Technology/Machinist\nMetal Fabricator\nSheet Metal Technology/Sheetworking\nTool and Die Technology/Technician\nWelding Technology/Welder\n\n', 'Mathematics and Statistics\n\nApplied Mathematics\n\nApplied Mathematics\nComputational and Applied Mathematics\nComputational Mathematics\nFinancial Mathematics\nMathematical Biology\n\n\nMathematics\n\nAlgebra and Number Theory\nAnalysis and Functional Analysis\nGeometry/Geometric Analysis\nMathematics\nTopology and Foundations\n\n\nStatistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n\n\n', 'Rhetoric and Composition/Writing Studies\n\nCreative Writing\nProfessional, Technical,  ...

# %%
list_keys1 = [ k for k in major1.keys() ]
list_keys2 = [ k for k in major2.keys() ]

print(list_keys1)
print(list_keys2)
# Out:
# ['Clinical, Hospital, and Managed Care Pharmacy', 'Financial Planning and Services', 'Inorganic Chemistry', 'Public Health', 'Auctioneering', 'Molecular Physiology', 'Physics', 'Fashion Merchandising', 'Latin Teacher Education', 'Metallurgical Technology/Technician', 'Theology/Theological Studies', 'Plant Molecular Biology', 'Sustainable Design and Technology ( Unity College in Maine )', 'Archives/Archival Administration', 'Ayurvedic Medicine/Ayurveda', 'Uralic Languages, Literatures, and Linguistics', 'Structural Engineering', 'Quality Control Technology/Technician', 'Geography Teacher Education', 'Conservation Biology', 'Meeting and Event Planning', 'Speech Teacher Education', 'Somatic Bodywork', 'Marketing Research', 'Finance', 'Radar Communications and Systems Technology', 'Space Systems Operations', 'Pathology/Experimental Pathology', 'Marine Biology and Biological Oceanography', 'General Studies', 'Fire Science/Fire-fighting', 'Youth Services/Administration', 'Fiber, Textile and Weaving Arts', 'Pipefitting/Pipefitter and Sprinkler Fitter', 'Sustainability Studies', 'Electrolysis/Electrology and Electrolysis Technician', 'Mathematics Teacher Education', 'Health Teacher Education', 'Health Information/Medical Records Administration/Administrator', 'Management Science', 'Contemporary Christian Music ( Greenville College)', 'Pathology/Pathologist Assistant', 'Hospital and Health Care Facilities Administration/Management', 'Mathematics', 'International Economics', 'Construction/Heavy Equipment/Earthmoving Equipment Operation', 'Caribbean Studies', 'Sheet Metal Technology/Sheetworking', 'Food Technology and Processing', 'American/United States Studies/Civilization', 'Pre-Physical Therapy Studies', 'Electrical and Power Transmission Installation/Installer', 'Musical Theatre', 'Spanish and Iberian Studies', 'Tourism Promotion Operations', 'Photobiology', 'Environmental Design/Architecture', 'Genetics', 'Pre-Medicine/Pre-Medical Studies', 'Metal Fabricator', 'Sports Communication', 'Civil Engineering Technology/Technician', 'Religion/Religious Studies', 'Religious/Sacred Music', 'Applied Linguistics', 'Medium/Heavy Vehicle and Truck Technology/Technician', 'Ecology and Evolutionary Biology', 'Gunsmithing/Gunsmith', 'Molecular Genetics', 'Korean Studies', 'Canadian Law/Legal Studies/Jurisprudence', 'Fire/Arson Investigation and Prevention', 'Hospitality and Recreation Marketing Operations', 'Juvenile Corrections', 'Community Organization and Advocacy', 'Mathematical Biology', 'Woodworking', 'Biomedical Sciences', 'Ocean Engineering', 'Computer Typography and Composition Equipment Operator', 'Homeland Security', 'Education', 'Banking and Financial Support Services', 'Game and Interactive Media Design', 'Chiropractic', 'Neurobiology and Behavior', 'Fashion Modeling', 'Arts, Entertainment,and Media Management', 'Veterinary Physiology', 'Nurse Anesthetist', 'Watchmaking and Jewelrymaking', 'Histologic Technology/Histotechnologist', 'Carpentry/Carpenter', 'Physical Fitness Technician', 'International and Intercultural Communication', 'East Asian Studies', 'Zoology/Animal Biology', 'Khmer/Cambodian Language and Literature', 'Pharmacoeconomics/Pharmaceutical Economics', 'Graphic Communications', 'Mobil Crane Operation/Operator', 'Telecommunications Technology/Technician', 'Agricultural Mechanization', 'Civil Engineering', 'Renal/Dialysis Technologist/Technician', 'Real Estate Development', 'Veterinary Toxicology and Pharmacology', 'Ceramic Arts and Ceramics', 'Cultural/Archaelogical Resources Protection', 'Historic Preservation and Conservation', 'Pre-Veterinary Studies', 'Electrical, Electronic and Communications Engineering Technology/Technician', 'Substance Abuse/Addiction Counseling', 'Advanced Legal Research/Studies', 'Phlebotomy Technician/Phlebotomist', 'Balkans Studies', 'Chemical Engineering', 'Latin American Studies', 'Czech Language and Literature', 'Urban Forestry', 'Library and Archives Assisting', 'Forensic Chemistry', 'Rom ...
# ['Business Administration, Management and Operations\n\nBusiness Administration and Management\nCustomer Service Management\nE-Commerce/Electronic Commerce\nLogistics, Materials, and Supply Chain Management\nNon-Profit/Public/Organizational Management\nOffice Management and Supervision\nOperations Management and Supervision\nOrganizational Leadership\nProject Management\nPurchasing, Procurement/Acquisitions and Contracts Management\nResearch and Development Management\nRetail Management\nTransportation/Mobility Management\n\n', 'Human Development, Family Studies, and Related Services\n\nAdult Development and Aging\nChild Care and Support Services Management\nChild Care Provider/Assistant\nChild Development\nDevelopmental Services Worker\nFamily and Community Services\nFamily Systems\nHuman Development and Family Studies\n\n', 'Ground Transportation\n\nConstruction/Heavy Equipment/Earthmoving Equipment Operation\nFlagging and Traffic Control\nMobil Crane Operation/Operator\nRailroad and Railway Transportation\nTruck and Bus Driver/Commercial Vehicle Operator and Instructor\n\n', 'Statistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n', 'Intelligence, Command Control and Information Operations\n\nCommand & Control (C3, C4I) Systems and Operations\nCyber/Electronic Operations and Warfare\nInformation Operations/Joint Information Operations\nInformation/Psychological Warfare and Military Media Relations\nIntelligence\nSignal/Geospatial Intelligence\nStrategic Intelligence\n\n', 'Urban Studies/Affairs\n\nUrban Studies/Affairs\n\n', 'Alternative and Complementary Medicine and Medical Systems\n\nAcupuncture and Oriental Medicine\nAyurvedic Medicine/Ayurveda\nHolistic Health\nHomeopathic Medicine/Homeopathy\nNaturopathic Medicine/Naturopathy\nTraditional Chinese Medicine and Chinese Herbology\n\n', 'Botany/Plant Biology\n\nBotany/Plant Biology\nPlant Molecular Biology\nPlant Pathology/Phytopathology\nPlant Physiology\n\n', 'Drafting/Design Engineering Technologies/Technicians\n\nArchitectural Drafting and Architectural CAD/CADD\nCAD/CADD Drafting and/or Design Technology/Technician\nCivil Drafting and Civil Engineering CAD/CADD\nDrafting and Design Technology/Technician\nElectrical/Electronics Drafting and Electrical/Electronics CAD/CADD\nMechanical Drafting and Mechanical Drafting CAD/CADD\n\n', 'Military Applied Sciences\n\nCombat Systems Engineering\nDirected Energy Systems\nEngineering Acoustics\nLow-Observables and Stealth Technology\nOperational Oceanography\nSpace Systems Operations\nUndersea Warfare\n\n', 'Natural Resources Conservation and Research\n\nEnvironmental Science\nEnvironmental Studies\nNatural Resources/Conservation\n\n', 'Ophthalmic and Optometric Support Services and Allied Professions\n\nOphthalmic Technician/Technologist\nOpticianry/Ophthalmic Dispensing Optician\nOptometric Technician/Assistant\nOrthoptics/Orthoptist\n\n', 'Social and Philosophical Foundations of Education\n\nSocial and Philosophical Foundations of Education\n\n', 'Visual and Performing Arts\n\nDigital Arts\nVisual and Performing Arts\n\n', 'Law\n\nLaw\n\n', 'Precision Metal Working\n\nComputer Numerically Controlled (CNC) Machinist Technology/CNC Machinist\nIronworking/Ironworker\nMachine Shop Technology/Assistant\nMachine Tool Technology/Machinist\nMetal Fabricator\nSheet Metal Technology/Sheetworking\nTool and Die Technology/Technician\nWelding Technology/Welder\n\n', 'Mathematics and Statistics\n\nApplied Mathematics\n\nApplied Mathematics\nComputational and Applied Mathematics\nComputational Mathematics\nFinancial Mathematics\nMathematical Biology\n\n\nMathematics\n\nAlgebra and Number Theory\nAnalysis and Functional Analysis\nGeometry/Geometric Analysis\nMathematics\nTopology and Foundations\n\n\nStatistics\n\nMathematical Statistics and Probability\nMathematics and Statistics\nStatistics\n\n\n\n', 'Rhetoric and Composition/Writing Studies\n\nCreative Writing\nProfessional, Technical, Business,  ...

# %%
list_combine = list_keys1 + list_keys2

print (list_combine)
# Out:
# ['Clinical, Hospital, and Managed Care Pharmacy', 'Financial Planning and Services', 'Inorganic Chemistry', 'Public Health', 'Auctioneering', 'Molecular Physiology', 'Physics', 'Fashion Merchandising', 'Latin Teacher Education', 'Metallurgical Technology/Technician', 'Theology/Theological Studies', 'Plant Molecular Biology', 'Sustainable Design and Technology ( Unity College in Maine )', 'Archives/Archival Administration', 'Ayurvedic Medicine/Ayurveda', 'Uralic Languages, Literatures, and Linguistics', 'Structural Engineering', 'Quality Control Technology/Technician', 'Geography Teacher Education', 'Conservation Biology', 'Meeting and Event Planning', 'Speech Teacher Education', 'Somatic Bodywork', 'Marketing Research', 'Finance', 'Radar Communications and Systems Technology', 'Space Systems Operations', 'Pathology/Experimental Pathology', 'Marine Biology and Biological Oceanography', 'General Studies', 'Fire Science/Fire-fighting', 'Youth Services/Administration', 'Fiber, Textile and Weaving Arts', 'Pipefitting/Pipefitter and Sprinkler Fitter', 'Sustainability Studies', 'Electrolysis/Electrology and Electrolysis Technician', 'Mathematics Teacher Education', 'Health Teacher Education', 'Health Information/Medical Records Administration/Administrator', 'Management Science', 'Contemporary Christian Music ( Greenville College)', 'Pathology/Pathologist Assistant', 'Hospital and Health Care Facilities Administration/Management', 'Mathematics', 'International Economics', 'Construction/Heavy Equipment/Earthmoving Equipment Operation', 'Caribbean Studies', 'Sheet Metal Technology/Sheetworking', 'Food Technology and Processing', 'American/United States Studies/Civilization', 'Pre-Physical Therapy Studies', 'Electrical and Power Transmission Installation/Installer', 'Musical Theatre', 'Spanish and Iberian Studies', 'Tourism Promotion Operations', 'Photobiology', 'Environmental Design/Architecture', 'Genetics', 'Pre-Medicine/Pre-Medical Studies', 'Metal Fabricator', 'Sports Communication', 'Civil Engineering Technology/Technician', 'Religion/Religious Studies', 'Religious/Sacred Music', 'Applied Linguistics', 'Medium/Heavy Vehicle and Truck Technology/Technician', 'Ecology and Evolutionary Biology', 'Gunsmithing/Gunsmith', 'Molecular Genetics', 'Korean Studies', 'Canadian Law/Legal Studies/Jurisprudence', 'Fire/Arson Investigation and Prevention', 'Hospitality and Recreation Marketing Operations', 'Juvenile Corrections', 'Community Organization and Advocacy', 'Mathematical Biology', 'Woodworking', 'Biomedical Sciences', 'Ocean Engineering', 'Computer Typography and Composition Equipment Operator', 'Homeland Security', 'Education', 'Banking and Financial Support Services', 'Game and Interactive Media Design', 'Chiropractic', 'Neurobiology and Behavior', 'Fashion Modeling', 'Arts, Entertainment,and Media Management', 'Veterinary Physiology', 'Nurse Anesthetist', 'Watchmaking and Jewelrymaking', 'Histologic Technology/Histotechnologist', 'Carpentry/Carpenter', 'Physical Fitness Technician', 'International and Intercultural Communication', 'East Asian Studies', 'Zoology/Animal Biology', 'Khmer/Cambodian Language and Literature', 'Pharmacoeconomics/Pharmaceutical Economics', 'Graphic Communications', 'Mobil Crane Operation/Operator', 'Telecommunications Technology/Technician', 'Agricultural Mechanization', 'Civil Engineering', 'Renal/Dialysis Technologist/Technician', 'Real Estate Development', 'Veterinary Toxicology and Pharmacology', 'Ceramic Arts and Ceramics', 'Cultural/Archaelogical Resources Protection', 'Historic Preservation and Conservation', 'Pre-Veterinary Studies', 'Electrical, Electronic and Communications Engineering Technology/Technician', 'Substance Abuse/Addiction Counseling', 'Advanced Legal Research/Studies', 'Phlebotomy Technician/Phlebotomist', 'Balkans Studies', 'Chemical Engineering', 'Latin American Studies', 'Czech Language and Literature', 'Urban Forestry', 'Library and Archives Assisting', 'Forensic Chemistry', 'Rom ...

# %%
df = pd.DataFrame(list_combine)
#print (df)

# %%
writer = pd.ExcelWriter('majors.xlsx')
df.to_excel(writer, index = False)
writer.save()

# %%
#updated excel with split "/"
new_list=[[]]

for i, element in enumerate(list_combine):
   #print (type(element))
   list_combine[i] = element.split('/')
      
for i, element in enumerate(list_combine):
   if (len(list_combine[i])== 2):
       #Given list of 2 strings
       #Get first string in list
       first_str = list_combine[i][0]
       #Get second string in list
       second_str =list_combine[i][1]
       #Cut last word of first string
       updated_str = first_str.rsplit(' ', 1)[0]
       #Combine updated_str with second string
       appended_str = updated_str + ' ' + second_str
       #Add current element from list_combine to new_list
       new_list.append(list_combine[i])
       #Make appended_str a list
       temp_list = [appended_str]
       #Add [appended_str] to new_list
       new_list.append(temp_list)
   else:
       #If the current element is not a list of two strings, just add it to the new_list.
       #No need to add new element we get above.
       new_list.append(list_combine[i])
#print(new_list)


#Flatten new_list
flattened = [val for sublist in new_list for val in sublist]
print(flattened)
# Out:
# ['Clinical, Hospital, and Managed Care Pharmacy', 'Financial Planning and Services', 'Inorganic Chemistry', 'Public Health', 'Auctioneering', 'Molecular Physiology', 'Physics', 'Fashion Merchandising', 'Latin Teacher Education', 'Metallurgical Technology', 'Technician', 'Metallurgical Technician', 'Theology', 'Theological Studies', 'Theology Theological Studies', 'Plant Molecular Biology', 'Sustainable Design and Technology ( Unity College in Maine )', 'Archives', 'Archival Administration', 'Archives Archival Administration', 'Ayurvedic Medicine', 'Ayurveda', 'Ayurvedic Ayurveda', 'Uralic Languages, Literatures, and Linguistics', 'Structural Engineering', 'Quality Control Technology', 'Technician', 'Quality Control Technician', 'Geography Teacher Education', 'Conservation Biology', 'Meeting and Event Planning', 'Speech Teacher Education', 'Somatic Bodywork', 'Marketing Research', 'Finance', 'Radar Communications and Systems Technology', 'Space Systems Operations', 'Pathology', 'Experimental Pathology', 'Pathology Experimental Pathology', 'Marine Biology and Biological Oceanography', 'General Studies', 'Fire Science', 'Fire-fighting', 'Fire Fire-fighting', 'Youth Services', 'Administration', 'Youth Administration', 'Fiber, Textile and Weaving Arts', 'Pipefitting', 'Pipefitter and Sprinkler Fitter', 'Pipefitting Pipefitter and Sprinkler Fitter', 'Sustainability Studies', 'Electrolysis', 'Electrology and Electrolysis Technician', 'Electrolysis Electrology and Electrolysis Technician', 'Mathematics Teacher Education', 'Health Teacher Education', 'Health Information', 'Medical Records Administration', 'Administrator', 'Management Science', 'Contemporary Christian Music ( Greenville College)', 'Pathology', 'Pathologist Assistant', 'Pathology Pathologist Assistant', 'Hospital and Health Care Facilities Administration', 'Management', 'Hospital and Health Care Facilities Management', 'Mathematics', 'International Economics', 'Construction', 'Heavy Equipment', 'Earthmoving Equipment Operation', 'Caribbean Studies', 'Sheet Metal Technology', 'Sheetworking', 'Sheet Metal Sheetworking', 'Food Technology and Processing', 'American', 'United States Studies', 'Civilization', 'Pre-Physical Therapy Studies', 'Electrical and Power Transmission Installation', 'Installer', 'Electrical and Power Transmission Installer', 'Musical Theatre', 'Spanish and Iberian Studies', 'Tourism Promotion Operations', 'Photobiology', 'Environmental Design', 'Architecture', 'Environmental Architecture', 'Genetics', 'Pre-Medicine', 'Pre-Medical Studies', 'Pre-Medicine Pre-Medical Studies', 'Metal Fabricator', 'Sports Communication', 'Civil Engineering Technology', 'Technician', 'Civil Engineering Technician', 'Religion', 'Religious Studies', 'Religion Religious Studies', 'Religious', 'Sacred Music', 'Religious Sacred Music', 'Applied Linguistics', 'Medium', 'Heavy Vehicle and Truck Technology', 'Technician', 'Ecology and Evolutionary Biology', 'Gunsmithing', 'Gunsmith', 'Gunsmithing Gunsmith', 'Molecular Genetics', 'Korean Studies', 'Canadian Law', 'Legal Studies', 'Jurisprudence', 'Fire', 'Arson Investigation and Prevention', 'Fire Arson Investigation and Prevention', 'Hospitality and Recreation Marketing Operations', 'Juvenile Corrections', 'Community Organization and Advocacy', 'Mathematical Biology', 'Woodworking', 'Biomedical Sciences', 'Ocean Engineering', 'Computer Typography and Composition Equipment Operator', 'Homeland Security', 'Education', 'Banking and Financial Support Services', 'Game and Interactive Media Design', 'Chiropractic', 'Neurobiology and Behavior', 'Fashion Modeling', 'Arts, Entertainment,and Media Management', 'Veterinary Physiology', 'Nurse Anesthetist', 'Watchmaking and Jewelrymaking', 'Histologic Technology', 'Histotechnologist', 'Histologic Histotechnologist', 'Carpentry', 'Carpenter', 'Carpentry Carpenter', 'Physical Fitness Technician', 'International and Intercultural Communication', 'East Asian Studies', 'Zoology', 'Animal Biology',  ...

# %%
flattened = flattened + ['information systems'] + ['information system'] + ['ELECTRONIC TECHNOLOGY']

df2 = pd.DataFrame(flattened)
writer = pd.ExcelWriter('majors2.xlsx')
df2.to_excel(writer, index = False)
writer.save()

# %% [markdown]
# # Majors

# %%
import pandas

df = pandas.read_excel('majors4.xlsx')

df.columns
major_file = df['Majors'].values
#major_file = flattened
major_lower = [item.lower() for item in major_file]
print (major_lower)

#resume_path = r"/Users/yiyangzhou/Desktop/Zeng_Leah_Resume.txt"
resume_path = os.path.join('testing','example.txt')
#resume_path = r"/Users/yiyangzhou/Desktop/Wang_YilinResume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Ryan Holder Resume.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/Shashidhar Karnati.txt"
#resume_path = r"/Users/yiyangzhou/Desktop/all_text1.txt"
resume_file = open(resume_path).read()
resume_file = resume_file.lower()
# Out:
# ['captive wildlife care and education( unity college in maine ) ', 'contemporary christian music ( greenville college)', 'individually structured major  ( university of colorado denver)', 'recording industry ( greenville college)', 'sustainable design and technology ( unity college in maine )', 'animal training', 'dog', 'pet', 'animal grooming', 'equestrian', 'equine studies', 'equestrian equine studies', 'taxidermy', 'taxidermist', 'taxidermy taxidermist', 'agricultural and food products processing', 'agribusiness', 'agricultural business operations', 'agribusiness agricultural business operations', 'agricultural business and management', 'agricultural business technology', 'agricultural economics', 'agricultural', 'farm supplies retailing and wholesaling', 'agricultural farm supplies retailing and wholesaling', 'farm', 'farm and ranch management', 'farm farm and ranch management', 'agricultural mechanics and equipment', 'machine technology', 'agricultural mechanics and machine technology', 'agricultural mechanization', 'agricultural power machinery operation', 'agricultural production operations', 'agroecology and sustainable agriculture', 'animal', 'livestock husbandry and production', 'animal livestock husbandry and production', 'aquaculture', 'crop production', 'dairy husbandry and production', 'horse husbandry', 'equine science and management', 'horse equine science and management', 'viticulture and enology', 'agricultural and extension education services', 'agricultural communication', 'journalism', 'agricultural journalism', 'agricultural animal breeding', 'animal health', 'animal nutrition', 'animal sciences', 'dairy science', 'livestock management', 'poultry science', 'applied horticulture', 'horticulture operations', 'applied horticulture operations', 'floriculture', 'floristry operations and management', 'floriculture floristry operations and management', 'greenhouse operations and management', 'landscaping and groundskeeping', 'ornamental horticulture', 'plant nursery operations and management', 'turf and turfgrass management', 'food science', 'food technology and processing', 'international agriculture', 'agricultural and horticultural plant breeding', 'agronomy and crop science', 'horticultural science', 'plant protection and integrated pest management', 'plant sciences', 'range science and management', 'soil chemistry and physics', 'soil microbiology', 'soil science and agronomy', 'architectural history and criticism', 'architectural and building sciences', 'technology', 'architectural and building technology', 'architectural technology', 'technician', 'architectural technician', 'architecture', 'city', 'urban, community and regional planning', 'city urban, community and regional planning', 'environmental design', 'architecture', 'environmental architecture', 'interior architecture', 'landscape architecture', 'real estate development', 'african studies', 'american', 'united states studies', 'civilization', 'asian studies', 'civilization', 'asian civilization', 'balkans studies', 'baltic studies', 'canadian studies', 'caribbean studies', 'chinese studies', 'commonwealth studies', 'east asian studies', 'european studies', 'civilization', 'european civilization', 'french studies', 'german studies', 'irish studies', 'italian studies', 'japanese studies', 'korean studies', 'latin american and caribbean studies', 'latin american studies', 'near and middle eastern studies', 'pacific area', 'pacific rim studies', 'pacific pacific rim studies', 'polish studies', 'regional studies (us, canadian, foreign)', 'russian studies', 'russian, central european, east european and eurasian studies', 'scandinavian studies', 'slavic studies', 'south asian studies', 'southeast asian studies', 'spanish and iberian studies', 'tibetan studies', 'ukraine studies', 'ural-altaic and central asian studies', 'western european studies', 'african-american', 'black studies', 'african-american black studies', 'american indian', 'native american s ...

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import WordPunctTokenizer
from nltk.collocations import BigramCollocationFinder
from nltk.metrics import BigramAssocMeasures
from nltk.tokenize import RegexpTokenizer
from nltk import ngrams

tokenizer = RegexpTokenizer(r'\w+')
resume_token = tokenizer.tokenize(resume_file) 

def get_bigrams(input):
    n = 2
    result = []
    bigrams = ngrams(input, n)
    for grams in bigrams:
        x = "%s %s" % grams
        result.append(x)
    return (result)    
    print (result)


test1 = get_bigrams(resume_token)
#print (test1)

def get_threegrams(input):
    n = 3
    result = []
    threegrams = ngrams(input, n)
    for grams in threegrams:
        x = "%s %s %s" % grams
        result.append(x)
    return (result)    
    print (result)

test2 = get_threegrams(resume_token)
#print (test2)

def extract_majors(a,b):
    majors=[]
    for x in a:
        if x in b:
            majors.append(x)
    return (majors)
    print (majors)
    

unigram_major = extract_majors(resume_token, major_lower)  
bigram_major = extract_majors(get_bigrams(resume_token), major_lower)
threegram_major = extract_majors(get_threegrams(resume_token), major_lower)


#print (unigram_major)
#print (bigram_major)
#print (threegram_major)


combined_majors_list = unigram_major + bigram_major + threegram_major

major_distinct = []
for i in combined_majors_list:
    if i not in major_distinct:
        major_distinct.append(i)
major_distinct.remove('international')
#print (combined_majors_list)
print (major_distinct)
# Out:
# ['farm', 'education', 'accounting', 'management', 'communications', 'information', 'web', 'business', 'service', 'cultural', 'art', 'writing', 'painting', 'history', 'information systems', 'international business', 'accounting and management']

# %%
dict = {'Name': 5}
for i, element in enumerate(major_distinct):
   x = resume_file.find(element)
   dict[element] = x
   

del dict['Name']
print(dict)
# Out:
# {'painting': 2473, 'international business': 2620, 'writing': 2446, 'web': 776, 'farm': 31, 'history': 2656, 'accounting and management': 194, 'accounting': 194, 'business': 1026, 'cultural': 1515, 'education': 104, 'information': 308, 'communications': 251, 'art': 2438, 'service': 1228, 'information systems': 308, 'management': 209}

# %%
import re
import string

regular_expression = re.compile(r"/BA|BS|Bachelor of Science|Bachelor of Arts|BBA |B/A|Bachelor of Business Administration/", re.IGNORECASE)
bach_major_result = re.search(regular_expression, resume_file)
if bach_major_result:
   bach_major_result = bach_major_result.group()
print (bach_major_result)

if bach_major_result is not None:
    bach_major_index = resume_file.find(bach_major_result)
    print(bach_major_index)
# Out:
# bachelor of science
# 173

# %%
import re
import string

regular_expression_two = re.compile(r"minor|Minor", re.IGNORECASE)
minor_result = re.search(regular_expression_two, resume_file)
if minor_result:
   minor_result = minor_result.group()
print (minor_result)

if minor_result is not None:
    minor_index = resume_file.find(minor_result)
    print(minor_index)
# Out:
# minor
# 244

# %%
import re
import string

regular_expression_three = re.compile(r"Master|master", re.IGNORECASE)
master_major_result = re.search(regular_expression_three, resume_file)
if master_major_result:
   master_major_result = master_major_result.group()
print (master_major_result)


if master_major_result is not None:
    master_major_index = resume_file.find(master_major_result)
    print(master_major_index)
# Out:
# master
# 267

# %%
import re
import string

regular_expression_four = re.compile(r"university", re.IGNORECASE)
university_major_result = re.search(regular_expression_four, resume_file)
if university_major_result:
   university_major_result = university_major_result.group()
print (university_major_result)

if university_major_result is not None:
    university_major_index = resume_file.find(university_major_result)
    print(university_major_index)
# Out:
# university
# 115

# %%
upper_bound = bach_major_index+50

updated_majors1 = []
indexes_majors1 = []
for k, v in dict.items():
   if (bach_major_index < v < upper_bound):
       updated_majors1.append(k)
       indexes_majors1.append(v)

print(updated_majors1)
print(indexes_majors1)
# Out:
# ['accounting and management', 'accounting', 'management']
# [194, 194, 209]

# %%
upper_bound = master_major_index+100

updated_majors2 = []
indexes_majors2 = []
for k, v in dict.items():
   if (master_major_index < v < upper_bound):
       updated_majors2.append(k)
       indexes_majors2.append(v)

print(updated_majors2)
print(indexes_majors2)
# Out:
# ['information', 'information systems']
# [308, 308]

# %%
upper_bound = university_major_index+100

updated_majors3 = []
indexes_majors3 = []
for k, v in dict.items():
   if (university_major_index < v < upper_bound):
       updated_majors3.append(k)
       indexes_majors3.append(v)

print(updated_majors3)
print(indexes_majors3)
# Out:
# ['accounting and management', 'accounting', 'management']
# [194, 194, 209]

# %%
upper_bound = minor_index+50

updated_majors4 = []
indexes_majors4 = []
for k, v in dict.items():
   if (minor_index < v < upper_bound):
       updated_majors4.append(k)
       indexes_majors4.append(v)

print(updated_majors4)
print(indexes_majors4)
# Out:
# ['communications']
# [251]

# %%
#getting distinct resume major
from fuzzywuzzy.process import dedupe

majors_minors_all = updated_majors1 + updated_majors2 + updated_majors3 + updated_majors4

majors_minors_final_list = dedupe(majors_minors_all)
print (majors_minors_final_list)
# Out:
# dict_keys(['information systems', 'accounting and management', 'communications'])

# %% [markdown]
# # Categorize Majors with Universities

# %%
universities_list = combined_university_extraction

# %%
#universities_list -> List of all extracted universities
#majors_minors_final_list -> List of all majors, masters, and minors
#universities_list = []
#majors_minors_final_list = []


universities_ind_list = [] #List of dictionaries
majors_dict = {'Name': 5} #Dictionary

#Create universities_ind_list with all universities matched to their index
for i, element in enumerate(universities_list):
    x = resume_file.find(element)
    temp = {element: x}
    universities_ind_list.append(temp)
    del temp
print(universities_ind_list)


##Order universities_ind_list by index, using bubble sort.
#alist = []
##my_range(start, end, step)
##for passnum in range(len(universities_ind_list)-1,0,-1):
#for passnum in range(len(universities_ind_list),0,-1):
    #for i in range(passnum):
        #alist[i] = list(universities_ind_list[i].values())[0]
        #alist[i+1] = list(universities_ind_list[i+1].values())[0]
        #if alist[i]>alist[i+1]:
            ##temp = alist[i]
            #temp = universities_ind_list[i]
            ##alist[i] = alist[i+1]
            #(universities_ind_list[i]) = (universities_ind_list[i+1])
            ##alist[i+1] = temp
            #(universities_ind_list[i+1]) = temp
#print(universities_ind_list)


#Create majors_dict with all majors matched to their index
for i, element in enumerate(majors_minors_final_list):
    x = resume_file.find(element)
    majors_dict[element] = x
del majors_dict['Name']
print(majors_dict)
# Out:
# [{'university of maryland': 115}, {'university of minnesota': -1}]
# {'accounting and management': 194, 'communications': 251, 'information systems': 308}

# %%
#Create final_list
final_list = [{'Univ1': ['major1','major2']},{'Univ2': ['major1','major2']}]
print (final_list)
del final_list[0]
del final_list[0]
print (final_list)
# Out:
# [{'Univ1': ['major1', 'major2']}, {'Univ2': ['major1', 'major2']}]
# []

# %%
universities_ind_list_len = len(universities_ind_list)
#0 Universities
if (not universities_list) or (universities_ind_list_len == 0):
    print("Universities list is empty")

#1 University
if (universities_ind_list_len == 1):
    #Then associate all majors in 150 char range, with this University 
    first_index = list(universities_ind_list[0].values())[0]
    
    #Get list of majors within the range
    first_majors = []
    lower_bound = first_index
    upper_bound = first_index+150
    for k, v in majors_dict.items():
        if (lower_bound < v < upper_bound):
            first_majors.append(k)
            
    #Associate list with single university in final_list
    first_university = list(universities_ind_list[0].keys())[0]
    #temp = {'Univ1': ['major1','major2']}
    #del temp['Univ1']
    #temp[first_university] = first_majors
    temp = {first_university: first_majors}
    final_list.append(temp)
    print(final_list)

# %%
#2 Universities
if (universities_ind_list_len == 2):
    #Then associate all majors in between the two Universities with the first University.
    #And associate all majors in 150 char range of the second University with the second University.
    first_index = list(universities_ind_list[0].values())[0]
    second_index = list(universities_ind_list[1].values())[0]
    len_until_next = (second_index - first_index)
    
    first_majors = []
    second_majors = []
    
    #Get list of majors within the two Universities
    lower_bound = first_index
    upper_bound = first_index+len_until_next
    for k, v in majors_dict.items():
        if (lower_bound < v < upper_bound):
            first_majors.append(k)
    
    #Get list of majors within 150 char range of the second University.
    lower_bound = second_index
    upper_bound = second_index+150
    for k, v in majors_dict.items():
        if (lower_bound < v < upper_bound):
            second_majors.append(k)
            
    #Associate lists with Universities
    first_university = list(universities_ind_list[0].keys())[0]
    second_university = list(universities_ind_list[1].keys())[0]
    temp1 = {first_university: first_majors}
    temp2 = {second_university: second_majors}
    final_list.append(temp1)
    final_list.append(temp2)
    print(final_list)
# Out:
# [{'university of maryland': []}, {'university of minnesota': []}]

# %%
#3 or more Universities
#Iterate through universities_ind_list
if (universities_ind_list_len > 2):
    for i in range(0, (universities_ind_list_len-2)):
        first_index = list(universities_ind_list[i].values())[0]
        second_index = list(universities_ind_list[i+1].values())[0]
        len_until_next = (second_index - first_index)

        first_majors = []
        second_majors = []

        #Get list of majors within the two Universities
        lower_bound = first_index
        upper_bound = first_index+len_until_next
        for k, v in majors_dict.items():
            if (lower_bound < v < upper_bound):
                first_majors.append(k)

        if ((i+1) == (universities_ind_list_len-1)):
        #if (i == (universities_dict_len-2))
            #Get majors of last University on the list
            lower_bound = second_index
            upper_bound = second_index+150
            for k, v in majors_dict.items():
                if (lower_bound < v < upper_bound):
                    second_majors.append(k)
        #Else continue loop until end
        
        #Associate lists with Universities.
        first_university = list(universities_ind_list[i].keys())[0]
        temp1 = {first_university: first_majors}
        final_list.append(temp1)
        if (second_majors):
        #If second_majors list is not empty, add it to final_list with its University.
            second_university = list(universities_ind_list[i+1].keys())[0]
            temp2 = {second_university, second_majors}
            final_list.append(temp2)
    print(final_list)

# %%
print("Bachelors:", updated_majors1)
print("Masters:", updated_majors2)
print("Minors:", updated_majors4)
print("Universities: ",universities_list)
print("Majors and Universities Categorized: ",final_list)
# Out:
# Bachelors: ['accounting and management', 'accounting', 'management']
# Masters: ['information', 'information systems']
# Minors: ['communications']
# Universities:  {'university of maryland', 'university of minnesota'}
# Majors and Universities Categorized:  [{'university of maryland': []}, {'university of minnesota': []}]

# %% [markdown]
# # Henry Dao

# %% [markdown]
# # 1. Extract Address

# %%
import re
import usaddress

#Extract the address from resume file 
def extract_address (text):
    text = text.replace('\n', ' ')
    regex = re.compile(r"[0-9]+ .*[.,-]? .*[.,-]? ([A-Z]{2}|\w+)[.,-]? [0-9]{5}(-[0-9]{4})?")
    result = re.search(regex, text)
    if result:
        result = result.group()
    return result

#Parse the components
def parse_address(result):
    address = usaddress.tag(result)
    return address

# %% [markdown]
# # ========Testing========

# %%
text = []
text.append('''Hi, Mr. Sam D. Richards lives here, 44 West 22nd Street, New York, NY 12345-4567. 
Can you contact him now? If you need any help, call me on 123 456 7891''')
text.append(''' ABEBAW AYELE
6040 14th St NW Washington DC 20011
202-629-7212 	abex72@gmail.com''')
text.append('''Amanda Yu
    	                       9700 Skyhill Way· Rockville· MD 20850·301-502-8705·yubo0107@hotmail.com''')
text.append('''Miguel Lorenzo M. Aviles
1644 New Windsor Ct
Crofton, Maryland 21114
(703) 501-1932
maviles@umd.edu
''')
text.append('''Alexander Berger
3711 Campus Drive
College Park, MD 20742
240-338-2206
alexfberger@gmail.com
Objective
I am seeking an entry-level position where I can use my design and software skills to provide better and more intuitive application design for customers and for my team.
''')

# %%
#Extracting Address
address=[]
for i in range(len(text)):
    address.append(extract_address(text[i])) 
    print(address[i])
# Out:
# 44 West 22nd Street, New York, NY 12345-4567
# 6040 14th St NW Washington DC 20011
# 9700 Skyhill Way· Rockville· MD 20850
# 1644 New Windsor Ct Crofton, Maryland 21114
# 3711 Campus Drive College Park, MD 20742

# %%
#Parse the component
address_components = []
for i in range(len(text)):
    address_components.append(parse_address(address[i]))
    print("Person {0}: {1}".format(i+1, parse_address(address[i])))
# Out:
# Person 1: (OrderedDict([('AddressNumber', '44'), ('StreetNamePreDirectional', 'West'), ('StreetName', '22nd'), ('StreetNamePostType', 'Street'), ('PlaceName', 'New York'), ('StateName', 'NY'), ('ZipCode', '12345-4567')]), 'Street Address')
# Person 2: (OrderedDict([('AddressNumber', '6040'), ('StreetName', '14th'), ('StreetNamePostType', 'St'), ('StreetNamePostDirectional', 'NW'), ('PlaceName', 'Washington'), ('StateName', 'DC'), ('ZipCode', '20011')]), 'Street Address')
# Person 3: (OrderedDict([('AddressNumber', '9700'), ('StreetName', 'Skyhill'), ('StreetNamePostType', 'Way·'), ('PlaceName', 'Rockville·'), ('StateName', 'MD'), ('ZipCode', '20850')]), 'Street Address')
# Person 4: (OrderedDict([('AddressNumber', '1644'), ('StreetName', 'New Windsor'), ('StreetNamePostType', 'Ct'), ('PlaceName', 'Crofton'), ('StateName', 'Maryland'), ('ZipCode', '21114')]), 'Street Address')
# Person 5: (OrderedDict([('AddressNumber', '3711'), ('StreetName', 'Campus'), ('StreetNamePostType', 'Drive'), ('PlaceName', 'College Park'), ('StateName', 'MD'), ('ZipCode', '20742')]), 'Street Address')

# %%
#Print the result
for i in range(len(address_components)):
    person = list(address_components[i][0].items())
    Address=''
    for j, item in enumerate(person):
        if person[j][0] == 'PlaceName':
            Placename = person[j][1]
        elif person[j][0] == 'StateName':
            State = person[j][1]
        elif person[j][0] == 'ZipCode':
            ZipCode = person[j][1]
        else:
            Address += person[j][1] + ' '

    print('\nPerson {}'.format(i+1))
    print("Address: {}".format(Address))
    print("City: {}".format(Placename))
    print("State: {}".format(State))
    print("ZipCode: {}".format(ZipCode))
# Out:
# Person 1
# Address: 44 West 22nd Street
# City: New York
# State: NY
# ZipCode: 12345-4567
#
# Person 2
# Address: 6040 14th St NW
# City: Washington
# State: DC
# ZipCode: 20011
#
# Person 3
# Address: 9700 Skyhill Way·
# City: Rockville·
# State: MD
# ZipCode: 20850
#
# Person 4
# Address: 1644 New Windsor Ct
# City: Crofton
# State: Maryland
# ZipCode: 21114
#
# Person 5
# Address: 3711 Campus Drive
# City: College Park
# State: MD
# ZipCode: 20742

# %% [markdown]
# # Extract Skills

# %%
import nltk
import pandas as pd
import os
import codecs

data = pd.read_excel("Skills.xlsx", header=0)
skill_list = list(data['Skill Names'])
skill_list = set(skill_list)
skill_list= [skill.lower() for skill in skill_list]
sorted(skill_list[0:10])
# Out:
# ['deployment of cloud services',
#  'fda 21 cfr part 11',
#  'glimmerhmm',
#  'hp load runner',
#  'ibm db2',
#  'programmers',
#  'rescue diving',
#  'riverbed modeler',
#  'sqoop',
#  'webdav']

# %%
import docx2txt
filename ='all_text1.txt'
trained_resume_path = os.path.join('Trained Resumes', filename)

# %%
#resume_text = docx2txt.process(test_resume_path)
resume_text = open(trained_resume_path, 'r', encoding='utf_8').read()

# %%
from nltk.corpus import stopwords

special_characters = ['!','#', '$', '%','&','*','-', '/', '=','?',
                      '^','.','_','`', '{', '|', '}','~', "'", ',', '(',')', ':', '•', '§' ]

# %%
# Processing text 

def resume_processing (resume_text):
    #tokenize sentences
    resume_sents = nltk.sent_tokenize(resume_text)

    #tokenize words
    resume_words = [nltk.word_tokenize(sent) for sent in resume_sents]
    
    #remove stopwords and special characters
    processed_resume=[]
    for sentence in resume_words:
        sent = [w.lower() for w in sentence 
                          if w.lower() not in stopwords.words('english') and w.lower() not in special_characters]
        processed_resume.append(sent)
    
    return processed_resume

# %%
unigram_resume = resume_processing(resume_text)
unigram_resume
# Out:
# [['jee',
#   'kang',
#   '3711',
#   'campus',
#   'drive',
#   'apt',
#   '139',
#   'college',
#   'park',
#   'md',
#   '4439447487',
#   'jwk1151',
#   '@',
#   'gmail.com',
#   'education',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'dual',
#   'degree',
#   'cumulative',
#   'gpa',
#   '3.7',
#   'anticipated',
#   'fall',
#   '2018',
#   'b.s'],
#  ['physiology', 'neurobiology', 'b.s'],
#  ['computer',
#   'science',
#   'relevant',
#   'courses',
#   'object',
#   'oriented',
#   'programming',
#   'ii',
#   'introduction',
#   'computer',
#   'systems',
#   'discrete',
#   'structures',
#   'innovators',
#   'think'],
#  ['languages',
#   'technologies',
#   'languages',
#   'java',
#   'c',
#   'programs',
#   'eclipse',
#   'android',
#   'studio',
#   'matlab',
#   'latex',
#   'labchart',
#   'projects',
#   'projects',
#   'found',
#   'github',
#   'github.com/jeekang',
#   'turnt',
#   'tower',
#   '2016',
#   'independently',
#   'developed',
#   'android',
#   'app',
#   'augment',
#   'block',
#   'tower',
#   'game',
#   'jenga'],
#  ['app', 'features', 'attractive', 'user-friendly', 'interface'],
#  ['language',
#   'java',
#   'android',
#   'java-based',
#   'dna',
#   'template',
#   'strand',
#   'transcription/translation',
#   '2016',
#   'built',
#   'program',
#   'using',
#   'java',
#   'takes',
#   'input',
#   'nucleotide',
#   'sequence',
#   'returns',
#   'complementary',
#   'strand',
#   'mrna',
#   'sequence',
#   'reading',
#   'frame',
#   'one',
#   'exists',
#   'amino',
#   'acid',
#   'sequence'],
#  ['independent',
#   'undergraduate',
#   'research',
#   'project',
#   '2016',
#   'part',
#   'center',
#   'bioinformatics',
#   'computational',
#   'biology',
#   'university',
#   'maryland'],
#  ['working',
#   'meta-genomic',
#   'analysis',
#   'algorithms',
#   'finding',
#   'limitations',
#   'existing',
#   'programs'],
#  ['details',
#   'determined',
#   'first',
#   'meeting',
#   'team',
#   'september',
#   '21st',
#   'achievements',
#   'received',
#   'integrated',
#   'life',
#   'sciences',
#   'honors',
#   'college',
#   'citation',
#   '2014',
#   'received',
#   'presidential',
#   'scholarship',
#   'university',
#   'maryland',
#   'fall',
#   '2012',
#   '–',
#   'spring',
#   '2016',
#   'scored',
#   '94th',
#   'percentile',
#   'mcats',
#   'jan',
#   '2015',
#   '6',
#   'semesters',
#   'dean',
#   '’',
#   'list',
#   'experience',
#   'affective',
#   'translational',
#   'neuroscience',
#   'laboratory',
#   'college',
#   'park',
#   'md',
#   'research',
#   'assistant',
#   'fall',
#   '2013-',
#   'spring',
#   '2015',
#   'brainstormed',
#   'ideas',
#   'trial',
#   'stages',
#   'track',
#   'social',
#   'habits/movements',
#   'subjects'],
#  ['front-end', 'experience', 'briefed', 'debriefed', 'study', 'participants'],
#  ['worked',
#   'psychology',
#   'clinic',
#   'university',
#   'maryland',
#   'using',
#   'titanium',
#   'excel',
#   'manage',
#   'patient',
#   'dsm-5',
#   'data'],
#  ['assisted',
#   'running',
#   'clinical',
#   'trials',
#   'involving',
#   'fmri',
#   'maryland',
#   'neuroimaging',
#   'center'],
#  ['\\n',
#   'yaw',
#   'owusu',
#   'appiah',
#   'experience',
#   'summary',
#   'qualified',
#   'clearable',
#   'oracle',
#   'database',
#   '12c/11g/10g/9i',
#   'dba',
#   '10',
#   'years',
#   'managing',
#   'working',
#   'leading',
#   'edge',
#   'projects',
#   'require',
#   'experience',
#   'diverse',
#   'oltp',
#   'big',
#   'data',
#   'environments',
#   'team',
#   'player',
#   'proven',
#   'expertise',
#   'training',
#   'education',
#   'well',
#   'experience',
#   'programming',
#   'linux',
#   'administration',
#   'oracle',
#   'database',
#   'administration',
#   'asm',
#   'setup',
#   'oracle',
#   'rac',
#   '10g/11g/12c',
#   'data',
#   'guard',
#   'implementation',
#   'real',
#   'time',
#   'disaster',
#   'recovery',
#   'skilled',
#   'leading',
#   'dbas',
#   'database',
#   'projects',
#   'within',
#   'different',
#   'methodologies',
#   'like',
#   'devops',
#   'experience',
#   'leveraging',
#   'cots',
#   'gots',
#   'products',
#   'large',
#   'organizations',
#   'private',
#   'government',
#   'sectors',
#   'highly',
#   'exposed',
#   'big',
#   'data',
#   'environments',
#   'excellent',
#   'skills',
#   'upgrade',
#   'migrations',
#   'applying',
#   'quarterly',
#   'patches',
#   'etc'],
#  ['versatile',
#   'establishing',
#   'client',
#   'relationships',
#   'understanding',
#   'business',
#   'processes',
#   'user',
#   'tasks',
#   'goals',
#   ';',
#   'analyzing',
#   'defining',
#   'requirements',
#   'ensure',
#   'efficient',
#   'cost-saving',
#   'technological',
#   'solutions',
#   'meet',
#   'exceed',
#   'client',
#   'needs',
#   'experienced',
#   'automating',
#   'database',
#   'creation',
#   'oracle',
#   'response',
#   'files',
#   'linux',
#   'shell',
#   'scripts',
#   'versed',
#   'oracle',
#   'management',
#   'tools',
#   'utilities',
#   'like',
#   'oracle',
#   'enterprise',
#   'manager',
#   'grid',
#   'asmca',
#   'srvctl',
#   'crsctl',
#   'performance',
#   'tuning',
#   'techniques',
#   'comprises',
#   'savvy',
#   'usage',
#   'indexes',
#   'tablespace',
#   'compression',
#   'i/o',
#   'minimizations',
#   'hardware',
#   'raid',
#   'load',
#   'balancing',
#   'techniques'],
#  ['well',
#   'exposed',
#   'oracle',
#   'engineered',
#   'systems',
#   'like',
#   'oda',
#   'oracle',
#   'data',
#   'appliance',
#   'experience',
#   'leveraging',
#   'systems',
#   'meet',
#   'challenging',
#   'evolving',
#   'client',
#   'data',
#   'needs'],
#  ['core',
#   'competencies',
#   'technical',
#   'training',
#   'oracle',
#   '11g/10g/12c',
#   'database',
#   'administration',
#   'unix',
#   'systems',
#   'solaris',
#   'aix',
#   'linux',
#   'linux/unix',
#   'administration',
#   'shell',
#   'scripting',
#   'capacity',
#   'planning',
#   'systems',
#   'integration',
#   'oracle',
#   'performance',
#   'tuning',
#   'pl/sql',
#   'programming',
#   'technical',
#   'documentation',
#   'technical',
#   'leadership',
#   'cloud',
#   'computing',
#   'work',
#   'experience',
#   'science',
#   'applications',
#   'international',
#   'corporation',
#   'saic',
#   'december',
#   '2012',
#   'present',
#   'lead',
#   'oracle',
#   'database',
#   'administrator',
#   'key',
#   'work',
#   'experience',
#   'lead',
#   'development',
#   'custom',
#   'shell',
#   'scripts',
#   'monitoring',
#   'specific',
#   'databases',
#   'united',
#   'states',
#   'citizenship',
#   'immigration',
#   'services',
#   'department',
#   'homeland',
#   'security',
#   'led',
#   'automation',
#   'database',
#   'security',
#   'audits',
#   'conducted',
#   'security',
#   'team',
#   'saic'],
#  ['effort',
#   'cut',
#   'database',
#   'security',
#   'auditing',
#   'time',
#   '50',
#   'relieved',
#   'several',
#   'hours',
#   'routine',
#   'dba',
#   'security',
#   'staff',
#   'work'],
#  ['build',
#   'sops',
#   'implement',
#   'oracle',
#   'migrations',
#   '11gr2',
#   '12c',
#   ';',
#   'migration',
#   'activities',
#   'touch',
#   'oracle',
#   'clusterware',
#   'automatic',
#   'storage',
#   'management',
#   'layer',
#   'operating',
#   'system',
#   'areas',
#   'support',
#   'oracle',
#   'related',
#   'deployment',
#   'effort',
#   'uscis',
#   'electronic',
#   'immigration',
#   'system',
#   'project',
#   'elis'],
#  ['support',
#   'activities',
#   'include',
#   'performance',
#   'tuning',
#   'exercises',
#   'backup',
#   'recovery',
#   'rac',
#   'installations',
#   'upgrades',
#   'patching',
#   'replication',
#   'disaster',
#   'recovery',
#   'scripting',
#   'data',
#   'loading',
#   'data',
#   'reporting',
#   'provide',
#   'support',
#   'dbas',
#   'use',
#   'maintain',
#   'customer',
#   'scripts',
#   'developed',
#   'database',
#   'housekeeping',
#   'tasks',
#   'backup',
#   'recovery',
#   'shutdown',
#   'maintenance',
#   'work',
#   'etc'],
#  ['municipal',
#   'securities',
#   'rulemaking',
#   'board',
#   'alexandria',
#   'va',
#   'december',
#   '2012',
#   'present',
#   'lead',
#   'oracle',
#   'dba',
#   'linux',
#   'instructor',
#   'key',
#   'work',
#   'experience',
#   'led',
#   'dbas',
#   'migrating',
#   'various',
#   'oracle',
#   'versions',
#   'windows',
#   'linux',
#   'platform',
#   'evaluated',
#   'provided',
#   'technical',
#   'recommendations',
#   'business',
#   'continuity',
#   'solutions',
#   'msrb',
#   'data',
#   'management',
#   'teams',
#   ';',
#   'evaluated',
#   'replication',
#   'solutions',
#   'like',
#   'goldengate',
#   'streams',
#   'led',
#   'dbas',
#   'automating',
#   'various',
#   'manual',
#   'routines',
#   'like',
#   'db',
#   'backup',
#   'recovery',
#   'data',
#   'pump',
#   'activities',
#   ';',
#   'overall',
#   'helped',
#   'relieve',
#   'dba',
#   'time',
#   '30',
#   'designed',
#   'implemented',
#   'custom',
#   'data',
#   'change',
#   'tracking',
#   'routines',
#   'database',
#   'systems',
#   'msrb',
#   ';',
#   'database',
#   'auditing',
#   'highest',
#   'msrb'],
#  ['db',
#   'changes',
#   'tracked',
#   'reported',
#   'upper',
#   'management',
#   'savvy',
#   'custom',
#   'reports.establish',
#   'maintain',
#   'information',
#   'security',
#   'standards',
#   'procedures',
#   'compliance',
#   'dhs',
#   'uscg',
#   'dia',
#   'risk',
#   'management',
#   'policies',
#   'standards',
#   'guidelines',
#   'trained',
#   'msrb',
#   'technical',
#   'staff',
#   'linux',
#   'platform',
#   ';',
#   'includes',
#   'developers',
#   'operations',
#   'staff',
#   'middle',
#   'management',
#   'dbas',
#   'whole',
#   'organization',
#   'advised',
#   'msrb',
#   'database',
#   'management',
#   'techniques',
#   'strategies',
#   'best',
#   'practices',
#   ';',
#   'documented',
#   'trained',
#   'dbas',
#   'accepted',
#   'recommendations',
#   'provided',
#   'technical',
#   'leadership',
#   'evaluating',
#   'oracle',
#   'data',
#   'appliance',
#   'on-site',
#   'proof-of-concept',
#   'exercises',
#   'mitre',
#   'corporation',
#   'mclean',
#   'va',
#   '2008',
#   '2011',
#   'senior',
#   'oracle',
#   'database',
#   'administrator',
#   'key',
#   'work',
#   'experience',
#   'installed',
#   'configured',
#   'oracle',
#   '11g',
#   'r1',
#   'rac',
#   'using',
#   'netapp',
#   'nfs',
#   'storage',
#   'conducted',
#   'bi-weekly',
#   'cold',
#   'backups',
#   'using',
#   'linux',
#   'lvm',
#   'snapshot',
#   'netapp',
#   'snapshot',
#   'disaster',
#   'recovery',
#   'offsite',
#   'locationevaluated',
#   'provided',
#   'technical',
#   'recommendations',
#   'business',
#   'continuity',
#   'solutions',
#   'msrb',
#   'data',
#   'management',
#   'teams',
#   ';',
#   'evaluated',
#   'replication',
#   'solutions',
#   'like',
#   'goldengate',
#   'streams'],
#  ['configured',
#   'oracle',
#   'database',
#   'server',
#   'connect',
#   'non-oracle',
#   'systems',
#   'like',
#   'hadoop',
#   'ms',
#   'sql',
#   'server',
#   'mysql',
#   'databases',
#   'fully',
#   'heterogeneous',
#   'environment',
#   'upgraded',
#   'oracle',
#   '11gr1',
#   '11gr2',
#   'performed',
#   'disaster',
#   'recovery',
#   'provided',
#   'recommendations',
#   'senior',
#   'management',
#   'implementation',
#   'performed',
#   'database',
#   'performance',
#   'tuning',
#   'activities',
#   'using',
#   'tools',
#   'like',
#   'addm',
#   'reports',
#   'sql',
#   'tuning',
#   'advisors',
#   'supported',
#   'research',
#   'efforts',
#   'oracle',
#   'replication',
#   'technologies',
#   'like',
#   'data',
#   'guard',
#   'automated',
#   'database',
#   'administration',
#   'routines',
#   'e.g'],
#  ['backup',
#   'recovery',
#   'data',
#   'pump',
#   'export/import',
#   'activities',
#   'schema',
#   'refresh',
#   'different',
#   'sources',
#   'creation',
#   'disk',
#   'usage',
#   'monitoring',
#   'designed',
#   'implemented',
#   'oracle',
#   'user',
#   'audit',
#   'collection',
#   'led',
#   'dba',
#   'team',
#   'architecting',
#   'data',
#   'flows',
#   'presentation',
#   'tiers',
#   'senior',
#   'management',
#   'analyzed',
#   'database',
#   'research',
#   'results',
#   'documented',
#   'findings',
#   'supported',
#   'oracle',
#   'research',
#   'work',
#   'conducted',
#   'various',
#   'airline',
#   'partners',
#   'mitre',
#   '’',
#   'aviation',
#   'initiatives',
#   'supported',
#   'research',
#   'efforts',
#   'large',
#   'databases',
#   'like',
#   'asterdata',
#   'greenplum',
#   'teradata',
#   'chaveran',
#   'inc.',
#   'bowie',
#   'md',
#   '2006',
#   '2013',
#   'part-time',
#   'technical',
#   'instructor',
#   'key',
#   'work',
#   'experience',
#   'trained',
#   'students',
#   'unix',
#   'linux',
#   'platforms',
#   'administration',
#   'trained',
#   'students',
#   'installing',
#   'configuring',
#   'oracle',
#   'asm',
#   'oracle',
#   'rac',
#   'stack',
#   'assisted',
#   'writing',
#   'technical',
#   'manuals',
#   'on-site',
#   'linux',
#   'administrators',
#   'assisted',
#   'developing',
#   'training',
#   'material',
#   'interns',
#   'designed',
#   'maintained',
#   'student',
#   'mail',
#   'ssh',
#   'jumpbox',
#   'web',
#   'servers',
#   'assisted',
#   'building',
#   'maintaining',
#   'chaveran',
#   'cloud',
#   'various',
#   'virtualizations',
#   'installed',
#   'configured',
#   'red',
#   'hat',
#   'file',
#   'servers',
#   'linux',
#   'appliances',
#   'installed',
#   'configured',
#   'linux',
#   'firewalls',
#   'client',
#   'using',
#   'iptables',
#   'bind',
#   'developed',
#   'hardware',
#   'requirements',
#   'specification',
#   'assisted',
#   'sizing',
#   'activities',
#   'saba',
#   'software',
#   'inc.',
#   'baltimore',
#   'md',
#   '2006',
#   '2008',
#   'technical',
#   'consultant/oracle',
#   'developer',
#   'key',
#   'work',
#   'experience',
#   'assisted',
#   'clients',
#   'problem',
#   'identification',
#   'database',
#   'system',
#   'architecture',
#   'problems',
#   'software',
#   'specifications',
#   'writing',
#   'software',
#   'implementation',
#   'testing',
#   'deployment',
#   'technical',
#   'highlights',
#   'fdic',
#   'thinq-to-saba',
#   'data',
#   'migration',
#   'technical',
#   'lead',
#   'high',
#   'risk',
#   'clearance'],
#  ['led',
#   'design',
#   'implementation',
#   'fdic',
#   '’',
#   'data',
#   'migration',
#   'effort',
#   'thinq',
#   'saba'],
#  ['supported',
#   'yum',
#   'brands',
#   'architectural',
#   'designs',
#   'data',
#   'migration',
#   'processes',
#   'assisted',
#   'data',
#   'migration',
#   'enbridge',
#   'gas',
#   'distribution',
#   'based',
#   'canada',
#   'served',
#   'technical',
#   'lead',
#   'saba',
#   'engagement',
#   'northrop',
#   'grumman',
#   'corporation'],
#  ['supported',
#   'client',
#   'saba',
#   'installations',
#   'oracle',
#   'data',
#   'migration',
#   'supported',
#   'atk',
#   'oracle',
#   'performance',
#   'tuning',
#   'efforts',
#   'using',
#   'explain',
#   'plans',
#   'awr',
#   'addm',
#   'reports',
#   'mentored',
#   'junior',
#   'consultants',
#   'saba',
#   '’',
#   'employee',
#   'mentorship',
#   'program'],
#  ['washington',
#   'baltimore',
#   'high',
#   'index',
#   'drug',
#   'trafficking',
#   'area',
#   'greenbelt',
#   'md',
#   '2001',
#   '2006',
#   'database',
#   'administrator/developer',
#   'key',
#   'work',
#   'experience',
#   'assisted',
#   'development',
#   'backend',
#   'database',
#   'stored',
#   'procedures',
#   'needed',
#   'middle',
#   'tiers',
#   'worked',
#   'extensively',
#   'classic',
#   'asp',
#   'access',
#   'reporting',
#   'tools',
#   'like',
#   'pivot',
#   'tables',
#   'conducted',
#   'demos',
#   'training',
#   'sessions',
#   'needed',
#   'use',
#   'released',
#   'products',
#   'worked',
#   'content',
#   'management',
#   'systems',
#   'like',
#   'drupal',
#   'mambo',
#   'assisted',
#   'web',
#   'development',
#   'projects',
#   'using',
#   'php',
#   'developed',
#   'database',
#   'application',
#   'tracking',
#   'web',
#   'logs',
#   'helped',
#   'create',
#   'frontend',
#   'interfaces',
#   'controlling',
#   'applications',
#   'extensively',
#   'dealt',
#   'schema',
#   'design',
#   'data',
#   'modeling',
#   'using',
#   'tools',
#   'like',
#   'oracle',
#   'data',
#   'modeler',
#   'conducted',
#   'demos',
#   'trained',
#   'personnel',
#   'using',
#   'visual',
#   'basic',
#   'application',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'maryland',
#   '2001',
#   'linux/network',
#   'administrator',
#   'key',
#   'work',
#   'experience',
#   'supported',
#   'student',
#   'network',
#   'setup',
#   'assisted',
#   'network',
#   'problem',
#   'shooting',
#   'assisted',
#   'network',
#   'deployment',
#   'troubleshooting',
#   'configured',
#   'student',
#   'private',
#   'routers',
#   'network',
#   'devices',
#   'trained',
#   'students',
#   'using',
#   'network',
#   'resources',
#   'campus',
#   'worked',
#   'team',
#   'help',
#   'students',
#   'install',
#   'linux',
#   'workstations',
#   'skills',
#   'sql',
#   'language',
#   'linux',
#   'shell',
#   'scripting',
#   'pl/sql',
#   'mysql/postgresql',
#   'database',
#   'oracle',
#   'data',
#   'guard',
#   'perl',
#   'scripting',
#   'windows',
#   'os',
#   'oracle',
#   'asm',
#   'exposed',
#   'greenplum',
#   'netezza',
#   'hadoop',
#   'linux',
#   'lan/wan',
#   'networking',
#   'object',
#   'oriented',
#   'programming',
#   'oop',
#   'concepts',
#   'gnu/linux',
#   'os',
#   '–',
#   'red',
#   'hat',
#   'debian',
#   'c++',
#   'c',
#   'java',
#   'tcp/ip',
#   'networking',
#   'sql',
#   'loader',
#   'pervasive',
#   'map',
#   'designer',
#   'joomla',
#   'cms',
#   'oracle',
#   'sql',
#   'developer',
#   'sql',
#   'data',
#   'modeler',
#   'oracle',
#   '12c',
#   'cloud',
#   'control',
#   'quest',
#   'toad',
#   'quest',
#   'spotlight/foglight',
#   'oracle',
#   'rman',
#   'adobe',
#   'fireworks',
#   'dreamweaver',
#   'microsoft',
#   'office',
#   'visio',
#   'virtual',
#   'box',
#   'vmware',
#   'xen',
#   'education',
#   'masters',
#   'science',
#   'information',
#   'systems',
#   '2012',
#   'university',
#   'maryland',
#   'baltimore',
#   'county',
#   'bachelor',
#   'science',
#   'computer',
#   'science',
#   '2006',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'bachelor',
#   'arts',
#   'economics',
#   '–',
#   '2006',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'clearance',
#   'certifications',
#   'public',
#   'trust',
#   'level',
#   '3',
#   'fbi',
#   'background',
#   'investigation',
#   'oracle',
#   'certified',
#   'professional',
#   'oracle',
#   'certified',
#   'associate',
#   'red',
#   'hat',
#   'certified',
#   'technician',
#   'jane',
#   'doe',
#   'paradyme',
#   'management',
#   'inc',
#   'page',
#   '1',
#   '5',
#   'yaw',
#   'owusu',
#   'appiah',
#   'paradyme',
#   'management',
#   'inc'],
#  ['page',
#   '2',
#   '5\\n',
#   'dimitri',
#   'richardson',
#   '114',
#   'division',
#   'st',
#   'neptune',
#   'nj',
#   '07753',
#   'phone',
#   '732-614-0217',
#   'e-mail',
#   'dimitri.richardson',
#   '@',
#   'gmail.com',
#   'experience',
#   'smart',
#   'tuition',
#   'june-august',
#   '2015',
#   'summer',
#   'internship',
#   ';',
#   'manage',
#   'accounts',
#   'private',
#   'schools',
#   'across',
#   'country'],
#  ['customer',
#   'service',
#   'assistant',
#   'answered',
#   'questions',
#   'parents',
#   'school',
#   'worked',
#   'along',
#   'side',
#   'school',
#   'account',
#   'mangers',
#   'laz',
#   'parking',
#   'may',
#   '2013-august',
#   '2015',
#   'parking',
#   'attendant',
#   'charge',
#   'collection',
#   'fees',
#   'parking',
#   'three-beach',
#   'side',
#   'customer',
#   'parking',
#   'facilities'],
#  ['handled',
#   'financial',
#   'transactions',
#   'wendy',
#   '’',
#   'july',
#   '2011-may',
#   '2012',
#   'cashier',
#   'responsibilities',
#   'included',
#   'greeting',
#   'customers',
#   'submitting',
#   'orders',
#   'operating',
#   'cash',
#   'register'],
#  ['demonstrated',
#   'customer',
#   'service',
#   'problem-solving',
#   'computer',
#   'skills'],
#  ['assisted', 'opening', 'closing', 'store'],
#  ['national',
#   'leadership',
#   'forum',
#   'law',
#   'csi',
#   'july',
#   '2010',
#   'experienced',
#   'full',
#   'range',
#   'professions',
#   'exist',
#   'legal',
#   'forensic',
#   'science',
#   'fields'],
#  ['explored',
#   'in-depth',
#   'entire',
#   'judicial',
#   'process',
#   'crime',
#   'collecting',
#   'analyzing',
#   'critical',
#   'evidence'],
#  ['examine', 'court', 'case', 'supreme', 'court', 'stimulation'],
#  ['took',
#   'part',
#   'legal',
#   'career',
#   'experience',
#   'courthouse',
#   'jersey',
#   'shore',
#   'university',
#   'medical',
#   'center',
#   'august',
#   '2010',
#   'volunteer',
#   'jsumc',
#   'assisting',
#   'caregiver',
#   'assistance',
#   'clerical',
#   'tasks',
#   'worked',
#   'information',
#   'desk',
#   'mail',
#   'room',
#   'billing',
#   'department'],
#  ['education',
#   'xavier',
#   'university',
#   '2012-2013',
#   'volunteer/member',
#   'xavier',
#   'university',
#   'black',
#   'student',
#   'association',
#   'member',
#   'track',
#   'field',
#   'team',
#   'member',
#   'xavier',
#   'university',
#   'club',
#   'football',
#   'team',
#   'west',
#   'virginia',
#   'university',
#   '2014-',
#   'present',
#   'current',
#   'finance',
#   'student',
#   'college',
#   'business',
#   'economics',
#   'graduation',
#   'date',
#   'may',
#   '2017',
#   '2\\n',
#   '3412',
#   'tulane',
#   'dr.',
#   '31',
#   'varsha',
#   'purswani',
#   'hyattsville',
#   'maryland',
#   'md',
#   '20783',
#   '301-318-6065',
#   'https',
#   '//www/linkedin.com/in/varsha022',
#   'varsha.purswani',
#   '@',
#   'rhsmith.umd.edu',
#   'education',
#   'robert',
#   'h.',
#   'smith',
#   'school',
#   'business',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'md',
#   'dec',
#   '2016',
#   'master',
#   'science',
#   'information',
#   'systems',
#   'g.p.a',
#   '3.9',
#   'related',
#   'coursework',
#   'data',
#   'mining',
#   'predictive',
#   'analytics',
#   'data',
#   'models',
#   'decisions',
#   'business',
#   'process',
#   'analysis',
#   'strategic',
#   'transformational',
#   'database',
#   'management',
#   'systems',
#   'digital',
#   'business',
#   'markets',
#   'shri',
#   'govindram',
#   'seksaria',
#   'institute',
#   'technology',
#   'science',
#   'indore',
#   'india',
#   'bachelor',
#   'engineering',
#   'computer',
#   'engineering',
#   'may',
#   '2012',
#   'professional',
#   'experience',
#   'sap',
#   'labs',
#   'india',
#   'pvt',
#   'ltd',
#   'bangalore',
#   'india',
#   'jun',
#   '2012',
#   '–',
#   'july',
#   '2015',
#   'software',
#   'developer',
#   '§\uf0a7',
#   'collaborated',
#   'customers',
#   'business',
#   'needs',
#   'translated',
#   'technical',
#   'requirements',
#   'producing',
#   'software',
#   'requirement',
#   'specification'],
#  ['§\uf0a7',
#   'consulted',
#   'italian',
#   'client',
#   'implementation',
#   'sap',
#   'fashion',
#   'management',
#   'solution',
#   'fms',
#   'critical',
#   'business',
#   'scenarios',
#   'resulting',
#   'smooth',
#   'launch'],
#  ['§\uf0a7',
#   'designed',
#   'data',
#   'model',
#   'sap',
#   'fms',
#   'order',
#   'allocation',
#   'run',
#   'a-run',
#   'enabled',
#   'execution',
#   'sap',
#   'hana',
#   'database',
#   'platform',
#   'resulting',
#   'performance',
#   'improvement',
#   '10',
#   'times',
#   'baseline'],
#  ['§\uf0a7',
#   'led',
#   'start-up',
#   'company',
#   'creating',
#   'supply',
#   'chain',
#   'management',
#   'scm',
#   'analytics',
#   'application',
#   'using',
#   'sap',
#   'hana',
#   'database',
#   'platform'],
#  ['projects',
#   'aug',
#   '2015',
#   '–',
#   'dec',
#   '2015',
#   '§\uf0a7',
#   'database',
#   'management',
#   'systems',
#   'designed',
#   'relational',
#   'database',
#   'virtual',
#   'client',
#   'defining',
#   'logical',
#   'model',
#   'using',
#   'entity',
#   'relationship',
#   'diagram',
#   'physical',
#   'model',
#   'using',
#   'sql',
#   '§\uf0a7',
#   'digitization',
#   'freelancing',
#   'collated',
#   'data',
#   'created',
#   'reports',
#   'online',
#   'freelancing',
#   'platform',
#   'upwork',
#   'analyzed',
#   'strategic',
#   'transformational',
#   'impact',
#   'society',
#   '§\uf0a7',
#   'business',
#   'process',
#   'analysis',
#   'leading',
#   'scrum',
#   'team',
#   'five',
#   'develop',
#   'reporting',
#   'mobile',
#   'app',
#   'demonstrating',
#   'health',
#   'statistics',
#   'individual',
#   '§\uf0a7',
#   'firm',
#   'analysis',
#   'mapbox',
#   'gathered',
#   'information',
#   'start',
#   'mapbox',
#   'analysed',
#   'business',
#   'domain',
#   'sources',
#   'competitive',
#   'advantage',
#   'industry',
#   'dynamics',
#   'strategic',
#   'drivers',
#   'performance'],
#  ['§\uf0a7',
#   'google',
#   'analytics',
#   'leading',
#   'team',
#   'four',
#   'improve',
#   'client',
#   '’',
#   'website',
#   'increase',
#   'click',
#   'rate',
#   'using',
#   'google',
#   'analytics',
#   'google',
#   'adwords'],
#  ['leadership',
#   'experience',
#   'university',
#   'maryland',
#   'aug',
#   '2015',
#   '–',
#   'dec',
#   '2015',
#   '§\uf0a7',
#   'managed',
#   'marketing',
#   'events',
#   'student',
#   'ambassador',
#   'clarice',
#   'smith',
#   'performing',
#   'arts',
#   'center'],
#  ['§\uf0a7',
#   'volunteered',
#   'kids',
#   'enjoy',
#   'exercise',
#   'keen',
#   'providing',
#   'recreational',
#   'opportunities',
#   'group',
#   '20',
#   'children',
#   'physical',
#   'mental',
#   'disabilities'],
#  ['sgsits',
#   'technical',
#   'cultural',
#   'events',
#   'may',
#   '2011',
#   '–',
#   'dec',
#   '2011',
#   '§\uf0a7',
#   'facilitated',
#   'office',
#   'career',
#   'services',
#   'smooth',
#   'execution',
#   'placement',
#   'process',
#   '500',
#   'students',
#   '§\uf0a7',
#   'supervised',
#   'budgeting',
#   'script',
#   'writing',
#   'compering',
#   'three',
#   'major',
#   'events',
#   'college',
#   '’',
#   'cultural',
#   'festival'],
#  ['technical',
#   'skills',
#   '§\uf0a7',
#   'languages',
#   'r',
#   'abap',
#   'java',
#   'c',
#   'sql',
#   'php',
#   'html',
#   'css',
#   'xml',
#   '§\uf0a7',
#   'tools',
#   'tableau',
#   'palisade',
#   'tools',
#   'excel',
#   'stat',
#   'tools',
#   '@',
#   'risk',
#   'precision',
#   'tree',
#   'solver',
#   'table',
#   'ms',
#   'visio',
#   'ms',
#   'office',
#   'salesforce.com',
#   'oracle10g',
#   'mysql',
#   'sap',
#   'hana',
#   'google',
#   'analytics',
#   'google',
#   'adwords',
#   'linux',
#   '\\n',
#   'kane',
#   'baccigalupi',
#   '935',
#   'scenic',
#   'place',
#   'pleasant',
#   'hill',
#   'ca',
#   '94523',
#   'mobile',
#   '510-228-9669',
#   'skill',
#   'summary',
#   'expert',
#   'technical',
#   'advisor',
#   '10',
#   'years',
#   'experience',
#   'cto',
#   'expert',
#   'consultant'],
#  ['team', 'leader', 'dedicated', 'advancing', 'developing', 'team', 'members'],
#  ['champion',
#   'organizational',
#   'diversity',
#   'benefits',
#   'business',
#   'objectives'],
#  ['business',
#   'strategist',
#   'focused',
#   'using',
#   'technical',
#   'innovation',
#   'move',
#   'organizations',
#   'quickly',
#   'towards',
#   'objectives'],
#  ['mentor', 'writer', 'speaker'],
#  ['data',
#   'driven',
#   'decision',
#   'maker',
#   'focused',
#   'user',
#   'research',
#   'customer',
#   'validation'],
#  ['public',
#   'servant',
#   'dedicated',
#   'bringing',
#   'best',
#   'innovations',
#   'private',
#   'sector',
#   'government'],
#  ['experience',
#   'innovation',
#   'strategist',
#   '18f',
#   'gsa',
#   'september',
#   '2015',
#   'present',
#   'gsa',
#   "'s",
#   '18f',
#   'innovation',
#   'agency',
#   'federal',
#   'government'],
#  ['worked',
#   'strategy',
#   'team',
#   'offering',
#   'technical',
#   'advice',
#   'hands-on',
#   'support',
#   'moving',
#   'agencies',
#   'projects',
#   'better',
#   'practices',
#   'outcomes'],
#  ['legacy',
#   'modernization',
#   'lead',
#   'educated',
#   '18f',
#   'leadership',
#   'staff',
#   'common',
#   'patterns',
#   'legacy',
#   'modernization'],
#  ['crafted',
#   'plans',
#   'alaska',
#   'missouri',
#   'medicaid',
#   'related',
#   'modernizations',
#   'starting',
#   'deep',
#   'technical',
#   'dive',
#   '18f',
#   'team',
#   'members',
#   'three-month',
#   'prototyping',
#   'vendor',
#   'contract',
#   'concluding',
#   'modular',
#   'procurement',
#   'plan'],
#  ['rebuilt',
#   'technical',
#   'product',
#   'strategy',
#   'health',
#   'human',
#   'services',
#   'unaccompanied',
#   'children',
#   'program',
#   'software',
#   'modernization',
#   'effor',
#   'switching',
#   'database',
#   'encapsulation',
#   'transformation'],
#  ['us',
#   'census',
#   'bureau',
#   'engagement',
#   'lead',
#   'acted',
#   'bridge',
#   'engineering',
#   'teams',
#   'census',
#   'top',
#   'leadership',
#   'introducing',
#   'product',
#   'development',
#   'processes',
#   'improving',
#   'agile',
#   'practices',
#   '2020',
#   'internet',
#   'data',
#   'collection',
#   'application'],
#  ['lead',
#   'discovery',
#   'improved',
#   'software',
#   'design',
#   'practices',
#   'crafted',
#   'two',
#   'day',
#   'engineering',
#   'design',
#   'workshop'],
#  ['worked',
#   'cio',
#   'deputy',
#   'director',
#   'address',
#   'highest',
#   'risk',
#   'issues',
#   'decennial',
#   'survey',
#   'cloud',
#   'infrastructure',
#   'governance'],
#  ['environmental',
#   'protection',
#   'agency',
#   'e-enterprise',
#   'program',
#   'engineering',
#   'strategist',
#   'co-lead',
#   'discovery',
#   'combined',
#   'air',
#   'emissions',
#   'reporting'],
#  ['crafted',
#   'data',
#   'architecture',
#   'would',
#   'allow',
#   'state',
#   'federal',
#   'program',
#   'managers',
#   'understand',
#   'data',
#   'reporting',
#   'query',
#   'separate',
#   'needs'],
#  ['taught',
#   'two',
#   'day',
#   'agile',
#   'workshop',
#   'bridged',
#   'gap',
#   'state',
#   'epa',
#   'needs'],
#  ['guided',
#   'epa',
#   'towards',
#   'low\u200b-risk',
#   'high-return',
#   'solutions',
#   'could',
#   'completed',
#   'within',
#   'month',
#   'establish',
#   'trust',
#   'state',
#   'participants'],
#  ['lead',
#   'agile',
#   'consultant',
#   'ministry',
#   'velocity',
#   'december',
#   '2014',
#   'august',
#   '2015',
#   'worked',
#   'engagements',
#   'lasting',
#   'one',
#   'day',
#   'six',
#   'months',
#   'advising',
#   'company',
#   'leadership',
#   'building',
#   'rebuilding',
#   'organization',
#   'core',
#   'software',
#   'products'],
#  ['lead',
#   'one\u200b-day',
#   'working',
#   'session',
#   'engineering',
#   'leadership',
#   'enterprise',
#   'saas',
#   'company',
#   'tackle',
#   'system',
#   'instability',
#   'leading',
#   'data',
#   'architecture',
#   'solution',
#   'increased',
#   'uptime'],
#  ['provided',
#   'expert',
#   'technical',
#   'organizational',
#   'advice',
#   'ceo/founder',
#   'food',
#   'delivery',
#   'startup',
#   'transitioning',
#   'hastily',
#   'built',
#   'prototype',
#   'scalable',
#   'customizable',
#   'solution'],
#  ['performed',
#   'hands\u200b-on',
#   'engineering',
#   'mentoring',
#   'two',
#   'enterprise',
#   'saas',
#   'companies',
#   'struggling',
#   'legacy',
#   'code',
#   'issues'],
#  ['improved',
#   'agile',
#   'software',
#   'practices',
#   'increased',
#   'velocity',
#   're\u200b-architected',
#   'failing',
#   'systems',
#   'applications'],
#  ['acting',
#   'director',
#   'gschool',
#   'galvanize',
#   'inc.',
#   'august',
#   '2014',
#   'november',
#   '2014',
#   'increased',
#   'operational',
#   'efficiency',
#   'web',
#   'education',
#   'school',
#   'company',
#   'acquired',
#   'zipfian',
#   'academy',
#   'merged',
#   'new',
#   'university',
#   'new',
#   'backed',
#   'masters',
#   'program',
#   'data',
#   'science'],
#  ['oversaw',
#   'instructions',
#   'admissions',
#   'student',
#   'outcomes',
#   'transition'],
#  ['reduced',
#   'instructor',
#   'costs',
#   '30',
#   'increased',
#   'facility',
#   'utilization',
#   'boulder',
#   'campus',
#   'via',
#   'concurrent',
#   'classes'],
#  ['launched',
#   'san',
#   'francisco',
#   'instruction',
#   'campus',
#   'creating',
#   'curriculum',
#   'leading',
#   'instruction',
#   'first',
#   'web',
#   'development',
#   'six',
#   'month',
#   'course'],
#  ['reorganized',
#   'school-wide',
#   'roles',
#   'increase',
#   'efficiency',
#   'improve',
#   'instructor',
#   'retention'],
#  ['streamlined',
#   'admissions',
#   'scattered',
#   'ad',
#   'hoc',
#   'processes',
#   'comprehensive',
#   'system',
#   'tracking',
#   'leads',
#   'conclusion'],
#  ['built',
#   'system',
#   'soft',
#   'hard',
#   'metrics',
#   'estimating',
#   'student',
#   'success',
#   'removing',
#   'bias',
#   'admissions',
#   'process',
#   'increasing',
#   'diversity'],
#  ['chief',
#   'technical',
#   'officer',
#   'socialchorus',
#   'inc.',
#   'november',
#   '2012',
#   'july',
#   '2014',
#   'transformed',
#   'brittle',
#   'monolithic',
#   'legacy',
#   'application',
#   'high-performance',
#   'service-oriented',
#   'architecture'],
#  ['converted',
#   'low-velocity',
#   'high-attrition',
#   'engineering',
#   'culture',
#   'happy',
#   'productive',
#   'work',
#   'environment'],
#  ['crafted',
#   'product',
#   'became',
#   'company',
#   "'s",
#   'top',
#   'competitive',
#   'advantage',
#   'via',
#   'better',
#   'user-interviews',
#   'user-testing',
#   'great',
#   'agile',
#   'practices'],
#  ['product',
#   'crafted',
#   'user-focused',
#   'real-time',
#   'advocate',
#   'experience',
#   'became',
#   'top',
#   'competitive',
#   'advantage',
#   'company'],
#  ['designed',
#   'product',
#   'via',
#   'user',
#   'interviews',
#   'rapid',
#   'build-out',
#   'working',
#   'prototype',
#   'finally',
#   'on-time',
#   '6-week',
#   'agile',
#   'execution',
#   'plan'],
#  ['enhanced',
#   'agile',
#   'process',
#   'via',
#   'stricter',
#   'story',
#   'processes',
#   'company-wide',
#   'retrospectives',
#   'user-focused',
#   'practices'],
#  ['engineering',
#   'transformed',
#   'stagnating',
#   'legacy',
#   'application',
#   'robust',
#   'service-oriented',
#   'architecture',
#   'driving',
#   'scale',
#   'development',
#   'speed'],
#  ['separated',
#   'administrative',
#   'facing',
#   'application',
#   'advocate',
#   'facing',
#   'application'],
#  ['crafted',
#   'high-performance',
#   'services',
#   'tracking',
#   'click',
#   'traffic',
#   'promoted',
#   'advocate',
#   'content'],
#  ['authored',
#   '6',
#   'open',
#   'source',
#   'libraries',
#   'including',
#   'mobile',
#   'first',
#   'front-end',
#   'framework',
#   'framework',
#   'developing',
#   'deploying',
#   'services'],
#  ['team',
#   'building',
#   'replaced',
#   'existing',
#   'small',
#   'engineering',
#   'team',
#   'new',
#   'group',
#   'ten',
#   'dedicated',
#   'developers',
#   'director',
#   'engineering',
#   'qa',
#   'staff'],
#  ['rebuilt', 'product', 'team'],
#  ['created',
#   'successful',
#   'internship',
#   'program',
#   'graduates',
#   'converted',
#   'team',
#   'leads'],
#  ['improved',
#   'engineering',
#   'company',
#   'culture',
#   'focus',
#   'problem',
#   'solving',
#   'striving',
#   'practical',
#   'best',
#   'practices'],
#  ['senior',
#   'agile',
#   'consultant',
#   'blazing',
#   'cloud',
#   'november',
#   '2011',
#   'november',
#   '2012',
#   'advised',
#   'several',
#   'companies',
#   'refining',
#   'improving',
#   'development',
#   'agile',
#   'practices',
#   'increase',
#   'velocity'],
#  ['blazing', 'cloud', 'acquired', 'indiegogo', '2013'],
#  ['recruited',
#   'interviewed',
#   'developer',
#   'talent',
#   'intern',
#   'senior',
#   'level',
#   'talents',
#   'ruby',
#   'javascript',
#   'objective-c.',
#   'mentored',
#   'interns',
#   'built',
#   'internal',
#   'company',
#   'best',
#   'practices',
#   'advised',
#   'internal',
#   'business',
#   'product',
#   'decisions'],
#  ['lead',
#   'technical',
#   'direction',
#   'product',
#   'management',
#   'graphically',
#   'intense',
#   'mobile',
#   'first',
#   'application',
#   'html',
#   'javascript'],
#  ['architect',
#   'cohuman',
#   'inc.',
#   'october',
#   '2009',
#   'august',
#   '2011',
#   'second',
#   'employee',
#   'saas',
#   'company',
#   'acquired',
#   'acquired',
#   'mindjet',
#   'currently',
#   'offered',
#   'mindjet',
#   'connect',
#   'task',
#   'management',
#   'solution'],
#  ['planned',
#   'developed',
#   'scalable',
#   'features',
#   'project',
#   'management',
#   'application',
#   'complex',
#   'permissions',
#   'notifications',
#   'systems'],
#  ['designed', 'oauth', 'authenticated', 'api'],
#  ['chief',
#   'technical',
#   'officer',
#   'clerkdogs',
#   'inc.',
#   'february',
#   '2009',
#   'october',
#   '2009',
#   'worked',
#   'ceo',
#   'build',
#   'combination',
#   'flexible',
#   'options',
#   'movie',
#   'recommendations',
#   'turn-key',
#   'whitelist',
#   'solutions',
#   ';',
#   'data',
#   'consumption',
#   'via',
#   'api',
#   'export'],
#  ['data', 'acquired', 'netflix', 'early', '2010'],
#  ['transformed',
#   'rough',
#   'untested',
#   'prototype',
#   'two',
#   'user',
#   'facing',
#   'applications',
#   'one',
#   'admin',
#   'one',
#   'consumers'],
#  ['consumer',
#   'application',
#   'modular',
#   'composable',
#   'application',
#   'could',
#   'graphically',
#   'skinned',
#   'match',
#   'company',
#   'look',
#   'feel',
#   'could',
#   'customized',
#   'components',
#   'according',
#   'needs',
#   'costs'],
#  ['hired', 'managed', 'remote', 'team'],
#  ['pioneered',
#   'agile',
#   'practices',
#   'testing',
#   'increase',
#   'velocity',
#   'stability'],
#  ['lead',
#   'developer',
#   'integral',
#   'impressions',
#   'may',
#   '2008',
#   'january',
#   '2009',
#   'crafted',
#   'content',
#   'management',
#   'system',
#   'sufficiently',
#   'flexible',
#   'company',
#   'could',
#   'rapidly',
#   'build',
#   'informational',
#   'client',
#   'websites',
#   'allowing',
#   'customer',
#   'add',
#   'pages',
#   'customize',
#   'content'],
#  ['managed',
#   'hired',
#   'remote',
#   'contract',
#   'team',
#   'engineers',
#   'infrastructure',
#   'architects'],
#  ['built',
#   'supervised',
#   'hand\u200bcrafted',
#   'custom',
#   'infrastructure',
#   'deployment',
#   'scripts',
#   'web',
#   'solutions'],
#  ['lead',
#   'engineering',
#   'larger',
#   'custom',
#   'web',
#   'solutions',
#   'highly',
#   'customized',
#   'product',
#   'engineering',
#   'needs'],
#  ['founder',
#   'chief',
#   'technical',
#   'officer',
#   'gpc',
#   'inc.',
#   'may',
#   '2005',
#   'january',
#   '2008',
#   'managed',
#   'aspects',
#   'business',
#   'hiring',
#   'contract',
#   'labor',
#   'generating',
#   'documentary',
#   'content',
#   'getting',
#   'press',
#   'national',
#   'publications',
#   'developing',
#   'software'],
#  ['created',
#   'web',
#   'application',
#   'solution',
#   'showcasing',
#   'documentary',
#   'video',
#   'content',
#   'variety',
#   'formats',
#   'sizes',
#   'flexibility',
#   'adjust',
#   'rapidly',
#   'best',
#   'product',
#   'market',
#   'fit'],
#  ['built',
#   'service',
#   'oriented',
#   'suite',
#   'custom',
#   'database',
#   'applications',
#   'scheduling',
#   'managing',
#   'contract',
#   'video',
#   'production',
#   'staff',
#   'interviewees'],
#  ['scaled',
#   'infrastructure',
#   'allow',
#   'thousands',
#   'simultaneous',
#   'streaming',
#   'connections',
#   'special',
#   'events'],
#  ['crafted',
#   'security',
#   'architecture',
#   'capable',
#   'storing',
#   'important',
#   'employment',
#   'personally',
#   'identifiable',
#   'information'],
#  ['engineering',
#   'intern',
#   'cern',
#   'atlas',
#   'project',
#   'lawrence',
#   'berkeley',
#   'national',
#   'laboratory',
#   'january',
#   '2002',
#   'may',
#   '2005',
#   'junior',
#   'member',
#   'five',
#   'person',
#   'mechanical',
#   'engineering',
#   'team',
#   'responsible',
#   'prototyping',
#   'building',
#   'inner',
#   'second',
#   'layer',
#   'atlas',
#   'detector',
#   'cern',
#   '’',
#   'large',
#   'hadron',
#   'collider'],
#  ['rebuilt',
#   'microscope',
#   'calibration',
#   'algorithms',
#   'fix',
#   'manufacturing',
#   'problems',
#   'radial',
#   'sensors'],
#  ['created',
#   'custom',
#   'database',
#   'application',
#   'analyzing',
#   'radiation',
#   'length',
#   'interference',
#   'detector',
#   'readings'],
#  ['devised',
#   'heat',
#   'transfer',
#   'static',
#   'force',
#   'analysis',
#   'simulation',
#   'validate',
#   'models'],
#  ['created',
#   'cad',
#   'designs',
#   'insertion',
#   'system',
#   'central',
#   'detector',
#   'machined',
#   'several',
#   'components'],
#  ['database',
#   'consultant',
#   'visual',
#   'designer',
#   'self-employed',
#   '1995',
#   '2008',
#   'worked',
#   'variety',
#   'customers',
#   'solve',
#   'software',
#   'and/or',
#   'product',
#   'problems',
#   'related',
#   'business',
#   'objectives'],
#  ['created',
#   'custom',
#   'database',
#   'applications',
#   'internal',
#   'business',
#   'processes',
#   'order',
#   'free',
#   'labor',
#   'higher',
#   'level',
#   'business',
#   'concerns'],
#  ['converted',
#   'custom',
#   'database',
#   'applications',
#   'web',
#   'solutions',
#   'increase',
#   'availability',
#   'eye',
#   'towards',
#   'portability',
#   'across',
#   'infrastructure',
#   'data',
#   'security'],
#  ['generated',
#   'product',
#   'specification',
#   'easy',
#   'use',
#   'user',
#   'interfaces',
#   'visual',
#   'design',
#   'needed'],
#  ['selected', 'speaking', 'engagements', 'c'],
#  ['\u200b-',
#   'women',
#   'code',
#   'san',
#   'francisco',
#   '2015',
#   'technical',
#   'presentation',
#   'data',
#   'structure',
#   'c',
#   'programmers',
#   'use',
#   'make',
#   'static',
#   'language',
#   'behave',
#   'dynamically'],
#  ['long',
#   'live',
#   'rubyist',
#   '\u200b-',
#   'women',
#   'code',
#   'san',
#   'francisco',
#   '2015',
#   'talk',
#   'concurrency',
#   'limits',
#   'ruby',
#   'programming',
#   'language'],
#  ['going',
#   'evergreen',
#   '\u200b-',
#   'rubyconf',
#   '2014',
#   'presentation',
#   'engineering',
#   'culture',
#   'principles',
#   'avoid',
#   'technical',
#   'debt',
#   'create',
#   'enjoyable',
#   'ongoing',
#   'software',
#   'work'],
#  ['diversity'],
#  [],
#  [],
#  ['-\u200b',
#   'pivotal',
#   'labs',
#   '2014',
#   'talk',
#   'describes',
#   'benefits',
#   'techniques',
#   'increasing',
#   'engineering',
#   'product',
#   'team',
#   'diversity'],
#  ['coding',
#   'towards',
#   'diversity',
#   '\u200b-',
#   '’',
#   'reilly',
#   'fluent',
#   'conference',
#   '2013',
#   'talk',
#   'takes',
#   'programmatic',
#   'approach',
#   'solving',
#   'diversity',
#   'problem',
#   'tech',
#   'industry'],
#  ['aqua',
#   'cool',
#   'clean',
#   'drink',
#   'ruby',
#   'object',
#   'persistence',
#   '-\u200b',
#   'rubyconf',
#   '2009',
#   'proof',
#   'concept',
#   'talk',
#   'creating',
#   'transparent',
#   'persistence',
#   'layer',
#   'pure',
#   'ruby',
#   'objects'],
#  ['selected',
#   'technical',
#   'writing',
#   'choose',
#   'design',
#   'architecture',
#   '\u200b-',
#   '18f',
#   'blog',
#   'https',
#   '//18f.gsa.gov/2015/11/17/choose-design-over-architecture',
#   'inverting',
#   'architectural',
#   'emphasis'],
#  ['voted',
#   'front',
#   'page',
#   'hacker',
#   'news',
#   'one',
#   'popular',
#   'post',
#   '18f',
#   'blog',
#   '2015'],
#  ['code',
#   'symptom',
#   '\u200b-',
#   'personal',
#   'blog',
#   'https',
#   '//medium.com/',
#   '@',
#   'rubyghetto/the-code-is-just-the-symptom-c77f43b29320',
#   'two',
#   'different',
#   'companies',
#   'leadership',
#   'conway',
#   '’',
#   'law',
#   'lead',
#   'problems',
#   'seen',
#   'deep',
#   'code'],
#  ['60,000', 'views'],
#  ['voted', 'front', 'page', 'hacker', 'news'],
#  ['education',
#   'university',
#   'california',
#   'berkeley',
#   'california',
#   '2',
#   '\u200b',
#   '002',
#   '2004',
#   'advanced',
#   'technical',
#   'coursework',
#   'bs',
#   'mechanical',
#   'engineering',
#   'uc',
#   'berkeley',
#   'extension',
#   'san',
#   'francisco',
#   'california',
#   '1',
#   '\u200b',
#   '998',
#   '1999',
#   'professional',
#   'coursework',
#   'software',
#   'database',
#   'design',
#   'san',
#   'francisco',
#   'art',
#   'institute',
#   'san',
#   'francisco',
#   'california',
#   '\u200b-',
#   '1993',
#   'bfa',
#   'painting',
#   'volunteer',
#   'work',
#   'board',
#   'directors',
#   'industry',
#   'technical',
#   'advisor',
#   'women',
#   'code',
#   'inc.',
#   'december',
#   '2013',
#   'june',
#   '2015',
#   '\\n',
#   'nirali',
#   'deliwala',
#   '301-683-4339',
#   'nirali18',
#   '@',
#   'umd.edu',
#   '8125',
#   '48th',
#   'avenue',
#   'apt',
#   '520',
#   'college',
#   'park',
#   'md',
#   '20740',
#   'education',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'md',
#   'expected',
#   'may',
#   '2018',
#   'masters',
#   'science',
#   'telecommunications',
#   'relevant',
#   'coursework',
#   'networks',
#   'protocols',
#   'ii',
#   'network',
#   'programming',
#   'using',
#   'c',
#   'digital',
#   'communication',
#   'systems',
#   'network',
#   'design',
#   'configuration',
#   'lab',
#   'cellular',
#   'communication',
#   'networks',
#   'telecoms',
#   'marketing',
#   'management',
#   'k.j'],
#  ['somaiya',
#   'college',
#   'engineering',
#   'autonomous',
#   'affiliated',
#   'university',
#   'mumbai',
#   '2011-2015',
#   'bachelor',
#   'engineering',
#   'electronics',
#   'relevant',
#   'coursework',
#   'networks',
#   'protocols',
#   'communication',
#   'networks',
#   'digital',
#   'communication',
#   'coding',
#   'techniques',
#   'technical',
#   'experience',
#   'accenture',
#   'services',
#   'pvt'],
#  ['ltd.',
#   'paid',
#   'june',
#   '2015',
#   '–',
#   'june',
#   '2016',
#   'associate',
#   'software',
#   'engineer',
#   'ase',
#   'project',
#   'project',
#   'name',
#   'lyondell',
#   'basell',
#   'chemical',
#   'company',
#   'objects',
#   'worked',
#   'worked',
#   'design',
#   'development',
#   'testing',
#   'support',
#   'sap',
#   'abap',
#   'developer',
#   'meet',
#   'business',
#   'needs'],
#  ['analyzed', 'functional', 'specification'],
#  ['created', 'technical', 'specification'],
#  ['developed',
#   'custom',
#   'objects',
#   'reports',
#   'email',
#   'standardization',
#   'sap',
#   'scripts',
#   'adobe',
#   'forms',
#   'skills',
#   'networking',
#   'software',
#   'cisco',
#   'packet',
#   'tracer',
#   'wireshark',
#   'programming',
#   'language',
#   'c',
#   'c++',
#   'java',
#   'sap',
#   'abap',
#   'html',
#   'python',
#   'operating',
#   'systems',
#   'windows',
#   'android',
#   'software',
#   '’',
#   'matlab',
#   'scilab',
#   'kiel',
#   'pspice',
#   'labview',
#   'eagle',
#   'proteus',
#   'autocad',
#   'microwind',
#   'projects',
#   'design',
#   'ip',
#   'domain',
#   'dossier',
#   'system',
#   'december',
#   '2016',
#   '•designed',
#   'client-server',
#   'system',
#   'using',
#   'socket',
#   'programming',
#   'c',
#   'linux',
#   'environment',
#   'using',
#   'tcp/ip',
#   'protocol'],
#  ['•implemented',
#   'server',
#   'side',
#   'using',
#   'linked',
#   'list',
#   'performs',
#   'serval',
#   'tasks',
#   'depending',
#   'request',
#   'code',
#   'passed',
#   'client',
#   '-to',
#   'find',
#   'add',
#   'delete',
#   'get',
#   'least',
#   'requested',
#   'record',
#   'data',
#   'base'],
#  ['-reject',
#   'inquiry',
#   'another',
#   'inquiry',
#   'received',
#   'originated',
#   'address',
#   'last',
#   '10',
#   'seconds'],
#  ['-shutdown', 'connection'],
#  ['•generated', 'log', 'file', 'events', 'occur', 'server', 'side'],
#  ['line',
#   'log',
#   'file',
#   'starts',
#   'date',
#   'time',
#   'provides',
#   'detailed',
#   'information',
#   'event'],
#  ['design',
#   'facial',
#   'emotion',
#   'recognition',
#   'system',
#   'may',
#   '2015',
#   '•detected',
#   'different',
#   'emotions',
#   'depicted',
#   'image',
#   'using',
#   'matlab',
#   '•accomplished',
#   'training',
#   'images',
#   'using',
#   'artificial',
#   'neural',
#   'network'],
#  ['implemented',
#   'image',
#   'processing',
#   'techniques',
#   'remove',
#   'unwanted',
#   'noise',
#   'background'],
#  ['classified',
#   'emotion',
#   'depicted',
#   'image',
#   'one',
#   'following',
#   'category-',
#   'happy',
#   'sad',
#   'neutral',
#   'angry',
#   'testing'],
#  ['design',
#   '8-contestant',
#   'quiz',
#   'buzzer',
#   'december',
#   '2014',
#   'developed',
#   'quiz',
#   'buzzer',
#   'using',
#   'microcontroller',
#   '89c51'],
#  ['executed',
#   'code',
#   'keil',
#   'simulated',
#   'using',
#   'proteus',
#   'implemented',
#   'pcb'],
#  ['design',
#   'electronic',
#   'harmonium',
#   'december',
#   '2013',
#   'based',
#   'ic-555',
#   'worked',
#   'oscillator'],
#  ['used',
#   'pcb',
#   '15',
#   'parallel',
#   'strips',
#   'strip',
#   'corresponding',
#   'one',
#   'note'],
#  ['additional',
#   'activities',
#   'participated',
#   'volunteer',
#   'technical',
#   'festival',
#   'abhyantriki',
#   'publicity',
#   'event'],
#  ['2013',
#   'assisted',
#   'event',
#   'head',
#   'various',
#   'events',
#   'cultural',
#   'festival',
#   'symphony'],
#  ['2014',
#   'worked',
#   'accenture',
#   'colleagues',
#   'hope',
#   'foundation',
#   'non-profit',
#   'organization',
#   'mumbai'],
#  ['2015',
#   'https',
#   '//www.linkedin.com/in/niralideliwala\\n',
#   'muhammad',
#   'afolayan',
#   '1129',
#   'quantril',
#   'way♦',
#   'baltimore',
#   'md',
#   '21205',
#   '240-593-1192',
#   '♦',
#   'afolayan.muhammad',
#   '@',
#   'gmail.com',
#   'education',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'bachelor',
#   'science',
#   '[',
#   'economics',
#   ']',
#   'class',
#   '2017',
#   '[',
#   'college',
#   'park',
#   'scholars',
#   ']',
#   'august',
#   '2011',
#   '–',
#   'may',
#   '2013',
#   '\uf0b7',
#   'developed',
#   'leadership',
#   'skills',
#   'experiences',
#   'internships',
#   'research',
#   'community',
#   'service'],
#  ['work',
#   'experience',
#   'bk',
#   'motors',
#   'baltimore',
#   'md',
#   'marketing/',
#   'administrative',
#   'june',
#   '2009',
#   '–',
#   'august',
#   '2011',
#   '\uf0b7',
#   'analyzed',
#   'prospective',
#   'client',
#   'portfolios',
#   'find',
#   'suitable',
#   'fit',
#   'client',
#   'company'],
#  ['\uf0b7',
#   'established',
#   'improved',
#   'client',
#   'communications',
#   ';',
#   'maintained',
#   'ongoing',
#   'relationships'],
#  ['\uf0b7',
#   'addressed',
#   'client',
#   'inquiries',
#   ';',
#   'interpreted',
#   'delivered',
#   'information',
#   ';',
#   'proposed',
#   'suggestions'],
#  ['conferences',
#   'visitors',
#   'services',
#   'customer',
#   'service/',
#   'hospitality',
#   '\uf0b7',
#   'planned',
#   'coordinated',
#   'executive',
#   'events'],
#  ['\uf0b7', 'trained', 'community', 'assistant', 'ca'],
#  ['college',
#   'park',
#   'md',
#   'summer',
#   '2013',
#   '–',
#   'summer',
#   '2014',
#   'footnotes',
#   'café',
#   'college',
#   'park',
#   'md',
#   'customer',
#   'service',
#   'february',
#   '2015-present',
#   '\uf0b7',
#   'often',
#   'said',
#   'bring',
#   'positive',
#   'atmosphere',
#   'work',
#   'regularly'],
#  ['\uf0b7',
#   'immensely',
#   'helped',
#   'sales',
#   'team',
#   'leader',
#   'taking',
#   'initiative'],
#  ['\uf0b7',
#   'gained',
#   'positive',
#   'feedback',
#   'customers',
#   'supervisors',
#   'exceptional',
#   'customer',
#   'service'],
#  ['money',
#   'one',
#   'federal',
#   'credit',
#   'union',
#   'account',
#   'associate',
#   '\uf0b7',
#   'promoted',
#   'overall',
#   'efficiency',
#   'bank',
#   'making',
#   'several',
#   'contributions',
#   'management'],
#  ['\uf0b7', 'performing', 'clerical', 'duties'],
#  ['\uf0b7', 'selling', 'financial', 'services'],
#  ['\uf0b7', 'supporting', 'bank', 'sales', 'identifying', 'customer', 'needs'],
#  ['greenbelt',
#   'md',
#   'leadership',
#   'experience',
#   'campus',
#   'mentoring',
#   'bigs',
#   'college',
#   'park',
#   'md',
#   'mentor',
#   'fall',
#   '2012',
#   '–',
#   'spring',
#   '2013',
#   '\uf0b7',
#   'big/little',
#   'mentoring',
#   'program',
#   ';',
#   'assisted',
#   'freshman',
#   'transition',
#   'high',
#   'school',
#   'college'],
#  ['randallstown',
#   'islamic',
#   'center',
#   'youth',
#   'leader',
#   '\uf0b7',
#   'regularly',
#   'took',
#   'charge',
#   'important',
#   'tasks',
#   'activities',
#   'around',
#   'mosque',
#   '\uf0b7',
#   'overseeing',
#   'development',
#   'personal',
#   'development',
#   'youth',
#   'members'],
#  [],
#  ['skills',
#   'volunteer',
#   'interests',
#   'skills',
#   '[',
#   'advanced',
#   'use',
#   'microsoft',
#   'word',
#   'typing',
#   '70',
#   'words',
#   'per',
#   'minute',
#   'powerpoint',
#   'excel',
#   ']',
#   'languages',
#   '[',
#   'fluent',
#   'yoruba',
#   ']',
#   'volunteer',
#   'several',
#   'community',
#   'service',
#   'events',
#   'incentive',
#   'awards',
#   'scholarship',
#   'program'],
#  ['affiliations',
#   'african',
#   'student',
#   'association',
#   'asa',
#   ';',
#   'muslim',
#   'student',
#   'association',
#   'msa',
#   ';',
#   'soccer',
#   'club',
#   'interests',
#   'soccer',
#   'problem',
#   'solving',
#   'technology',
#   'gaming',
#   'weightlifting',
#   'art'],
#  ['randallstown',
#   'md',
#   'spring',
#   '2012',
#   '\\n',
#   'terence',
#   'mcpartland',
#   'pmp',
#   'designer',
#   'problem',
#   'solver',
# ...
#   '1987',
#   '1993',
#   'network',
#   'manager/customer',
#   'service',
#   'sandy',
#   'spring',
#   'national',
#   'bank',
#   '1985',
#   '1987',
#   'customer',
#   'service',
#   'representative',
#   'education',
#   'bachelor',
#   'arts',
#   'liberal',
#   'arts',
#   'specialization',
#   'business',
#   'cum',
#   'laude',
#   'american',
#   'university',
#   'washington',
#   'd.c.',
#   'joseph',
#   'cristiano',
#   'jr.',
#   'paradyme',
#   'management',
#   'inc'],
#  ['page', '3', '3', '\\n', 'ishmeet', 'singh', '8125', '48th', 'ave', 'apt'],
#  ['514',
#   'college',
#   'park',
#   'md',
#   '20740',
#   '240',
#   '714-2866',
#   'ishmeetsingh1973',
#   '@',
#   'gmail.com',
#   'education',
#   'university',
#   'maryland',
#   'ms',
#   'telecommunications',
#   'engineering',
#   '–',
#   '3.76',
#   'gpa',
#   'college',
#   'park',
#   'md',
#   'expected',
#   'may',
#   '2018',
#   'itm',
#   'university',
#   'b.tech',
#   'electronics',
#   'communications',
#   '–',
#   '3.7',
#   'gpa',
#   'gurgaon',
#   'india',
#   'may',
#   '2015',
#   'experience',
#   'compro',
#   'technologies',
#   'new',
#   'delhi',
#   'india',
#   'associate',
#   'software',
#   'testing',
#   'engineer',
#   'feb',
#   '2016',
#   '–',
#   'july',
#   '2016',
#   '\uf0b7',
#   'independently',
#   'functional',
#   'validation',
#   'gradeit',
#   'pct',
#   'applications',
#   '\uf0b7',
#   'coordinated',
#   'development',
#   'team',
#   'regarding',
#   'bug',
#   'fixes',
#   'smooth',
#   'delivery',
#   'project',
#   'content',
#   'client',
#   '\uf0b7',
#   'configured',
#   'new',
#   'projects',
#   'mb',
#   'unit',
#   'regression',
#   'testing',
#   'aircel',
#   'ltd.',
#   'new',
#   'delhi',
#   'india',
#   'intern',
#   'may',
#   '2014',
#   '–',
#   'july',
#   '2014',
#   '\uf0b7',
#   'studied',
#   'gsm',
#   'network',
#   'detail',
#   'attained',
#   'practical',
#   'knowledge',
#   'visiting',
#   'msc',
#   'site',
#   '\uf0b7',
#   'assisted',
#   'senior',
#   'personnel',
#   'resolve',
#   'issues',
#   'like',
#   'call',
#   'drop',
#   'call',
#   'muting',
#   'network',
#   'registration',
#   'failure',
#   'etc'],
#  ['siemens',
#   'ltd.',
#   'gurgaon',
#   'india',
#   'intern',
#   'june',
#   '2013',
#   '–',
#   'july',
#   '2013',
#   '\uf0b7',
#   'analyzed',
#   'non-conformance',
#   'costs',
#   'data',
#   'various',
#   'plants',
#   'across',
#   'nation',
#   'published',
#   'report',
#   '\uf0b7',
#   'collaborated',
#   'various',
#   'departments',
#   'perform',
#   'root',
#   'cause',
#   'analysis',
#   'issues',
#   'academic',
#   'projects',
#   'edge',
#   'detection',
#   'images',
#   'using',
#   'matlab',
#   '\uf0b7',
#   'developed',
#   'algorithm',
#   'matlab',
#   'identify',
#   'discontinuities',
#   'surface',
#   '\uf0b7',
#   'designed',
#   'gui',
#   'serve',
#   'functions',
#   'like',
#   'open',
#   'save',
#   'clear',
#   'close',
#   'et',
#   'al'],
#  ['aug',
#   '2014',
#   '–',
#   'may',
#   '2015',
#   'carry-skip',
#   'adder',
#   'using',
#   'cadence',
#   'aug',
#   '2014',
#   '–',
#   'dec',
#   '2014',
#   '\uf0b7',
#   'performed',
#   'transient',
#   'analysis',
#   'using',
#   'virtuouso',
#   'make',
#   'quantitative',
#   'qualitative',
#   'comparison',
#   'various',
#   'adders',
#   '\uf0b7',
#   'published',
#   'research',
#   'paper',
#   'international',
#   'journal',
#   'vlsi',
#   'system',
#   'design',
#   'communication',
#   'systems',
#   'ijvdcs',
#   'low',
#   'power',
#   'techniques',
#   'vlsi',
#   'using',
#   'cadence',
#   'aug',
#   '2014',
#   '–',
#   'dec',
#   '2014',
#   '\uf0b7',
#   'computed',
#   'transient',
#   'analysis',
#   'virtuouso',
#   'implementing',
#   'techniques',
#   'like',
#   'stacking',
#   'mtcmos',
#   'reduce',
#   'leakage',
#   'power',
#   'cmos',
#   'circuit',
#   'clap',
#   'counter',
#   'using',
#   '8051',
#   'micro',
#   'controller',
#   'dec',
#   '2013',
#   '–',
#   'may',
#   '2014',
#   '\uf0b7',
#   'integrated',
#   'sound',
#   'sensor',
#   'at89c51',
#   'lcd',
#   'module',
#   'increased',
#   'count',
#   '1',
#   'every',
#   'time',
#   'sound',
#   'produced',
#   '\uf0b7',
#   'verified',
#   'code',
#   'keil',
#   'µvision',
#   'circuit',
#   'isis',
#   'proteus',
#   '7',
#   'implementing',
#   'circuit',
#   'pcb',
#   'board',
#   'skills',
#   'programming',
#   'skills',
#   'c',
#   'python',
#   'protocols',
#   'known',
#   'rip',
#   'rip',
#   'v2',
#   'ospf',
#   'bgp',
#   'igrp',
#   'eigrp',
#   'framework',
#   'mbunit',
#   'database',
#   'sql',
#   'server',
#   '2008',
#   'applications',
#   'microsoft',
#   'word',
#   'excel',
#   'access',
#   'powerpoint',
#   'keil',
#   'virtuoso',
#   'activities',
#   'subah',
#   '\uf0b7',
#   'worked',
#   'local',
#   'ngo',
#   'projects',
#   'focused',
#   'health',
#   'poverty',
#   'may',
#   '2014',
#   '–',
#   'may',
#   '2016',
#   'data',
#   'compilation',
#   'team',
#   '\uf0b7',
#   'formulated',
#   'shared',
#   'results',
#   'various',
#   'events',
#   'annual',
#   'university',
#   'cultural',
#   'fest',
#   'jury',
#   'global',
#   'young',
#   'leaders',
#   'conference',
#   'gylc',
#   '\uf0b7',
#   'participated',
#   'model',
#   'un',
#   'washington',
#   'dc',
#   'new',
#   'york',
#   'representing',
#   'russian',
#   'federation',
#   'oct',
#   '2012',
#   'june',
#   '2009',
#   '\\n',
#   'samyak',
#   'shah',
#   '3406',
#   'tulane',
#   'drive',
#   '21',
#   'hyattsville',
#   'md',
#   '20783',
#   'education',
#   '240',
#   '-360-6597',
#   'samyak.shah',
#   '@',
#   'rhsmith.umd.edu',
#   'robert',
#   'h.',
#   'smith',
#   'school',
#   'business',
#   'university',
#   'maryland',
#   'college',
#   'park',
#   'md',
#   'aug',
#   '2015-',
#   'dec',
#   '2016',
#   'master',
#   'science',
#   'ms',
#   'information',
#   'systems',
#   'gre',
#   '325/340',
#   ';',
#   'gpa',
#   '3.8/4',
#   'data',
#   'networks',
#   'infrastructure',
#   'database',
#   'management',
#   'system',
#   'managing',
#   'digital',
#   'markets',
#   'data',
#   'models',
#   'decisions',
#   'big',
#   'data',
#   'data',
#   'mining',
#   'predictive',
#   'analytics',
#   'business',
#   'process',
#   'analysis',
#   'strategic',
#   'k',
#   'j',
#   'somaiya',
#   'college',
#   'engineering',
#   'university',
#   'mumbai',
#   'jul',
#   '2011-may',
#   '2015',
#   'bachelor',
#   'engineering-computer',
#   'engineering',
#   '–first',
#   'class',
#   'publications',
#   '–',
#   '‘',
#   'somewhat',
#   'homomorphic',
#   'encryption',
#   'key',
#   'management',
#   'protocol',
#   '’',
#   '‘',
#   'big',
#   'data',
#   'analytics',
#   'using',
#   'r',
#   '’',
#   'experience',
#   'rak',
#   'commodities',
#   'mumbai',
#   'india',
#   'analyst',
#   'intern',
#   'jun',
#   '2014-jul',
#   '2014',
#   '\uf0a7',
#   'provided',
#   'commodities',
#   'analysis',
#   'valuation',
#   '20',
#   'valued',
#   'customers',
#   'firm',
#   '\uf0a7',
#   'performed',
#   'data',
#   'analysis',
#   'using',
#   'excel',
#   '–',
#   'vlookup',
#   'visual',
#   'basic',
#   'macros',
#   'pivot',
#   'tables',
#   'mark-to',
#   'market',
#   'calculation',
#   'helped',
#   'increase',
#   'prediction',
#   'accuracy',
#   'commodities',
#   'pricing',
#   'projects',
#   'encryption',
#   'cloud',
#   'computing',
#   'jul',
#   '2014-jun',
#   '2015',
#   '\uf0a7',
#   'somewhat',
#   'homomorphic',
#   'encryption',
#   'cloud',
#   '-achieved',
#   'encryption',
#   'amazon',
#   'web',
#   'services',
#   'dynamodb',
#   'nosql',
#   'cloud',
#   'database',
#   'using',
#   'java',
#   'aws',
#   'sdk',
#   'reducing',
#   'time',
#   'taken',
#   'query',
#   'processing',
#   'encrypted',
#   'data',
#   'following',
#   'software',
#   'development',
#   'lifecycle',
#   '\uf0a7',
#   'prepared',
#   'software',
#   'requirement',
#   'specification',
#   'srs',
#   'document',
#   'software',
#   'architecture',
#   'project',
#   'management',
#   'plan',
#   'testing',
#   'user',
#   'manual',
#   'using',
#   'rational',
#   'rose',
#   'visio',
#   'customer',
#   'care',
#   'database',
#   'management',
#   'sep',
#   '2015-dec',
#   '2015',
#   '\uf0a7',
#   'built',
#   'suite',
#   'database',
#   'backend',
#   'sql',
#   'server',
#   '2012',
#   'tables',
#   'views',
#   'transactional',
#   'queries',
#   'frontend',
#   'salesforce.com',
#   'using',
#   'reports',
#   'dashboards',
#   'views',
#   'workflow',
#   'rules',
#   'validation',
#   'rules',
#   'permission',
#   'sets',
#   'page',
#   'layouts',
#   'banking',
#   'data',
#   'data',
#   'analysis',
#   'using',
#   'tableau',
#   'jan',
#   '2016-feb',
#   '2016',
#   '\uf0a7',
#   'investigated',
#   'dognition',
#   'company',
#   'data',
#   'set',
#   'designed',
#   'structured',
#   'pyramid',
#   'analysis',
#   'plan',
#   'analyzed',
#   'using',
#   'tableau',
#   'importing',
#   'excel',
#   'data',
#   'tableau',
#   'creating',
#   'data',
#   'views',
#   'dashboard',
#   'filters',
#   'parameters',
#   'calculated',
#   'fields',
#   'published',
#   'recommendation',
#   'report',
#   'client-',
#   'based',
#   'project',
#   'following',
#   'scrum',
#   'methodology',
#   'feb',
#   '2016-',
#   'may',
#   '2016',
#   '\uf0a7',
#   'developing',
#   'application',
#   'student',
#   'peer',
#   'reviews',
#   'related',
#   'analytics',
#   'part',
#   'scrum',
#   'team',
#   'java',
#   'sql',
#   'using',
#   'ibm',
#   'bluemix',
#   'web',
#   'services',
#   'also',
#   'participating',
#   'scrum',
#   'ceremonies',
#   'data',
#   'mining',
#   'predictive',
#   'analytics',
#   'using',
#   'r',
#   '\uf0a7',
#   'working',
#   'rossman',
#   'stores',
#   'dataset',
#   'analyze',
#   'data',
#   'using',
#   'knn',
#   'naïve',
#   'bayes',
#   'classification',
#   'regression',
#   'algorithms',
#   'predict',
#   'store',
#   'sales',
#   '7',
#   'weeks'],
#  ['leadership',
#   'youth',
#   'vision',
#   'consultant',
#   'hanoi',
#   'vietnam',
#   'jun',
#   '2013-',
#   'jul',
#   '2013',
#   '\uf0a7',
#   'planned',
#   'managed',
#   '‘',
#   'vietnam',
#   'youth',
#   'icon',
#   '’',
#   'project',
#   'including',
#   'four',
#   'day',
#   'camps',
#   'event',
#   'named',
#   'international',
#   'youth',
#   'day'],
#  ['worked',
#   '15',
#   'interns',
#   '12',
#   'different',
#   'countries',
#   'month',
#   'catered',
#   'around',
#   '150',
#   'delegates',
#   'aiesec',
#   'navi',
#   'mumbai',
#   'india',
#   'feb',
#   '2013-feb',
#   '2015',
#   '\uf0a7',
#   'arranged',
#   'youth',
#   'leadership',
#   'conference',
#   'core',
#   'committee',
#   'logistics',
#   'february',
#   '2015',
#   'silvassa',
#   'india',
#   'catering',
#   '400',
#   'delegates',
#   'country',
#   '\uf0a7',
#   'led',
#   'team',
#   '5',
#   'people',
#   'team',
#   'leader',
#   'human',
#   'resources',
#   'january',
#   '2014-december',
#   '2014',
#   'responsible',
#   'talent',
#   'planning',
#   'acquisition',
#   'training',
#   'retention',
#   'managed',
#   'around',
#   '40',
#   'employees',
#   '\uf0a7',
#   'acted',
#   'team',
#   'leader',
#   'international',
#   'student',
#   'exchange',
#   'social',
#   'january',
#   '2013-',
#   'june',
#   '2013',
#   'increased',
#   'number',
#   'exchanges',
#   '250',
#   'additional',
#   'information',
#   '\uf0a7',
#   'technical',
#   'java',
#   'c++',
#   'html',
#   'sql',
#   'salesforce.com',
#   'tableau',
#   'r',
#   'wireshark',
#   'microsoft',
#   'excel',
#   'statistical',
#   'tools',
#   '@',
#   'risk',
#   'precisiontree',
#   'stattools',
#   'solvertable',
#   'visio',
#   'rational',
#   'rose',
#   'python',
#   'sharepoint',
#   'hadoop',
#   'impala',
#   'pig',
#   'hive',
#   '[',
#   'may',
#   '2016',
#   ']',
#   'spark',
#   '[',
#   'may',
#   '2016',
#   ']',
#   'microsoft',
#   'project',
#   'management',
#   'ms',
#   'access',
#   'weka',
#   '\uf0a7',
#   'online',
#   'courses',
#   'intermediate',
#   'r',
#   'data',
#   'analysis',
#   'r',
#   'machine',
#   'learning',
#   'r',
#   'software',
#   'processes',
#   'agile',
#   'practices',
#   'amazon',
#   'web',
#   'services-',
#   'big',
#   'data',
#   'technology',
#   'fundamentals',
#   'hadoop',
#   'application',
#   'development',
#   'framework'],
#  ['\\n',
#   'arpit',
#   'kapoor',
#   '8125',
#   '48thave',
#   '509',
#   '■',
#   'college',
#   'park',
#   'md',
#   '20740',
#   '■',
#   '240.481.4996',
#   '■',
#   'arpit.kapoor',
#   '@',
#   'rhsmith.umd.edu',
#   '■',
#   'www.linkedin.com/in/arpit-kapoor',
#   'education',
#   'robert',
#   'h.',
#   'smith',
#   'school',
#   'business',
#   'university',
#   'maryland',
#   'december',
#   '2017',
#   'master',
#   'science',
#   'information',
#   'systems',
#   'gre',
#   '322',
#   'coursework',
#   'data',
#   'models',
#   'decisions',
#   'dbms',
#   'managing',
#   'digital',
#   'business',
#   'markets',
#   'bigdata',
#   'data',
#   'mining',
#   'predictive',
#   'analysis',
#   'strategic',
#   'business',
#   'process',
#   'analysis',
#   'data',
#   'networks',
#   'infrastructure',
#   'thapar',
#   'university',
#   'patiala',
#   'india',
#   'bachelor',
#   'engineering',
#   'major',
#   'electronics',
#   'instrumentation',
#   'control',
#   'june',
#   '2013',
#   'technical',
#   'skills',
#   'programming',
#   'languages',
#   'c',
#   'c++',
#   'perl',
#   'shell',
#   'scripting',
#   'sql',
#   'python',
#   'tools',
#   'cygwin',
#   'iperf',
#   'tera',
#   'term',
#   'perl',
#   'modules',
#   'wireshark',
#   'jenkins',
#   'fail2ban',
#   'apache-tomcat',
#   'git',
#   'ansible',
#   'microsoft',
#   'office',
#   'tableau',
#   'excel',
#   'salesforce',
#   'sql',
#   'management',
#   'studio',
#   'lucid',
#   'chart',
#   'operating',
#   'systems',
#   'windows',
#   'linux',
#   'mac',
#   'os',
#   'x',
#   'professional',
#   'experience',
#   'lybrate',
#   'india',
#   'pvt',
#   'ltd',
#   'faridabad',
#   'india',
#   '2015',
#   '–',
#   '2016',
#   'devops',
#   'engineer',
#   '\uf0a7',
#   'managed',
#   '3-member',
#   'team',
#   'responsible',
#   'daily',
#   'build',
#   'releases',
#   'maintaining',
#   'website',
#   'support',
#   '3000',
#   'daily',
#   'transactions'],
#  ['jenkins',
#   'aws',
#   'apache-tomcat',
#   '\uf0a7',
#   'planned',
#   'developed',
#   'automation',
#   'frameworks',
#   'analyzed',
#   'implemented',
#   'new',
#   'tools',
#   'methods',
#   'scale',
#   'technology'],
#  ['shell',
#   'sql',
#   'ansible',
#   '\uf0a7',
#   'installed',
#   'implemented',
#   'security',
#   'programs',
#   '8',
#   'servers',
#   'monitored',
#   'network',
#   'inefficiencies'],
#  ['\uf0a7',
#   'analyzed',
#   'user',
#   'feedback',
#   'reported',
#   'critical',
#   'software',
#   'bugs',
#   'resulting',
#   'customer',
#   'satisfaction',
#   'relationship',
#   'management'],
#  ['\uf0a7',
#   'supervised',
#   'configuration',
#   'tool',
#   'prevent',
#   'phishing',
#   'attacks'],
#  ['helped',
#   'reduce',
#   'constant',
#   'monitoring',
#   'procedures',
#   'workload',
#   'bringing',
#   'server',
#   'overloads',
#   '50'],
#  ['fail2ban',
#   'cavium',
#   'networks',
#   'india',
#   'pvt',
#   'ltd',
#   'bangalore',
#   'india',
#   '2013',
#   '–',
#   '2015',
#   'system',
#   'validation',
#   'engineer',
#   '\uf0a7',
#   'coordinated',
#   'testing',
#   'across',
#   '4',
#   'offices',
#   'ensure',
#   'product',
#   'testing',
#   'end',
#   'end',
#   'testing',
#   'ipsec',
#   'testing',
#   '3',
#   'products'],
#  ['lte',
#   'small',
#   'cells',
#   'cellular',
#   'base',
#   'stations',
#   '\uf0a7',
#   'collaborated',
#   'developers',
#   'clients',
#   'site',
#   'teams',
#   'creating',
#   'testing',
#   'field',
#   'conditions',
#   'ensure',
#   'reliability',
#   'product'],
#  ['\uf0a7',
#   'created',
#   'executed',
#   'test',
#   'plans',
#   'performed',
#   'rigorous',
#   'testing',
#   'release',
#   'features',
#   'ensure',
#   'delivery',
#   'efficient',
#   'functional',
#   'product'],
#  ['\uf0a7',
#   'conducted',
#   'quality',
#   'functional',
#   'testing',
#   'reported',
#   'software',
#   'bugs',
#   'sample',
#   '128',
#   'users',
#   'incorporated',
#   'network',
#   'feedback'],
#  ['tm500',
#   'bugzilla',
#   'wireshark',
#   '\uf0a7',
#   'developed',
#   'automation',
#   'framework',
#   'end',
#   'end',
#   'testing'],
#  ['used',
#   'across',
#   '3',
#   'teams',
#   'decreasing',
#   'manual',
#   'work',
#   'mistakes',
#   '75'],
#  ['perl',
#   'shell',
#   'socket',
#   'programming',
#   'projects',
#   'university',
#   'rankings',
#   'database',
#   '\uf0a7',
#   'gathered',
#   'extracted',
#   'processed',
#   'data',
#   'regarding',
#   'three',
#   'courses',
#   'mba',
#   'msba',
#   'msis',
#   'across',
#   'universities',
#   'us',
#   'design',
#   'aggregator'],
#  ['\uf0a7',
#   'performed',
#   'data',
#   'transformation',
#   'upload',
#   'sql',
#   'server',
#   'using',
#   'sql',
#   'server',
#   'management',
#   'studio'],
#  ['\uf0a7',
#   'used',
#   'salesforce',
#   'help',
#   'visualize',
#   'data',
#   'using',
#   'dashboards',
#   'reports'],
#  ['telecom',
#   'services',
#   'analysis',
#   '\uf0a7',
#   'worked',
#   'team',
#   '5',
#   'analyze',
#   'provide',
#   'technology',
#   'consulting',
#   'telecom',
#   'service',
#   'provider',
#   'based',
#   'zambia'],
#  ['\\n',
#   'binod',
#   'kumar',
#   'singh',
#   '22650',
#   'shining',
#   'harness',
#   'street',
#   'clarksburg',
#   'md',
#   '20871',
#   'c',
#   '262-309-3367',
#   'bks.iitr',
#   '@',
#   'gmail.com',
#   'professional',
#   'summary',
#   '13',
#   'years',
#   'hands-on',
#   'experience',
#   'industry',
#   'expertise',
#   'design/development',
#   'delivery',
#   'client',
#   'server',
#   'applications',
#   'using',
#   'java',
#   'j2ee'],
#  ['keep',
#   'learning',
#   'applying',
#   'new',
#   'technology/feature',
#   'live',
#   'ongoing',
#   'projects'],
#  ['possess',
#   'blend',
#   'business',
#   'management',
#   'technical',
#   'skills',
#   'ability',
#   'translate',
#   'business',
#   'needs',
#   'real',
#   'world',
#   'solutions'],
#  ...]

# %%
from gensim.models import Phrases

#Create bigram model
bigram_model_path = 'bigram_model'

bigram_model = Phrases(unigram_resume)
bigram_model.save(bigram_model_path)

# %%
# Create bigram words
def create_bigram (unigram_resume):
    bigram_model = Phrases.load(bigram_model_path)
    bigram_resume = [bigram_model[sentence] for sentence in unigram_resume]
    return bigram_resume

# %%
bigram_resume = create_bigram(unigram_resume)
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")

# %%
#Create trigram model 
trigram_model_path = 'trigram_model'

trigram_model = Phrases(bigram_resume)
trigram_model.save(trigram_model_path)

# %%
# Create trigram words
def create_trigram (bigram_resume):
    trigram_model = Phrases.load(trigram_model_path)
    trigram_resume = [trigram_model[sentence] for sentence in bigram_resume]
    return trigram_resume

# %%
trigram_resume = create_trigram(bigram_resume)
trigram_resume
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# [['jee',
#   'kang',
#   '3711',
#   'campus',
#   'drive',
#   'apt',
#   '139',
#   'college_park_md',
#   '4439447487',
#   'jwk1151',
#   '@_gmail.com_education_university',
#   'maryland_college_park',
#   'dual',
#   'degree',
#   'cumulative_gpa',
#   '3.7',
#   'anticipated',
#   'fall',
#   '2018',
#   'b.s'],
#  ['physiology', 'neurobiology', 'b.s'],
#  ['computer_science',
#   'relevant_courses',
#   'object_oriented_programming',
#   'ii',
#   'introduction_computer_systems',
#   'discrete_structures',
#   'innovators',
#   'think'],
#  ['languages',
#   'technologies',
#   'languages_java',
#   'c',
#   'programs',
#   'eclipse',
#   'android_studio',
#   'matlab',
#   'latex',
#   'labchart',
#   'projects',
#   'projects',
#   'found',
#   'github',
#   'github.com/jeekang',
#   'turnt',
#   'tower',
#   '2016',
#   'independently',
#   'developed',
#   'android',
#   'app',
#   'augment',
#   'block',
#   'tower',
#   'game',
#   'jenga'],
#  ['app', 'features', 'attractive', 'user-friendly', 'interface'],
#  ['language',
#   'java',
#   'android',
#   'java-based',
#   'dna',
#   'template',
#   'strand',
#   'transcription/translation',
#   '2016',
#   'built',
#   'program',
#   'using',
#   'java',
#   'takes',
#   'input',
#   'nucleotide',
#   'sequence',
#   'returns',
#   'complementary',
#   'strand',
#   'mrna',
#   'sequence',
#   'reading',
#   'frame',
#   'one',
#   'exists',
#   'amino',
#   'acid',
#   'sequence'],
#  ['independent',
#   'undergraduate',
#   'research',
#   'project',
#   '2016',
#   'part',
#   'center',
#   'bioinformatics',
#   'computational',
#   'biology',
#   'university_maryland'],
#  ['working',
#   'meta-genomic',
#   'analysis',
#   'algorithms',
#   'finding',
#   'limitations',
#   'existing',
#   'programs'],
#  ['details',
#   'determined',
#   'first',
#   'meeting',
#   'team',
#   'september',
#   '21st',
#   'achievements',
#   'received',
#   'integrated',
#   'life',
#   'sciences',
#   'honors_college',
#   'citation',
#   '2014',
#   'received',
#   'presidential',
#   'scholarship',
#   'university_maryland',
#   'fall',
#   '2012_–',
#   'spring_2016',
#   'scored',
#   '94th',
#   'percentile',
#   'mcats',
#   'jan_2015',
#   '6',
#   'semesters',
#   'dean_’_list',
#   'experience',
#   'affective',
#   'translational',
#   'neuroscience',
#   'laboratory',
#   'college_park_md',
#   'research_assistant',
#   'fall',
#   '2013-',
#   'spring_2015',
#   'brainstormed',
#   'ideas',
#   'trial',
#   'stages',
#   'track',
#   'social',
#   'habits/movements',
#   'subjects'],
#  ['front-end', 'experience', 'briefed', 'debriefed', 'study', 'participants'],
#  ['worked',
#   'psychology',
#   'clinic',
#   'university_maryland',
#   'using',
#   'titanium',
#   'excel',
#   'manage',
#   'patient',
#   'dsm-5',
#   'data'],
#  ['assisted',
#   'running',
#   'clinical',
#   'trials',
#   'involving',
#   'fmri',
#   'maryland',
#   'neuroimaging',
#   'center'],
#  ['\\n',
#   'yaw',
#   'owusu',
#   'appiah',
#   'experience_summary',
#   'qualified',
#   'clearable',
#   'oracle_database',
#   '12c/11g/10g/9i',
#   'dba',
#   '10_years',
#   'managing',
#   'working',
#   'leading',
#   'edge',
#   'projects',
#   'require',
#   'experience',
#   'diverse',
#   'oltp',
#   'big_data',
#   'environments',
#   'team_player',
#   'proven',
#   'expertise',
#   'training',
#   'education',
#   'well',
#   'experience',
#   'programming',
#   'linux',
#   'administration',
#   'oracle_database',
#   'administration',
#   'asm',
#   'setup',
#   'oracle_rac',
#   '10g/11g/12c',
#   'data_guard',
#   'implementation',
#   'real_time',
#   'disaster_recovery',
#   'skilled',
#   'leading',
#   'dbas',
#   'database',
#   'projects',
#   'within',
#   'different',
#   'methodologies',
#   'like',
#   'devops',
#   'experience',
#   'leveraging',
#   'cots',
#   'gots',
#   'products',
#   'large',
#   'organizations',
#   'private',
#   'government',
#   'sectors',
#   'highly',
#   'exposed',
#   'big_data',
#   'environments',
#   'excellent',
#   'skills',
#   'upgrade',
#   'migrations',
#   'applying',
#   'quarterly',
#   'patches',
#   'etc'],
#  ['versatile',
#   'establishing',
#   'client',
#   'relationships',
#   'understanding',
#   'business_processes',
#   'user',
#   'tasks',
#   'goals',
#   ';',
#   'analyzing',
#   'defining',
#   'requirements',
#   'ensure',
#   'efficient',
#   'cost-saving',
#   'technological',
#   'solutions',
#   'meet',
#   'exceed',
#   'client',
#   'needs',
#   'experienced',
#   'automating',
#   'database',
#   'creation',
#   'oracle',
#   'response',
#   'files',
#   'linux',
#   'shell_scripts',
#   'versed',
#   'oracle',
#   'management',
#   'tools',
#   'utilities',
#   'like',
#   'oracle_enterprise_manager',
#   'grid',
#   'asmca',
#   'srvctl',
#   'crsctl',
#   'performance_tuning',
#   'techniques',
#   'comprises',
#   'savvy',
#   'usage',
#   'indexes',
#   'tablespace',
#   'compression',
#   'i/o',
#   'minimizations',
#   'hardware',
#   'raid',
#   'load_balancing',
#   'techniques'],
#  ['well',
#   'exposed',
#   'oracle',
#   'engineered',
#   'systems',
#   'like',
#   'oda',
#   'oracle',
#   'data',
#   'appliance',
#   'experience',
#   'leveraging',
#   'systems',
#   'meet',
#   'challenging',
#   'evolving',
#   'client',
#   'data',
#   'needs'],
#  ['core_competencies',
#   'technical',
#   'training',
#   'oracle',
#   '11g/10g/12c',
#   'database',
#   'administration',
#   'unix',
#   'systems',
#   'solaris',
#   'aix',
#   'linux',
#   'linux/unix',
#   'administration',
#   'shell_scripting',
#   'capacity_planning',
#   'systems',
#   'integration',
#   'oracle',
#   'performance_tuning',
#   'pl/sql',
#   'programming',
#   'technical_documentation',
#   'technical',
#   'leadership',
#   'cloud_computing',
#   'work_experience',
#   'science',
#   'applications',
#   'international_corporation',
#   'saic',
#   'december',
#   '2012',
#   'present',
#   'lead',
#   'oracle_database_administrator',
#   'key_work_experience',
#   'lead',
#   'development',
#   'custom',
#   'shell_scripts',
#   'monitoring',
#   'specific',
#   'databases',
#   'united_states',
#   'citizenship',
#   'immigration',
#   'services',
#   'department_homeland_security',
#   'led',
#   'automation',
#   'database',
#   'security',
#   'audits',
#   'conducted',
#   'security',
#   'team',
#   'saic'],
#  ['effort',
#   'cut',
#   'database',
#   'security',
#   'auditing',
#   'time',
#   '50',
#   'relieved',
#   'several',
#   'hours',
#   'routine',
#   'dba',
#   'security',
#   'staff',
#   'work'],
#  ['build',
#   'sops',
#   'implement',
#   'oracle',
#   'migrations',
#   '11gr2',
#   '12c',
#   ';',
#   'migration',
#   'activities',
#   'touch',
#   'oracle',
#   'clusterware',
#   'automatic',
#   'storage',
#   'management',
#   'layer',
#   'operating_system',
#   'areas',
#   'support',
#   'oracle',
#   'related',
#   'deployment',
#   'effort',
#   'uscis',
#   'electronic',
#   'immigration',
#   'system',
#   'project',
#   'elis'],
#  ['support',
#   'activities',
#   'include',
#   'performance_tuning',
#   'exercises',
#   'backup_recovery',
#   'rac',
#   'installations_upgrades',
#   'patching',
#   'replication',
#   'disaster_recovery',
#   'scripting',
#   'data',
#   'loading_data',
#   'reporting',
#   'provide_support',
#   'dbas',
#   'use',
#   'maintain',
#   'customer',
#   'scripts',
#   'developed',
#   'database',
#   'housekeeping',
#   'tasks',
#   'backup_recovery',
#   'shutdown',
#   'maintenance',
#   'work',
#   'etc'],
#  ['municipal',
#   'securities',
#   'rulemaking',
#   'board',
#   'alexandria_va',
#   'december',
#   '2012',
#   'present',
#   'lead',
#   'oracle_dba',
#   'linux',
#   'instructor',
#   'key_work_experience',
#   'led',
#   'dbas',
#   'migrating',
#   'various',
#   'oracle',
#   'versions',
#   'windows_linux',
#   'platform',
#   'evaluated',
#   'provided',
#   'technical',
#   'recommendations',
#   'business_continuity',
#   'solutions',
#   'msrb',
#   'data',
#   'management',
#   'teams',
#   ';',
#   'evaluated',
#   'replication',
#   'solutions',
#   'like',
#   'goldengate',
#   'streams',
#   'led',
#   'dbas',
#   'automating',
#   'various',
#   'manual',
#   'routines',
#   'like',
#   'db',
#   'backup_recovery',
#   'data_pump',
#   'activities',
#   ';',
#   'overall',
#   'helped',
#   'relieve',
#   'dba',
#   'time',
#   '30',
#   'designed_implemented',
#   'custom',
#   'data',
#   'change_tracking',
#   'routines',
#   'database',
#   'systems',
#   'msrb',
#   ';',
#   'database',
#   'auditing',
#   'highest',
#   'msrb'],
#  ['db',
#   'changes',
#   'tracked',
#   'reported',
#   'upper_management',
#   'savvy',
#   'custom',
#   'reports.establish',
#   'maintain',
#   'information_security',
#   'standards',
#   'procedures',
#   'compliance',
#   'dhs',
#   'uscg',
#   'dia',
#   'risk_management',
#   'policies',
#   'standards',
#   'guidelines',
#   'trained',
#   'msrb',
#   'technical',
#   'staff',
#   'linux_platform',
#   ';',
#   'includes',
#   'developers',
#   'operations',
#   'staff',
#   'middle',
#   'management',
#   'dbas',
#   'whole',
#   'organization',
#   'advised',
#   'msrb',
#   'database',
#   'management',
#   'techniques',
#   'strategies',
#   'best_practices',
#   ';',
#   'documented',
#   'trained',
#   'dbas',
#   'accepted',
#   'recommendations',
#   'provided',
#   'technical',
#   'leadership',
#   'evaluating',
#   'oracle',
#   'data',
#   'appliance',
#   'on-site',
#   'proof-of-concept',
#   'exercises',
#   'mitre',
#   'corporation',
#   'mclean_va',
#   '2008',
#   '2011',
#   'senior',
#   'oracle_database_administrator',
#   'key_work_experience',
#   'installed_configured',
#   'oracle_11g',
#   'r1',
#   'rac',
#   'using',
#   'netapp',
#   'nfs',
#   'storage',
#   'conducted',
#   'bi-weekly',
#   'cold',
#   'backups',
#   'using',
#   'linux',
#   'lvm',
#   'snapshot',
#   'netapp',
#   'snapshot',
#   'disaster_recovery',
#   'offsite',
#   'locationevaluated',
#   'provided',
#   'technical',
#   'recommendations',
#   'business_continuity',
#   'solutions',
#   'msrb',
#   'data',
#   'management',
#   'teams',
#   ';',
#   'evaluated',
#   'replication',
#   'solutions',
#   'like',
#   'goldengate',
#   'streams'],
#  ['configured',
#   'oracle_database',
#   'server',
#   'connect',
#   'non-oracle',
#   'systems',
#   'like',
#   'hadoop',
#   'ms_sql_server',
#   'mysql',
#   'databases',
#   'fully',
#   'heterogeneous',
#   'environment',
#   'upgraded',
#   'oracle',
#   '11gr1',
#   '11gr2',
#   'performed',
#   'disaster_recovery',
#   'provided',
#   'recommendations',
#   'senior_management',
#   'implementation',
#   'performed',
#   'database',
#   'performance_tuning',
#   'activities',
#   'using',
#   'tools_like',
#   'addm',
#   'reports',
#   'sql',
#   'tuning',
#   'advisors',
#   'supported',
#   'research',
#   'efforts',
#   'oracle',
#   'replication',
#   'technologies',
#   'like',
#   'data_guard',
#   'automated',
#   'database',
#   'administration',
#   'routines',
#   'e.g'],
#  ['backup_recovery',
#   'data_pump',
#   'export/import',
#   'activities',
#   'schema',
#   'refresh',
#   'different',
#   'sources',
#   'creation',
#   'disk',
#   'usage',
#   'monitoring',
#   'designed_implemented',
#   'oracle',
#   'user',
#   'audit',
#   'collection',
#   'led',
#   'dba',
#   'team',
#   'architecting',
#   'data',
#   'flows',
#   'presentation',
#   'tiers',
#   'senior_management',
#   'analyzed',
#   'database',
#   'research',
#   'results',
#   'documented',
#   'findings',
#   'supported',
#   'oracle',
#   'research',
#   'work',
#   'conducted',
#   'various',
#   'airline',
#   'partners',
#   'mitre',
#   '’',
#   'aviation',
#   'initiatives',
#   'supported',
#   'research',
#   'efforts',
#   'large',
#   'databases_like',
#   'asterdata',
#   'greenplum',
#   'teradata',
#   'chaveran',
#   'inc.',
#   'bowie_md',
#   '2006',
#   '2013',
#   'part-time',
#   'technical',
#   'instructor',
#   'key_work_experience',
#   'trained',
#   'students',
#   'unix_linux',
#   'platforms',
#   'administration',
#   'trained',
#   'students',
#   'installing_configuring',
#   'oracle',
#   'asm',
#   'oracle_rac',
#   'stack',
#   'assisted',
#   'writing',
#   'technical',
#   'manuals',
#   'on-site',
#   'linux',
#   'administrators',
#   'assisted',
#   'developing',
#   'training_material',
#   'interns',
#   'designed',
#   'maintained',
#   'student',
#   'mail',
#   'ssh',
#   'jumpbox',
#   'web_servers',
#   'assisted',
#   'building',
#   'maintaining',
#   'chaveran',
#   'cloud',
#   'various',
#   'virtualizations',
#   'installed_configured',
#   'red_hat',
#   'file',
#   'servers',
#   'linux',
#   'appliances',
#   'installed_configured',
#   'linux',
#   'firewalls',
#   'client',
#   'using',
#   'iptables',
#   'bind',
#   'developed',
#   'hardware',
#   'requirements',
#   'specification',
#   'assisted',
#   'sizing',
#   'activities',
#   'saba',
#   'software',
#   'inc.',
#   'baltimore_md',
#   '2006',
#   '2008',
#   'technical',
#   'consultant/oracle',
#   'developer',
#   'key_work_experience',
#   'assisted',
#   'clients',
#   'problem',
#   'identification',
#   'database',
#   'system',
#   'architecture',
#   'problems',
#   'software',
#   'specifications',
#   'writing',
#   'software',
#   'implementation',
#   'testing',
#   'deployment',
#   'technical',
#   'highlights',
#   'fdic',
#   'thinq-to-saba',
#   'data_migration',
#   'technical_lead',
#   'high',
#   'risk',
#   'clearance'],
#  ['led',
#   'design_implementation',
#   'fdic',
#   '’',
#   'data_migration',
#   'effort',
#   'thinq',
#   'saba'],
#  ['supported',
#   'yum',
#   'brands',
#   'architectural',
#   'designs',
#   'data_migration',
#   'processes',
#   'assisted',
#   'data_migration',
#   'enbridge',
#   'gas',
#   'distribution',
#   'based',
#   'canada',
#   'served',
#   'technical_lead',
#   'saba',
#   'engagement',
#   'northrop_grumman',
#   'corporation'],
#  ['supported',
#   'client',
#   'saba',
#   'installations',
#   'oracle',
#   'data_migration',
#   'supported',
#   'atk',
#   'oracle',
#   'performance_tuning',
#   'efforts',
#   'using',
#   'explain',
#   'plans',
#   'awr',
#   'addm',
#   'reports',
#   'mentored',
#   'junior',
#   'consultants',
#   'saba',
#   '’',
#   'employee',
#   'mentorship',
#   'program'],
#  ['washington',
#   'baltimore',
#   'high',
#   'index',
#   'drug',
#   'trafficking',
#   'area',
#   'greenbelt_md',
#   '2001',
#   '2006',
#   'database',
#   'administrator/developer',
#   'key_work_experience',
#   'assisted',
#   'development',
#   'backend',
#   'database',
#   'stored_procedures',
#   'needed',
#   'middle',
#   'tiers',
#   'worked_extensively',
#   'classic',
#   'asp',
#   'access',
#   'reporting',
#   'tools_like',
#   'pivot_tables',
#   'conducted',
#   'demos',
#   'training_sessions',
#   'needed',
#   'use',
#   'released',
#   'products',
#   'worked',
#   'content_management',
#   'systems',
#   'like',
#   'drupal',
#   'mambo',
#   'assisted',
#   'web',
#   'development',
#   'projects',
#   'using',
#   'php',
#   'developed',
#   'database',
#   'application',
#   'tracking',
#   'web',
#   'logs',
#   'helped',
#   'create',
#   'frontend',
#   'interfaces',
#   'controlling',
#   'applications',
#   'extensively',
#   'dealt',
#   'schema',
#   'design',
#   'data_modeling',
#   'using',
#   'tools_like',
#   'oracle',
#   'data_modeler',
#   'conducted',
#   'demos',
#   'trained',
#   'personnel',
#   'using',
#   'visual_basic',
#   'application',
#   'university_maryland_college_park',
#   'maryland',
#   '2001',
#   'linux/network',
#   'administrator_key',
#   'work_experience',
#   'supported',
#   'student',
#   'network',
#   'setup',
#   'assisted',
#   'network',
#   'problem',
#   'shooting',
#   'assisted',
#   'network_deployment',
#   'troubleshooting',
#   'configured',
#   'student',
#   'private',
#   'routers',
#   'network_devices',
#   'trained',
#   'students',
#   'using',
#   'network',
#   'resources',
#   'campus',
#   'worked',
#   'team',
#   'help',
#   'students',
#   'install',
#   'linux',
#   'workstations',
#   'skills',
#   'sql',
#   'language',
#   'linux',
#   'shell_scripting',
#   'pl/sql',
#   'mysql/postgresql',
#   'database',
#   'oracle_data_guard',
#   'perl_scripting',
#   'windows_os',
#   'oracle',
#   'asm',
#   'exposed',
#   'greenplum',
#   'netezza',
#   'hadoop',
#   'linux',
#   'lan/wan',
#   'networking',
#   'object_oriented_programming',
#   'oop',
#   'concepts',
#   'gnu/linux',
#   'os',
#   '–',
#   'red_hat',
#   'debian',
#   'c++',
#   'c_java',
#   'tcp/ip',
#   'networking',
#   'sql_loader',
#   'pervasive',
#   'map',
#   'designer',
#   'joomla',
#   'cms',
#   'oracle_sql_developer',
#   'sql',
#   'data_modeler',
#   'oracle',
#   '12c',
#   'cloud_control',
#   'quest',
#   'toad',
#   'quest',
#   'spotlight/foglight',
#   'oracle',
#   'rman',
#   'adobe',
#   'fireworks',
#   'dreamweaver',
#   'microsoft_office',
#   'visio',
#   'virtual',
#   'box',
#   'vmware',
#   'xen',
#   'education_masters',
#   'science_information_systems',
#   '2012',
#   'university_maryland',
#   'baltimore_county',
#   'bachelor_science_computer_science',
#   '2006',
#   'university_maryland_college_park',
#   'bachelor_arts_economics',
#   '–',
#   '2006',
#   'university_maryland_college_park',
#   'clearance',
#   'certifications',
#   'public_trust',
#   'level',
#   '3',
#   'fbi',
#   'background',
#   'investigation',
#   'oracle',
#   'certified_professional',
#   'oracle',
#   'certified_associate',
#   'red_hat_certified',
#   'technician',
#   'jane_doe_paradyme_management',
#   'inc_page_1_5',
#   'yaw',
#   'owusu',
#   'appiah',
#   'paradyme_management_inc'],
#  ['page_2',
#   '5\\n',
#   'dimitri',
#   'richardson',
#   '114',
#   'division',
#   'st',
#   'neptune',
#   'nj',
#   '07753',
#   'phone',
#   '732-614-0217',
#   'e-mail',
#   'dimitri.richardson',
#   '@_gmail.com',
#   'experience',
#   'smart',
#   'tuition',
#   'june-august',
#   '2015',
#   'summer',
#   'internship',
#   ';',
#   'manage',
#   'accounts',
#   'private',
#   'schools',
#   'across_country'],
#  ['customer_service',
#   'assistant',
#   'answered',
#   'questions',
#   'parents',
#   'school',
#   'worked',
#   'along',
#   'side',
#   'school',
#   'account',
#   'mangers',
#   'laz',
#   'parking',
#   'may',
#   '2013-august',
#   '2015',
#   'parking',
#   'attendant',
#   'charge',
#   'collection',
#   'fees',
#   'parking',
#   'three-beach',
#   'side',
#   'customer',
#   'parking',
#   'facilities'],
#  ['handled',
#   'financial',
#   'transactions',
#   'wendy',
#   '’',
#   'july',
#   '2011-may',
#   '2012',
#   'cashier',
#   'responsibilities_included',
#   'greeting',
#   'customers',
#   'submitting',
#   'orders',
#   'operating',
#   'cash_register'],
#  ['demonstrated', 'customer_service', 'problem-solving', 'computer_skills'],
#  ['assisted', 'opening', 'closing', 'store'],
#  ['national',
#   'leadership',
#   'forum',
#   'law',
#   'csi',
#   'july',
#   '2010',
#   'experienced',
#   'full_range',
#   'professions',
#   'exist',
#   'legal',
#   'forensic',
#   'science',
#   'fields'],
#  ['explored',
#   'in-depth',
#   'entire',
#   'judicial',
#   'process',
#   'crime',
#   'collecting',
#   'analyzing',
#   'critical',
#   'evidence'],
#  ['examine', 'court', 'case', 'supreme', 'court', 'stimulation'],
#  ['took_part',
#   'legal',
#   'career',
#   'experience',
#   'courthouse',
#   'jersey',
#   'shore',
#   'university',
#   'medical_center',
#   'august_2010',
#   'volunteer',
#   'jsumc',
#   'assisting',
#   'caregiver',
#   'assistance',
#   'clerical',
#   'tasks',
#   'worked',
#   'information',
#   'desk',
#   'mail',
#   'room',
#   'billing',
#   'department'],
#  ['education',
#   'xavier',
#   'university',
#   '2012-2013',
#   'volunteer/member',
#   'xavier',
#   'university',
#   'black',
#   'student_association',
#   'member',
#   'track',
#   'field',
#   'team_member',
#   'xavier',
#   'university',
#   'club',
#   'football',
#   'team',
#   'west',
#   'virginia',
#   'university',
#   '2014-',
#   'present',
#   'current',
#   'finance',
#   'student',
#   'college',
#   'business',
#   'economics',
#   'graduation_date',
#   'may_2017',
#   '2\\n',
#   '3412',
#   'tulane',
#   'dr.',
#   '31',
#   'varsha',
#   'purswani',
#   'hyattsville',
#   'maryland',
#   'md_20783',
#   '301-318-6065',
#   'https',
#   '//www/linkedin.com/in/varsha022',
#   'varsha.purswani',
#   '@_rhsmith.umd.edu_education_robert',
#   'h._smith_school_business',
#   'university_maryland_college_park',
#   'md',
#   'dec_2016_master_science',
#   'information_systems',
#   'g.p.a',
#   '3.9',
#   'related_coursework',
#   'data_mining_predictive_analytics',
#   'data_models_decisions',
#   'business_process_analysis',
#   'strategic_transformational',
#   'database',
#   'management',
#   'systems',
#   'digital_business',
#   'markets',
#   'shri',
#   'govindram',
#   'seksaria',
#   'institute_technology',
#   'science',
#   'indore',
#   'india_bachelor',
#   'engineering_computer',
#   'engineering',
#   'may_2012_professional_experience',
#   'sap',
#   'labs',
#   'india_pvt',
#   'ltd_bangalore',
#   'india_jun',
#   '2012_–',
#   'july_2015',
#   'software_developer',
#   '§\uf0a7',
#   'collaborated',
#   'customers',
#   'business_needs',
#   'translated',
#   'technical',
#   'requirements',
#   'producing',
#   'software',
#   'requirement_specification'],
#  ['§\uf0a7',
#   'consulted',
#   'italian',
#   'client',
#   'implementation',
#   'sap',
#   'fashion',
#   'management',
#   'solution',
#   'fms',
#   'critical',
#   'business',
#   'scenarios',
#   'resulting',
#   'smooth',
#   'launch'],
#  ['§\uf0a7',
#   'designed',
#   'data_model',
#   'sap',
#   'fms',
#   'order',
#   'allocation',
#   'run',
#   'a-run',
#   'enabled',
#   'execution',
#   'sap_hana',
#   'database',
#   'platform',
#   'resulting',
#   'performance_improvement',
#   '10',
#   'times',
#   'baseline'],
#  ['§\uf0a7',
#   'led',
#   'start-up',
#   'company',
#   'creating',
#   'supply_chain_management',
#   'scm',
#   'analytics',
#   'application',
#   'using',
#   'sap_hana',
#   'database',
#   'platform'],
#  ['projects',
#   'aug_2015',
#   '–_dec_2015',
#   '§\uf0a7',
#   'database',
#   'management',
#   'systems',
#   'designed',
#   'relational_database',
#   'virtual',
#   'client',
#   'defining',
#   'logical',
#   'model',
#   'using',
#   'entity',
#   'relationship',
#   'diagram',
#   'physical',
#   'model',
#   'using',
#   'sql',
#   '§\uf0a7',
#   'digitization',
#   'freelancing',
#   'collated',
#   'data',
#   'created',
#   'reports',
#   'online',
#   'freelancing',
#   'platform',
#   'upwork',
#   'analyzed',
#   'strategic_transformational',
#   'impact',
#   'society',
#   '§\uf0a7',
#   'business_process_analysis',
#   'leading',
#   'scrum_team',
#   'five',
#   'develop',
#   'reporting',
#   'mobile_app',
#   'demonstrating',
#   'health',
#   'statistics',
#   'individual',
#   '§\uf0a7',
#   'firm',
#   'analysis',
#   'mapbox',
#   'gathered',
#   'information',
#   'start',
#   'mapbox',
#   'analysed',
#   'business',
#   'domain',
#   'sources',
#   'competitive_advantage',
#   'industry',
#   'dynamics',
#   'strategic',
#   'drivers',
#   'performance'],
#  ['§\uf0a7',
#   'google_analytics',
#   'leading',
#   'team_four',
#   'improve',
#   'client_’',
#   'website',
#   'increase',
#   'click',
#   'rate',
#   'using',
#   'google_analytics_google_adwords'],
#  ['leadership_experience',
#   'university_maryland',
#   'aug_2015',
#   '–_dec_2015',
#   '§\uf0a7',
#   'managed',
#   'marketing',
#   'events',
#   'student_ambassador',
#   'clarice',
#   'smith',
#   'performing',
#   'arts',
#   'center'],
#  ['§\uf0a7',
#   'volunteered',
#   'kids',
#   'enjoy',
#   'exercise',
#   'keen',
#   'providing',
#   'recreational',
#   'opportunities',
#   'group',
#   '20',
#   'children',
#   'physical',
#   'mental',
#   'disabilities'],
#  ['sgsits',
#   'technical',
#   'cultural',
#   'events',
#   'may',
#   '2011_–',
#   'dec_2011',
#   '§\uf0a7',
#   'facilitated',
#   'office',
#   'career',
#   'services',
#   'smooth',
#   'execution',
#   'placement',
#   'process',
#   '500',
#   'students',
#   '§\uf0a7',
#   'supervised',
#   'budgeting',
#   'script',
#   'writing',
#   'compering',
#   'three',
#   'major',
#   'events',
#   'college',
#   '’',
#   'cultural_festival'],
#  ['technical_skills',
#   '§\uf0a7',
#   'languages',
#   'r',
#   'abap',
#   'java_c',
#   'sql',
#   'php_html',
#   'css_xml',
#   '§\uf0a7',
#   'tools',
#   'tableau',
#   'palisade',
#   'tools',
#   'excel',
#   'stat_tools',
#   '@_risk',
#   'precision_tree',
#   'solver_table',
#   'ms_visio',
#   'ms_office',
#   'salesforce.com',
#   'oracle10g',
#   'mysql',
#   'sap_hana',
#   'google_analytics_google_adwords',
#   'linux',
#   '\\n',
#   'kane',
#   'baccigalupi',
#   '935',
#   'scenic',
#   'place',
#   'pleasant',
#   'hill',
#   'ca',
#   '94523',
#   'mobile',
#   '510-228-9669',
#   'skill',
#   'summary',
#   'expert',
#   'technical',
#   'advisor',
#   '10_years_experience',
#   'cto',
#   'expert',
#   'consultant'],
#  ['team_leader', 'dedicated', 'advancing', 'developing', 'team_members'],
#  ['champion',
#   'organizational',
#   'diversity',
#   'benefits',
#   'business_objectives'],
#  ['business',
#   'strategist',
#   'focused',
#   'using',
#   'technical',
#   'innovation',
#   'move',
#   'organizations',
#   'quickly',
#   'towards',
#   'objectives'],
#  ['mentor', 'writer', 'speaker'],
#  ['data_driven',
#   'decision',
#   'maker',
#   'focused',
#   'user',
#   'research',
#   'customer',
#   'validation'],
#  ['public',
#   'servant',
#   'dedicated',
#   'bringing',
#   'best',
#   'innovations',
#   'private_sector',
#   'government'],
#  ['experience',
#   'innovation',
#   'strategist',
#   '18f',
#   'gsa',
#   'september_2015',
#   'present',
#   'gsa',
#   "'s",
#   '18f',
#   'innovation',
#   'agency',
#   'federal_government'],
#  ['worked',
#   'strategy',
#   'team',
#   'offering',
#   'technical',
#   'advice',
#   'hands-on',
#   'support',
#   'moving',
#   'agencies',
#   'projects',
#   'better',
#   'practices',
#   'outcomes'],
#  ['legacy',
#   'modernization',
#   'lead',
#   'educated',
#   '18f',
#   'leadership',
#   'staff',
#   'common',
#   'patterns',
#   'legacy',
#   'modernization'],
#  ['crafted',
#   'plans',
#   'alaska',
#   'missouri',
#   'medicaid',
#   'related',
#   'modernizations',
#   'starting',
#   'deep',
#   'technical',
#   'dive',
#   '18f',
#   'team_members',
#   'three-month',
#   'prototyping',
#   'vendor',
#   'contract',
#   'concluding',
#   'modular',
#   'procurement',
#   'plan'],
#  ['rebuilt',
#   'technical',
#   'product',
#   'strategy',
#   'health_human_services',
#   'unaccompanied',
#   'children',
#   'program',
#   'software',
#   'modernization',
#   'effor',
#   'switching',
#   'database',
#   'encapsulation',
#   'transformation'],
#  ['us_census_bureau',
#   'engagement',
#   'lead',
#   'acted',
#   'bridge',
#   'engineering',
#   'teams',
#   'census',
#   'top',
#   'leadership',
#   'introducing',
#   'product_development',
#   'processes',
#   'improving',
#   'agile_practices',
#   '2020',
#   'internet',
#   'data_collection',
#   'application'],
#  ['lead',
#   'discovery',
#   'improved',
#   'software',
#   'design',
#   'practices',
#   'crafted',
#   'two',
#   'day',
#   'engineering',
#   'design',
#   'workshop'],
#  ['worked',
#   'cio',
#   'deputy_director',
#   'address',
#   'highest',
#   'risk',
#   'issues',
#   'decennial',
#   'survey',
#   'cloud',
#   'infrastructure',
#   'governance'],
#  ['environmental',
#   'protection',
#   'agency',
#   'e-enterprise',
#   'program',
#   'engineering',
#   'strategist',
#   'co-lead',
#   'discovery',
#   'combined',
#   'air',
#   'emissions',
#   'reporting'],
#  ['crafted',
#   'data',
#   'architecture',
#   'would',
#   'allow',
#   'state',
#   'federal',
#   'program_managers',
#   'understand',
#   'data',
#   'reporting',
#   'query',
#   'separate',
#   'needs'],
#  ['taught',
#   'two',
#   'day',
#   'agile',
#   'workshop',
#   'bridged',
#   'gap',
#   'state',
#   'epa',
#   'needs'],
#  ['guided',
#   'epa',
#   'towards',
#   'low\u200b-risk',
#   'high-return',
#   'solutions',
#   'could',
#   'completed',
#   'within',
#   'month',
#   'establish',
#   'trust',
#   'state',
#   'participants'],
#  ['lead',
#   'agile',
#   'consultant',
#   'ministry',
#   'velocity',
#   'december_2014',
#   'august_2015',
#   'worked',
#   'engagements',
#   'lasting',
#   'one',
#   'day',
#   'six',
#   'months',
#   'advising',
#   'company',
#   'leadership',
#   'building',
#   'rebuilding',
#   'organization',
#   'core',
#   'software',
#   'products'],
#  ['lead',
#   'one\u200b-day',
#   'working',
#   'session',
#   'engineering',
#   'leadership',
#   'enterprise',
#   'saas',
#   'company',
#   'tackle',
#   'system',
#   'instability',
#   'leading',
#   'data',
#   'architecture',
#   'solution',
#   'increased',
#   'uptime'],
#  ['provided',
#   'expert',
#   'technical',
#   'organizational',
#   'advice',
#   'ceo/founder',
#   'food',
#   'delivery',
#   'startup',
#   'transitioning',
#   'hastily',
#   'built',
#   'prototype',
#   'scalable',
#   'customizable',
#   'solution'],
#  ['performed',
#   'hands\u200b-on',
#   'engineering',
#   'mentoring',
#   'two',
#   'enterprise',
#   'saas',
#   'companies',
#   'struggling',
#   'legacy',
#   'code_issues'],
#  ['improved',
#   'agile',
#   'software',
#   'practices',
#   'increased',
#   'velocity',
#   're\u200b-architected',
#   'failing',
#   'systems',
#   'applications'],
#  ['acting',
#   'director',
#   'gschool',
#   'galvanize',
#   'inc.',
#   'august_2014',
#   'november_2014',
#   'increased',
#   'operational_efficiency',
#   'web',
#   'education',
#   'school',
#   'company',
#   'acquired',
#   'zipfian',
#   'academy',
#   'merged',
#   'new',
#   'university',
#   'new',
#   'backed',
#   'masters',
#   'program',
#   'data_science'],
#  ['oversaw',
#   'instructions',
#   'admissions',
#   'student',
#   'outcomes',
#   'transition'],
#  ['reduced',
#   'instructor',
#   'costs',
#   '30',
#   'increased',
#   'facility',
#   'utilization',
#   'boulder',
#   'campus',
#   'via',
#   'concurrent',
#   'classes'],
#  ['launched',
#   'san_francisco',
#   'instruction',
#   'campus',
#   'creating',
#   'curriculum',
#   'leading',
#   'instruction',
#   'first',
#   'web',
#   'development',
#   'six',
#   'month',
#   'course'],
#  ['reorganized',
#   'school-wide',
#   'roles',
#   'increase_efficiency',
#   'improve',
#   'instructor',
#   'retention'],
#  ['streamlined',
#   'admissions',
#   'scattered',
#   'ad_hoc',
#   'processes',
#   'comprehensive',
#   'system',
#   'tracking',
#   'leads',
#   'conclusion'],
#  ['built',
#   'system',
#   'soft',
#   'hard',
#   'metrics',
#   'estimating',
#   'student',
#   'success',
#   'removing',
#   'bias',
#   'admissions',
#   'process',
#   'increasing',
#   'diversity'],
#  ['chief',
#   'technical',
#   'officer',
#   'socialchorus',
#   'inc.',
#   'november',
#   '2012',
#   'july_2014',
#   'transformed',
#   'brittle',
#   'monolithic',
#   'legacy',
#   'application',
#   'high-performance',
#   'service-oriented_architecture'],
#  ['converted',
#   'low-velocity',
#   'high-attrition',
#   'engineering',
#   'culture',
#   'happy',
#   'productive',
#   'work',
#   'environment'],
#  ['crafted',
#   'product',
#   'became',
#   "company_'s",
#   'top',
#   'competitive_advantage',
#   'via',
#   'better',
#   'user-interviews',
#   'user-testing',
#   'great',
#   'agile_practices'],
#  ['product',
#   'crafted',
#   'user-focused',
#   'real-time',
#   'advocate',
#   'experience',
#   'became',
#   'top',
#   'competitive_advantage',
#   'company'],
#  ['designed',
#   'product',
#   'via',
#   'user_interviews',
#   'rapid',
#   'build-out',
#   'working',
#   'prototype',
#   'finally',
#   'on-time',
#   '6-week',
#   'agile',
#   'execution',
#   'plan'],
#  ['enhanced',
#   'agile',
#   'process',
#   'via',
#   'stricter',
#   'story',
#   'processes',
#   'company-wide',
#   'retrospectives',
#   'user-focused',
#   'practices'],
#  ['engineering',
#   'transformed',
#   'stagnating',
#   'legacy',
#   'application',
#   'robust',
#   'service-oriented_architecture',
#   'driving',
#   'scale',
#   'development',
#   'speed'],
#  ['separated',
#   'administrative',
#   'facing',
#   'application',
#   'advocate',
#   'facing',
#   'application'],
#  ['crafted',
#   'high-performance',
#   'services',
#   'tracking',
#   'click',
#   'traffic',
#   'promoted',
#   'advocate',
#   'content'],
#  ['authored',
#   '6',
#   'open_source',
#   'libraries',
#   'including',
#   'mobile',
#   'first',
#   'front-end',
#   'framework',
#   'framework',
#   'developing_deploying',
#   'services'],
#  ['team',
#   'building',
#   'replaced',
#   'existing',
#   'small',
#   'engineering',
#   'team',
#   'new',
#   'group',
#   'ten',
#   'dedicated',
#   'developers',
#   'director',
#   'engineering',
#   'qa',
#   'staff'],
#  ['rebuilt', 'product', 'team'],
#  ['created',
#   'successful',
#   'internship',
#   'program',
#   'graduates',
#   'converted',
#   'team',
#   'leads'],
#  ['improved',
#   'engineering',
#   'company',
#   'culture',
#   'focus',
#   'problem_solving',
#   'striving',
#   'practical',
#   'best_practices'],
#  ['senior',
#   'agile',
#   'consultant',
#   'blazing',
#   'cloud',
#   'november',
#   '2011',
#   'november',
#   '2012',
#   'advised',
#   'several',
#   'companies',
#   'refining',
#   'improving',
#   'development',
#   'agile_practices',
#   'increase',
#   'velocity'],
#  ['blazing', 'cloud', 'acquired', 'indiegogo', '2013'],
#  ['recruited',
#   'interviewed',
#   'developer',
#   'talent',
#   'intern',
#   'senior',
#   'level',
#   'talents',
#   'ruby',
#   'javascript',
#   'objective-c.',
#   'mentored',
#   'interns',
#   'built',
#   'internal',
#   'company',
#   'best_practices',
#   'advised',
#   'internal',
#   'business',
#   'product',
#   'decisions'],
#  ['lead',
#   'technical',
#   'direction',
#   'product',
#   'management',
#   'graphically',
#   'intense',
#   'mobile',
#   'first',
#   'application',
#   'html_javascript'],
#  ['architect',
#   'cohuman',
#   'inc.',
#   'october',
#   '2009',
#   'august_2011',
#   'second',
#   'employee',
#   'saas',
#   'company',
#   'acquired',
#   'acquired',
#   'mindjet',
#   'currently',
#   'offered',
#   'mindjet',
#   'connect',
#   'task',
#   'management',
#   'solution'],
#  ['planned',
#   'developed',
#   'scalable',
#   'features',
#   'project_management',
#   'application',
#   'complex',
#   'permissions',
#   'notifications',
#   'systems'],
#  ['designed', 'oauth', 'authenticated', 'api'],
#  ['chief',
#   'technical',
#   'officer',
#   'clerkdogs',
#   'inc.',
#   'february',
#   '2009',
#   'october',
#   '2009',
#   'worked',
#   'ceo',
#   'build',
#   'combination',
#   'flexible',
#   'options',
#   'movie',
#   'recommendations',
#   'turn-key',
#   'whitelist',
#   'solutions',
#   ';',
#   'data',
#   'consumption',
#   'via',
#   'api',
#   'export'],
#  ['data', 'acquired', 'netflix', 'early', '2010'],
#  ['transformed',
#   'rough',
#   'untested',
#   'prototype',
#   'two',
#   'user',
#   'facing',
#   'applications',
#   'one',
#   'admin',
#   'one',
#   'consumers'],
#  ['consumer',
#   'application',
#   'modular',
#   'composable',
#   'application',
#   'could',
#   'graphically',
#   'skinned',
#   'match',
#   'company',
#   'look',
#   'feel',
#   'could',
#   'customized',
#   'components',
#   'according',
#   'needs',
#   'costs'],
#  ['hired', 'managed', 'remote', 'team'],
#  ['pioneered',
#   'agile_practices',
#   'testing',
#   'increase',
#   'velocity',
#   'stability'],
#  ['lead_developer',
#   'integral',
#   'impressions',
#   'may',
#   '2008',
#   'january_2009',
#   'crafted',
#   'content_management',
#   'system',
#   'sufficiently',
#   'flexible',
#   'company',
#   'could',
#   'rapidly',
#   'build',
#   'informational',
#   'client',
#   'websites',
#   'allowing',
#   'customer',
#   'add',
#   'pages',
#   'customize',
#   'content'],
#  ['managed',
#   'hired',
#   'remote',
#   'contract',
#   'team',
#   'engineers',
#   'infrastructure',
#   'architects'],
#  ['built',
#   'supervised',
#   'hand\u200bcrafted',
#   'custom',
#   'infrastructure',
#   'deployment',
#   'scripts',
#   'web',
#   'solutions'],
#  ['lead',
#   'engineering',
#   'larger',
#   'custom',
#   'web',
#   'solutions',
#   'highly',
#   'customized',
#   'product',
#   'engineering',
#   'needs'],
#  ['founder',
#   'chief',
#   'technical',
#   'officer',
#   'gpc',
#   'inc.',
#   'may_2005',
#   'january',
#   '2008',
#   'managed_aspects',
#   'business',
#   'hiring',
#   'contract',
#   'labor',
#   'generating',
#   'documentary',
#   'content',
#   'getting',
#   'press',
#   'national',
#   'publications',
#   'developing',
#   'software'],
#  ['created',
#   'web_application',
#   'solution',
#   'showcasing',
#   'documentary',
#   'video',
#   'content',
#   'variety',
#   'formats',
#   'sizes',
#   'flexibility',
#   'adjust',
#   'rapidly',
#   'best',
#   'product',
#   'market',
#   'fit'],
#  ['built',
#   'service_oriented',
#   'suite',
#   'custom',
#   'database',
#   'applications',
#   'scheduling',
#   'managing',
#   'contract',
#   'video',
#   'production',
#   'staff',
#   'interviewees'],
#  ['scaled',
#   'infrastructure',
#   'allow',
#   'thousands',
#   'simultaneous',
#   'streaming',
#   'connections',
#   'special_events'],
#  ['crafted',
#   'security',
#   'architecture',
#   'capable',
#   'storing',
#   'important',
#   'employment',
#   'personally',
#   'identifiable',
#   'information'],
#  ['engineering',
#   'intern',
#   'cern',
#   'atlas',
#   'project',
#   'lawrence',
#   'berkeley',
#   'national',
#   'laboratory',
#   'january_2002',
#   'may_2005',
#   'junior',
#   'member',
#   'five',
#   'person',
#   'mechanical_engineering',
#   'team',
#   'responsible',
#   'prototyping',
#   'building',
#   'inner',
#   'second',
#   'layer',
#   'atlas',
#   'detector',
#   'cern',
#   '’',
#   'large',
#   'hadron',
#   'collider'],
#  ['rebuilt',
#   'microscope',
#   'calibration',
#   'algorithms',
#   'fix',
#   'manufacturing',
#   'problems',
#   'radial',
#   'sensors'],
#  ['created',
#   'custom',
#   'database',
#   'application',
#   'analyzing',
#   'radiation',
#   'length',
#   'interference',
#   'detector',
#   'readings'],
#  ['devised',
#   'heat',
#   'transfer',
#   'static',
#   'force',
#   'analysis',
#   'simulation',
#   'validate',
#   'models'],
#  ['created',
#   'cad',
#   'designs',
#   'insertion',
#   'system',
#   'central',
#   'detector',
#   'machined',
#   'several',
#   'components'],
#  ['database',
#   'consultant',
#   'visual',
#   'designer',
#   'self-employed',
#   '1995',
#   '2008',
#   'worked',
#   'variety',
#   'customers',
#   'solve',
#   'software',
#   'and/or',
#   'product',
#   'problems_related',
#   'business_objectives'],
#  ['created',
#   'custom',
#   'database',
#   'applications',
#   'internal',
#   'business_processes',
#   'order',
#   'free',
#   'labor',
#   'higher',
#   'level',
#   'business',
#   'concerns'],
#  ['converted',
#   'custom',
#   'database',
#   'applications',
#   'web',
#   'solutions',
#   'increase',
#   'availability',
#   'eye',
#   'towards',
#   'portability',
#   'across',
#   'infrastructure',
#   'data',
#   'security'],
#  ['generated',
#   'product',
#   'specification',
#   'easy',
#   'use',
#   'user_interfaces',
#   'visual',
#   'design',
#   'needed'],
#  ['selected', 'speaking', 'engagements', 'c'],
#  ['\u200b-',
#   'women',
#   'code',
#   'san_francisco',
#   '2015',
#   'technical',
#   'presentation',
#   'data',
#   'structure',
#   'c',
#   'programmers',
#   'use',
#   'make',
#   'static',
#   'language',
#   'behave',
#   'dynamically'],
#  ['long',
#   'live',
#   'rubyist',
#   '\u200b-',
#   'women',
#   'code',
#   'san_francisco',
#   '2015',
#   'talk',
#   'concurrency',
#   'limits',
#   'ruby',
#   'programming_language'],
#  ['going',
#   'evergreen',
#   '\u200b-',
#   'rubyconf',
#   '2014',
#   'presentation',
#   'engineering',
#   'culture',
#   'principles',
#   'avoid',
#   'technical',
#   'debt',
#   'create',
#   'enjoyable',
#   'ongoing',
#   'software',
#   'work'],
#  ['diversity'],
#  [],
#  [],
#  ['-\u200b',
#   'pivotal',
#   'labs',
#   '2014',
#   'talk',
#   'describes',
#   'benefits',
#   'techniques',
#   'increasing',
#   'engineering',
#   'product',
#   'team',
#   'diversity'],
#  ['coding',
#   'towards',
#   'diversity',
#   '\u200b-',
#   '’',
#   'reilly',
#   'fluent',
#   'conference',
#   '2013',
#   'talk',
#   'takes',
#   'programmatic',
#   'approach',
#   'solving',
#   'diversity',
#   'problem',
#   'tech',
#   'industry'],
#  ['aqua',
#   'cool',
#   'clean',
#   'drink',
#   'ruby',
#   'object',
#   'persistence',
#   '-\u200b',
#   'rubyconf',
#   '2009',
#   'proof_concept',
#   'talk',
#   'creating',
#   'transparent',
#   'persistence_layer',
#   'pure',
#   'ruby',
#   'objects'],
#  ['selected',
#   'technical',
#   'writing',
#   'choose',
#   'design',
#   'architecture',
#   '\u200b-',
#   '18f',
#   'blog',
#   'https',
#   '//18f.gsa.gov/2015/11/17/choose-design-over-architecture',
#   'inverting',
#   'architectural',
#   'emphasis'],
#  ['voted',
#   'front',
#   'page',
#   'hacker',
#   'news',
#   'one',
#   'popular',
#   'post',
#   '18f',
#   'blog',
#   '2015'],
#  ['code',
#   'symptom',
#   '\u200b-',
#   'personal',
#   'blog',
#   'https',
#   '//medium.com/',
#   '@',
#   'rubyghetto/the-code-is-just-the-symptom-c77f43b29320',
#   'two',
#   'different',
#   'companies',
#   'leadership',
#   'conway',
#   '’',
#   'law',
#   'lead',
#   'problems',
#   'seen',
#   'deep',
#   'code'],
#  ['60,000', 'views'],
#  ['voted', 'front', 'page', 'hacker', 'news'],
#  ['education_university',
#   'california',
#   'berkeley',
#   'california',
#   '2',
#   '\u200b',
#   '002',
#   '2004',
#   'advanced',
#   'technical',
#   'coursework',
#   'bs',
#   'mechanical_engineering',
#   'uc',
#   'berkeley',
#   'extension',
#   'san_francisco',
#   'california',
#   '1',
#   '\u200b',
#   '998',
#   '1999',
#   'professional',
#   'coursework',
#   'software',
#   'database_design',
#   'san_francisco',
#   'art',
#   'institute',
#   'san_francisco',
#   'california',
#   '\u200b-',
#   '1993',
#   'bfa',
#   'painting',
#   'volunteer',
#   'work',
#   'board_directors',
#   'industry',
#   'technical',
#   'advisor',
#   'women',
#   'code',
#   'inc.',
#   'december',
#   '2013',
#   'june_2015',
#   '\\n',
#   'nirali',
#   'deliwala',
#   '301-683-4339',
#   'nirali18',
#   '@_umd.edu',
#   '8125_48th',
#   'avenue_apt',
#   '520',
#   'college_park_md_20740',
#   'education_university_maryland_college',
#   'park_md',
#   'expected_may_2018',
#   'masters_science',
#   'telecommunications',
#   'relevant_coursework',
#   'networks_protocols',
#   'ii',
#   'network',
#   'programming',
#   'using',
#   'c',
#   'digital_communication',
#   'systems',
#   'network',
#   'design',
#   'configuration',
#   'lab',
#   'cellular_communication_networks',
#   'telecoms',
#   'marketing',
#   'management',
#   'k.j'],
#  ['somaiya_college_engineering',
#   'autonomous',
#   'affiliated',
#   'university_mumbai',
#   '2011-2015',
#   'bachelor_engineering',
#   'electronics',
#   'relevant_coursework',
#   'networks_protocols',
#   'communication_networks',
#   'digital_communication',
#   'coding',
#   'techniques',
#   'technical',
#   'experience',
#   'accenture_services',
#   'pvt'],
#  ['ltd.',
#   'paid',
#   'june_2015',
#   '–_june_2016',
#   'associate_software_engineer',
#   'ase',
#   'project',
#   'project_name',
#   'lyondell',
#   'basell',
#   'chemical',
#   'company',
#   'objects',
#   'worked',
#   'worked',
#   'design_development_testing',
#   'support',
#   'sap_abap',
#   'developer',
#   'meet',
#   'business_needs'],
#  ['analyzed', 'functional_specification'],
#  ['created', 'technical_specification'],
#  ['developed',
#   'custom',
#   'objects',
#   'reports',
#   'email',
#   'standardization',
#   'sap',
#   'scripts',
#   'adobe',
#   'forms',
#   'skills',
#   'networking',
#   'software',
#   'cisco_packet_tracer',
#   'wireshark',
#   'programming_language',
#   'c_c++_java',
#   'sap_abap',
#   'html_python',
#   'operating_systems_windows',
#   'android',
#   'software',
#   '’',
#   'matlab',
#   'scilab',
#   'kiel',
#   'pspice',
#   'labview',
#   'eagle',
#   'proteus',
#   'autocad',
#   'microwind',
#   'projects',
#   'design',
#   'ip_domain_dossier_system',
#   'december_2016',
#   '•designed',
#   'client-server',
#   'system',
#   'using',
#   'socket_programming',
#   'c',
#   'linux',
#   'environment',
#   'using',
#   'tcp/ip',
#   'protocol'],
#  ['•implemented',
#   'server_side',
#   'using',
#   'linked_list',
#   'performs',
#   'serval',
#   'tasks',
#   'depending',
#   'request',
#   'code',
#   'passed',
#   'client',
#   '-to',
#   'find',
#   'add',
#   'delete',
#   'get',
#   'least',
#   'requested',
#   'record',
#   'data',
#   'base'],
#  ['-reject',
#   'inquiry',
#   'another',
#   'inquiry',
#   'received',
#   'originated',
#   'address',
#   'last',
#   '10',
#   'seconds'],
#  ['-shutdown', 'connection'],
#  ['•generated', 'log_file', 'events', 'occur', 'server_side'],
#  ['line',
#   'log_file',
#   'starts',
#   'date',
#   'time',
#   'provides',
#   'detailed',
#   'information',
#   'event'],
#  ['design',
#   'facial',
#   'emotion',
#   'recognition',
#   'system',
#   'may_2015',
#   '•detected',
#   'different',
#   'emotions',
#   'depicted',
#   'image',
#   'using',
#   'matlab',
#   '•accomplished',
#   'training',
#   'images',
#   'using',
#   'artificial',
#   'neural',
#   'network'],
#  ['implemented',
#   'image_processing',
#   'techniques',
#   'remove',
#   'unwanted',
#   'noise',
#   'background'],
#  ['classified',
#   'emotion',
#   'depicted',
#   'image',
#   'one',
#   'following',
#   'category-',
#   'happy',
#   'sad',
#   'neutral',
#   'angry',
#   'testing'],
#  ['design',
#   '8-contestant',
#   'quiz',
#   'buzzer',
#   'december_2014',
#   'developed',
#   'quiz',
#   'buzzer',
#   'using',
#   'microcontroller',
#   '89c51'],
#  ['executed',
#   'code',
#   'keil',
#   'simulated',
#   'using',
#   'proteus',
#   'implemented',
#   'pcb'],
#  ['design',
#   'electronic',
#   'harmonium',
#   'december',
#   '2013',
#   'based',
#   'ic-555',
#   'worked',
#   'oscillator'],
#  ['used',
#   'pcb',
#   '15',
#   'parallel',
#   'strips',
#   'strip',
#   'corresponding',
#   'one',
#   'note'],
#  ['additional',
#   'activities',
#   'participated',
#   'volunteer',
#   'technical_festival',
#   'abhyantriki',
#   'publicity',
#   'event'],
#  ['2013',
#   'assisted',
#   'event',
#   'head',
#   'various',
#   'events',
#   'cultural_festival',
#   'symphony'],
#  ['2014',
#   'worked',
#   'accenture',
#   'colleagues',
#   'hope',
#   'foundation',
#   'non-profit',
#   'organization',
#   'mumbai'],
#  ['2015',
#   'https',
#   '//www.linkedin.com/in/niralideliwala\\n',
#   'muhammad',
#   'afolayan',
#   '1129',
#   'quantril',
#   'way♦',
#   'baltimore_md',
#   '21205',
#   '240-593-1192',
#   '♦',
#   'afolayan.muhammad',
#   '@_gmail.com_education_university',
#   'maryland_college_park',
#   'bachelor_science',
#   '[',
#   'economics',
#   ']',
#   'class',
#   '2017',
#   '[',
#   'college_park',
#   'scholars',
#   ']',
#   'august_2011',
#   '–_may_2013',
#   '\uf0b7',
#   'developed',
#   'leadership_skills',
#   'experiences',
#   'internships',
#   'research',
#   'community_service'],
#  ['work_experience',
#   'bk',
#   'motors',
#   'baltimore_md',
#   'marketing/',
#   'administrative',
#   'june_2009',
#   '–_august',
#   '2011',
#   '\uf0b7_analyzed',
#   'prospective',
#   'client',
#   'portfolios',
#   'find',
#   'suitable',
#   'fit',
#   'client',
#   'company'],
#  ['\uf0b7',
#   'established',
#   'improved',
#   'client',
#   'communications',
#   ';',
#   'maintained',
#   'ongoing',
#   'relationships'],
#  ['\uf0b7',
#   'addressed',
#   'client',
#   'inquiries',
#   ';',
#   'interpreted',
#   'delivered',
#   'information',
#   ';',
#   'proposed',
#   'suggestions'],
#  ['conferences',
#   'visitors',
#   'services',
#   'customer',
#   'service/',
#   'hospitality',
#   '\uf0b7',
#   'planned_coordinated',
#   'executive',
#   'events'],
#  ['\uf0b7', 'trained', 'community', 'assistant', 'ca'],
#  ['college_park_md',
#   'summer',
#   '2013_–',
#   'summer_2014',
#   'footnotes',
#   'café',
#   'college_park_md',
#   'customer_service',
#   'february',
#   '2015-present',
#   '\uf0b7',
#   'often',
#   'said',
#   'bring',
#   'positive',
#   'atmosphere',
#   'work',
#   'regularly'],
#  ['\uf0b7',
#   'immensely',
#   'helped',
#   'sales',
#   'team_leader',
#   'taking',
#   'initiative'],
#  ['\uf0b7',
#   'gained',
#   'positive',
#   'feedback',
#   'customers',
#   'supervisors',
#   'exceptional',
#   'customer_service'],
#  ['money',
#   'one',
#   'federal',
#   'credit',
#   'union',
#   'account',
#   'associate',
#   '\uf0b7',
#   'promoted',
#   'overall',
#   'efficiency',
#   'bank',
#   'making',
#   'several',
#   'contributions',
#   'management'],
#  ['\uf0b7', 'performing', 'clerical', 'duties'],
#  ['\uf0b7', 'selling', 'financial_services'],
#  ['\uf0b7', 'supporting', 'bank', 'sales', 'identifying', 'customer', 'needs'],
#  ['greenbelt_md',
#   'leadership_experience',
#   'campus',
#   'mentoring',
#   'bigs',
#   'college_park_md',
#   'mentor',
#   'fall',
#   '2012_–',
#   'spring',
#   '2013',
#   '\uf0b7',
#   'big/little',
#   'mentoring',
#   'program',
#   ';',
#   'assisted',
#   'freshman',
#   'transition',
#   'high_school',
#   'college'],
#  ['randallstown',
#   'islamic',
#   'center',
#   'youth',
#   'leader',
#   '\uf0b7',
#   'regularly',
#   'took',
#   'charge',
#   'important',
#   'tasks',
#   'activities',
#   'around',
#   'mosque',
#   '\uf0b7',
#   'overseeing',
#   'development',
#   'personal',
#   'development',
#   'youth',
#   'members'],
#  [],
#  ['skills',
#   'volunteer',
#   'interests',
#   'skills',
#   '[',
#   'advanced',
#   'use',
#   'microsoft_word',
#   'typing',
#   '70',
#   'words',
#   'per',
#   'minute',
#   'powerpoint_excel',
#   ']',
#   'languages',
#   '[',
#   'fluent',
#   'yoruba',
#   ']',
#   'volunteer',
#   'several',
#   'community_service',
#   'events',
#   'incentive',
#   'awards',
#   'scholarship',
#   'program'],
#  ['affiliations',
#   'african',
#   'student_association',
#   'asa',
#   ';',
#   'muslim',
#   'student_association',
#   'msa',
#   ';',
#   'soccer_club',
#   'interests',
#   'soccer',
#   'problem_solving',
#   'technology',
#   'gaming',
#   'weightlifting',
#   'art'],
#  ['randallstown',
#   'md',
#   'spring',
#   '2012',
#   '\\n',
#   'terence',
#   'mcpartland',
#   'pmp',
#   'designer',
#   'problem',
#   'solver',
#   '30+',
#   'years',
#   'application',
#   'analysis_design',
#   'full',
#   'software_development_lifecycle',
#   'focus',
#   'creating',
#   'actionable',
#   'data',
#   'decision_making'],
#  ['specialty', 'business_process', 'design', 'data', 'lifecycle'],
#  ['extensive',
#   'project_management',
#   'experience',
#   'excellent',
#   'analytic',
#   'communication_skills'],
#  ['past',
#   'projects',
#   'census',
#   'business',
#   'system',
#   '–',
#   'financial',
#   'feeder',
#   'application',
#   'modernization',
#   'overhauled',
#   'external',
#   'accounts_payable',
#   'receivable',
#   'systems',
#   'including',
#   'database',
#   'redesign',
#   'service_oriented_architecture',
#   'requirements',
#   'business_process',
#   'reengineering'],
#  ['streamlined',
#   'build',
#   'time',
#   'new',
#   'apps',
#   'reduced',
#   'application',
#   'maintenance',
#   'costs',
#   'factor',
#   '20'],
#  ['engineered',
#   'solutions',
#   'corrected',
#   'hundreds',
#   'thousands',
#   'dollars',
#   'vendor',
#   'overpayments'],
#  ['paradyme_management',
#   '–',
#   'quality',
#   'management',
#   'systems',
#   'implementation',
#   'reengineered',
#   'corporate',
#   'business_processes',
#   'support',
#   'iso_9001',
#   'cmmi_level',
#   '3',
#   'certifications'],
#  ['designed',
#   'new',
#   'systems',
#   'data_structures',
#   'compliance',
#   'procedures',
#   'collect',
#   'maintain',
#   'review',
#   'performance_metrics',
#   'aspects',
#   'corporate',
#   'operations'],
#  ['district_columbia',
#   'government',
#   '–',
#   'cost',
#   'driver',
#   'project',
#   'created',
#   'methods',
#   'systems',
#   'assessing',
#   'return',
#   'investment',
#   'district',
#   'spending',
#   'across',
#   '75',
#   'separate',
#   'agencies',
#   'per',
#   'budget',
#   'line',
#   'basis'],
#  ['designed',
#   'financial',
#   'reporting',
#   'system',
#   'identified',
#   'cost',
#   'drivers',
#   'tracked',
#   'actual',
#   'cost',
#   'impact',
#   'policy',
#   'decisions',
#   'using',
#   'statistical',
#   'methods'],
#  ['provided',
#   'data_driven',
#   'oversight',
#   'saved',
#   'millions',
#   'year',
#   'overtime',
#   'management'],
#  ['district_columbia',
#   'government',
#   '–',
#   'educational',
#   'data_warehouse',
#   'developed',
#   'requirements',
# ...
#   'activities'],
#  ['\uf0b7',
#   'leading',
#   'supporting',
#   'business',
#   'development',
#   'participating',
#   'architecture',
#   'studies',
#   'review',
#   'supporting',
#   'cost',
#   'estimating',
#   'development',
#   'project',
#   'plans',
#   'include',
#   'integration_testing',
#   'promotion',
#   'production',
#   'operations_maintenance',
#   'activities',
#   'developing',
#   'cost',
#   'proposals',
#   'submission',
#   'clients',
#   'participating',
#   'negotiation',
#   'sessions',
#   'clients',
#   'establish',
#   'contract',
#   'effort',
#   'monitoring',
#   'controlling',
#   'project',
#   'related',
#   'costs'],
#  ['\uf0b7',
#   'provided',
#   'c-level',
#   'advising',
#   'client_’',
#   'senior_management',
#   'ibm_websphere_portal',
#   'strategy',
#   'enterprise_wide',
#   'implementations'],
#  ['joseph', 'cristiano', 'jr.', 'paradyme_management_inc'],
#  ['page_2',
#   '3',
#   '2002_–',
#   '2004',
#   'unisys',
#   'corporation',
#   'project_manager',
#   '2000',
#   '–2002',
#   'andersen',
#   'llp',
#   'manager',
#   'telecorp',
#   'pcs',
#   '1999',
#   '2000',
#   'senior',
#   'manager',
#   'carramerica',
#   'realty',
#   'corporation',
#   'cre',
#   '1998',
#   '1999',
#   'manager',
#   '1993',
#   '–',
#   '1998',
#   'discovery',
#   'communications',
#   'inc'],
#  ['manager',
#   'sandy',
#   'spring',
#   'national',
#   'bank',
#   '1987',
#   '1993',
#   'network',
#   'manager/customer',
#   'service',
#   'sandy',
#   'spring',
#   'national',
#   'bank',
#   '1985',
#   '1987',
#   'customer_service',
#   'representative',
#   'education_bachelor_arts',
#   'liberal',
#   'arts',
#   'specialization',
#   'business',
#   'cum_laude',
#   'american',
#   'university',
#   'washington_d.c.',
#   'joseph',
#   'cristiano',
#   'jr.',
#   'paradyme_management_inc'],
#  ['page_3', '3', '\\n', 'ishmeet', 'singh', '8125_48th_ave_apt'],
#  ['514',
#   'college_park_md_20740',
#   '240',
#   '714-2866',
#   'ishmeetsingh1973',
#   '@_gmail.com_education_university',
#   'maryland',
#   'ms_telecommunications_engineering',
#   '–',
#   '3.76',
#   'gpa',
#   'college_park_md_expected',
#   'may_2018',
#   'itm',
#   'university',
#   'b.tech',
#   'electronics',
#   'communications',
#   '–',
#   '3.7',
#   'gpa',
#   'gurgaon_india',
#   'may_2015',
#   'experience',
#   'compro',
#   'technologies',
#   'new_delhi_india',
#   'associate_software',
#   'testing',
#   'engineer',
#   'feb_2016',
#   '–_july_2016',
#   '\uf0b7',
#   'independently',
#   'functional',
#   'validation',
#   'gradeit',
#   'pct',
#   'applications',
#   '\uf0b7',
#   'coordinated',
#   'development',
#   'team',
#   'regarding',
#   'bug_fixes',
#   'smooth',
#   'delivery',
#   'project',
#   'content',
#   'client',
#   '\uf0b7',
#   'configured',
#   'new',
#   'projects',
#   'mb',
#   'unit',
#   'regression_testing',
#   'aircel',
#   'ltd.',
#   'new_delhi_india',
#   'intern',
#   'may_2014',
#   '–_july',
#   '2014',
#   '\uf0b7_studied',
#   'gsm',
#   'network',
#   'detail',
#   'attained',
#   'practical',
#   'knowledge',
#   'visiting',
#   'msc',
#   'site',
#   '\uf0b7',
#   'assisted',
#   'senior',
#   'personnel',
#   'resolve_issues',
#   'like',
#   'call',
#   'drop',
#   'call',
#   'muting',
#   'network',
#   'registration',
#   'failure',
#   'etc'],
#  ['siemens',
#   'ltd.',
#   'gurgaon_india',
#   'intern_june',
#   '2013_–',
#   'july_2013',
#   '\uf0b7_analyzed',
#   'non-conformance',
#   'costs',
#   'data',
#   'various',
#   'plants',
#   'across',
#   'nation',
#   'published',
#   'report',
#   '\uf0b7_collaborated',
#   'various_departments',
#   'perform',
#   'root_cause_analysis',
#   'issues',
#   'academic_projects',
#   'edge',
#   'detection',
#   'images',
#   'using',
#   'matlab',
#   '\uf0b7',
#   'developed',
#   'algorithm',
#   'matlab',
#   'identify',
#   'discontinuities',
#   'surface',
#   '\uf0b7',
#   'designed',
#   'gui',
#   'serve',
#   'functions',
#   'like',
#   'open',
#   'save',
#   'clear',
#   'close',
#   'et',
#   'al'],
#  ['aug_2014',
#   '–_may_2015',
#   'carry-skip',
#   'adder',
#   'using',
#   'cadence',
#   'aug_2014',
#   '–_dec_2014',
#   '\uf0b7',
#   'performed',
#   'transient',
#   'analysis',
#   'using',
#   'virtuouso',
#   'make',
#   'quantitative',
#   'qualitative',
#   'comparison',
#   'various',
#   'adders',
#   '\uf0b7',
#   'published',
#   'research_paper',
#   'international_journal',
#   'vlsi',
#   'system',
#   'design',
#   'communication',
#   'systems',
#   'ijvdcs',
#   'low',
#   'power',
#   'techniques',
#   'vlsi',
#   'using',
#   'cadence',
#   'aug_2014',
#   '–_dec_2014',
#   '\uf0b7',
#   'computed',
#   'transient',
#   'analysis',
#   'virtuouso',
#   'implementing',
#   'techniques',
#   'like',
#   'stacking',
#   'mtcmos',
#   'reduce',
#   'leakage',
#   'power',
#   'cmos',
#   'circuit',
#   'clap',
#   'counter',
#   'using',
#   '8051',
#   'micro',
#   'controller',
#   'dec_2013',
#   '–_may_2014',
#   '\uf0b7',
#   'integrated',
#   'sound',
#   'sensor',
#   'at89c51',
#   'lcd',
#   'module',
#   'increased',
#   'count',
#   '1',
#   'every',
#   'time',
#   'sound',
#   'produced',
#   '\uf0b7',
#   'verified',
#   'code',
#   'keil',
#   'µvision',
#   'circuit',
#   'isis',
#   'proteus',
#   '7',
#   'implementing',
#   'circuit',
#   'pcb',
#   'board',
#   'skills_programming',
#   'skills',
#   'c',
#   'python',
#   'protocols',
#   'known',
#   'rip',
#   'rip',
#   'v2',
#   'ospf_bgp',
#   'igrp_eigrp',
#   'framework',
#   'mbunit',
#   'database',
#   'sql_server_2008',
#   'applications',
#   'microsoft_word',
#   'excel',
#   'access',
#   'powerpoint',
#   'keil',
#   'virtuoso',
#   'activities',
#   'subah',
#   '\uf0b7',
#   'worked',
#   'local',
#   'ngo',
#   'projects',
#   'focused',
#   'health',
#   'poverty',
#   'may_2014',
#   '–_may_2016',
#   'data',
#   'compilation',
#   'team',
#   '\uf0b7',
#   'formulated',
#   'shared',
#   'results',
#   'various',
#   'events',
#   'annual',
#   'university',
#   'cultural',
#   'fest',
#   'jury',
#   'global',
#   'young',
#   'leaders',
#   'conference',
#   'gylc',
#   '\uf0b7',
#   'participated',
#   'model',
#   'un',
#   'washington_dc',
#   'new_york',
#   'representing',
#   'russian',
#   'federation',
#   'oct',
#   '2012',
#   'june_2009',
#   '\\n',
#   'samyak',
#   'shah',
#   '3406',
#   'tulane_drive',
#   '21',
#   'hyattsville_md_20783',
#   'education',
#   '240',
#   '-360-6597',
#   'samyak.shah',
#   '@_rhsmith.umd.edu',
#   'robert_h._smith_school',
#   'business_university_maryland_college',
#   'park_md',
#   'aug_2015-',
#   'dec_2016_master_science',
#   'ms',
#   'information_systems',
#   'gre',
#   '325/340',
#   ';',
#   'gpa',
#   '3.8/4',
#   'data_networks_infrastructure',
#   'database',
#   'management_system',
#   'managing_digital',
#   'markets',
#   'data_models_decisions',
#   'big_data_data_mining',
#   'predictive_analytics',
#   'business_process_analysis',
#   'strategic',
#   'k',
#   'j',
#   'somaiya_college_engineering',
#   'university_mumbai',
#   'jul',
#   '2011-may',
#   '2015',
#   'bachelor',
#   'engineering-computer',
#   'engineering',
#   '–first',
#   'class',
#   'publications',
#   '–',
#   '‘',
#   'somewhat',
#   'homomorphic',
#   'encryption',
#   'key',
#   'management',
#   'protocol',
#   '’_‘',
#   'big_data',
#   'analytics',
#   'using',
#   'r',
#   '’',
#   'experience',
#   'rak',
#   'commodities',
#   'mumbai_india',
#   'analyst_intern',
#   'jun',
#   '2014-jul',
#   '2014',
#   '\uf0a7',
#   'provided',
#   'commodities',
#   'analysis',
#   'valuation',
#   '20',
#   'valued',
#   'customers',
#   'firm',
#   '\uf0a7',
#   'performed',
#   'data_analysis',
#   'using_excel',
#   '–',
#   'vlookup',
#   'visual_basic',
#   'macros',
#   'pivot_tables',
#   'mark-to',
#   'market',
#   'calculation',
#   'helped',
#   'increase',
#   'prediction',
#   'accuracy',
#   'commodities',
#   'pricing',
#   'projects',
#   'encryption',
#   'cloud_computing',
#   'jul',
#   '2014-jun',
#   '2015',
#   '\uf0a7',
#   'somewhat',
#   'homomorphic',
#   'encryption',
#   'cloud',
#   '-achieved',
#   'encryption',
#   'amazon_web_services',
#   'dynamodb',
#   'nosql',
#   'cloud',
#   'database',
#   'using',
#   'java',
#   'aws',
#   'sdk',
#   'reducing_time',
#   'taken',
#   'query',
#   'processing',
#   'encrypted',
#   'data',
#   'following',
#   'software_development_lifecycle',
#   '\uf0a7',
#   'prepared',
#   'software',
#   'requirement_specification',
#   'srs',
#   'document',
#   'software',
#   'architecture',
#   'project_management',
#   'plan',
#   'testing',
#   'user',
#   'manual',
#   'using_rational_rose',
#   'visio',
#   'customer_care',
#   'database',
#   'management',
#   'sep',
#   '2015-dec_2015',
#   '\uf0a7',
#   'built',
#   'suite',
#   'database',
#   'backend',
#   'sql_server_2012',
#   'tables',
#   'views',
#   'transactional',
#   'queries',
#   'frontend',
#   'salesforce.com',
#   'using',
#   'reports_dashboards',
#   'views',
#   'workflow',
#   'rules',
#   'validation',
#   'rules',
#   'permission',
#   'sets',
#   'page',
#   'layouts',
#   'banking',
#   'data',
#   'data_analysis',
#   'using_tableau',
#   'jan',
#   '2016-feb',
#   '2016_\uf0a7',
#   'investigated',
#   'dognition',
#   'company',
#   'data',
#   'set',
#   'designed',
#   'structured',
#   'pyramid',
#   'analysis',
#   'plan',
#   'analyzed',
#   'using_tableau',
#   'importing',
#   'excel',
#   'data',
#   'tableau',
#   'creating',
#   'data',
#   'views',
#   'dashboard',
#   'filters',
#   'parameters',
#   'calculated',
#   'fields',
#   'published',
#   'recommendation',
#   'report',
#   'client-',
#   'based',
#   'project',
#   'following',
#   'scrum_methodology',
#   'feb',
#   '2016-_may_2016',
#   '\uf0a7',
#   'developing',
#   'application',
#   'student',
#   'peer',
#   'reviews',
#   'related',
#   'analytics',
#   'part',
#   'scrum_team',
#   'java',
#   'sql',
#   'using',
#   'ibm_bluemix',
#   'web_services',
#   'also',
#   'participating',
#   'scrum',
#   'ceremonies',
#   'data_mining_predictive_analytics',
#   'using',
#   'r',
#   '\uf0a7',
#   'working',
#   'rossman',
#   'stores',
#   'dataset',
#   'analyze',
#   'data',
#   'using',
#   'knn',
#   'naïve_bayes',
#   'classification',
#   'regression',
#   'algorithms',
#   'predict',
#   'store',
#   'sales',
#   '7',
#   'weeks'],
#  ['leadership',
#   'youth',
#   'vision',
#   'consultant',
#   'hanoi_vietnam',
#   'jun',
#   '2013-',
#   'jul_2013',
#   '\uf0a7',
#   'planned_managed',
#   '‘',
#   'vietnam',
#   'youth',
#   'icon',
#   '’',
#   'project',
#   'including',
#   'four',
#   'day',
#   'camps',
#   'event',
#   'named',
#   'international',
#   'youth',
#   'day'],
#  ['worked',
#   '15',
#   'interns',
#   '12',
#   'different',
#   'countries',
#   'month',
#   'catered',
#   'around',
#   '150',
#   'delegates',
#   'aiesec',
#   'navi',
#   'mumbai_india',
#   'feb',
#   '2013-feb',
#   '2015',
#   '\uf0a7',
#   'arranged',
#   'youth',
#   'leadership',
#   'conference',
#   'core_committee',
#   'logistics',
#   'february_2015',
#   'silvassa',
#   'india',
#   'catering',
#   '400',
#   'delegates',
#   'country',
#   '\uf0a7_led_team',
#   '5',
#   'people',
#   'team_leader',
#   'human_resources',
#   'january',
#   '2014-december',
#   '2014',
#   'responsible',
#   'talent',
#   'planning',
#   'acquisition',
#   'training',
#   'retention',
#   'managed',
#   'around',
#   '40',
#   'employees',
#   '\uf0a7',
#   'acted',
#   'team_leader',
#   'international',
#   'student',
#   'exchange',
#   'social',
#   'january',
#   '2013-',
#   'june_2013',
#   'increased',
#   'number',
#   'exchanges',
#   '250',
#   'additional_information_\uf0a7',
#   'technical',
#   'java_c++',
#   'html_sql',
#   'salesforce.com',
#   'tableau_r',
#   'wireshark',
#   'microsoft_excel',
#   'statistical',
#   'tools',
#   '@_risk',
#   'precisiontree',
#   'stattools',
#   'solvertable',
#   'visio_rational',
#   'rose',
#   'python',
#   'sharepoint',
#   'hadoop',
#   'impala',
#   'pig_hive',
#   '[',
#   'may_2016',
#   ']',
#   'spark',
#   '[',
#   'may_2016',
#   ']',
#   'microsoft',
#   'project_management',
#   'ms_access',
#   'weka',
#   '\uf0a7',
#   'online_courses',
#   'intermediate',
#   'r',
#   'data_analysis',
#   'r',
#   'machine_learning',
#   'r',
#   'software',
#   'processes',
#   'agile_practices',
#   'amazon_web',
#   'services-',
#   'big_data',
#   'technology',
#   'fundamentals',
#   'hadoop',
#   'application',
#   'development',
#   'framework'],
#  ['\\n',
#   'arpit',
#   'kapoor',
#   '8125',
#   '48thave',
#   '509',
#   '■_college',
#   'park_md_20740',
#   '■',
#   '240.481.4996',
#   '■',
#   'arpit.kapoor',
#   '@_rhsmith.umd.edu',
#   '■',
#   'www.linkedin.com/in/arpit-kapoor',
#   'education_robert_h._smith',
#   'school_business_university_maryland',
#   'december_2017',
#   'master_science_information_systems',
#   'gre',
#   '322',
#   'coursework',
#   'data_models_decisions',
#   'dbms',
#   'managing_digital_business_markets',
#   'bigdata',
#   'data_mining_predictive_analysis',
#   'strategic',
#   'business_process_analysis',
#   'data_networks_infrastructure',
#   'thapar',
#   'university',
#   'patiala',
#   'india_bachelor',
#   'engineering_major',
#   'electronics',
#   'instrumentation',
#   'control',
#   'june_2013',
#   'technical_skills_programming_languages',
#   'c_c++',
#   'perl_shell',
#   'scripting',
#   'sql_python',
#   'tools',
#   'cygwin',
#   'iperf',
#   'tera',
#   'term',
#   'perl',
#   'modules',
#   'wireshark',
#   'jenkins',
#   'fail2ban',
#   'apache-tomcat',
#   'git',
#   'ansible',
#   'microsoft_office',
#   'tableau_excel',
#   'salesforce',
#   'sql',
#   'management_studio',
#   'lucid',
#   'chart',
#   'operating_systems',
#   'windows_linux',
#   'mac_os_x',
#   'professional_experience',
#   'lybrate',
#   'india_pvt_ltd',
#   'faridabad',
#   'india',
#   '2015_–',
#   '2016',
#   'devops_engineer',
#   '\uf0a7',
#   'managed',
#   '3-member',
#   'team',
#   'responsible',
#   'daily',
#   'build',
#   'releases',
#   'maintaining',
#   'website',
#   'support',
#   '3000',
#   'daily',
#   'transactions'],
#  ['jenkins',
#   'aws',
#   'apache-tomcat',
#   '\uf0a7',
#   'planned',
#   'developed',
#   'automation',
#   'frameworks',
#   'analyzed',
#   'implemented_new',
#   'tools',
#   'methods',
#   'scale',
#   'technology'],
#  ['shell',
#   'sql',
#   'ansible',
#   '\uf0a7',
#   'installed',
#   'implemented',
#   'security',
#   'programs',
#   '8',
#   'servers',
#   'monitored',
#   'network',
#   'inefficiencies'],
#  ['\uf0a7_analyzed',
#   'user',
#   'feedback',
#   'reported',
#   'critical',
#   'software',
#   'bugs',
#   'resulting',
#   'customer_satisfaction',
#   'relationship_management'],
#  ['\uf0a7',
#   'supervised',
#   'configuration',
#   'tool',
#   'prevent',
#   'phishing',
#   'attacks'],
#  ['helped',
#   'reduce',
#   'constant',
#   'monitoring',
#   'procedures',
#   'workload',
#   'bringing',
#   'server',
#   'overloads',
#   '50'],
#  ['fail2ban',
#   'cavium',
#   'networks',
#   'india_pvt',
#   'ltd_bangalore',
#   'india',
#   '2013_–',
#   '2015',
#   'system',
#   'validation',
#   'engineer',
#   '\uf0a7',
#   'coordinated',
#   'testing',
#   'across',
#   '4',
#   'offices',
#   'ensure',
#   'product',
#   'testing',
#   'end_end_testing',
#   'ipsec',
#   'testing',
#   '3',
#   'products'],
#  ['lte',
#   'small',
#   'cells',
#   'cellular_base',
#   'stations',
#   '\uf0a7_collaborated',
#   'developers',
#   'clients',
#   'site',
#   'teams',
#   'creating',
#   'testing',
#   'field',
#   'conditions',
#   'ensure',
#   'reliability',
#   'product'],
#  ['\uf0a7',
#   'created_executed',
#   'test_plans',
#   'performed',
#   'rigorous',
#   'testing',
#   'release',
#   'features',
#   'ensure',
#   'delivery',
#   'efficient',
#   'functional',
#   'product'],
#  ['\uf0a7_conducted',
#   'quality',
#   'functional_testing',
#   'reported',
#   'software',
#   'bugs',
#   'sample',
#   '128',
#   'users',
#   'incorporated',
#   'network',
#   'feedback'],
#  ['tm500',
#   'bugzilla',
#   'wireshark',
#   '\uf0a7',
#   'developed',
#   'automation_framework',
#   'end_end_testing'],
#  ['used',
#   'across',
#   '3',
#   'teams',
#   'decreasing_manual',
#   'work',
#   'mistakes',
#   '75'],
#  ['perl_shell',
#   'socket_programming',
#   'projects',
#   'university',
#   'rankings',
#   'database',
#   '\uf0a7',
#   'gathered',
#   'extracted',
#   'processed',
#   'data',
#   'regarding',
#   'three',
#   'courses',
#   'mba',
#   'msba',
#   'msis',
#   'across',
#   'universities',
#   'us',
#   'design',
#   'aggregator'],
#  ['\uf0a7',
#   'performed',
#   'data_transformation',
#   'upload',
#   'sql_server',
#   'using',
#   'sql_server_management_studio'],
#  ['\uf0a7',
#   'used',
#   'salesforce',
#   'help',
#   'visualize',
#   'data',
#   'using',
#   'dashboards',
#   'reports'],
#  ['telecom',
#   'services',
#   'analysis',
#   '\uf0a7',
#   'worked',
#   'team',
#   '5',
#   'analyze',
#   'provide',
#   'technology',
#   'consulting',
#   'telecom',
#   'service_provider',
#   'based',
#   'zambia'],
#  ['\\n',
#   'binod',
#   'kumar',
#   'singh',
#   '22650',
#   'shining',
#   'harness',
#   'street',
#   'clarksburg',
#   'md',
#   '20871',
#   'c',
#   '262-309-3367',
#   'bks.iitr',
#   '@_gmail.com',
#   'professional_summary',
#   '13',
#   'years',
#   'hands-on_experience',
#   'industry',
#   'expertise',
#   'design/development',
#   'delivery',
#   'client',
#   'server',
#   'applications',
#   'using',
#   'java_j2ee'],
#  ['keep',
#   'learning',
#   'applying',
#   'new',
#   'technology/feature',
#   'live',
#   'ongoing',
#   'projects'],
#  ['possess',
#   'blend',
#   'business',
#   'management',
#   'technical_skills',
#   'ability',
#   'translate',
#   'business_needs',
#   'real_world',
#   'solutions'],
#  ...]

# %%
import re

#Normalize bigram/trigram words 
def normalize_words (trigram_resume):
    for sentence in trigram_resume:
        for i, word in enumerate(sentence):   
            if len(re.findall(r'\w+\_\w+', word))!= 0:
                sentence[i] = re.sub('_', ' ', word)
    return trigram_resume

# %%
normalized_resume = normalize_words(trigram_resume)

# %%
#label skills in the resume
def labeled_word (sentence):
    labels=[]
    for word in sentence:
        if word in skill_list:
            labels.append((word, 'skill'))
        else:
            labels.append((word, 'not skill'))
    return labels

# %%
labeled_words=[labeled_word(sentence) for sentence in normalized_resume]
labeled_words
# Out:
# [[('jee', 'not skill'),
#   ('kang', 'not skill'),
#   ('3711', 'not skill'),
#   ('campus', 'not skill'),
#   ('drive', 'not skill'),
#   ('apt', 'not skill'),
#   ('139', 'not skill'),
#   ('college park md', 'not skill'),
#   ('4439447487', 'not skill'),
#   ('jwk1151', 'not skill'),
#   ('@ gmail.com education university', 'not skill'),
#   ('maryland college park', 'not skill'),
#   ('dual', 'not skill'),
#   ('degree', 'not skill'),
#   ('cumulative gpa', 'not skill'),
#   ('3.7', 'not skill'),
#   ('anticipated', 'not skill'),
#   ('fall', 'not skill'),
#   ('2018', 'not skill'),
#   ('b.s', 'not skill')],
#  [('physiology', 'not skill'),
#   ('neurobiology', 'not skill'),
#   ('b.s', 'not skill')],
#  [('computer science', 'not skill'),
#   ('relevant courses', 'not skill'),
#   ('object oriented programming', 'skill'),
#   ('ii', 'not skill'),
#   ('introduction computer systems', 'not skill'),
#   ('discrete structures', 'not skill'),
#   ('innovators', 'not skill'),
#   ('think', 'not skill')],
#  [('languages', 'not skill'),
#   ('technologies', 'not skill'),
#   ('languages java', 'not skill'),
#   ('c', 'skill'),
#   ('programs', 'not skill'),
#   ('eclipse', 'skill'),
#   ('android studio', 'skill'),
#   ('matlab', 'skill'),
#   ('latex', 'skill'),
#   ('labchart', 'skill'),
#   ('projects', 'not skill'),
#   ('projects', 'not skill'),
#   ('found', 'not skill'),
#   ('github', 'skill'),
#   ('github.com/jeekang', 'not skill'),
#   ('turnt', 'not skill'),
#   ('tower', 'not skill'),
#   ('2016', 'not skill'),
#   ('independently', 'not skill'),
#   ('developed', 'not skill'),
#   ('android', 'skill'),
#   ('app', 'not skill'),
#   ('augment', 'not skill'),
#   ('block', 'not skill'),
#   ('tower', 'not skill'),
#   ('game', 'not skill'),
#   ('jenga', 'not skill')],
#  [('app', 'not skill'),
#   ('features', 'not skill'),
#   ('attractive', 'not skill'),
#   ('user-friendly', 'not skill'),
#   ('interface', 'not skill')],
#  [('language', 'not skill'),
#   ('java', 'skill'),
#   ('android', 'skill'),
#   ('java-based', 'not skill'),
#   ('dna', 'not skill'),
#   ('template', 'not skill'),
#   ('strand', 'not skill'),
#   ('transcription/translation', 'not skill'),
#   ('2016', 'not skill'),
#   ('built', 'not skill'),
#   ('program', 'not skill'),
#   ('using', 'not skill'),
#   ('java', 'skill'),
#   ('takes', 'not skill'),
#   ('input', 'not skill'),
#   ('nucleotide', 'not skill'),
#   ('sequence', 'not skill'),
#   ('returns', 'not skill'),
#   ('complementary', 'not skill'),
#   ('strand', 'not skill'),
#   ('mrna', 'not skill'),
#   ('sequence', 'not skill'),
#   ('reading', 'not skill'),
#   ('frame', 'not skill'),
#   ('one', 'not skill'),
#   ('exists', 'not skill'),
#   ('amino', 'not skill'),
#   ('acid', 'not skill'),
#   ('sequence', 'not skill')],
#  [('independent', 'not skill'),
#   ('undergraduate', 'not skill'),
#   ('research', 'not skill'),
#   ('project', 'skill'),
#   ('2016', 'not skill'),
#   ('part', 'not skill'),
#   ('center', 'not skill'),
#   ('bioinformatics', 'not skill'),
#   ('computational', 'not skill'),
#   ('biology', 'not skill'),
#   ('university maryland', 'not skill')],
#  [('working', 'not skill'),
#   ('meta-genomic', 'not skill'),
#   ('analysis', 'not skill'),
#   ('algorithms', 'not skill'),
#   ('finding', 'not skill'),
#   ('limitations', 'not skill'),
#   ('existing', 'not skill'),
#   ('programs', 'not skill')],
#  [('details', 'not skill'),
#   ('determined', 'not skill'),
#   ('first', 'not skill'),
#   ('meeting', 'not skill'),
#   ('team', 'not skill'),
#   ('september', 'not skill'),
#   ('21st', 'not skill'),
#   ('achievements', 'not skill'),
#   ('received', 'not skill'),
#   ('integrated', 'not skill'),
#   ('life', 'not skill'),
#   ('sciences', 'not skill'),
#   ('honors college', 'not skill'),
#   ('citation', 'not skill'),
#   ('2014', 'not skill'),
#   ('received', 'not skill'),
#   ('presidential', 'not skill'),
#   ('scholarship', 'not skill'),
#   ('university maryland', 'not skill'),
#   ('fall', 'not skill'),
#   ('2012_–', 'not skill'),
#   ('spring 2016', 'not skill'),
#   ('scored', 'not skill'),
#   ('94th', 'not skill'),
#   ('percentile', 'not skill'),
#   ('mcats', 'not skill'),
#   ('jan 2015', 'not skill'),
#   ('6', 'not skill'),
#   ('semesters', 'not skill'),
#   ('dean_’_list', 'not skill'),
#   ('experience', 'not skill'),
#   ('affective', 'not skill'),
#   ('translational', 'not skill'),
#   ('neuroscience', 'not skill'),
#   ('laboratory', 'not skill'),
#   ('college park md', 'not skill'),
#   ('research assistant', 'not skill'),
#   ('fall', 'not skill'),
#   ('2013-', 'not skill'),
#   ('spring 2015', 'not skill'),
#   ('brainstormed', 'not skill'),
#   ('ideas', 'not skill'),
#   ('trial', 'not skill'),
#   ('stages', 'not skill'),
#   ('track', 'not skill'),
#   ('social', 'not skill'),
#   ('habits/movements', 'not skill'),
#   ('subjects', 'not skill')],
#  [('front-end', 'not skill'),
#   ('experience', 'not skill'),
#   ('briefed', 'not skill'),
#   ('debriefed', 'not skill'),
#   ('study', 'not skill'),
#   ('participants', 'not skill')],
#  [('worked', 'not skill'),
#   ('psychology', 'not skill'),
#   ('clinic', 'not skill'),
#   ('university maryland', 'not skill'),
#   ('using', 'not skill'),
#   ('titanium', 'not skill'),
#   ('excel', 'skill'),
#   ('manage', 'not skill'),
#   ('patient', 'not skill'),
#   ('dsm-5', 'not skill'),
#   ('data', 'skill')],
#  [('assisted', 'not skill'),
#   ('running', 'not skill'),
#   ('clinical', 'not skill'),
#   ('trials', 'not skill'),
#   ('involving', 'not skill'),
#   ('fmri', 'not skill'),
#   ('maryland', 'not skill'),
#   ('neuroimaging', 'not skill'),
#   ('center', 'not skill')],
#  [('\\n', 'not skill'),
#   ('yaw', 'not skill'),
#   ('owusu', 'not skill'),
#   ('appiah', 'not skill'),
#   ('experience summary', 'not skill'),
#   ('qualified', 'not skill'),
#   ('clearable', 'not skill'),
#   ('oracle database', 'not skill'),
#   ('12c/11g/10g/9i', 'not skill'),
#   ('dba', 'not skill'),
#   ('10 years', 'not skill'),
#   ('managing', 'not skill'),
#   ('working', 'not skill'),
#   ('leading', 'not skill'),
#   ('edge', 'not skill'),
#   ('projects', 'not skill'),
#   ('require', 'not skill'),
#   ('experience', 'not skill'),
#   ('diverse', 'not skill'),
#   ('oltp', 'not skill'),
#   ('big data', 'not skill'),
#   ('environments', 'not skill'),
#   ('team player', 'skill'),
#   ('proven', 'not skill'),
#   ('expertise', 'not skill'),
#   ('training', 'skill'),
#   ('education', 'not skill'),
#   ('well', 'not skill'),
#   ('experience', 'not skill'),
#   ('programming', 'skill'),
#   ('linux', 'skill'),
#   ('administration', 'not skill'),
#   ('oracle database', 'not skill'),
#   ('administration', 'not skill'),
#   ('asm', 'not skill'),
#   ('setup', 'not skill'),
#   ('oracle rac', 'not skill'),
#   ('10g/11g/12c', 'not skill'),
#   ('data guard', 'not skill'),
#   ('implementation', 'skill'),
#   ('real time', 'not skill'),
#   ('disaster recovery', 'not skill'),
#   ('skilled', 'not skill'),
#   ('leading', 'not skill'),
#   ('dbas', 'not skill'),
#   ('database', 'not skill'),
#   ('projects', 'not skill'),
#   ('within', 'not skill'),
#   ('different', 'not skill'),
#   ('methodologies', 'not skill'),
#   ('like', 'not skill'),
#   ('devops', 'skill'),
#   ('experience', 'not skill'),
#   ('leveraging', 'not skill'),
#   ('cots', 'not skill'),
#   ('gots', 'not skill'),
#   ('products', 'not skill'),
#   ('large', 'not skill'),
#   ('organizations', 'not skill'),
#   ('private', 'not skill'),
#   ('government', 'not skill'),
#   ('sectors', 'not skill'),
#   ('highly', 'not skill'),
#   ('exposed', 'not skill'),
#   ('big data', 'not skill'),
#   ('environments', 'not skill'),
#   ('excellent', 'not skill'),
#   ('skills', 'not skill'),
#   ('upgrade', 'not skill'),
#   ('migrations', 'not skill'),
#   ('applying', 'not skill'),
#   ('quarterly', 'not skill'),
#   ('patches', 'not skill'),
#   ('etc', 'not skill')],
#  [('versatile', 'not skill'),
#   ('establishing', 'not skill'),
#   ('client', 'not skill'),
#   ('relationships', 'not skill'),
#   ('understanding', 'not skill'),
#   ('business processes', 'not skill'),
#   ('user', 'not skill'),
#   ('tasks', 'not skill'),
#   ('goals', 'not skill'),
#   (';', 'not skill'),
#   ('analyzing', 'not skill'),
#   ('defining', 'not skill'),
#   ('requirements', 'not skill'),
#   ('ensure', 'not skill'),
#   ('efficient', 'not skill'),
#   ('cost-saving', 'not skill'),
#   ('technological', 'not skill'),
#   ('solutions', 'not skill'),
#   ('meet', 'not skill'),
#   ('exceed', 'not skill'),
#   ('client', 'not skill'),
#   ('needs', 'not skill'),
#   ('experienced', 'not skill'),
#   ('automating', 'not skill'),
#   ('database', 'not skill'),
#   ('creation', 'not skill'),
#   ('oracle', 'skill'),
#   ('response', 'not skill'),
#   ('files', 'not skill'),
#   ('linux', 'skill'),
#   ('shell scripts', 'not skill'),
#   ('versed', 'not skill'),
#   ('oracle', 'skill'),
#   ('management', 'skill'),
#   ('tools', 'not skill'),
#   ('utilities', 'not skill'),
#   ('like', 'not skill'),
#   ('oracle enterprise manager', 'not skill'),
#   ('grid', 'not skill'),
#   ('asmca', 'not skill'),
#   ('srvctl', 'not skill'),
#   ('crsctl', 'not skill'),
#   ('performance tuning', 'not skill'),
#   ('techniques', 'not skill'),
#   ('comprises', 'not skill'),
#   ('savvy', 'not skill'),
#   ('usage', 'not skill'),
#   ('indexes', 'not skill'),
#   ('tablespace', 'not skill'),
#   ('compression', 'not skill'),
#   ('i/o', 'not skill'),
#   ('minimizations', 'not skill'),
#   ('hardware', 'skill'),
#   ('raid', 'not skill'),
#   ('load balancing', 'skill'),
#   ('techniques', 'not skill')],
#  [('well', 'not skill'),
#   ('exposed', 'not skill'),
#   ('oracle', 'skill'),
#   ('engineered', 'not skill'),
#   ('systems', 'not skill'),
#   ('like', 'not skill'),
#   ('oda', 'not skill'),
#   ('oracle', 'skill'),
#   ('data', 'skill'),
#   ('appliance', 'not skill'),
#   ('experience', 'not skill'),
#   ('leveraging', 'not skill'),
#   ('systems', 'not skill'),
#   ('meet', 'not skill'),
#   ('challenging', 'not skill'),
#   ('evolving', 'not skill'),
#   ('client', 'not skill'),
#   ('data', 'skill'),
#   ('needs', 'not skill')],
#  [('core competencies', 'not skill'),
#   ('technical', 'skill'),
#   ('training', 'skill'),
#   ('oracle', 'skill'),
#   ('11g/10g/12c', 'not skill'),
#   ('database', 'not skill'),
#   ('administration', 'not skill'),
#   ('unix', 'skill'),
#   ('systems', 'not skill'),
#   ('solaris', 'not skill'),
#   ('aix', 'skill'),
#   ('linux', 'skill'),
#   ('linux/unix', 'not skill'),
#   ('administration', 'not skill'),
#   ('shell scripting', 'skill'),
#   ('capacity planning', 'not skill'),
#   ('systems', 'not skill'),
#   ('integration', 'not skill'),
#   ('oracle', 'skill'),
#   ('performance tuning', 'not skill'),
#   ('pl/sql', 'skill'),
#   ('programming', 'skill'),
#   ('technical documentation', 'not skill'),
#   ('technical', 'skill'),
#   ('leadership', 'skill'),
#   ('cloud computing', 'not skill'),
#   ('work experience', 'not skill'),
#   ('science', 'not skill'),
#   ('applications', 'not skill'),
#   ('international corporation', 'not skill'),
#   ('saic', 'not skill'),
#   ('december', 'not skill'),
#   ('2012', 'not skill'),
#   ('present', 'not skill'),
#   ('lead', 'not skill'),
#   ('oracle database administrator', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('lead', 'not skill'),
#   ('development', 'skill'),
#   ('custom', 'not skill'),
#   ('shell scripts', 'not skill'),
#   ('monitoring', 'not skill'),
#   ('specific', 'not skill'),
#   ('databases', 'skill'),
#   ('united states', 'not skill'),
#   ('citizenship', 'not skill'),
#   ('immigration', 'skill'),
#   ('services', 'not skill'),
#   ('department homeland security', 'not skill'),
#   ('led', 'not skill'),
#   ('automation', 'not skill'),
#   ('database', 'not skill'),
#   ('security', 'skill'),
#   ('audits', 'not skill'),
#   ('conducted', 'not skill'),
#   ('security', 'skill'),
#   ('team', 'not skill'),
#   ('saic', 'not skill')],
#  [('effort', 'not skill'),
#   ('cut', 'not skill'),
#   ('database', 'not skill'),
#   ('security', 'skill'),
#   ('auditing', 'not skill'),
#   ('time', 'not skill'),
#   ('50', 'not skill'),
#   ('relieved', 'not skill'),
#   ('several', 'not skill'),
#   ('hours', 'not skill'),
#   ('routine', 'not skill'),
#   ('dba', 'not skill'),
#   ('security', 'skill'),
#   ('staff', 'not skill'),
#   ('work', 'not skill')],
#  [('build', 'not skill'),
#   ('sops', 'not skill'),
#   ('implement', 'not skill'),
#   ('oracle', 'skill'),
#   ('migrations', 'not skill'),
#   ('11gr2', 'not skill'),
#   ('12c', 'not skill'),
#   (';', 'not skill'),
#   ('migration', 'not skill'),
#   ('activities', 'not skill'),
#   ('touch', 'not skill'),
#   ('oracle', 'skill'),
#   ('clusterware', 'not skill'),
#   ('automatic', 'not skill'),
#   ('storage', 'not skill'),
#   ('management', 'skill'),
#   ('layer', 'not skill'),
#   ('operating system', 'not skill'),
#   ('areas', 'not skill'),
#   ('support', 'not skill'),
#   ('oracle', 'skill'),
#   ('related', 'not skill'),
#   ('deployment', 'not skill'),
#   ('effort', 'not skill'),
#   ('uscis', 'not skill'),
#   ('electronic', 'not skill'),
#   ('immigration', 'skill'),
#   ('system', 'not skill'),
#   ('project', 'skill'),
#   ('elis', 'not skill')],
#  [('support', 'not skill'),
#   ('activities', 'not skill'),
#   ('include', 'not skill'),
#   ('performance tuning', 'not skill'),
#   ('exercises', 'not skill'),
#   ('backup recovery', 'not skill'),
#   ('rac', 'not skill'),
#   ('installations upgrades', 'not skill'),
#   ('patching', 'not skill'),
#   ('replication', 'not skill'),
#   ('disaster recovery', 'not skill'),
#   ('scripting', 'skill'),
#   ('data', 'skill'),
#   ('loading data', 'not skill'),
#   ('reporting', 'skill'),
#   ('provide support', 'not skill'),
#   ('dbas', 'not skill'),
#   ('use', 'not skill'),
#   ('maintain', 'not skill'),
#   ('customer', 'not skill'),
#   ('scripts', 'not skill'),
#   ('developed', 'not skill'),
#   ('database', 'not skill'),
#   ('housekeeping', 'not skill'),
#   ('tasks', 'not skill'),
#   ('backup recovery', 'not skill'),
#   ('shutdown', 'not skill'),
#   ('maintenance', 'not skill'),
#   ('work', 'not skill'),
#   ('etc', 'not skill')],
#  [('municipal', 'not skill'),
#   ('securities', 'not skill'),
#   ('rulemaking', 'not skill'),
#   ('board', 'not skill'),
#   ('alexandria va', 'not skill'),
#   ('december', 'not skill'),
#   ('2012', 'not skill'),
#   ('present', 'not skill'),
#   ('lead', 'not skill'),
#   ('oracle dba', 'not skill'),
#   ('linux', 'skill'),
#   ('instructor', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('led', 'not skill'),
#   ('dbas', 'not skill'),
#   ('migrating', 'not skill'),
#   ('various', 'not skill'),
#   ('oracle', 'skill'),
#   ('versions', 'not skill'),
#   ('windows linux', 'not skill'),
#   ('platform', 'not skill'),
#   ('evaluated', 'not skill'),
#   ('provided', 'not skill'),
#   ('technical', 'skill'),
#   ('recommendations', 'not skill'),
#   ('business continuity', 'not skill'),
#   ('solutions', 'not skill'),
#   ('msrb', 'not skill'),
#   ('data', 'skill'),
#   ('management', 'skill'),
#   ('teams', 'not skill'),
#   (';', 'not skill'),
#   ('evaluated', 'not skill'),
#   ('replication', 'not skill'),
#   ('solutions', 'not skill'),
#   ('like', 'not skill'),
#   ('goldengate', 'not skill'),
#   ('streams', 'not skill'),
#   ('led', 'not skill'),
#   ('dbas', 'not skill'),
#   ('automating', 'not skill'),
#   ('various', 'not skill'),
#   ('manual', 'not skill'),
#   ('routines', 'not skill'),
#   ('like', 'not skill'),
#   ('db', 'not skill'),
#   ('backup recovery', 'not skill'),
#   ('data pump', 'not skill'),
#   ('activities', 'not skill'),
#   (';', 'not skill'),
#   ('overall', 'not skill'),
#   ('helped', 'not skill'),
#   ('relieve', 'not skill'),
#   ('dba', 'not skill'),
#   ('time', 'not skill'),
#   ('30', 'not skill'),
#   ('designed implemented', 'not skill'),
#   ('custom', 'not skill'),
#   ('data', 'skill'),
#   ('change tracking', 'not skill'),
#   ('routines', 'not skill'),
#   ('database', 'not skill'),
#   ('systems', 'not skill'),
#   ('msrb', 'not skill'),
#   (';', 'not skill'),
#   ('database', 'not skill'),
#   ('auditing', 'not skill'),
#   ('highest', 'not skill'),
#   ('msrb', 'not skill')],
#  [('db', 'not skill'),
#   ('changes', 'not skill'),
#   ('tracked', 'not skill'),
#   ('reported', 'not skill'),
#   ('upper management', 'not skill'),
#   ('savvy', 'not skill'),
#   ('custom', 'not skill'),
#   ('reports.establish', 'not skill'),
#   ('maintain', 'not skill'),
#   ('information security', 'skill'),
#   ('standards', 'not skill'),
#   ('procedures', 'not skill'),
#   ('compliance', 'not skill'),
#   ('dhs', 'not skill'),
#   ('uscg', 'not skill'),
#   ('dia', 'not skill'),
#   ('risk management', 'skill'),
#   ('policies', 'not skill'),
#   ('standards', 'not skill'),
#   ('guidelines', 'not skill'),
#   ('trained', 'not skill'),
#   ('msrb', 'not skill'),
#   ('technical', 'skill'),
#   ('staff', 'not skill'),
#   ('linux platform', 'not skill'),
#   (';', 'not skill'),
#   ('includes', 'not skill'),
#   ('developers', 'not skill'),
#   ('operations', 'skill'),
#   ('staff', 'not skill'),
#   ('middle', 'not skill'),
#   ('management', 'skill'),
#   ('dbas', 'not skill'),
#   ('whole', 'not skill'),
#   ('organization', 'skill'),
#   ('advised', 'not skill'),
#   ('msrb', 'not skill'),
#   ('database', 'not skill'),
#   ('management', 'skill'),
#   ('techniques', 'not skill'),
#   ('strategies', 'not skill'),
#   ('best practices', 'not skill'),
#   (';', 'not skill'),
#   ('documented', 'not skill'),
#   ('trained', 'not skill'),
#   ('dbas', 'not skill'),
#   ('accepted', 'not skill'),
#   ('recommendations', 'not skill'),
#   ('provided', 'not skill'),
#   ('technical', 'skill'),
#   ('leadership', 'skill'),
#   ('evaluating', 'not skill'),
#   ('oracle', 'skill'),
#   ('data', 'skill'),
#   ('appliance', 'not skill'),
#   ('on-site', 'not skill'),
#   ('proof-of-concept', 'not skill'),
#   ('exercises', 'not skill'),
#   ('mitre', 'not skill'),
#   ('corporation', 'not skill'),
#   ('mclean va', 'not skill'),
#   ('2008', 'not skill'),
#   ('2011', 'not skill'),
#   ('senior', 'not skill'),
#   ('oracle database administrator', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('installed configured', 'not skill'),
#   ('oracle 11g', 'not skill'),
#   ('r1', 'not skill'),
#   ('rac', 'not skill'),
#   ('using', 'not skill'),
#   ('netapp', 'not skill'),
#   ('nfs', 'not skill'),
#   ('storage', 'not skill'),
#   ('conducted', 'not skill'),
#   ('bi-weekly', 'not skill'),
#   ('cold', 'not skill'),
#   ('backups', 'not skill'),
#   ('using', 'not skill'),
#   ('linux', 'skill'),
#   ('lvm', 'not skill'),
#   ('snapshot', 'not skill'),
#   ('netapp', 'not skill'),
#   ('snapshot', 'not skill'),
#   ('disaster recovery', 'not skill'),
#   ('offsite', 'not skill'),
#   ('locationevaluated', 'not skill'),
#   ('provided', 'not skill'),
#   ('technical', 'skill'),
#   ('recommendations', 'not skill'),
#   ('business continuity', 'not skill'),
#   ('solutions', 'not skill'),
#   ('msrb', 'not skill'),
#   ('data', 'skill'),
#   ('management', 'skill'),
#   ('teams', 'not skill'),
#   (';', 'not skill'),
#   ('evaluated', 'not skill'),
#   ('replication', 'not skill'),
#   ('solutions', 'not skill'),
#   ('like', 'not skill'),
#   ('goldengate', 'not skill'),
#   ('streams', 'not skill')],
#  [('configured', 'not skill'),
#   ('oracle database', 'not skill'),
#   ('server', 'not skill'),
#   ('connect', 'not skill'),
#   ('non-oracle', 'not skill'),
#   ('systems', 'not skill'),
#   ('like', 'not skill'),
#   ('hadoop', 'skill'),
#   ('ms sql server', 'skill'),
#   ('mysql', 'skill'),
#   ('databases', 'skill'),
#   ('fully', 'not skill'),
#   ('heterogeneous', 'not skill'),
#   ('environment', 'not skill'),
#   ('upgraded', 'not skill'),
#   ('oracle', 'skill'),
#   ('11gr1', 'not skill'),
#   ('11gr2', 'not skill'),
#   ('performed', 'not skill'),
#   ('disaster recovery', 'not skill'),
#   ('provided', 'not skill'),
#   ('recommendations', 'not skill'),
#   ('senior management', 'not skill'),
#   ('implementation', 'skill'),
#   ('performed', 'not skill'),
#   ('database', 'not skill'),
#   ('performance tuning', 'not skill'),
#   ('activities', 'not skill'),
#   ('using', 'not skill'),
#   ('tools like', 'not skill'),
#   ('addm', 'not skill'),
#   ('reports', 'not skill'),
#   ('sql', 'skill'),
#   ('tuning', 'not skill'),
#   ('advisors', 'not skill'),
#   ('supported', 'not skill'),
#   ('research', 'not skill'),
#   ('efforts', 'not skill'),
#   ('oracle', 'skill'),
#   ('replication', 'not skill'),
#   ('technologies', 'not skill'),
#   ('like', 'not skill'),
#   ('data guard', 'not skill'),
#   ('automated', 'not skill'),
#   ('database', 'not skill'),
#   ('administration', 'not skill'),
#   ('routines', 'not skill'),
#   ('e.g', 'not skill')],
#  [('backup recovery', 'not skill'),
#   ('data pump', 'not skill'),
#   ('export/import', 'not skill'),
#   ('activities', 'not skill'),
#   ('schema', 'not skill'),
#   ('refresh', 'not skill'),
#   ('different', 'not skill'),
#   ('sources', 'not skill'),
#   ('creation', 'not skill'),
#   ('disk', 'not skill'),
#   ('usage', 'not skill'),
#   ('monitoring', 'not skill'),
#   ('designed implemented', 'not skill'),
#   ('oracle', 'skill'),
#   ('user', 'not skill'),
#   ('audit', 'not skill'),
#   ('collection', 'not skill'),
#   ('led', 'not skill'),
#   ('dba', 'not skill'),
#   ('team', 'not skill'),
#   ('architecting', 'not skill'),
#   ('data', 'skill'),
#   ('flows', 'not skill'),
#   ('presentation', 'not skill'),
#   ('tiers', 'not skill'),
#   ('senior management', 'not skill'),
#   ('analyzed', 'not skill'),
#   ('database', 'not skill'),
#   ('research', 'not skill'),
#   ('results', 'not skill'),
#   ('documented', 'not skill'),
#   ('findings', 'not skill'),
#   ('supported', 'not skill'),
#   ('oracle', 'skill'),
#   ('research', 'not skill'),
#   ('work', 'not skill'),
#   ('conducted', 'not skill'),
#   ('various', 'not skill'),
#   ('airline', 'not skill'),
#   ('partners', 'not skill'),
#   ('mitre', 'not skill'),
#   ('’', 'not skill'),
#   ('aviation', 'not skill'),
#   ('initiatives', 'not skill'),
#   ('supported', 'not skill'),
#   ('research', 'not skill'),
#   ('efforts', 'not skill'),
#   ('large', 'not skill'),
#   ('databases like', 'not skill'),
#   ('asterdata', 'not skill'),
#   ('greenplum', 'not skill'),
#   ('teradata', 'skill'),
#   ('chaveran', 'not skill'),
#   ('inc.', 'not skill'),
#   ('bowie md', 'not skill'),
#   ('2006', 'not skill'),
#   ('2013', 'not skill'),
#   ('part-time', 'not skill'),
#   ('technical', 'skill'),
#   ('instructor', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('trained', 'not skill'),
#   ('students', 'not skill'),
#   ('unix linux', 'not skill'),
#   ('platforms', 'not skill'),
#   ('administration', 'not skill'),
#   ('trained', 'not skill'),
#   ('students', 'not skill'),
#   ('installing configuring', 'not skill'),
#   ('oracle', 'skill'),
#   ('asm', 'not skill'),
#   ('oracle rac', 'not skill'),
#   ('stack', 'not skill'),
#   ('assisted', 'not skill'),
#   ('writing', 'not skill'),
#   ('technical', 'skill'),
#   ('manuals', 'not skill'),
#   ('on-site', 'not skill'),
#   ('linux', 'skill'),
#   ('administrators', 'not skill'),
#   ('assisted', 'not skill'),
#   ('developing', 'not skill'),
#   ('training material', 'not skill'),
#   ('interns', 'not skill'),
#   ('designed', 'not skill'),
#   ('maintained', 'not skill'),
#   ('student', 'not skill'),
#   ('mail', 'not skill'),
#   ('ssh', 'skill'),
#   ('jumpbox', 'not skill'),
#   ('web servers', 'not skill'),
#   ('assisted', 'not skill'),
#   ('building', 'not skill'),
#   ('maintaining', 'not skill'),
#   ('chaveran', 'not skill'),
#   ('cloud', 'not skill'),
#   ('various', 'not skill'),
#   ('virtualizations', 'not skill'),
#   ('installed configured', 'not skill'),
#   ('red hat', 'skill'),
#   ('file', 'not skill'),
#   ('servers', 'not skill'),
#   ('linux', 'skill'),
#   ('appliances', 'not skill'),
#   ('installed configured', 'not skill'),
#   ('linux', 'skill'),
#   ('firewalls', 'skill'),
#   ('client', 'not skill'),
#   ('using', 'not skill'),
#   ('iptables', 'not skill'),
#   ('bind', 'not skill'),
#   ('developed', 'not skill'),
#   ('hardware', 'skill'),
#   ('requirements', 'not skill'),
#   ('specification', 'not skill'),
#   ('assisted', 'not skill'),
#   ('sizing', 'not skill'),
#   ('activities', 'not skill'),
#   ('saba', 'not skill'),
#   ('software', 'skill'),
#   ('inc.', 'not skill'),
#   ('baltimore md', 'not skill'),
#   ('2006', 'not skill'),
#   ('2008', 'not skill'),
#   ('technical', 'skill'),
#   ('consultant/oracle', 'not skill'),
#   ('developer', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('assisted', 'not skill'),
#   ('clients', 'not skill'),
#   ('problem', 'not skill'),
#   ('identification', 'not skill'),
#   ('database', 'not skill'),
#   ('system', 'not skill'),
#   ('architecture', 'not skill'),
#   ('problems', 'not skill'),
#   ('software', 'skill'),
#   ('specifications', 'not skill'),
#   ('writing', 'not skill'),
#   ('software', 'skill'),
#   ('implementation', 'skill'),
#   ('testing', 'skill'),
#   ('deployment', 'not skill'),
#   ('technical', 'skill'),
#   ('highlights', 'not skill'),
#   ('fdic', 'not skill'),
#   ('thinq-to-saba', 'not skill'),
#   ('data migration', 'not skill'),
#   ('technical lead', 'not skill'),
#   ('high', 'not skill'),
#   ('risk', 'not skill'),
#   ('clearance', 'not skill')],
#  [('led', 'not skill'),
#   ('design implementation', 'not skill'),
#   ('fdic', 'not skill'),
#   ('’', 'not skill'),
#   ('data migration', 'not skill'),
#   ('effort', 'not skill'),
#   ('thinq', 'not skill'),
#   ('saba', 'not skill')],
#  [('supported', 'not skill'),
#   ('yum', 'not skill'),
#   ('brands', 'not skill'),
#   ('architectural', 'not skill'),
#   ('designs', 'not skill'),
#   ('data migration', 'not skill'),
#   ('processes', 'not skill'),
#   ('assisted', 'not skill'),
#   ('data migration', 'not skill'),
#   ('enbridge', 'not skill'),
#   ('gas', 'not skill'),
#   ('distribution', 'not skill'),
#   ('based', 'not skill'),
#   ('canada', 'not skill'),
#   ('served', 'not skill'),
#   ('technical lead', 'not skill'),
#   ('saba', 'not skill'),
#   ('engagement', 'skill'),
#   ('northrop grumman', 'not skill'),
#   ('corporation', 'not skill')],
#  [('supported', 'not skill'),
#   ('client', 'not skill'),
#   ('saba', 'not skill'),
#   ('installations', 'not skill'),
#   ('oracle', 'skill'),
#   ('data migration', 'not skill'),
#   ('supported', 'not skill'),
#   ('atk', 'not skill'),
#   ('oracle', 'skill'),
#   ('performance tuning', 'not skill'),
#   ('efforts', 'not skill'),
#   ('using', 'not skill'),
#   ('explain', 'not skill'),
#   ('plans', 'not skill'),
#   ('awr', 'not skill'),
#   ('addm', 'not skill'),
#   ('reports', 'not skill'),
#   ('mentored', 'not skill'),
#   ('junior', 'not skill'),
#   ('consultants', 'not skill'),
#   ('saba', 'not skill'),
#   ('’', 'not skill'),
#   ('employee', 'not skill'),
#   ('mentorship', 'not skill'),
#   ('program', 'not skill')],
#  [('washington', 'not skill'),
#   ('baltimore', 'not skill'),
#   ('high', 'not skill'),
#   ('index', 'not skill'),
#   ('drug', 'not skill'),
#   ('trafficking', 'not skill'),
#   ('area', 'not skill'),
#   ('greenbelt md', 'not skill'),
#   ('2001', 'not skill'),
#   ('2006', 'not skill'),
#   ('database', 'not skill'),
#   ('administrator/developer', 'not skill'),
#   ('key work experience', 'not skill'),
#   ('assisted', 'not skill'),
#   ('development', 'skill'),
#   ('backend', 'not skill'),
#   ('database', 'not skill'),
#   ('stored procedures', 'not skill'),
#   ('needed', 'not skill'),
#   ('middle', 'not skill'),
#   ('tiers', 'not skill'),
#   ('worked extensively', 'not skill'),
#   ('classic', 'not skill'),
#   ('asp', 'not skill'),
#   ('access', 'not skill'),
#   ('reporting', 'skill'),
#   ('tools like', 'not skill'),
#   ('pivot tables', 'skill'),
#   ('conducted', 'not skill'),
#   ('demos', 'not skill'),
#   ('training sessions', 'not skill'),
#   ('needed', 'not skill'),
#   ('use', 'not skill'),
#   ('released', 'not skill'),
#   ('products', 'not skill'),
#   ('worked', 'not skill'),
#   ('content management', 'not skill'),
#   ('systems', 'not skill'),
#   ('like', 'not skill'),
#   ('drupal', 'skill'),
#   ('mambo', 'not skill'),
#   ('assisted', 'not skill'),
#   ('web', 'skill'),
#   ('development', 'skill'),
#   ('projects', 'not skill'),
#   ('using', 'not skill'),
#   ('php', 'skill'),
#   ('developed', 'not skill'),
#   ('database', 'not skill'),
#   ('application', 'not skill'),
#   ('tracking', 'skill'),
#   ('web', 'skill'),
#   ('logs', 'not skill'),
#   ('helped', 'not skill'),
#   ('create', 'not skill'),
#   ('frontend', 'not skill'),
#   ('interfaces', 'not skill'),
#   ('controlling', 'not skill'),
#   ('applications', 'not skill'),
#   ('extensively', 'not skill'),
#   ('dealt', 'not skill'),
#   ('schema', 'not skill'),
#   ('design', 'skill'),
#   ('data modeling', 'skill'),
#   ('using', 'not skill'),
#   ('tools like', 'not skill'),
#   ('oracle', 'skill'),
#   ('data modeler', 'skill'),
#   ('conducted', 'not skill'),
#   ('demos', 'not skill'),
#   ('trained', 'not skill'),
#   ('personnel', 'not skill'),
#   ('using', 'not skill'),
#   ('visual basic', 'skill'),
#   ('application', 'not skill'),
#   ('university maryland college park', 'not skill'),
#   ('maryland', 'not skill'),
#   ('2001', 'not skill'),
#   ('linux/network', 'not skill'),
#   ('administrator key', 'not skill'),
#   ('work experience', 'not skill'),
#   ('supported', 'not skill'),
#   ('student', 'not skill'),
#   ('network', 'not skill'),
#   ('setup', 'not skill'),
#   ('assisted', 'not skill'),
#   ('network', 'not skill'),
#   ('problem', 'not skill'),
#   ('shooting', 'not skill'),
#   ('assisted', 'not skill'),
#   ('network deployment', 'not skill'),
#   ('troubleshooting', 'skill'),
#   ('configured', 'not skill'),
#   ('student', 'not skill'),
#   ('private', 'not skill'),
#   ('routers', 'skill'),
#   ('network devices', 'not skill'),
#   ('trained', 'not skill'),
#   ('students', 'not skill'),
#   ('using', 'not skill'),
#   ('network', 'not skill'),
#   ('resources', 'not skill'),
#   ('campus', 'not skill'),
#   ('worked', 'not skill'),
#   ('team', 'not skill'),
#   ('help', 'not skill'),
#   ('students', 'not skill'),
#   ('install', 'not skill'),
#   ('linux', 'skill'),
#   ('workstations', 'not skill'),
#   ('skills', 'not skill'),
#   ('sql', 'skill'),
#   ('language', 'not skill'),
#   ('linux', 'skill'),
#   ('shell scripting', 'skill'),
#   ('pl/sql', 'skill'),
#   ('mysql/postgresql', 'not skill'),
#   ('database', 'not skill'),
#   ('oracle data guard', 'not skill'),
#   ('perl scripting', 'not skill'),
#   ('windows os', 'skill'),
#   ('oracle', 'skill'),
#   ('asm', 'not skill'),
#   ('exposed', 'not skill'),
#   ('greenplum', 'not skill'),
#   ('netezza', 'not skill'),
#   ('hadoop', 'skill'),
#   ('linux', 'skill'),
#   ('lan/wan', 'skill'),
#   ('networking', 'skill'),
#   ('object oriented programming', 'skill'),
#   ('oop', 'not skill'),
#   ('concepts', 'not skill'),
#   ('gnu/linux', 'not skill'),
#   ('os', 'not skill'),
#   ('–', 'not skill'),
#   ('red hat', 'skill'),
#   ('debian', 'not skill'),
#   ('c++', 'skill'),
#   ('c java', 'skill'),
#   ('tcp/ip', 'skill'),
#   ('networking', 'skill'),
#   ('sql loader', 'not skill'),
#   ('pervasive', 'not skill'),
#   ('map', 'not skill'),
#   ('designer', 'not skill'),
#   ('joomla', 'not skill'),
#   ('cms', 'not skill'),
#   ('oracle sql developer', 'skill'),
#   ('sql', 'skill'),
#   ('data modeler', 'skill'),
#   ('oracle', 'skill'),
#   ('12c', 'not skill'),
#   ('cloud control', 'not skill'),
#   ('quest', 'not skill'),
#   ('toad', 'skill'),
#   ('quest', 'not skill'),
#   ('spotlight/foglight', 'not skill'),
#   ('oracle', 'skill'),
#   ('rman', 'not skill'),
#   ('adobe', 'not skill'),
#   ('fireworks', 'not skill'),
#   ('dreamweaver', 'skill'),
#   ('microsoft office', 'skill'),
#   ('visio', 'skill'),
#   ('virtual', 'not skill'),
#   ('box', 'not skill'),
#   ('vmware', 'skill'),
#   ('xen', 'skill'),
#   ('education masters', 'not skill'),
#   ('science information systems', 'not skill'),
#   ('2012', 'not skill'),
#   ('university maryland', 'not skill'),
#   ('baltimore county', 'not skill'),
#   ('bachelor science computer science', 'not skill'),
#   ('2006', 'not skill'),
#   ('university maryland college park', 'not skill'),
#   ('bachelor arts economics', 'not skill'),
#   ('–', 'not skill'),
#   ('2006', 'not skill'),
#   ('university maryland college park', 'not skill'),
#   ('clearance', 'not skill'),
#   ('certifications', 'not skill'),
#   ('public trust', 'not skill'),
#   ('level', 'not skill'),
#   ('3', 'not skill'),
#   ('fbi', 'not skill'),
#   ('background', 'not skill'),
#   ('investigation', 'not skill'),
#   ('oracle', 'skill'),
#   ('certified professional', 'not skill'),
#   ('oracle', 'skill'),
#   ('certified associate', 'not skill'),
#   ('red hat certified', 'not skill'),
#   ('technician', 'not skill'),
#   ('jane doe paradyme management', 'not skill'),
#   ('inc page 1 5', 'not skill'),
#   ('yaw', 'not skill'),
#   ('owusu', 'not skill'),
#   ('appiah', 'not skill'),
#   ('paradyme management inc', 'not skill')],
#  [('page 2', 'not skill'),
#   ('5\\n', 'not skill'),
#   ('dimitri', 'not skill'),
#   ('richardson', 'not skill'),
#   ('114', 'not skill'),
#   ('division', 'not skill'),
#   ('st', 'not skill'),
#   ('neptune', 'not skill'),
#   ('nj', 'not skill'),
#   ('07753', 'not skill'),
#   ('phone', 'not skill'),
#   ('732-614-0217', 'not skill'),
#   ('e-mail', 'not skill'),
#   ('dimitri.richardson', 'not skill'),
#   ('@_gmail.com', 'not skill'),
#   ('experience', 'not skill'),
#   ('smart', 'not skill'),
#   ('tuition', 'not skill'),
#   ('june-august', 'not skill'),
#   ('2015', 'not skill'),
#   ('summer', 'not skill'),
#   ('internship', 'not skill'),
#   (';', 'not skill'),
#   ('manage', 'not skill'),
#   ('accounts', 'not skill'),
#   ('private', 'not skill'),
#   ('schools', 'not skill'),
#   ('across country', 'not skill')],
#  [('customer service', 'not skill'),
#   ('assistant', 'not skill'),
#   ('answered', 'not skill'),
#   ('questions', 'not skill'),
#   ('parents', 'not skill'),
#   ('school', 'not skill'),
#   ('worked', 'not skill'),
#   ('along', 'not skill'),
#   ('side', 'not skill'),
#   ('school', 'not skill'),
#   ('account', 'not skill'),
#   ('mangers', 'not skill'),
#   ('laz', 'not skill'),
#   ('parking', 'not skill'),
#   ('may', 'not skill'),
#   ('2013-august', 'not skill'),
#   ('2015', 'not skill'),
#   ('parking', 'not skill'),
#   ('attendant', 'not skill'),
#   ('charge', 'not skill'),
#   ('collection', 'not skill'),
#   ('fees', 'not skill'),
#   ('parking', 'not skill'),
#   ('three-beach', 'not skill'),
#   ('side', 'not skill'),
#   ('customer', 'not skill'),
#   ('parking', 'not skill'),
#   ('facilities', 'not skill')],
#  [('handled', 'not skill'),
#   ('financial', 'not skill'),
#   ('transactions', 'not skill'),
#   ('wendy', 'not skill'),
#   ('’', 'not skill'),
#   ('july', 'not skill'),
#   ('2011-may', 'not skill'),
#   ('2012', 'not skill'),
#   ('cashier', 'not skill'),
#   ('responsibilities included', 'not skill'),
#   ('greeting', 'not skill'),
#   ('customers', 'not skill'),
#   ('submitting', 'not skill'),
#   ('orders', 'not skill'),
#   ('operating', 'not skill'),
#   ('cash register', 'not skill')],
#  [('demonstrated', 'not skill'),
#   ('customer service', 'not skill'),
#   ('problem-solving', 'not skill'),
#   ('computer skills', 'not skill')],
#  [('assisted', 'not skill'),
#   ('opening', 'not skill'),
#   ('closing', 'not skill'),
#   ('store', 'not skill')],
#  [('national', 'not skill'),
#   ('leadership', 'skill'),
#   ('forum', 'not skill'),
#   ('law', 'not skill'),
#   ('csi', 'not skill'),
#   ('july', 'not skill'),
#   ('2010', 'not skill'),
#   ('experienced', 'not skill'),
#   ('full range', 'not skill'),
#   ('professions', 'not skill'),
#   ('exist', 'not skill'),
#   ('legal', 'not skill'),
#   ('forensic', 'not skill'),
#   ('science', 'not skill'),
#   ('fields', 'not skill')],
#  [('explored', 'not skill'),
#   ('in-depth', 'not skill'),
#   ('entire', 'not skill'),
#   ('judicial', 'not skill'),
#   ('process', 'not skill'),
#   ('crime', 'not skill'),
#   ('collecting', 'not skill'),
#   ('analyzing', 'not skill'),
#   ('critical', 'not skill'),
#   ('evidence', 'not skill')],
#  [('examine', 'not skill'),
#   ('court', 'not skill'),
#   ('case', 'not skill'),
#   ('supreme', 'not skill'),
#   ('court', 'not skill'),
#   ('stimulation', 'not skill')],
#  [('took part', 'not skill'),
#   ('legal', 'not skill'),
#   ('career', 'not skill'),
#   ('experience', 'not skill'),
#   ('courthouse', 'not skill'),
#   ('jersey', 'not skill'),
#   ('shore', 'not skill'),
#   ('university', 'not skill'),
#   ('medical center', 'not skill'),
#   ('august 2010', 'not skill'),
#   ('volunteer', 'not skill'),
#   ('jsumc', 'not skill'),
#   ('assisting', 'not skill'),
#   ('caregiver', 'not skill'),
#   ('assistance', 'not skill'),
#   ('clerical', 'not skill'),
#   ('tasks', 'not skill'),
#   ('worked', 'not skill'),
#   ('information', 'not skill'),
#   ('desk', 'not skill'),
#   ('mail', 'not skill'),
#   ('room', 'not skill'),
#   ('billing', 'not skill'),
#   ('department', 'not skill')],
#  [('education', 'not skill'),
#   ('xavier', 'not skill'),
#   ('university', 'not skill'),
#   ('2012-2013', 'not skill'),
#   ('volunteer/member', 'not skill'),
#   ('xavier', 'not skill'),
#   ('university', 'not skill'),
#   ('black', 'not skill'),
#   ('student association', 'not skill'),
#   ('member', 'not skill'),
#   ('track', 'not skill'),
#   ('field', 'not skill'),
#   ('team member', 'not skill'),
#   ('xavier', 'not skill'),
#   ('university', 'not skill'),
#   ('club', 'not skill'),
#   ('football', 'not skill'),
#   ('team', 'not skill'),
#   ('west', 'not skill'),
#   ('virginia', 'not skill'),
#   ('university', 'not skill'),
#   ('2014-', 'not skill'),
#   ('present', 'not skill'),
#   ('current', 'not skill'),
#   ('finance', 'not skill'),
#   ('student', 'not skill'),
#   ('college', 'not skill'),
#   ('business', 'not skill'),
#   ('economics', 'not skill'),
#   ('graduation date', 'not skill'),
#   ('may 2017', 'not skill'),
#   ('2\\n', 'not skill'),
#   ('3412', 'not skill'),
#   ('tulane', 'not skill'),
#   ('dr.', 'not skill'),
#   ('31', 'not skill'),
#   ('varsha', 'not skill'),
#   ('purswani', 'not skill'),
#   ('hyattsville', 'not skill'),
#   ('maryland', 'not skill'),
#   ('md 20783', 'not skill'),
#   ('301-318-6065', 'not skill'),
#   ('https', 'not skill'),
#   ('//www/linkedin.com/in/varsha022', 'not skill'),
#   ('varsha.purswani', 'not skill'),
#   ('@ rhsmith.umd.edu education robert', 'not skill'),
#   ('h. smith school business', 'not skill'),
#   ('university maryland college park', 'not skill'),
#   ('md', 'not skill'),
#   ('dec 2016 master science', 'not skill'),
#   ('information systems', 'not skill'),
#   ('g.p.a', 'not skill'),
#   ('3.9', 'not skill'),
#   ('related coursework', 'not skill'),
#   ('data mining predictive analytics', 'not skill'),
#   ('data models decisions', 'not skill'),
#   ('business process analysis', 'not skill'),
#   ('strategic transformational', 'not skill'),
#   ('database', 'not skill'),
#   ('management', 'skill'),
#   ('systems', 'not skill'),
#   ('digital business', 'not skill'),
#   ('markets', 'not skill'),
#   ('shri', 'not skill'),
#   ('govindram', 'not skill'),
#   ('seksaria', 'not skill'),
#   ('institute technology', 'not skill'),
#   ('science', 'not skill'),
#   ('indore', 'not skill'),
#   ('india bachelor', 'not skill'),
#   ('engineering computer', 'not skill'),
#   ('engineering', 'skill'),
#   ('may 2012 professional experience', 'not skill'),
#   ('sap', 'skill'),
#   ('labs', 'not skill'),
#   ('india pvt', 'not skill'),
#   ('ltd bangalore', 'not skill'),
#   ('india jun', 'not skill'),
#   ('2012_–', 'not skill'),
#   ('july 2015', 'not skill'),
#   ('software developer', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('collaborated', 'not skill'),
#   ('customers', 'not skill'),
#   ('business needs', 'not skill'),
#   ('translated', 'not skill'),
#   ('technical', 'skill'),
#   ('requirements', 'not skill'),
#   ('producing', 'not skill'),
#   ('software', 'skill'),
#   ('requirement specification', 'not skill')],
#  [('§\uf0a7', 'not skill'),
#   ('consulted', 'not skill'),
#   ('italian', 'not skill'),
#   ('client', 'not skill'),
#   ('implementation', 'skill'),
#   ('sap', 'skill'),
#   ('fashion', 'not skill'),
#   ('management', 'skill'),
#   ('solution', 'not skill'),
#   ('fms', 'not skill'),
#   ('critical', 'not skill'),
#   ('business', 'not skill'),
#   ('scenarios', 'not skill'),
#   ('resulting', 'not skill'),
#   ('smooth', 'not skill'),
#   ('launch', 'not skill')],
#  [('§\uf0a7', 'not skill'),
#   ('designed', 'not skill'),
#   ('data model', 'not skill'),
#   ('sap', 'skill'),
#   ('fms', 'not skill'),
#   ('order', 'not skill'),
#   ('allocation', 'not skill'),
#   ('run', 'not skill'),
#   ('a-run', 'not skill'),
#   ('enabled', 'not skill'),
#   ('execution', 'skill'),
#   ('sap hana', 'not skill'),
#   ('database', 'not skill'),
#   ('platform', 'not skill'),
#   ('resulting', 'not skill'),
#   ('performance improvement', 'skill'),
#   ('10', 'not skill'),
#   ('times', 'not skill'),
#   ('baseline', 'not skill')],
#  [('§\uf0a7', 'not skill'),
#   ('led', 'not skill'),
#   ('start-up', 'not skill'),
#   ('company', 'not skill'),
#   ('creating', 'not skill'),
#   ('supply chain management', 'not skill'),
#   ('scm', 'not skill'),
#   ('analytics', 'not skill'),
#   ('application', 'not skill'),
#   ('using', 'not skill'),
#   ('sap hana', 'not skill'),
#   ('database', 'not skill'),
#   ('platform', 'not skill')],
#  [('projects', 'not skill'),
#   ('aug 2015', 'not skill'),
#   ('– dec 2015', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('database', 'not skill'),
#   ('management', 'skill'),
#   ('systems', 'not skill'),
#   ('designed', 'not skill'),
#   ('relational database', 'not skill'),
#   ('virtual', 'not skill'),
#   ('client', 'not skill'),
#   ('defining', 'not skill'),
#   ('logical', 'not skill'),
#   ('model', 'not skill'),
#   ('using', 'not skill'),
#   ('entity', 'not skill'),
#   ('relationship', 'not skill'),
#   ('diagram', 'not skill'),
#   ('physical', 'not skill'),
#   ('model', 'not skill'),
#   ('using', 'not skill'),
#   ('sql', 'skill'),
#   ('§\uf0a7', 'not skill'),
#   ('digitization', 'not skill'),
#   ('freelancing', 'not skill'),
#   ('collated', 'not skill'),
#   ('data', 'skill'),
#   ('created', 'not skill'),
#   ('reports', 'not skill'),
#   ('online', 'not skill'),
#   ('freelancing', 'not skill'),
#   ('platform', 'not skill'),
#   ('upwork', 'not skill'),
#   ('analyzed', 'not skill'),
#   ('strategic transformational', 'not skill'),
#   ('impact', 'not skill'),
#   ('society', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('business process analysis', 'not skill'),
#   ('leading', 'not skill'),
#   ('scrum team', 'not skill'),
#   ('five', 'not skill'),
#   ('develop', 'not skill'),
#   ('reporting', 'skill'),
#   ('mobile app', 'not skill'),
#   ('demonstrating', 'not skill'),
#   ('health', 'not skill'),
#   ('statistics', 'skill'),
#   ('individual', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('firm', 'not skill'),
#   ('analysis', 'not skill'),
#   ('mapbox', 'not skill'),
#   ('gathered', 'not skill'),
#   ('information', 'not skill'),
#   ('start', 'not skill'),
#   ('mapbox', 'not skill'),
#   ('analysed', 'not skill'),
#   ('business', 'not skill'),
#   ('domain', 'not skill'),
#   ('sources', 'not skill'),
#   ('competitive advantage', 'not skill'),
#   ('industry', 'not skill'),
#   ('dynamics', 'not skill'),
#   ('strategic', 'not skill'),
#   ('drivers', 'not skill'),
#   ('performance', 'not skill')],
#  [('§\uf0a7', 'not skill'),
#   ('google analytics', 'skill'),
#   ('leading', 'not skill'),
#   ('team four', 'not skill'),
#   ('improve', 'not skill'),
#   ('client_’', 'not skill'),
#   ('website', 'not skill'),
#   ('increase', 'not skill'),
#   ('click', 'not skill'),
#   ('rate', 'not skill'),
#   ('using', 'not skill'),
#   ('google analytics google adwords', 'not skill')],
#  [('leadership experience', 'not skill'),
#   ('university maryland', 'not skill'),
#   ('aug 2015', 'not skill'),
#   ('– dec 2015', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('managed', 'not skill'),
#   ('marketing', 'skill'),
#   ('events', 'not skill'),
#   ('student ambassador', 'not skill'),
#   ('clarice', 'not skill'),
#   ('smith', 'not skill'),
#   ('performing', 'not skill'),
#   ('arts', 'not skill'),
#   ('center', 'not skill')],
#  [('§\uf0a7', 'not skill'),
#   ('volunteered', 'not skill'),
#   ('kids', 'not skill'),
#   ('enjoy', 'not skill'),
#   ('exercise', 'not skill'),
#   ('keen', 'not skill'),
#   ('providing', 'not skill'),
#   ('recreational', 'not skill'),
#   ('opportunities', 'not skill'),
#   ('group', 'not skill'),
#   ('20', 'not skill'),
#   ('children', 'not skill'),
#   ('physical', 'not skill'),
#   ('mental', 'not skill'),
#   ('disabilities', 'not skill')],
#  [('sgsits', 'not skill'),
#   ('technical', 'skill'),
#   ('cultural', 'not skill'),
#   ('events', 'not skill'),
#   ('may', 'not skill'),
#   ('2011_–', 'not skill'),
#   ('dec 2011', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('facilitated', 'not skill'),
#   ('office', 'not skill'),
#   ('career', 'not skill'),
#   ('services', 'not skill'),
#   ('smooth', 'not skill'),
#   ('execution', 'skill'),
#   ('placement', 'not skill'),
#   ('process', 'not skill'),
#   ('500', 'not skill'),
#   ('students', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('supervised', 'skill'),
#   ('budgeting', 'not skill'),
#   ('script', 'not skill'),
#   ('writing', 'not skill'),
#   ('compering', 'not skill'),
#   ('three', 'not skill'),
#   ('major', 'not skill'),
#   ('events', 'not skill'),
#   ('college', 'not skill'),
#   ('’', 'not skill'),
#   ('cultural festival', 'not skill')],
#  [('technical skills', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('languages', 'not skill'),
#   ('r', 'skill'),
#   ('abap', 'skill'),
#   ('java c', 'not skill'),
#   ('sql', 'skill'),
#   ('php html', 'not skill'),
#   ('css xml', 'not skill'),
#   ('§\uf0a7', 'not skill'),
#   ('tools', 'not skill'),
#   ('tableau', 'skill'),
#   ('palisade', 'skill'),
#   ('tools', 'not skill'),
#   ('excel', 'skill'),
#   ('stat tools', 'not skill'),
#   ('@_risk', 'not skill'),
#   ('precision tree', 'skill'),
#   ('solver table', 'skill'),
#   ('ms visio', 'skill'),
#   ('ms office', 'skill'),
#   ('salesforce.com', 'not skill'),
#   ('oracle10g', 'not skill'),
#   ('mysql', 'skill'),
#   ('sap hana', 'not skill'),
#   ('google analytics google adwords', 'not skill'),
#   ('linux', 'skill'),
#   ('\\n', 'not skill'),
#   ('kane', 'not skill'),
#   ('baccigalupi', 'not skill'),
#   ('935', 'not skill'),
#   ('scenic', 'not skill'),
#   ('place', 'not skill'),
#   ('pleasant', 'not skill'),
#   ('hill', 'not skill'),
#   ('ca', 'not skill'),
#   ('94523', 'not skill'),
#   ('mobile', 'skill'),
#   ('510-228-9669', 'not skill'),
#   ('skill', 'not skill'),
#   ('summary', 'not skill'),
#   ('expert', 'not skill'),
#   ('technical', 'skill'),
#   ('advisor', 'not skill'),
#   ('10 years experience', 'not skill'),
#   ('cto', 'not skill'),
#   ('expert', 'not skill'),
#   ('consultant', 'not skill')],
#  [('team leader', 'not skill'),
#   ('dedicated', 'not skill'),
#   ('advancing', 'not skill'),
#   ('developing', 'not skill'),
#   ('team members', 'not skill')],
#  [('champion', 'not skill'),
#   ('organizational', 'skill'),
#   ('diversity', 'not skill'),
#   ('benefits', 'not skill'),
#   ('business objectives', 'not skill')],
#  [('business', 'not skill'),
#   ('strategist', 'not skill'),
#   ('focused', 'not skill'),
#   ('using', 'not skill'),
#   ('technical', 'skill'),
#   ('innovation', 'not skill'),
#   ('move', 'not skill'),
#   ('organizations', 'not skill'),
#   ('quickly', 'not skill'),
#   ('towards', 'not skill'),
#   ('objectives', 'not skill')],
#  [('mentor', 'not skill'), ('writer', 'not skill'), ('speaker', 'not skill')],
#  [('data driven', 'not skill'),
#   ('decision', 'not skill'),
#   ('maker', 'not skill'),
#   ('focused', 'not skill'),
#   ('user', 'not skill'),
#   ('research', 'not skill'),
#   ('customer', 'not skill'),
#   ('validation', 'not skill')],
#  [('public', 'not skill'),
#   ('servant', 'skill'),
#   ('dedicated', 'not skill'),
#   ('bringing', 'not skill'),
#   ('best', 'not skill'),
#   ('innovations', 'not skill'),
#   ('private sector', 'not skill'),
#   ('government', 'not skill')],
#  [('experience', 'not skill'),
#   ('innovation', 'not skill'),
#   ('strategist', 'not skill'),
#   ('18f', 'not skill'),
#   ('gsa', 'not skill'),
#   ('september 2015', 'not skill'),
#   ('present', 'not skill'),
#   ('gsa', 'not skill'),
#   ("'s", 'not skill'),
#   ('18f', 'not skill'),
#   ('innovation', 'not skill'),
#   ('agency', 'not skill'),
#   ('federal government', 'not skill')],
#  [('worked', 'not skill'),
#   ('strategy', 'skill'),
#   ('team', 'not skill'),
#   ('offering', 'not skill'),
#   ('technical', 'skill'),
#   ('advice', 'not skill'),
#   ('hands-on', 'not skill'),
#   ('support', 'not skill'),
#   ('moving', 'not skill'),
#   ('agencies', 'not skill'),
#   ('projects', 'not skill'),
#   ('better', 'not skill'),
#   ('practices', 'not skill'),
#   ('outcomes', 'not skill')],
#  [('legacy', 'not skill'),
#   ('modernization', 'skill'),
#   ('lead', 'not skill'),
#   ('educated', 'not skill'),
#   ('18f', 'not skill'),
#   ('leadership', 'skill'),
#   ('staff', 'not skill'),
#   ('common', 'not skill'),
#   ('patterns', 'not skill'),
#   ('legacy', 'not skill'),
#   ('modernization', 'skill')],
#  [('crafted', 'not skill'),
#   ('plans', 'not skill'),
#   ('alaska', 'not skill'),
#   ('missouri', 'not skill'),
#   ('medicaid', 'not skill'),
#   ('related', 'not skill'),
#   ('modernizations', 'not skill'),
#   ('starting', 'not skill'),
#   ('deep', 'not skill'),
#   ('technical', 'skill'),
#   ('dive', 'not skill'),
#   ('18f', 'not skill'),
#   ('team members', 'not skill'),
#   ('three-month', 'not skill'),
#   ('prototyping', 'not skill'),
#   ('vendor', 'not skill'),
#   ('contract', 'not skill'),
#   ('concluding', 'not skill'),
#   ('modular', 'not skill'),
#   ('procurement', 'not skill'),
#   ('plan', 'not skill')],
#  [('rebuilt', 'not skill'),
#   ('technical', 'skill'),
# ...
#   ('salesforce.com', 'not skill'),
#   ('using', 'not skill'),
#   ('reports dashboards', 'not skill'),
#   ('views', 'not skill'),
#   ('workflow', 'not skill'),
#   ('rules', 'not skill'),
#   ('validation', 'not skill'),
#   ('rules', 'not skill'),
#   ('permission', 'not skill'),
#   ('sets', 'not skill'),
#   ('page', 'not skill'),
#   ('layouts', 'not skill'),
#   ('banking', 'not skill'),
#   ('data', 'skill'),
#   ('data analysis', 'skill'),
#   ('using tableau', 'not skill'),
#   ('jan', 'not skill'),
#   ('2016-feb', 'not skill'),
#   ('2016_\uf0a7', 'not skill'),
#   ('investigated', 'not skill'),
#   ('dognition', 'not skill'),
#   ('company', 'not skill'),
#   ('data', 'skill'),
#   ('set', 'not skill'),
#   ('designed', 'not skill'),
#   ('structured', 'not skill'),
#   ('pyramid', 'not skill'),
#   ('analysis', 'not skill'),
#   ('plan', 'not skill'),
#   ('analyzed', 'not skill'),
#   ('using tableau', 'not skill'),
#   ('importing', 'not skill'),
#   ('excel', 'skill'),
#   ('data', 'skill'),
#   ('tableau', 'skill'),
#   ('creating', 'not skill'),
#   ('data', 'skill'),
#   ('views', 'not skill'),
#   ('dashboard', 'not skill'),
#   ('filters', 'not skill'),
#   ('parameters', 'not skill'),
#   ('calculated', 'not skill'),
#   ('fields', 'not skill'),
#   ('published', 'not skill'),
#   ('recommendation', 'not skill'),
#   ('report', 'not skill'),
#   ('client-', 'not skill'),
#   ('based', 'not skill'),
#   ('project', 'skill'),
#   ('following', 'not skill'),
#   ('scrum methodology', 'not skill'),
#   ('feb', 'not skill'),
#   ('2016- may 2016', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('developing', 'not skill'),
#   ('application', 'not skill'),
#   ('student', 'not skill'),
#   ('peer', 'not skill'),
#   ('reviews', 'not skill'),
#   ('related', 'not skill'),
#   ('analytics', 'not skill'),
#   ('part', 'not skill'),
#   ('scrum team', 'not skill'),
#   ('java', 'skill'),
#   ('sql', 'skill'),
#   ('using', 'not skill'),
#   ('ibm bluemix', 'skill'),
#   ('web services', 'skill'),
#   ('also', 'not skill'),
#   ('participating', 'not skill'),
#   ('scrum', 'skill'),
#   ('ceremonies', 'not skill'),
#   ('data mining predictive analytics', 'not skill'),
#   ('using', 'not skill'),
#   ('r', 'skill'),
#   ('\uf0a7', 'not skill'),
#   ('working', 'not skill'),
#   ('rossman', 'not skill'),
#   ('stores', 'not skill'),
#   ('dataset', 'not skill'),
#   ('analyze', 'not skill'),
#   ('data', 'skill'),
#   ('using', 'not skill'),
#   ('knn', 'not skill'),
#   ('naïve bayes', 'not skill'),
#   ('classification', 'not skill'),
#   ('regression', 'skill'),
#   ('algorithms', 'not skill'),
#   ('predict', 'not skill'),
#   ('store', 'not skill'),
#   ('sales', 'not skill'),
#   ('7', 'not skill'),
#   ('weeks', 'not skill')],
#  [('leadership', 'skill'),
#   ('youth', 'not skill'),
#   ('vision', 'not skill'),
#   ('consultant', 'not skill'),
#   ('hanoi vietnam', 'not skill'),
#   ('jun', 'not skill'),
#   ('2013-', 'not skill'),
#   ('jul 2013', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('planned managed', 'not skill'),
#   ('‘', 'not skill'),
#   ('vietnam', 'not skill'),
#   ('youth', 'not skill'),
#   ('icon', 'not skill'),
#   ('’', 'not skill'),
#   ('project', 'skill'),
#   ('including', 'not skill'),
#   ('four', 'not skill'),
#   ('day', 'not skill'),
#   ('camps', 'not skill'),
#   ('event', 'not skill'),
#   ('named', 'not skill'),
#   ('international', 'not skill'),
#   ('youth', 'not skill'),
#   ('day', 'not skill')],
#  [('worked', 'not skill'),
#   ('15', 'not skill'),
#   ('interns', 'not skill'),
#   ('12', 'not skill'),
#   ('different', 'not skill'),
#   ('countries', 'not skill'),
#   ('month', 'not skill'),
#   ('catered', 'not skill'),
#   ('around', 'not skill'),
#   ('150', 'not skill'),
#   ('delegates', 'not skill'),
#   ('aiesec', 'not skill'),
#   ('navi', 'not skill'),
#   ('mumbai india', 'not skill'),
#   ('feb', 'not skill'),
#   ('2013-feb', 'not skill'),
#   ('2015', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('arranged', 'not skill'),
#   ('youth', 'not skill'),
#   ('leadership', 'skill'),
#   ('conference', 'not skill'),
#   ('core committee', 'not skill'),
#   ('logistics', 'not skill'),
#   ('february 2015', 'not skill'),
#   ('silvassa', 'not skill'),
#   ('india', 'not skill'),
#   ('catering', 'not skill'),
#   ('400', 'not skill'),
#   ('delegates', 'not skill'),
#   ('country', 'not skill'),
#   ('\uf0a7 led team', 'not skill'),
#   ('5', 'not skill'),
#   ('people', 'not skill'),
#   ('team leader', 'not skill'),
#   ('human resources', 'not skill'),
#   ('january', 'not skill'),
#   ('2014-december', 'not skill'),
#   ('2014', 'not skill'),
#   ('responsible', 'not skill'),
#   ('talent', 'not skill'),
#   ('planning', 'skill'),
#   ('acquisition', 'not skill'),
#   ('training', 'skill'),
#   ('retention', 'not skill'),
#   ('managed', 'not skill'),
#   ('around', 'not skill'),
#   ('40', 'not skill'),
#   ('employees', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('acted', 'not skill'),
#   ('team leader', 'not skill'),
#   ('international', 'not skill'),
#   ('student', 'not skill'),
#   ('exchange', 'not skill'),
#   ('social', 'not skill'),
#   ('january', 'not skill'),
#   ('2013-', 'not skill'),
#   ('june 2013', 'not skill'),
#   ('increased', 'not skill'),
#   ('number', 'not skill'),
#   ('exchanges', 'not skill'),
#   ('250', 'not skill'),
#   ('additional information \uf0a7', 'not skill'),
#   ('technical', 'skill'),
#   ('java c++', 'not skill'),
#   ('html sql', 'not skill'),
#   ('salesforce.com', 'not skill'),
#   ('tableau r', 'not skill'),
#   ('wireshark', 'skill'),
#   ('microsoft excel', 'skill'),
#   ('statistical', 'not skill'),
#   ('tools', 'not skill'),
#   ('@_risk', 'not skill'),
#   ('precisiontree', 'skill'),
#   ('stattools', 'skill'),
#   ('solvertable', 'skill'),
#   ('visio rational', 'not skill'),
#   ('rose', 'not skill'),
#   ('python', 'skill'),
#   ('sharepoint', 'skill'),
#   ('hadoop', 'skill'),
#   ('impala', 'not skill'),
#   ('pig hive', 'not skill'),
#   ('[', 'not skill'),
#   ('may 2016', 'not skill'),
#   (']', 'not skill'),
#   ('spark', 'skill'),
#   ('[', 'not skill'),
#   ('may 2016', 'not skill'),
#   (']', 'not skill'),
#   ('microsoft', 'skill'),
#   ('project management', 'skill'),
#   ('ms access', 'skill'),
#   ('weka', 'skill'),
#   ('\uf0a7', 'not skill'),
#   ('online courses', 'not skill'),
#   ('intermediate', 'not skill'),
#   ('r', 'skill'),
#   ('data analysis', 'skill'),
#   ('r', 'skill'),
#   ('machine learning', 'skill'),
#   ('r', 'skill'),
#   ('software', 'skill'),
#   ('processes', 'not skill'),
#   ('agile practices', 'not skill'),
#   ('amazon web', 'not skill'),
#   ('services-', 'not skill'),
#   ('big data', 'not skill'),
#   ('technology', 'skill'),
#   ('fundamentals', 'not skill'),
#   ('hadoop', 'skill'),
#   ('application', 'not skill'),
#   ('development', 'skill'),
#   ('framework', 'not skill')],
#  [('\\n', 'not skill'),
#   ('arpit', 'not skill'),
#   ('kapoor', 'not skill'),
#   ('8125', 'not skill'),
#   ('48thave', 'not skill'),
#   ('509', 'not skill'),
#   ('■_college', 'not skill'),
#   ('park md 20740', 'not skill'),
#   ('■', 'not skill'),
#   ('240.481.4996', 'not skill'),
#   ('■', 'not skill'),
#   ('arpit.kapoor', 'not skill'),
#   ('@_rhsmith.umd.edu', 'not skill'),
#   ('■', 'not skill'),
#   ('www.linkedin.com/in/arpit-kapoor', 'not skill'),
#   ('education robert h. smith', 'not skill'),
#   ('school business university maryland', 'not skill'),
#   ('december 2017', 'not skill'),
#   ('master science information systems', 'not skill'),
#   ('gre', 'not skill'),
#   ('322', 'not skill'),
#   ('coursework', 'not skill'),
#   ('data models decisions', 'not skill'),
#   ('dbms', 'skill'),
#   ('managing digital business markets', 'not skill'),
#   ('bigdata', 'not skill'),
#   ('data mining predictive analysis', 'not skill'),
#   ('strategic', 'not skill'),
#   ('business process analysis', 'not skill'),
#   ('data networks infrastructure', 'not skill'),
#   ('thapar', 'not skill'),
#   ('university', 'not skill'),
#   ('patiala', 'not skill'),
#   ('india bachelor', 'not skill'),
#   ('engineering major', 'not skill'),
#   ('electronics', 'not skill'),
#   ('instrumentation', 'not skill'),
#   ('control', 'not skill'),
#   ('june 2013', 'not skill'),
#   ('technical skills programming languages', 'not skill'),
#   ('c c++', 'not skill'),
#   ('perl shell', 'not skill'),
#   ('scripting', 'skill'),
#   ('sql python', 'not skill'),
#   ('tools', 'not skill'),
#   ('cygwin', 'skill'),
#   ('iperf', 'skill'),
#   ('tera', 'not skill'),
#   ('term', 'not skill'),
#   ('perl', 'skill'),
#   ('modules', 'not skill'),
#   ('wireshark', 'skill'),
#   ('jenkins', 'skill'),
#   ('fail2ban', 'skill'),
#   ('apache-tomcat', 'skill'),
#   ('git', 'skill'),
#   ('ansible', 'skill'),
#   ('microsoft office', 'skill'),
#   ('tableau excel', 'not skill'),
#   ('salesforce', 'skill'),
#   ('sql', 'skill'),
#   ('management studio', 'not skill'),
#   ('lucid', 'not skill'),
#   ('chart', 'not skill'),
#   ('operating systems', 'skill'),
#   ('windows linux', 'not skill'),
#   ('mac os x', 'skill'),
#   ('professional experience', 'not skill'),
#   ('lybrate', 'not skill'),
#   ('india pvt ltd', 'not skill'),
#   ('faridabad', 'not skill'),
#   ('india', 'not skill'),
#   ('2015_–', 'not skill'),
#   ('2016', 'not skill'),
#   ('devops engineer', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('managed', 'not skill'),
#   ('3-member', 'not skill'),
#   ('team', 'not skill'),
#   ('responsible', 'not skill'),
#   ('daily', 'not skill'),
#   ('build', 'not skill'),
#   ('releases', 'not skill'),
#   ('maintaining', 'not skill'),
#   ('website', 'not skill'),
#   ('support', 'not skill'),
#   ('3000', 'not skill'),
#   ('daily', 'not skill'),
#   ('transactions', 'not skill')],
#  [('jenkins', 'skill'),
#   ('aws', 'skill'),
#   ('apache-tomcat', 'skill'),
#   ('\uf0a7', 'not skill'),
#   ('planned', 'not skill'),
#   ('developed', 'not skill'),
#   ('automation', 'not skill'),
#   ('frameworks', 'not skill'),
#   ('analyzed', 'not skill'),
#   ('implemented new', 'not skill'),
#   ('tools', 'not skill'),
#   ('methods', 'not skill'),
#   ('scale', 'not skill'),
#   ('technology', 'skill')],
#  [('shell', 'skill'),
#   ('sql', 'skill'),
#   ('ansible', 'skill'),
#   ('\uf0a7', 'not skill'),
#   ('installed', 'not skill'),
#   ('implemented', 'not skill'),
#   ('security', 'skill'),
#   ('programs', 'not skill'),
#   ('8', 'not skill'),
#   ('servers', 'not skill'),
#   ('monitored', 'not skill'),
#   ('network', 'not skill'),
#   ('inefficiencies', 'not skill')],
#  [('\uf0a7_analyzed', 'not skill'),
#   ('user', 'not skill'),
#   ('feedback', 'not skill'),
#   ('reported', 'not skill'),
#   ('critical', 'not skill'),
#   ('software', 'skill'),
#   ('bugs', 'not skill'),
#   ('resulting', 'not skill'),
#   ('customer satisfaction', 'not skill'),
#   ('relationship management', 'not skill')],
#  [('\uf0a7', 'not skill'),
#   ('supervised', 'skill'),
#   ('configuration', 'not skill'),
#   ('tool', 'not skill'),
#   ('prevent', 'not skill'),
#   ('phishing', 'skill'),
#   ('attacks', 'not skill')],
#  [('helped', 'not skill'),
#   ('reduce', 'not skill'),
#   ('constant', 'not skill'),
#   ('monitoring', 'not skill'),
#   ('procedures', 'not skill'),
#   ('workload', 'not skill'),
#   ('bringing', 'not skill'),
#   ('server', 'not skill'),
#   ('overloads', 'not skill'),
#   ('50', 'not skill')],
#  [('fail2ban', 'skill'),
#   ('cavium', 'not skill'),
#   ('networks', 'skill'),
#   ('india pvt', 'not skill'),
#   ('ltd bangalore', 'not skill'),
#   ('india', 'not skill'),
#   ('2013_–', 'not skill'),
#   ('2015', 'not skill'),
#   ('system', 'not skill'),
#   ('validation', 'not skill'),
#   ('engineer', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('coordinated', 'not skill'),
#   ('testing', 'skill'),
#   ('across', 'not skill'),
#   ('4', 'not skill'),
#   ('offices', 'not skill'),
#   ('ensure', 'not skill'),
#   ('product', 'not skill'),
#   ('testing', 'skill'),
#   ('end end testing', 'not skill'),
#   ('ipsec', 'skill'),
#   ('testing', 'skill'),
#   ('3', 'not skill'),
#   ('products', 'not skill')],
#  [('lte', 'skill'),
#   ('small', 'not skill'),
#   ('cells', 'not skill'),
#   ('cellular base', 'not skill'),
#   ('stations', 'not skill'),
#   ('\uf0a7_collaborated', 'not skill'),
#   ('developers', 'not skill'),
#   ('clients', 'not skill'),
#   ('site', 'not skill'),
#   ('teams', 'not skill'),
#   ('creating', 'not skill'),
#   ('testing', 'skill'),
#   ('field', 'not skill'),
#   ('conditions', 'not skill'),
#   ('ensure', 'not skill'),
#   ('reliability', 'not skill'),
#   ('product', 'not skill')],
#  [('\uf0a7', 'not skill'),
#   ('created executed', 'not skill'),
#   ('test plans', 'skill'),
#   ('performed', 'not skill'),
#   ('rigorous', 'not skill'),
#   ('testing', 'skill'),
#   ('release', 'not skill'),
#   ('features', 'not skill'),
#   ('ensure', 'not skill'),
#   ('delivery', 'not skill'),
#   ('efficient', 'not skill'),
#   ('functional', 'not skill'),
#   ('product', 'not skill')],
#  [('\uf0a7_conducted', 'not skill'),
#   ('quality', 'not skill'),
#   ('functional testing', 'skill'),
#   ('reported', 'not skill'),
#   ('software', 'skill'),
#   ('bugs', 'not skill'),
#   ('sample', 'not skill'),
#   ('128', 'not skill'),
#   ('users', 'not skill'),
#   ('incorporated', 'not skill'),
#   ('network', 'not skill'),
#   ('feedback', 'not skill')],
#  [('tm500', 'not skill'),
#   ('bugzilla', 'skill'),
#   ('wireshark', 'skill'),
#   ('\uf0a7', 'not skill'),
#   ('developed', 'not skill'),
#   ('automation framework', 'not skill'),
#   ('end end testing', 'not skill')],
#  [('used', 'not skill'),
#   ('across', 'not skill'),
#   ('3', 'not skill'),
#   ('teams', 'not skill'),
#   ('decreasing manual', 'not skill'),
#   ('work', 'not skill'),
#   ('mistakes', 'not skill'),
#   ('75', 'not skill')],
#  [('perl shell', 'not skill'),
#   ('socket programming', 'skill'),
#   ('projects', 'not skill'),
#   ('university', 'not skill'),
#   ('rankings', 'not skill'),
#   ('database', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('gathered', 'not skill'),
#   ('extracted', 'not skill'),
#   ('processed', 'not skill'),
#   ('data', 'skill'),
#   ('regarding', 'not skill'),
#   ('three', 'not skill'),
#   ('courses', 'not skill'),
#   ('mba', 'not skill'),
#   ('msba', 'not skill'),
#   ('msis', 'not skill'),
#   ('across', 'not skill'),
#   ('universities', 'not skill'),
#   ('us', 'not skill'),
#   ('design', 'skill'),
#   ('aggregator', 'not skill')],
#  [('\uf0a7', 'not skill'),
#   ('performed', 'not skill'),
#   ('data transformation', 'not skill'),
#   ('upload', 'not skill'),
#   ('sql server', 'skill'),
#   ('using', 'not skill'),
#   ('sql server management studio', 'skill')],
#  [('\uf0a7', 'not skill'),
#   ('used', 'not skill'),
#   ('salesforce', 'skill'),
#   ('help', 'not skill'),
#   ('visualize', 'not skill'),
#   ('data', 'skill'),
#   ('using', 'not skill'),
#   ('dashboards', 'not skill'),
#   ('reports', 'not skill')],
#  [('telecom', 'not skill'),
#   ('services', 'not skill'),
#   ('analysis', 'not skill'),
#   ('\uf0a7', 'not skill'),
#   ('worked', 'not skill'),
#   ('team', 'not skill'),
#   ('5', 'not skill'),
#   ('analyze', 'not skill'),
#   ('provide', 'not skill'),
#   ('technology', 'skill'),
#   ('consulting', 'not skill'),
#   ('telecom', 'not skill'),
#   ('service provider', 'not skill'),
#   ('based', 'not skill'),
#   ('zambia', 'not skill')],
#  [('\\n', 'not skill'),
#   ('binod', 'not skill'),
#   ('kumar', 'not skill'),
#   ('singh', 'not skill'),
#   ('22650', 'not skill'),
#   ('shining', 'not skill'),
#   ('harness', 'not skill'),
#   ('street', 'not skill'),
#   ('clarksburg', 'not skill'),
#   ('md', 'not skill'),
#   ('20871', 'not skill'),
#   ('c', 'skill'),
#   ('262-309-3367', 'not skill'),
#   ('bks.iitr', 'not skill'),
#   ('@_gmail.com', 'not skill'),
#   ('professional summary', 'not skill'),
#   ('13', 'not skill'),
#   ('years', 'not skill'),
#   ('hands-on experience', 'not skill'),
#   ('industry', 'not skill'),
#   ('expertise', 'not skill'),
#   ('design/development', 'not skill'),
#   ('delivery', 'not skill'),
#   ('client', 'not skill'),
#   ('server', 'not skill'),
#   ('applications', 'not skill'),
#   ('using', 'not skill'),
#   ('java j2ee', 'not skill')],
#  [('keep', 'not skill'),
#   ('learning', 'not skill'),
#   ('applying', 'not skill'),
#   ('new', 'not skill'),
#   ('technology/feature', 'not skill'),
#   ('live', 'not skill'),
#   ('ongoing', 'not skill'),
#   ('projects', 'not skill')],
#  [('possess', 'not skill'),
#   ('blend', 'not skill'),
#   ('business', 'not skill'),
#   ('management', 'skill'),
#   ('technical skills', 'not skill'),
#   ('ability', 'not skill'),
#   ('translate', 'not skill'),
#   ('business needs', 'not skill'),
#   ('real world', 'not skill'),
#   ('solutions', 'not skill')],
#  ...]

# %%
def similar_prob(word):
    count = 0
    terms = get_related_terms(word,25)
    for w in terms:
        if w in skill_list:
            count+=1
    return count/25

# %%
def in_skill_cluster(word):
    if word in skill_list:
        return True
    return False

# %%
def get_related_terms(token,topn):
    arr =[]
    for word,similar in res2vec.wv.most_similar(positive = [token],topn=topn):
        #print(word,':',round(similar,3))
        arr.append(word)
    return arr

# %%
#extract featurres of skills 
def extract_features (sentence, i):
    features={}
    #first feature: evaluate if that word is in skill list
    features["({})in_skill_list".format(sentence[i])]= (sentence[i] in skill_list)
    
    if sentence[i] in res2vec.wv.vocab:
        features["probality_of_similar_words_skills"] = similar_prob(sentence[i])
        features["in_skill_cluster"] = in_skill_cluster(sentence[i])
    
    #if the word is in begining of the sentence, return <Start> for prev_word
    if i==0 and len(sentence)-1 != 0:
        features["prev_word_in_skill_list"]= '<Start>'
        features["next_word_in_skill_list"]= (sentence[i+1] in skill_list)
    
    #if the word is in begining of the sentence, return <End> for next_word
    elif i == len(sentence)-1 and  i != 0:
        features["prev_word_in_skill_list"]= (sentence[i-1] in skill_list)
        features["next_word_in_skill_list"]= '<End>'
    
    #if the sentence has only 1 word, return False for both prev_word and next_word
    elif i==0 and len(sentence)-1 == 0:
        features["prev_word_in_skill_list"]= False
        features["next_word_in_skill_list"]= False
    else:
        features["prev_word_in_skill_list"]= (sentence[i-1] in skill_list)
        features["next_word_in_skill_list"]= (sentence[i+1] in skill_list)
    return features

# %%
# %%time
featuresets=[]
for labeled_sent in labeled_words:
    unlabeled_sent = [word[0] for word in labeled_sent]
    for i, (w, label) in enumerate(labeled_sent):
        featuresets.append((extract_features(unlabeled_sent, i), label))
# Out:
# CPU times: user 5min 20s, sys: 604 ms, total: 5min 20s
# Wall time: 8min 53s

# %%
#Save the features in a file
featuresets_file = 'features_file.txt'
file = open(featuresets_file, 'w', encoding='utf_8')
file.write('\n'.join('%s %s' % item for item in featuresets ))
# Out:
# 42642857

# %%
size = int(len(featuresets)*0.1)
train_set = featuresets[size:]
test_set = featuresets[:size]

# %%
train_set
classifier = nltk.NaiveBayesClassifier.train(train_set)

# %%
nltk.classify.accuracy(classifier, test_set)
# Out:
# 0.9984589418067072

# %%
classifier.show_most_informative_features(15)
# Out:
# Most Informative Features
# probality_of_similar_words_skills = 0.52            skill : not sk =     75.3 : 1.0
# probality_of_similar_words_skills = 0.56            skill : not sk =     44.2 : 1.0
# probality_of_similar_words_skills = 0.6             skill : not sk =     17.5 : 1.0
# probality_of_similar_words_skills = 0.48            skill : not sk =     17.1 : 1.0
# probality_of_similar_words_skills = 0.28            skill : not sk =      8.2 : 1.0
# probality_of_similar_words_skills = 0.24            skill : not sk =      8.2 : 1.0
# probality_of_similar_words_skills = 0.44            skill : not sk =      8.0 : 1.0
# probality_of_similar_words_skills = 0.36            skill : not sk =      7.5 : 1.0
# probality_of_similar_words_skills = 0.4             skill : not sk =      6.7 : 1.0
# probality_of_similar_words_skills = 0.2             skill : not sk =      4.7 : 1.0
# probality_of_similar_words_skills = 0.64            skill : not sk =      4.0 : 1.0
# probality_of_similar_words_skills = 0.32            skill : not sk =      4.0 : 1.0
#  prev_word_in_skill_list = '<Start>'      not sk : skill  =      2.8 : 1.0
# probality_of_similar_words_skills = 0.04           not sk : skill  =      2.6 : 1.0
# probality_of_similar_words_skills = None           not sk : skill  =      2.2 : 1.0

# %% [markdown]
# # =========Testing=========

# %%
test_file =['sampleMechanical Engineering Resume.txt', 'desktop support engineer resume.txt','Henrydao -Resume.txt',
            'Electrical Engineering Student Resume.txt','Technical Consultant Resume.txt','Technical Manager Resume.txt',
           'Technical Support Resume.txt', 'Technical Writer Resume.txt', 'Yiyang (Eric) Zhou Resume 2017 Spring.txt']

def extract_skills(normalized_test_res, resume_number, filename):
    skills =[]
    for sent in normalized_test_res:
        for (i,_) in enumerate(sent):
            if classifier.classify(extract_features(sent, i))=='skill':
                skills.append(sent[i])
                extracted_skills = set(skills)
    print('\nResume {}:{} ({} skills)\n'.format(resume_number+1,filename, len(extracted_skills)), extracted_skills)
    
for i, filename in enumerate(test_file):
    test_resume_path= os.path.join('Test Resumes', filename)

    test_resume = open(test_resume_path, 'r').read()
    unigram_test_res = resume_processing(test_resume)
    bigram_test_res = create_bigram(unigram_test_res)
    trigram_test_res = create_trigram(bigram_test_res)
    normalized_test_res = normalize_words(trigram_test_res)
    extract_skills(normalized_test_res, i, filename)
# Out:
# /home/jared/Parsing/parseVirt/lib/python3.5/site-packages/gensim/models/phrases.py:274: UserWarning: For a faster implementation, use the gensim.models.phrases.Phraser class
#   warnings.warn("For a faster implementation, use the gensim.models.phrases.Phraser class")
# Resume 1:sampleMechanical Engineering Resume.txt (16 skills)
#  {'programming', 'ms excel', 'fortran', 'technology', 'graphics', 'unix', 'windows', 'design', 'testing', 'c++', 'engineering', 'autocad', 'spring', 'ms word', 'software', 'matlab'}
#
# Resume 2:desktop support engineer resume.txt (18 skills)
#  {'technical', 'software', 'email', 'verbal', 'technical support', 'escalations', 'data', 'ethernet', 'routing', 'voip', 'innovative', 'networking', 'installation', 'reporting', 'troubleshooting', 'tcp/ip', 'excel', 'networks'}
#
# Resume 3:Henrydao -Resume.txt (35 skills)
#  {'sdlc', 'scrum', 'mac os x', 'design', 'tableau', 'lucidchart', 'data analysis', 'marketing', 'social media', 'precisiontree', 'rational rose', 'entrepreneurship', 'arena', 'business analyst', 'sql', 'uml', 'software', 'advanced excel', 'minitab', 'training', 'palisade', 'technology', 'html css', 'data science', 'project', 'programming', 'stattool', 'data', 'solvertable', 'ms visio', 'r python', 'reporting', 'healthcare', 'c', 'operating systems'}
#
# Resume 4:Electrical Engineering Student Resume.txt (32 skills)
#  {'supervised', 'fortran', 'wimax', 'design', 'development', 'communication', 'cdma', 'global', 'implementation', 'umts', 'gsm', 'lan', 'optimization', 'software', 'technology', 'project', 'terminal', 'processing', 'mathematics', 'wcdma', 'mobile', 'networks', 'programming', 'technical', 'simulink', 'telecommunication', 'data', 'engineering', 'tracking', 'statistics', 'regression', 'matlab'}
#
# Resume 5:Technical Consultant Resume.txt (29 skills)
#  {'crm', 'communication', 'development', 'design', 'lotus notes', 'implementation', 'email', 'uat', 'management', 'test scenarios', 'testing', 'business analyst', 'technical specifications', 'abap', 'managerial', 'sms', 'training', 'project', 'planning', 'installation', 'sap', 'project management', 'mobile', 'programming', 'technical', 'sap abap', 'data', 'engineering', 'reporting'}
#
# Resume 6:Technical Manager Resume.txt (42 skills)
#  {'sdlc', 'growth', 'communication', 'development', 'design', 'troubleshooting', 'implementation', 'operations', 'help desk', 'email', 'management', 'lan', 'business analyst', 'metrics', 'optimization', 'networking', 'software', 'firewalls', 'organizational', 'project planning', 'microsoft', 'training', 'technology', 'network security', 'organization', 'project', 'planning', 'routing', 'solver', 'installation', 'sap', 'project management', 'mobile', 'strategy', 'technical', 'negotiation', 'wan', 'preparation', 'data', 'presentations', 'reporting', 'security'}
#
# Resume 7:Technical Support Resume.txt (31 skills)
#  {'technical support', 'development', 'workflows', 'scripting', 'social media', 'operations', 'help desk', 'linux', 'oracle', 'management', 'quality assurance', 'organizational', 'training', 'technology', 'pc', 'planning', 'spring', 'project management', 'programming', 'strategy', 'technical', 'trends', 'leadership', 'data', 'web', 'presentations', 'documentation', 'mysql', 'databases', 'statistics', 'task'}
#
# Resume 8:Technical Writer Resume.txt (30 skills)
#  {'flash', 'java', 'development', 'perl', '.net', 'documenting', 'xml', 'oracle', 'testing', 'photoshop', 'weblogic', 'software', 'illustrator', 'training', 'http', 'google', 'web services', 'framemaker', 'project', 'robohelp', 'installation', 'informatica', 'mac', 'programming', 'technical', 'unix', 'web', 'documentation', 'engineering', 'html'}
#
# Resume 9:Yiyang (Eric) Zhou Resume 2017 Spring.txt (16 skills)
#  {'strategy', 'training', 'sdlc', 'spreadsheet', 'r', 'management', 'data', 'organization', 'project', 'data mining', 'tableau', 'python', 'sql', 'twitter', 'marketing', 'html'}

# %% [markdown]
# # 3. Extract Companies

# %%
import codecs
import os

filename = 'BrandonThomasResume.txt'
#Open file
def open_file(filename):
    resume = open(filename, 'r', errors='ignore').read()
    return resume

# %%
resume = open_file(filename)
print(resume)
# Out:
# ﻿Brandon Thomas
# 5514 First St NW Apt# 203 Washington D.C., 20011
# • Mobile: 202-520-1835 • Email: brandonthomas280@gmail.com
#
#
# Objective: My goal is to become employed with a company in the technology industry where I can utilize my IT & Computer Science skills and gain to continue to learn new skills while enhancing the company’s productivity and reputation.
#
# WORK EXPERIENCE:
# Encentric Inc., Fairfax, VA								   	  (April 2016 – June 2016)
# Help Desk Technician
# • Disconnect work stations and bag them properly for moving.
# • Reconnect workstations at new work-space according to end-user specifications.
#
# Levy Restaurant at Nationals Park, Washington, D.C  						      (April 2015 – Present)
# Server
# • Attend to customers during events, interact and answer questions.
# • Set up, serve, and break down all event food tables.
#
# U.S. Department of the Treasury- Internal Revenue Service (IRS), Washington, D.C.			 (June 2012- August 2012)
# Student Intern-Management and Staff Assistant
# • Improved the IRS website by providing recommendations on outdated formats and trends.
# • Recognized by team for my dedication for the duration of my internship.
# • Keep official records for meetings.
# • Sorted, organized, and disposed of documents.
#
# Paramount Baptist Church, Washington, D.C.						            (Summer 2008, 2009, 2010)
# Summer Camp Counselor
# • Assisted camp staff in daily activities with the children.
# • Participated in all camp activities, (i.e., campfires, song practice, talent show, hikes, free time activities, etc.).
# • Observed the children and used positive reinforcement to help modify the children’s behavior.
# • Encouraged and motivated the children to be well-rounded individuals with good manners and wholesome values.
# • Promoted a positive healthy environment for the campers.
#
# EDUCATION:
# University of the District of Columbia, Washington, DC  GPA: ~ 3.1
# School of Engineering and Applied Science				         			 	     (August-2014- Present)
#
# StreetWise Partners, Inc., Washington, D.C.  - Trainee		                               (April 2016 – June 2016)
# Developed my professional skills through career training program with business professionals
#
# South Carolina State University, Orangeburg, SC
# College of Science, Mathematics, Engineering & Technology	     					(August-2009- May 2014)
#
# St. John’s College High School, Washington, DC							(August 2005- June 2009)
#
# SKILLS:
# • Computer Skills
# o Proficient in the use of Windows Vista & Windows XP.
# o Proficient in the use of Microsoft Word, Excel, and PowerPoint.
# o Learns new software applications quickly.
# o Proficient in the use of HTML & CSS
#
# VOLUNTEER EXPERIENCE:
# St. Augustine Academy, Washington, DC						  		 (August 2005-June 2009)
# Teacher’s Aide
# • Provided tutoring in mathematics and supervised playtime to children in grades 1-7.

# %%
#Import different put of experience headers
data = pd.read_excel("Work Experience.xlsx", header=0)
experience_list = list(data['Example'])
experience_list
# Out:
# ['ADDITIONAL EXPERIENCE',
#  'Additional Experience',
#  'ARMY EXPERIENCE',
#  'Army Experience',
#  'CAREER RELATED EXPERIENCE',
#  'Career Related Experience',
#  'EMPLOYMENT HISTORY',
#  'Employment History',
#  'EXPERIENCE',
#  'Experience',
#  'FREELANCE',
#  'Freelance',
#  'FREELANCE EXPERIENCE',
#  'Freelance Experience',
#  'MILITARY BACKGROUND',
#  'Military Background',
#  'MILITARY EXPERIENCE',
#  'Military Experience',
#  'PROFESSIONAL BACKGROUND',
#  'Professional Background',
#  'PROFESSIONAL EXPERIENCE',
#  'Professional Experience',
#  'Project',
#  'PROJECT',
#  'Projects',
#  'PROJECTS',
#  'Related Experience',
#  'RELATED EXPERIENCE',
#  'WORK EXPERIENCE',
#  'Work Experience',
#  'Work History',
#  'WORK HISTORY',
#  'Professional History',
#  'PROFESSIONAL HISTORY']

# %%
from fuzzywuzzy.process import dedupe

#Find the experience header
def find_exp_header (resume):
    exp_header_list=[]
    for word in experience_list:
        if resume.find(word) != -1:
            exp_header_list.append(word)
    
    #remove duplicates of experience header
    exp_header = list(dedupe(exp_header_list))
    return exp_header

# %%
exp_header = find_exp_header(resume)
exp_header
# Out:
# ['WORK EXPERIENCE']

# %%
exp_header = (exp_header[0], resume.find(exp_header[0]))
exp_header
# Out:
# ('WORK EXPERIENCE', 362)

# %%
import re
import itertools

#List of all sections in a typical resume
section_list =['EDUCATION', 'Education', 'Skills', 'SKILLS', 'VOLUNTEER EXPERIENCE', 'Volunteer Experience',
              'Technical Skills', 'TECHNICAL SKILS', 'SUMMARY', 'summary', 'Professional Summary', 'PROFESSIONAL SUMMARY',
              'DEMONSTRATED SKILLS', 'Demonstrated Skills', 'Additional Information', 'ADDITIONAL INFORMATION', 
               'Leadership Experience', 'LEADERSHIP EXPERIENCE', 'REFERENCES', 'References', 
               'Certificates & Trainings', 'CERTIFICATE & TRAININGS', 'TRAINING', 'Training', 'Certificate', 'CERTIFICATE', 
               'RELEVANT COURSES', 'LANGUAGES', 'Relevant Courses', 'Languages', 'LEADERSHIP AND VOLUNTEER EXPERIENCE',
               'Leadership and Volunteer Experience', 'LEADERSHIP & VOLUNTEER EXPERIENCE', 'Leadership & Volunteer Experience',
               'EDUCATION AND TRAINING', 'Education and Training', 'Key Projects', 'KEY PROJECTS', 'RELEVANT ACADEMIC PROJECTS', 
               'Relevant Academic Projects', 'ACADEMIC PROJECTS', 'Academic Projects', 'EXTRACURRICULAR ACTIVITIES', 
               'Extracurricular Activities'
              ]

# %%
#Find next section header
def find_next_section (resume):
    #Find all capitalized words
    next_section_upper = re.findall(r'([A-Z]{3,}( [A-Z]+)?( [A-Z]+)?( [A-Z]+)?)', 
                                   resume[(exp_header[1] + len(exp_header[0])+ 1):])
    next_section_upper = list((itertools.chain.from_iterable(next_section_upper)))
    
    #Find all words with the first letter capitalized
    next_section_lower = re.findall(r'([A-Z]{1}\w+( [A-Z]{1}\w+)?( [A-Z]{1}\w+)?( [A-Z]{1}\w+)?)',
                                    resume[(exp_header[1] + len(exp_header[0])+ 1):])
    next_section_lower = list((itertools.chain.from_iterable(next_section_lower)))
    
    #Combine into a list
    next_section_list = next_section_upper + next_section_lower
    
    #if one of the items matches items in section list, that item is the next section header
    next_section=()
    for item in next_section_list:
        if item in section_list and (resume[resume.find(item)+len(item)]=='\n' or resume[resume.find(item)-1]=='\n'):
            next_section = (item, resume.find(item))
            break
    return next_section

# %%
next_section = find_next_section(resume)
next_section
# Out:
# ('EDUCATION', 1808)

# %%
def get_workexp_section(resume):
    if next_section:
        workexp_section = str(resume[(exp_header[1]+ len(exp_header[0])+ 1):next_section[1]])
    else:
        workexp_section = str(resume[(exp_header[1]+ len(exp_header[0])+ 1):])
    return workexp_section

# %%
workexp_section = get_workexp_section(resume)
workexp_section = workexp_section.split('\n')
workexp_section
# Out:
# ['',
#  'Encentric Inc., Fairfax, VA\t\t\t\t\t\t\t\t   \t  (April 2016 – June 2016)',
#  'Help Desk Technician',
#  '• Disconnect work stations and bag them properly for moving. ',
#  '• Reconnect workstations at new work-space according to end-user specifications.',
#  '',
#  'Levy Restaurant at Nationals Park, Washington, D.C  \t\t\t\t\t\t      (April 2015 – Present)',
#  'Server\t\t\t\t\t\t\t\t\t\t\t       ',
#  '• Attend to customers during events, interact and answer questions.',
#  '• Set up, serve, and break down all event food tables.',
#  '',
#  'U.S. Department of the Treasury- Internal Revenue Service (IRS), Washington, D.C.\t\t\t (June 2012- August 2012)',
#  'Student Intern-Management and Staff Assistant',
#  '• Improved the IRS website by providing recommendations on outdated formats and trends.',
#  '• Recognized by team for my dedication for the duration of my internship.',
#  '• Keep official records for meetings.',
#  '• Sorted, organized, and disposed of documents.',
#  '',
#  'Paramount Baptist Church, Washington, D.C.\t\t\t\t\t\t            (Summer 2008, 2009, 2010)',
#  'Summer Camp Counselor',
#  '• Assisted camp staff in daily activities with the children.',
#  '• Participated in all camp activities, (i.e., campfires, song practice, talent show, hikes, free time activities, etc.).',
#  '• Observed the children and used positive reinforcement to help modify the children’s behavior.',
#  '• Encouraged and motivated the children to be well-rounded individuals with good manners and wholesome values.',
#  '• Promoted a positive healthy environment for the campers.',
#  '',
#  '']

# %%
#Remove the detail and get the experience information
def get_exp_info(work_exp):
    company_info=[]
    temp_str=''
    for i, sent in enumerate(work_exp):
        if sent != '':
            #Everything before the bullet will be put into one sentence, for one company
            if not sent.startswith(('•','', u'\uf095', '§', '§')): 
                temp_str += sent + ' '
            else:
                if not work_exp[i-1].startswith(('•','', u'\uf095', '§', '§')):
                    company_info.append(temp_str)
                    temp_str=''
    return company_info

# %%
company_info = get_exp_info(workexp_section)
for i, company in enumerate(company_info):
    company = company.replace('\t', '')
    print('\nCompany {}:'.format(i+1), company)
# Out:
# Company 1: Encentric Inc., Fairfax, VA     (April 2016 – June 2016) Help Desk Technician
#
# Company 2: Levy Restaurant at Nationals Park, Washington, D.C        (April 2015 – Present) Server
#
# Company 3: U.S. Department of the Treasury- Internal Revenue Service (IRS), Washington, D.C. (June 2012- August 2012) Student Intern-Management and Staff Assistant
#
# Company 4: Paramount Baptist Church, Washington, D.C.            (Summer 2008, 2009, 2010) Summer Camp Counselor

# %%
import spacy
from nltk.corpus import stopwords
nlp = spacy.load('en')

def extract_exp_info(company_info, filename):
    count = 0
    print(filename)
    for i, sent in enumerate(company_info):
        sent = sent.replace('\t', '')
        parsed_sent = nlp(sent)
        print('\nCompany {}'.format(i+1))
        
        company=''
        location=''
        time=''
        role=''
        for i ,token in enumerate(parsed_sent):
            if token.ent_type_ =='ORG':
                company += ' ' + str(token)
            elif token.ent_type_ =='GPE':
                location += ' ' + str(token)
            elif token.ent_type_ =='DATE' or token.ent_type_ =='TIME':
                time += ' ' + str(token)
            elif token.ent_type_ =='':
                if str(token).isalpha() and str(token) not in stopwords.words('english'):
                    role += ' ' + str(token)
        
        print('Company: {}'.format(company))
        print('Location: {}'.format(location))
        print('Time: {}'.format(time))
        print('Role: {}'.format(role))

# %%
extract_exp_info(company_info, filename)
# Out:
# BrandonThomasResume.txt
#
# Company 1
# Company:  Encentric Inc. VA
# Location:  Fairfax
# Time:  April 2016 June 2016
# Role:  Help Desk Technician
#
# Company 2
# Company:  Levy Restaurant
# Location:  Washington D.C
# Time:  April 2015
# Role:  Nationals Present Server
#
# Company 3
# Company:  U.S. Department Internal Revenue Service IRS
# Location:  Washington D.C.
# Time:  June 2012- August 2012
# Role:  Student Intern Management Staff Assistant
#
# Company 4
# Company:  Paramount Baptist Church Summer Camp
# Location:  Washington D.C.
# Time:  Summer 2008 , 2009 , 2010
# Role:  Counselor

# %% [markdown]
# # John Park

# %% [markdown]
# ## Labeling all the clusters and training the Naive Bayes model

# %%
import numpy as np
from sklearn.naive_bayes import GaussianNB
all_classes = [0,1,2,3]
clf = GaussianNB()

ctemp = np.array([res2vec.wv['issue']])
#cluster 0 - skills
for key,item in word_centroid_map.items():
    if( item == 0 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 1 - skills
ctemp = np.array([res2vec.wv['rule']])
for key,item in word_centroid_map.items():
    if( item == 1 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 2 - skills
ctemp = np.array([res2vec.wv['excel']])
for key,item in word_centroid_map.items():
    if( item == 2 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 3 - Experience
ctemp = np.array([res2vec.wv['lead']])
for key,item in word_centroid_map.items():
    if( item == 3 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 4 - Misc
ctemp = np.array([res2vec.wv['peoplesoft']])
for key,item in word_centroid_map.items():
    if( item == 4 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),2)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 5 - Experience
ctemp = np.array([res2vec.wv['skill']])
for key,item in word_centroid_map.items():
    if( item == 5 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 6 - Skills
ctemp = np.array([res2vec.wv['server']])
for key,item in word_centroid_map.items():
    if( item == 6 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 7 - Experience
ctemp = np.array([res2vec.wv['the']])
for key,item in word_centroid_map.items():
    if( item == 7 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 8 - Experience
ctemp = np.array([res2vec.wv['and']])
for key,item in word_centroid_map.items():
    if( item == 8 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 9 - Experience
ctemp = np.array([res2vec.wv['bi']])
for key,item in word_centroid_map.items():
    if( item == 9 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 10 - Experience
ctemp = np.array([res2vec.wv['employee']])
for key,item in word_centroid_map.items():
    if( item == 10 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 11 - Experience
ctemp = np.array([res2vec.wv['time']])
for key,item in word_centroid_map.items():
    if( item == 11 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 12 - Experience
ctemp = np.array([res2vec.wv['professional']])
for key,item in word_centroid_map.items():
    if( item == 12 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 13 - Experience
ctemp = np.array([res2vec.wv['at']])
for key,item in word_centroid_map.items():
    if( item == 13 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 14 - Experience
ctemp = np.array([res2vec.wv['information']])
for key,item in word_centroid_map.items():
    if( item == 14 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 15 - Education
ctemp = np.array([res2vec.wv['university']])
for key,item in word_centroid_map.items():
    if( item == 15 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),3)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 16 - Misc
ctemp = np.array([res2vec.wv['present']])
for key,item in word_centroid_map.items():
    if( item == 16 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),2)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 17 - Skills
ctemp = np.array([res2vec.wv['java']])
for key,item in word_centroid_map.items():
    if( item == 17 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 18 - Skills
ctemp = np.array([res2vec.wv['java']])
for key,item in word_centroid_map.items():
    if( item == 18 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 19 - Experience
ctemp = np.array([res2vec.wv['employee']])
for key,item in word_centroid_map.items():
    if( item == 19 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 20 - Experience
ctemp = np.array([res2vec.wv['employee']])
for key,item in word_centroid_map.items():
    if( item == 20 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 21 - Skills
ctemp = np.array([res2vec.wv['java']])
for key,item in word_centroid_map.items():
    if( item == 21 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 22 - Skills
ctemp = np.array([res2vec.wv['java']])
for key,item in word_centroid_map.items():
    if( item == 22 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 23 - Experience
ctemp = np.array([res2vec.wv['employee']])
for key,item in word_centroid_map.items():
    if( item == 23 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),1)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 24 - Misc
ctemp = np.array([res2vec.wv['+']])
for key,item in word_centroid_map.items():
    if( item == 24 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),2)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 25 - Skills
ctemp = np.array([res2vec.wv['java']])
for key,item in word_centroid_map.items():
    if( item == 25 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),0)
clf.partial_fit(ctemp,samp,classes=all_classes)

#Cluster 26 - Education
ctemp = np.array([res2vec.wv['human']])
for key,item in word_centroid_map.items():
    if( item == 26 ):
        ctemp=np.vstack([ctemp,res2vec.wv[key]])
samp = np.full(len(ctemp),3)
clf.partial_fit(ctemp,samp,classes=all_classes)
# Out:
# GaussianNB(priors=None)

# %% [markdown]
# ## Determine category of input word

# %%
testWord = 'university'
totest = np.array(res2vec.wv[testWord])
totest = totest.reshape(1,-1)
prediction=clf.predict(totest)
print(prediction)
if prediction[0] == 0:
    print(testWord + " is in SKILLS")
if prediction[0] == 1:
    print(testWord + " is in EXPERIENCE")
if prediction[0] == 2:
    print(testWord + " is in MISC")
if prediction[0] == 3:
    print(testWord + " is in EDUCATION")
# Out:
# [1]
# university is in EXPERIENCE

# %% [markdown]
# # Organization Extraction

# %%
import sys
import codecs
from docx import *
from io import StringIO

location = os.path.join('Resumes','AmandaYuResume.docx')
document = Document(location)
s = ""
for paragraph in document.paragraphs:
    s += str(paragraph.text.encode(errors='ignore'))

# %% [markdown]
# # Ashish Aggarwal

# %%
# import all headers
import re
import os

# %%
# function to extract all URLs
# implemented using regex
def extract_URLs(parsedResume):
    parsedResume = parsedResume.replace('\n', ' ')
    regex = regex = re.compile('(?:(?:https?|ftp|file)://|www\.|ftp\.)[-A-Z0-9+&@#/%=~_|$?!:,.]*[A-Z0-9+&@#/%=~_|$]', re.IGNORECASE)
    result = re.findall(regex, parsedResume)
    #if result:
        #result = result.group()
    return result

# %%
# function to extract LinkedIN Profile
# implemented using regex
def extract_linkedin(parsedResume):
    parsedResume = parsedResume.replace('\n', ' ')
    regex = re.compile(r"https://www.linkedin.com/in/([a-zA-Z]|[0-9]|[-])+/?")
    result = re.search(regex, parsedResume)
    if result:
        result = result.group()
    return result

# %%
# TESTING
# path where all resumes are located
test_resume_path = 'Test Resumes'
counter = 0

print("URLs in Test Resumes")
for filename in os.listdir(test_resume_path):
    # print(filename)
    if '.txt' in filename:
        counter = counter + 1
        resume_path= os.path.join('Test Resumes', filename)
        test_resume = open(resume_path, 'r').read()
    
        print("Resume ", (counter), ":")
        print("All URLs => ", extract_URLs(test_resume))
        print("LinkedIn Profiles => ", extract_linkedin(test_resume))
# Out:
# URLs in Test Resumes
# Resume  1 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  2 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  3 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  4 :
# All URLs =>  ['https://www.linkedin.com/in/jared-ross-15439b83/', 'https://github.com/JaredJRoss/']
# LinkedIn Profiles =>  https://www.linkedin.com/in/jared-ross-15439b83/
# Resume  5 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  6 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  7 :
# All URLs =>  ['http://apireferencedocs.codebase.ebay.com', 'http://www.phoons.com/john/classes/coursesTaught.html']
# LinkedIn Profiles =>  None
# Resume  8 :
# All URLs =>  []
# LinkedIn Profiles =>  None
# Resume  9 :
# All URLs =>  []
# LinkedIn Profiles =>  None

# %% [markdown]
# # Vaibhav Bhilare

# %%
import csv
import re

#Email Address
def check_email(string_to_search):
    regular_expression = re.compile(r"[A-Z0-9._%+-]+@[A-Z0-9.-]+\.[A-Z]{2,3}", re.IGNORECASE)
    result = re.search(regular_expression, string_to_search)
    if result:
        result = result.group()
    return result
    #except:
     #   result=0
      #  return result

#LinkedIn Address
def check_linkedin(string_to_search):
    regular_expression1 = re.compile(r"https://"
                                    r"[A-Z]{2,3}"
                                    r".linkedin.com/in/"
                                    r"[-_a-z 0-9]{5,30}", re.IGNORECASE)
    result = re.search(regular_expression1, string_to_search)
    try:
        result = result.group()
        return result
    except:
        regular_expression1 = re.compile(r"[A-Z]{2,3}"
                                        r".linkedin.com/in/"
                                        r"[-_a-z 0-9]{5,30}", re.IGNORECASE)
        result = re.search(regular_expression1, string_to_search)
        try:
            result=result.group()
            return result
        except:
            regular_expression1 = re.compile(r"[A-Z]{2,3}"
                                        r".linkedin.com/"
                                        r"[-_a-z 0-9]{5,30}", re.IGNORECASE)
            result = re.search(regular_expression1, string_to_search)
            try:
                result=result.group()
                return result
            except:
                return None

#GitHub Address
def check_GitHub(string_to_search):
    regular_expression = re.compile(r"https://github.com/"
                                    r"[-_A-Z0-9]{5,30}", re.IGNORECASE)
    result = re.search(regular_expression, string_to_search)
    try:
        result = result.group()
        return result
    except:
        return None

#Contact Number
def check_phone_number(string_to_search):
    try:
        regular_expression = re.compile(r"\(?"  # open parenthesis
                                        r"(\d{3})?"  # area code
                                        r"\)?"  # close parenthesis
                                        r"[\s\.-]{0,2}?"  # area code, phone separator
                                        r"(\d{3})"  # 3 digit exchange
                                        r"[\s\.-]{0,2}"  # separator bbetween 3 digit exchange, 4 digit local
                                        r"(\d{4})",  # 4 digit local
                                        re.IGNORECASE)
        result = re.search(regular_expression, string_to_search)
        if result:
            result = result.groups()
            result = "-".join(result)
        return result
    except:
        return None

def main():
#    with open('Resume_Test.txt', 'r',encoding="utf8") as myfile:
    with open('BrandonThomasResume.txt', 'r') as myfile:
        data=myfile.read().replace('\n',' **** ')
    string="https://www.linkedin.com/in/vaibhav-bhilare"
    string_G="https://github.com/paragsal"
    #print(string)
    result=check_email(data)
    result_L=check_linkedin(data)
    result_P=check_phone_number(data)
    result_G=check_GitHub(data)
    print("Email Address:",result)
    print("Contact Number:",result_P)
    print("Linkedin Profile:",result_L)
    print("GitHub Profile:",result_G)
    #print(data)
main()
# Out:
# Email Address: brandonthomas280@gmail.com
# Contact Number: 202-520-1835
# Linkedin Profile: https://www.linkedin.com/in/jared-ross-15439b83
# GitHub Profile: https://github.com/JaredJRoss
